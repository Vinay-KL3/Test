# %%
import pandas as pd
from tqdm import tqdm

# %%
path = "/Users/vinay_kl/Downloads/Shriram Entity Check - organised.csv"

# %%
df = pd.read_csv(path)
df.head(2)
# Out:
#                                           templateId  \
# 0  utter_account_closed_predue_static_U_F_Shriram...
# 1  utter_account_closed_predue_static_U_M_Shriram...
#
#                                                Hindi Hindi_replaceableFields  \
# 0  ओके, ये रिपोर्ट करने के लिए थैंक्यू। हमारी टीम...                      []
# 1  ओके। ये रिपोर्ट करने के लिए थैंक्यू। हमारी टीम...                      []
#
#                                                Tamil  \
# 0  utter_account_closed_predue_static_U_F_Shriram...
# 1  utter_account_closed_predue_static_U_M_Shriram...
#
#                                              Tamil.1 Tamil_replaceableFields  \
# 0  கண்டிப்பா, எங்களுக்கு அப்டேட் பண்ணதுக்கு நன்றி...                      []
# 1  கண்டிப்பா, எங்களுக்கு அப்டேட் பண்ணதுக்கு நன்றி...                      []
#
#                                               Telugu  \
# 0  utter_account_closed_predue_static_U_F_Shriram...
# 1  utter_account_closed_predue_static_U_M_Shriram...
#
# ...

# %%
Hindi_Entities = df["Hindi_replaceableFields"]

final_hindi_1 = []


for i in tqdm(range(len(df))):
    #text = sorted(Hindi_Entities[i])
    text = Hindi_Entities[i]
    #text2 = sorted(list(text))
    print((text))
    #final_hindi_1 = final_hindi_1.append(text)
#print(final_hindi_1)
# Out:
# 100%|██████████████████████████████████████| 438/438 [00:00<00:00, 32217.48it/s]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ["client_name"]
# ["client_name"]
# ["client_name"]
# ["client_name"]
# ["monthly_emi"]
# ["monthly_emi"]
# ["monthly_emi_date"]
# ["monthly_emi_date"]
# ["intrest_rate"]
# ["intrest_rate"]
# ["late_fee_percentage"]
# ["late_fee_percentage"]
# ["loan_end_date"]
# ["loan_end_date"]
# ["loan_end_date"]
# ["loan_end_date"]
# ["loan_remaining_amount"]
# ["loan_remaining_amount"]
# ["loan_remaining_amount"]
# ["loan_remaining_amount"]
# ["loan_start_date"]
# ["loan_start_date"]
# ["loan_start_date"]
# ["loan_start_date"]
# []
# []
# ["principal_amount"]
# ["principal_amount"]
# ["loan_end_date","no_of_EM।s_pending"]
# ["loan_end_date","no_of_EM।s_pending"]
# ["today_date"]
# ["today_date"]
# []
# []
# []
# []
# ["user_requested_payment_option"]
# ["user_requested_payment_option"]
# ["user_requested_payment_option"]
# ...
