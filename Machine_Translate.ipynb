# %%
# !pip install fairseq
# Out:
# ...
#      |████████████████████████████████| 9.6 MB 6.0 MB/s eta 0:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#     Preparing wheel metadata ... done
# ...
#      |████████████████████████████████| 135.3 MB 6.0 MB/s eta 0:00:011    |██████████████████▊             | 79.1 MB 3.9 MB/s eta 0:00:15
# ...
#      |████████████████████████████████| 3.3 MB 6.2 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 123 kB 5.9 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 112 kB 9.9 MB/s eta 0:00:01
# ...
#   ERROR: Command errored out with exit status 1:
#    command: /Users/vinay_kl/opt/anaconda3/bin/python /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages/pip/_vendor/pep517/in_process/_in_process.py build_wheel /var/folders/tr/mwr4dkgn0tb5jh53c7lyvfmw0000gn/T/tmpujpd3sqy
# ...

# %%
# clone the repo for running evaluation
# !git clone https://github.com/AI4Bharat/indicTrans.git
# %cd indicTrans
# clone requirements repositories
# !git clone https://github.com/anoopkunchukuttan/indic_nlp_library.git
# !git clone https://github.com/anoopkunchukuttan/indic_nlp_resources.git
# !git clone https://github.com/rsennrich/subword-nmt.git
# %cd ..
# Out:
# xcrun: error: invalid active developer path (/Library/Developer/CommandLineTools), missing xcrun at: /Library/Developer/CommandLineTools/usr/bin/xcrun
# [Errno 2] No such file or directory: 'indicTrans'
# /Users/vinay_kl
# xcrun: error: invalid active developer path (/Library/Developer/CommandLineTools), missing xcrun at: /Library/Developer/CommandLineTools/usr/bin/xcrun
# xcrun: error: invalid active developer path (/Library/Developer/CommandLineTools), missing xcrun at: /Library/Developer/CommandLineTools/usr/bin/xcrun
# xcrun: error: invalid active developer path (/Library/Developer/CommandLineTools), missing xcrun at: /Library/Developer/CommandLineTools/usr/bin/xcrun
# /Users

# %%
# Install the necessary libraries
# !pip install sacremoses pandas mock sacrebleu tensorboardX pyarrow indic-nlp-library
! pip install mosestokenizer subword-nmt
# Install fairseq from source
# !git clone https://github.com/pytorch/fairseq.git
# %cd fairseq
# !git checkout da9eaba12d82b9bfc1442f0e2c6fc1b895f4d35d
# !pip install ./
! pip install xformers
# %cd ..
# Out:
# ...
# xcrun: error: invalid active developer path (/Library/Developer/CommandLineTools), missing xcrun at: /Library/Developer/CommandLineTools/usr/bin/xcrun
# [Errno 2] No such file or directory: 'fairseq'
# /Users
# ERROR: Directory './' is not installable. Neither 'setup.py' nor 'pyproject.toml' found.
# ...
#   Using cached xformers-0.0.13.tar.gz (292 kB)
#     ERROR: Command errored out with exit status 1:
# ...

# %%
# add fairseq folder to python path
import os
os.environ['PYTHONPATH'] += ":/content/fairseq/"
# sanity check to see if fairseq is installed
from fairseq import checkpoint_utils, distributed_utils, options, tasks, utils
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [7], in <cell line: 3>()
#       1 # add fairseq folder to python path
#       2 import os
# ----> 3 os.environ['PYTHONPATH'] += ":/content/fairseq/"
#       4 # sanity check to see if fairseq is installed
#       5 from fairseq import checkpoint_utils, distributed_utils, options, tasks, utils
#
# File ~/opt/anaconda3/lib/python3.9/os.py:679, in _Environ.__getitem__(self, key)
#     676     value = self._data[self.encodekey(key)]
#     677 except KeyError:
#     678     # raise KeyError with the original key value
# --> 679     raise KeyError(key) from None
#     680 return self.decodevalue(value)
#
# KeyError: 'PYTHONPATH'

# %%
# !wget https://ai4b-public-nlu-nlg.objectstore.e2enetworks.net/en2indic.zip
# !unzip en2indic.zip

# %cd indicTrans
# Out:
# --2023-01-18 13:22:37--  https://ai4b-public-nlu-nlg.objectstore.e2enetworks.net/en2indic.zip
# Resolving ai4b-public-nlu-nlg.objectstore.e2enetworks.net (ai4b-public-nlu-nlg.objectstore.e2enetworks.net)... 101.53.152.33, 164.52.210.58, 164.52.206.154, ...
# Connecting to ai4b-public-nlu-nlg.objectstore.e2enetworks.net (ai4b-public-nlu-nlg.objectstore.e2enetworks.net)|101.53.152.33|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4811880516 (4.5G) [application/zip]
# en2indic.zip: Read-only file system
#
# Cannot write to 'en2indic.zip' (Success).
# unzip:  cannot find or open en2indic.zip, en2indic.zip.zip or en2indic.zip.ZIP.
# [Errno 2] No such file or directory: 'indicTrans'
# /

# %%
from indicTrans.inference.engine import Model

model = Model(expdir='../en-indic')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [9], in <cell line: 1>()
# ----> 1 from indicTrans.inference.engine import Model
#       3 model = Model(expdir='../en-indic')
#
# ModuleNotFoundError: No module named 'indicTrans'

# %%
import pandas as pd

df = pd.read_csv('/Users/vinay_kl/Downloads/data.csv')
texts = df['text'].tolist()

# for language in ['bn', 'gu', 'kn', 'ml', 'mr', 'or', 'pa', 'ta', 'te']:
# print(f'Translating in {language} now:')
translated = model.batch_translate(texts, 'en', 'hi')
df['hi'] = translated
# df[language] = translated
print('Done')

df.to_csv('/Users/vinay_kl/Downloads/translated.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [10], in <cell line: 8>()
#       4 texts = df['text'].tolist()
#       6 # for language in ['bn', 'gu', 'kn', 'ml', 'mr', 'or', 'pa', 'ta', 'te']:
#       7 # print(f'Translating in {language} now:')
# ----> 8 translated = model.batch_translate(texts, 'en', 'hi')
#       9 df['hi'] = translated
#      10 # df[language] = translated
#
# NameError: name 'model' is not defined
