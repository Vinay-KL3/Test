# %%
from selenium import webdriver
import time
from selenium.webdriver.common.alert import Alert
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.support.select import Select

# %%
driver = webdriver.Chrome("chromedriver.exe")
wait = driver.implicitly_wait(20)

driver.get("https://aws.pravid.io/")
wait

driver.find_element("xpath", '//*[@id="root"]/div/div[1]/div[1]/div/div[2]/button[1]').click()
wait

driver.find_element("xpath", '//*[@id="auto_E-mail"]').send_keys("Vinaykumar@pravid.io")
wait

driver.find_element("xpath", '//*[@id="auto_Password"]').send_keys("Saarthi@123")
wait

driver.find_element("xpath", '//input[@value="Log In"]').click()
wait

driver.find_element("xpath", "//div[@id='auto_leftMenu_option_Campaign']//span[@id='auto_leftMenu_option_4']").click()
wait

driver.find_element("xpath", '//*[@id="auto_leftMenu_option_Campaign Testing Info"]').click()
wait

driver.find_element("xpath", '//*[@title="Select Client"]').click()
wait

driver.find_element("xpath", '//*[@id="dropdown_input"]').send_keys("Axio Testing")
wait

driver.find_element("xpath", '//*[text()="Axio Testing"]').click()







wait
trigger_whatsapp = driver.find_element("xpath", '//*[@id="fullscreen"]/div[2]/div/div/div/div[4]/div/div[3]/p')
wait
trigger_whatsapp.click()
# trigger_whatsapp.click()
# trigger_whatsapp.click()


#1 get the name of the current window
p = driver.current_window_handle
print(p)

#2 switch to new window/tab & open your required url
driver.switch_to.new_window('tab')

driver.get("https://web.whatsapp.com/")

c = driver.current_window_handle
print(c)

#now capture all the windows/tabs opened    ---first opened window will be zero, next opened will be 1,.....
count = driver.window_handles

# for i in count:
#     driver.switch_to.window(i)
#     time.sleep(2)
# #     print(drivetitletle)
    
driver.switch_to.window(p)
time.sleep(2)
driver.switch_to.window(c)
time.sleep(2)
driver.switch_to.window(p)
time.sleep(2)
driver.switch_to.window(c)
time.sleep(2)



# time.sleep(15)
# trigger_whatsapp
# time.sleep(15)
# trigger_whatsapp
# time.sleep(15)
# trigger_whatsapp
# time.sleep(10)
# trigger_whatsapp


#new tab
# we can use keys class to replicate the ctrl + n

# driver.find_element("xpath", "/html/body").send_keys(Keys.COMMAND + "n")
# wait
# driver.switch_to.window(driver.window_handles[-1])
# wait
# driver.get("https://web.whatsapp.com/")
# time.sleep(10)
# driver.switch_to.window(driver.window_handles[0])



# #geeks for geeks
# # Clicks on privacy and it opens in new window
# driver.find_element("class", "privacy").click()
  
# # switch window in 7 seconds
# time.sleep(7)  
  
# # window_handles[1] is a second window
# driver.switch_to.window(driver.window_handles[1])
# time.sleep(7)  
# driver.switch_to.window(driver.window_handles[0])



# collects handle ID of current window
# first_tab_handle = driver.current_window_handle
# print("first_tab_handle : "+str(first_tab_handle))

# new_tab_link = driver.get("https://web.whatsapp.com/")
# time.sleep(5)

# action = ActionChains(driver)
# action.key_down(Keys.CONTROL).click(new_tab_link).key_up(Keys.CONTROL).perform() 
# time.sleep(3)
# print("driver.window_handles : " + str(driver.window_handles))
# print("current window handle : "+ str(driver.current_window_handle))
# if driver.current_window_handle == first_tab_handle:
#     print("driver focus is not switched to new tab opened using actionChains.")
# else:
#     print("window handle has changed. Driver switched focus to new tab.")
# driver.switch_to.window(driver.window_handles[1])
# time.sleep(3)




time.sleep(10)
driver.quit()
# Out:
# /var/folders/tr/mwr4dkgn0tb5jh53c7lyvfmw0000gn/T/ipykernel_72351/1798689447.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome("chromedriver.exe")
# BE792DF5C77370E93231846AAB789ECA
# BBF7ECC971C12EDF1A9EE1A16C8E6BEC

# %%
message = ["i cant pay now", "i dont have money now", "having some family problems"]

driver = webdriver.Chrome("chromedriver.exe")
wait = driver.implicitly_wait(20)

driver.get("https://web.whatsapp.com/")
driver.implicitly_wait(150)

driver.find_element("xpath", '//*[@id="side"]/div[1]/div/div/div[2]/div/div[1]/p').click()
wait

driver.find_element("xpath", '//*[@id="side"]/div[1]/div/div/div[2]/div/div[1]/p').send_keys("8088078032")
wait

driver.find_element("xpath", "//span[@title='+91 80880 78032']").click()
wait

driver.find_element("xpath", '//*[@id="main"]/footer/div[1]/div/span[2]/div/div[2]/div[1]/div/div[1]/p').send_keys("i cant pay now")
driver.implicitly_wait(3)

driver.find_element("xpath", '//*[@id="main"]/footer/div[1]/div/span[2]/div/div[2]/div[2]/button/span').click()
time.sleep(15)

driver.find_element("xpath", '//*[@id="main"]/footer/div[1]/div/span[2]/div/div[2]/div[1]/div/div[1]/p').send_keys("i dont have money now")
driver.implicitly_wait(3)

driver.find_element("xpath", '//*[@id="main"]/footer/div[1]/div/span[2]/div/div[2]/div[2]/button/span').click()
time.sleep(15)

driver.find_element("xpath", '//*[@id="main"]/footer/div[1]/div/span[2]/div/div[2]/div[1]/div/div[1]/p').send_keys("having some family problems")
driver.implicitly_wait(3)

driver.find_element("xpath", '//*[@id="main"]/footer/div[1]/div/span[2]/div/div[2]/div[2]/button/span').click()
time.sleep(15)

driver.quit()
# Out:
# /var/folders/tr/mwr4dkgn0tb5jh53c7lyvfmw0000gn/T/ipykernel_72351/2064836120.py:3: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome("chromedriver.exe")

# %%
0B1A2FDABD8BCB551B22135ABB4131C9
E76088F4F772E035D907D7F5AF3A44E4

Pravid | AI-led Debt Collections. Reliable, Affordable and Personalized
WhatsApp

# %%
from selenium import webdriver
import time
from selenium.webdriver.common.alert import Alert
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.support.select import Select
import pandas as pd



chrome_options = webdriver.ChromeOptions()
# chrome_options.add_argument("headless")
chrome_options.add_argument("--ignore-certificate-errors")


driver = webdriver.Chrome("chromedriver.exe", options = chrome_options)
wait = driver.implicitly_wait(20)

driver.get("https://aws.pravid.io/")
wait

driver.maximize_window()


driver.find_element("xpath", '//*[@id="root"]/div/div[1]/div[1]/div/div[2]/button[1]').click()
wait

driver.find_element("xpath", '//*[@id="auto_E-mail"]').send_keys("Vinaykumar@pravid.io")
wait

driver.find_element("xpath", '//*[@id="auto_Password"]').send_keys("Saarthi@123")
wait

driver.find_element("xpath", '//input[@value="Log In"]').click()
wait

driver.find_element("xpath", "//div[@id='auto_leftMenu_option_Campaign']//span[@id='auto_leftMenu_option_4']").click()
wait

driver.find_element("xpath", '//*[@id="auto_leftMenu_option_Campaign Testing Info"]').click()
wait

driver.find_element("xpath", '//*[@title="Select Client"]').click()
wait

driver.find_element("xpath", '//*[@id="dropdown_input"]').send_keys("Axio Testing")
wait

driver.find_element("xpath", '//*[text()="Axio Testing"]').click()
wait


trigger_whatsapp = driver.find_element("xpath", '//*[@id="fullscreen"]/div[2]/div/div/div/div[4]/div/div[3]/p')
wait

trigger_whatsapp.click()
time.sleep(20)






p = driver.current_window_handle
# print(p)

#2 switch to new window/tab & open your required url
driver.switch_to.new_window('tab')

driver.get("https://web.whatsapp.com/")

c = driver.current_window_handle
# print(c)

driver.implicitly_wait(150)





driver.find_element("xpath", '//*[@id="side"]/div[1]/div/div/div[2]/div/div[1]/p').click()
wait

driver.find_element("xpath", '//*[@id="side"]/div[1]/div/div/div[2]/div/div[1]/p').send_keys("8088078032")
wait

driver.find_element("xpath", "//span[@title='+91 80880 78032']").click()
wait

driver.find_element("xpath", '//*[@id="main"]/footer/div[1]/div/span[2]/div/div[2]/div[1]/div/div[1]/p').send_keys("i cant pay now")
driver.implicitly_wait(3)

driver.find_element("xpath", '//*[@id="main"]/footer/div[1]/div/span[2]/div/div[2]/div[2]/button/span').click()
time.sleep(15)

driver.find_element("xpath", '//*[@id="main"]/footer/div[1]/div/span[2]/div/div[2]/div[1]/div/div[1]/p').send_keys("i dont have money now")
driver.implicitly_wait(3)

driver.find_element("xpath", '//*[@id="main"]/footer/div[1]/div/span[2]/div/div[2]/div[2]/button/span').click()
time.sleep(15)




# driver.switch_to.window(p)
# time.sleep(2)
# driver.switch_to.window(c)
# time.sleep(2)
# driver.switch_to.window(p)
# trigger_whatsapp.click()
# time.sleep(1)
# driver.switch_to.window(c)
# time.sleep(1)



# time.sleep(15)
# trigger_whatsapp
# time.sleep(15)
# trigger_whatsapp
# time.sleep(15)
# trigger_whatsapp
# time.sleep(10)
# trigger_whatsapp


#new tab
# we can use keys class to replicate the ctrl + n

# driver.find_element("xpath", "/html/body").send_keys(Keys.COMMAND + "n")
# wait
# driver.switch_to.window(driver.window_handles[-1])
# wait
# driver.get("https://web.whatsapp.com/")
# time.sleep(10)
# driver.switch_to.window(driver.window_handles[0])



# #geeks for geeks
# # Clicks on privacy and it opens in new window
# driver.find_element("class", "privacy").click()
  
# # switch window in 7 seconds
# time.sleep(7)  
  
# # window_handles[1] is a second window
# driver.switch_to.window(driver.window_handles[1])
# time.sleep(7)  
# driver.switch_to.window(driver.window_handles[0])



# collects handle ID of current window
# first_tab_handle = driver.current_window_handle
# print("first_tab_handle : "+str(first_tab_handle))

# new_tab_link = driver.get("https://web.whatsapp.com/")
# time.sleep(5)

# action = ActionChains(driver)
# action.key_down(Keys.CONTROL).click(new_tab_link).key_up(Keys.CONTROL).perform() 
# time.sleep(3)
# print("driver.window_handles : " + str(driver.window_handles))
# print("current window handle : "+ str(driver.current_window_handle))
# if driver.current_window_handle == first_tab_handle:
#     print("driver focus is not switched to new tab opened using actionChains.")
# else:
#     print("window handle has changed. Driver switched focus to new tab.")
# driver.switch_to.window(driver.window_handles[1])
# time.sleep(3)


def TRIGGER():
    driver.switch_to.window(p)
    wait
    trigger_whatsapp.click()
    time.sleep(1)
    driver.switch_to.window(c)
    time.sleep(1)


    
    
dataCSV = "/Users/vinay_kl/Downloads/btfile.csv"

df = pd.read_csv(dataCSV)
Utterance_Coloum = df["Final_List"]
for i in range(0, len(Utterance_Coloum)):
    Utterance_List = eval(Utterance_Coloum[i])
    for j in range(0,len(Utterance_List)):
        Final_Utterance = Utterance_List[j]
        print(Final_Utterance)
        
        if Final_Utterance == "IM":
            TRIGGER()
        else:
            time.sleep(15)
            driver.find_element("xpath", '//*[@id="main"]/footer/div[1]/div/span[2]/div/div[2]/div[1]/div/div[1]/p').send_keys(Final_Utterance)
            driver.implicitly_wait(3)

            driver.find_element("xpath", '//*[@id="main"]/footer/div[1]/div/span[2]/div/div[2]/div[2]/button/span').click()
            time.sleep(15)
            
            
            
            
time.sleep(10)
driver.quit()
# Out:
# /var/folders/tr/mwr4dkgn0tb5jh53c7lyvfmw0000gn/T/ipykernel_72351/3848833776.py:10: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome("chromedriver.exe")
# IM
# am facing some issue while paying through your agent
# IM
# am facing some issue while paying through your app
# IM
# am facing some issue while paying through your branch
# IM
# am facing some issue while paying through my card
# IM
# am facing some issue while paying through net banking
# IM
# am facing some issue while paying through online
# IM
# am facing some issue while paying through upi
# IM
# am facing some issue while paying through wallet
# IM
# am facing some issue while paying through the payment link
# IM
# am facing some issue while paying through the payment method
# IM
# no
# i will pay today
# IM
# no
# arey idiot, i will pay today
# IM
# no
# i will pay next year
# IM
# no
# i will pay
# IM
# no
# i cant pay now, will pay later
# IM
# no
# ...

# %%
import pandas as pd

dataCSV = "/Users/vinay_kl/Downloads/btfile.csv"

df = pd.read_csv(dataCSV)
Utterance_Coloum = df["Final_List"]
for i in range(0, len(Utterance_Coloum)):
    Utterance_List = eval(Utterance_Coloum[i])
    for j in range(0,len(Utterance_List)):
        Final_Utterance = Utterance_List[j]
        print(Final_Utterance)
        
        if Final_Utterance == "IM":
            TRIGGER()
        else:
            driver.find_element("xpath", '//*[@id="main"]/footer/div[1]/div/span[2]/div/div[2]/div[1]/div/div[1]/p').send_keys(Final_Utterance)
            driver.implicitly_wait(3)

            driver.find_element("xpath", '//*[@id="main"]/footer/div[1]/div/span[2]/div/div[2]/div[2]/button/span').click()
            time.sleep(15)
# Out:
# IM
# i will pay today
# IM
# arey idiot, i will pay today
# IM
# i will pay next year
# IM
# i will pay
# IM
# i cant pay now, will pay later
# IM
# arey idiot, i cant pay now, will pay later
# IM
# can i pay half amount
# IM
# i will pay with late payment charges
# IM
# i have already done payment twice on july 10th
# IM
# i have already done payment twice
# IM
# there is balance in my account, you can debit it
# IM
# autodebit is already initiated
# IM
# there is no balance in my account
# IM
# i wont do the payment
# IM
# arey idiot, i wont do the payment
# IM
# yes
# IM
# no
# IM
# yes, i can
# IM
# no, i cant
# IM
# Medical Emergency
# IM
# Insufficient Funds
# IM
# Facing Technical Issue
# IM
# Bank account issue
# IM
# Personal Issue
# IM
# Death of Borrower
# IM
# Job Loss
# IM
# Salary Not Received
# IM
# Family Dispute
# IM
# Others
# no
# IM
# tell me the process of paying through agent
# IM
# tell me the process of paying through app
# IM
# ...

# %%
time.sleep(10)
driver.quit()
