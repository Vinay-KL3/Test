# %%
age = "22"

# %%
if int(age) >= 18 and int(age) <= 30:
    final_age = "Y"
    print(final_age)
    
elif int(age) >= 31 and int(age) <= 45:
    final_age = "M"
    print(final_age)
    
elif int(age) >= 46 and int(age) <= 60:
    final_age = "O"
    print(final_age)   
    
else:
    final_age = "given age is not valid"
    print(final_age)
# Out:
# Y

# %%
import requests
import json
import pandas as pd
from pprint import pprint
import csv
import time
import random
import datetime
import re

# %%
dataCSV = "/Users/vinay_kl/Downloads/Stellantis Bot TestSet - Business_Scenarios.csv"
# list = []
# listst2 = ["yes", "yes, on the same day","same location","dont need any pickup or drop"]

# %%
df = pd.read_csv(dataCSV)
df.head()


TestCase_No = df["S_NO"]
Utterance_Coloum = df["List_1"]


for i in range(0,len(Utterance_Coloum)):
    
    Final_T_NO = TestCase_No[i]
    print(Final_T_NO)
    
    Utterance_List = eval(Utterance_Coloum[i])
    for j in range(0,len(Utterance_List)):
        Final_Utterance = Utterance_List[j]
        print(Final_Utterance)


# for k in range(0,len(TestCase_No)):
#     TNO = TestCase_No[k]
#     print(TNO)
# Out:
# 1
# /initial_message
# yes
# /no_response
# 2
# /initial_message
# yes
# yes
# /no_response
# 3
# /initial_message
# yes
# yes
# yes
# /no_response
# only drop service is required
# 4
# /initial_message
# yes
# yes
# yes
# only pickup service is required
# 5
# /initial_message
# yes
# yes
# yes
# yes
# 6
# /initial_message
# yes
# yes
# yes
# no
# 7
# /initial_message
# yes
# yes
# no
# /no_response
# Bangalore
# 8
# /initial_message
# yes
# yes
# no
# Karnataka
# 9
# /initial_message
# yes
# yes
# no
# not sure
# Karnataka
# 10
# /initial_message
# yes
# yes
# no
# no
# Bangalore
# 11
# /initial_message
# yes
# no
# 16th May
# 12
# /initial_message
# yes
# i will take the service later
# /no_response
# 13
# /initial_message
# yes
# i will book for a service later
# /no_response
# 14
# /initial_message
# yes
# i am unable to book for a service online
# 15
# /initial_message
# yes
# i want to raise a complaint regarding the parts missing
# 16
# /initial_message
# yes
# ...

# %%
with open(dataCSV, 'r') as f:
    reader = csv.reader(f)
    print(reader)
    the_whole_file = list(reader)    
    
count = 0
while(count < (len(the_whole_file)-1)):
    count = count + 1
    text = the_whole_file[count][0]
    print(text)
    
    try:
        NLU(text = text)
        
    except Exception as e:
        print(e)
# Out:
# ...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [16], in <cell line: 1>()
#       2     reader = csv.reader(f)
#       3     print(reader)
# ----> 4     the_whole_file = list(reader)
#       6 count = 0
#       7 while(count < (len(the_whole_file)-1)):
#
# TypeError: 'list' object is not callable

# %%
for i in listst2:
    print(i)
# Out:
# yes
# yes, on the same day
# same location
# dont need any pickup or drop

# %%
response = "{
    "sender_id": "Guru-5lklkkkkjkllkkllllllllkkllkk",
    "request_id": "request11j27",
    "user_id": "9482152447",
    "nlu_data": {
        "text": "/initial_message",
        "intent": {
            "name": "initial_message",
            "confidence": 1.0
        },
        "intent_ranking": [
            {
                "name": "initial_message",
                "confidence": 1.0
            }
        ],
        "entities": []
    },
    "custom": {
        "alternate_lead": null,
        "bot_gender": null,
        "callback_time": null,
        "competitor": null,
        "contact_no": null,
        "current_city": null,
        "customer_name": "power cat",
        "desired_loan_amount": null,
        "disposition_id": [
            "initial_message"
        ],
        "due_date": null,
        "emi_amount": null,
        "flow_type": "appointment_booking",
        "given_date": null,
        "interest": null,
        "interested_brand": null,
        "lead_category": null,
        "loan_amount": null,
        "loan_id": null,
        "partial_amount": null,
        "past_application_date": null,
        "past_applications": null,
        "payment_link": null,
        "planned_availing_date": null,
        "planned_availing_date_secondary": null,
        "primary_interested_product": null,
        "product": null,
        "ptp_date": null,
        "ptp_recheck": null,
        "reason": null,
        "response_time": "2023-05-07 13:37:47.168624",
        "right_party_contact": null,
        "secondary_interested_product": null,
        "sheet_name": null,
        "status": 702,
        "time_limit": 8,
        "visit_date": null,
        "visit_status": null,
        "visit_type": null,
        "website": null,
        "tts": "en-IN",
        "stt": "en-IN",
        "tts_gender": "FEMALE",
        "tts_speaking_rate": "0.9",
        "tts_voice_name": "en-IN-Standard-A"
    },
    "data": [
        {
            "text": "Hi, I'm Stella , calling from None - Bangalore . Am I talking to power cat ?",
            "buttons": [],
            "quick_replies": [],
            "hash": "72f1273256692779378f2b630f2f3becstellantis",
            "temaplate_id": "utter_RPC_initial_message_stellantis_AB_FW_G_F",
            "force": 1,
            "voice_data": "https://poojafin.saarthi.ai/zstellantis_tts/wav?message=Hi, I'm Stella , calling from None - Bangalore . Am I talking to power cat ?&template_name=utter_RPC_initial_message_stellantis_AB_FW_G_F&language=english"
        }
    ],
    "elements": [],
    "attachments": []
}"
# Out:
#   Input In [21]
#     response = "{
#                  ^
# SyntaxError: EOL while scanning string literal
