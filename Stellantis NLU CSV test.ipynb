# %%
import requests
import json
import pandas as pd
from pprint import pprint
import csv
import time
import random
import datetime
import re

# %%
# Find the updated staging endpoints below-

# NLU voice - stage-fastapi-appointment-booking-nlu-nologger.saarthi.ai/predict

# NLU whatsapp - https://stage-appointment-whatsapp-nlu.saarthi.ai/predict

# NER - stage-ner-appointment-book.saarthi.ai/predict

# Stellantis whatsapp prod
# EndPoint = "http://20.219.229.9:8000/predict"

#Collections
# EndPoint = "http://20.204.231.204:8000/predict"
#coll_whatsapp
EndPoint = "https://stage-maia-whatsapp-nlu.saarthi.ai/predict"
#Stellantis
# EndPoint = "http://20.204.184.99:8000/predict"
#PoliticalEdge
# EndPoint = "http://20.207.68.13:8000/predict"

# EndPoint = "https://stage-appointment-whatsapp-nlu.saarthi.ai/predict"
# EndPoint = "https://stage-fastapi-appointment-booking-nlu-nologger.saarthi.ai/predict"

# dataCSV = "/Users/vinay_kl/Downloads/Stellantis_NLU_Issues - 2 Jun.csv"
dataCSV = "/Users/vinay_kl/Downloads/whatsapp_nlu_testset.csv"

# %%
#Stellantis


def NLU(text = None):
    headers = {'Content-Type':'application/json'}    
    payload = json.dumps ({

    "text": text
                          })
    response = requests.request("POST", EndPoint, headers=headers, data=payload).json()

    # pprint(response)

    intent_pred = (response["intent"][0]["name"])
    intent_acc = (response["intent"][0]["confidence"])

    sub_intent_pred = (response["sub_intent"][0]["name"])
    sub_intent_acc = (response["sub_intent"][0]["confidence"])

    context_pred = (response["context"][0]["name"])
    context_acc = (response["context"][0]["confidence"])

    sub_context_pred = (response["sub_context"][0]["name"])
    sub_context_acc = (response["sub_context"][0]["confidence"])

    signal_pred = (response["signal"][0]["name"])
    signal_acc = (response["signal"][0]["confidence"])

    reason_pred = (response["reason"][0]["name"])
    reason_acc = (response["reason"][0]["confidence"])

    third_person_pred = (response["third_person"][0]["name"])
    third_person_acc = (response["third_person"][0]["confidence"])

    humiliate_pred = (response["humiliate"][0]["name"])
    humiliate_acc = (response["humiliate"][0]["confidence"])

    sentiment_pred = (response["sentiment"][0]["name"])
    sentiment_acc = (response["sentiment"][0]["confidence"])



    # print(
    #       intent_pred,intent_acc,
    #       sub_intent_pred,sub_intent_acc,
    #       context_pred,context_acc,
    #       sub_context_pred,sub_context_acc,
    #       signal_pred,signal_acc,
    #       reason_pred,reason_acc,
    #       third_person_pred,third_person_acc,
    #       humiliate_pred,humiliate_acc,
    #       sentiment_pred,sentiment_acc,
    #      )


    print(intent_pred,"\t",intent_acc,"\t",sub_intent_pred,"\t",sub_intent_acc,"\t",context_pred,"\t",context_acc,"\t",sub_context_pred,"\t",sub_context_acc,"\t",signal_pred,"\t",signal_acc,"\t",reason_pred,"\t",reason_acc,"\t",third_person_pred,"\t",third_person_acc,"\t",humiliate_pred,"\t",humiliate_acc,"\t",sentiment_pred,"\t",sentiment_acc)

# %%
#PoliticalEdge


def NLU(text = None):
    headers = {'Content-Type':'application/json'}    
    payload = json.dumps ({
        
    "text": text
                          })
    response = requests.request("POST", EndPoint, headers=headers, data=payload).json()



    intent_pred = (response["response"]["intent"][0]["name"])
    intent_acc = (response["response"]["intent"][0]["confidence"])

    sub_intent_pred = (response["response"]["sub_intent"][0]["name"])
    sub_intent_acc = (response["response"]["sub_intent"][0]["confidence"])

    context_pred = (response["response"]["context"][0]["name"])
    context_acc = (response["response"]["context"][0]["confidence"])

    sub_context_pred = (response["response"]["sub_context"][0]["name"])
    sub_context_acc = (response["response"]["sub_context"][0]["confidence"])

    signal_pred = (response["response"]["signal"][0]["name"])
    signal_acc = (response["response"]["signal"][0]["confidence"])

    reason_pred = (response["response"]["reason"][0]["name"])
    reason_acc = (response["response"]["reason"][0]["confidence"])

    third_person_pred = (response["response"]["third_person"][0]["name"])
    third_person_acc = (response["response"]["third_person"][0]["confidence"])

    humiliate_pred = (response["response"]["humiliate"][0]["name"])
    humiliate_acc = (response["response"]["humiliate"][0]["confidence"])

    sentiment_pred = (response["response"]["sentiment"][0]["name"])
    sentiment_acc = (response["response"]["sentiment"][0]["confidence"])



    # print(
    #       intent_pred,intent_acc,
    #       sub_intent_pred,sub_intent_acc,
    #       context_pred,context_acc,
    #       sub_context_pred,sub_context_acc,
    #       signal_pred,signal_acc,
    #       reason_pred,reason_acc,
    #       third_person_pred,third_person_acc,
    #       humiliate_pred,humiliate_acc,
    #       sentiment_pred,sentiment_acc,
    #      )


    print(intent_pred,"\t",intent_acc,"\t",sub_intent_pred,"\t",sub_intent_acc,"\t",context_pred,"\t",context_acc,"\t",sub_context_pred,"\t",sub_context_acc,"\t",signal_pred,"\t",signal_acc,"\t",reason_pred,"\t",reason_acc,"\t",third_person_pred,"\t",third_person_acc,"\t",humiliate_pred,"\t",humiliate_acc,"\t",sentiment_pred,"\t",sentiment_acc)

# %%
#collections


def NLU(text = None):
    headers = {'Content-Type':'application/json'}    
    payload = json.dumps ({
        
    "text": text
                          })
    response = requests.request("POST", EndPoint, headers=headers, data=payload).json()



    intent_pred = (response["response"]["intent"][0]["name"])
    intent_acc = (response["response"]["intent"][0]["confidence"])

    sub_intent_pred = (response["response"]["sub-intent"][0]["name"])
    sub_intent_acc = (response["response"]["sub-intent"][0]["confidence"])

    context_pred = (response["response"]["context"][0]["name"])
    context_acc = (response["response"]["context"][0]["confidence"])

    sub_context_pred = (response["response"]["sub-context"][0]["name"])
    sub_context_acc = (response["response"]["sub-context"][0]["confidence"])

    signal_pred = (response["response"]["signal"][0]["name"])
    signal_acc = (response["response"]["signal"][0]["confidence"])

    reason_pred = (response["response"]["delay_reason"][0]["name"])
    reason_acc = (response["response"]["delay_reason"][0]["confidence"])

    third_person_pred = (response["response"]["third_person"][0]["name"])
    third_person_acc = (response["response"]["third_person"][0]["confidence"])

    humiliate_pred = (response["response"]["humiliate"][0]["name"])
    humiliate_acc = (response["response"]["humiliate"][0]["confidence"])

    sentiment_pred = (response["response"]["sentiment"][0]["name"])
    sentiment_acc = (response["response"]["sentiment"][0]["confidence"])



    # print(
    #       intent_pred,intent_acc,
    #       sub_intent_pred,sub_intent_acc,
    #       context_pred,context_acc,
    #       sub_context_pred,sub_context_acc,
    #       signal_pred,signal_acc,
    #       reason_pred,reason_acc,
    #       third_person_pred,third_person_acc,
    #       humiliate_pred,humiliate_acc,
    #       sentiment_pred,sentiment_acc,
    #      )


    print(intent_pred,"\t",intent_acc,"\t",sub_intent_pred,"\t",sub_intent_acc,"\t",context_pred,"\t",context_acc,"\t",sub_context_pred,"\t",sub_context_acc,"\t",signal_pred,"\t",signal_acc,"\t",reason_pred,"\t",reason_acc,"\t",third_person_pred,"\t",third_person_acc,"\t",humiliate_pred,"\t",humiliate_acc,"\t",sentiment_pred,"\t",sentiment_acc)

# %%
#collections Whatsapp


def NLU(text = None):
    headers = {'Content-Type':'application/json'}    
    payload = json.dumps ({
        
    "text": text
                          })
    response = requests.request("POST", EndPoint, headers=headers, data=payload).json()



    intent_pred = (response["response"]["intent"][0]["name"])
    intent_acc = (response["response"]["intent"][0]["confidence"])

    sub_intent_pred = (response["response"]["sub-intent"][0]["name"])
    sub_intent_acc = (response["response"]["sub-intent"][0]["confidence"])

    context_pred = (response["response"]["context"][0]["name"])
    context_acc = (response["response"]["context"][0]["confidence"])

    sub_context_pred = (response["response"]["sub-context"][0]["name"])
    sub_context_acc = (response["response"]["sub-context"][0]["confidence"])

    signal_pred = (response["response"]["signal"][0]["name"])
    signal_acc = (response["response"]["signal"][0]["confidence"])

    reason_pred = (response["response"]["delay_reason"][0]["name"])
    reason_acc = (response["response"]["delay_reason"][0]["confidence"])

    third_person_pred = (response["response"]["third_person"][0]["name"])
    third_person_acc = (response["response"]["third_person"][0]["confidence"])

    humiliate_pred = (response["response"]["humiliate"][0]["name"])
    humiliate_acc = (response["response"]["humiliate"][0]["confidence"])

    sentiment_pred = (response["response"]["sentiment"][0]["name"])
    sentiment_acc = (response["response"]["sentiment"][0]["confidence"])

    language_pred = (response["response"]["lang"][0]["name"])
    language_acc = (response["response"]["lang"][0]["confidence"])

    # print(
    #       intent_pred,intent_acc,
    #       sub_intent_pred,sub_intent_acc,
    #       context_pred,context_acc,
    #       sub_context_pred,sub_context_acc,
    #       signal_pred,signal_acc,
    #       reason_pred,reason_acc,
    #       third_person_pred,third_person_acc,
    #       humiliate_pred,humiliate_acc,
    #       sentiment_pred,sentiment_acc,
    #      )


    print(intent_pred,"\t",intent_acc,"\t",sub_intent_pred,"\t",sub_intent_acc,"\t",context_pred,"\t",context_acc,"\t",sub_context_pred,"\t",sub_context_acc,"\t",signal_pred,"\t",signal_acc,"\t",reason_pred,"\t",reason_acc,"\t",third_person_pred,"\t",third_person_acc,"\t",humiliate_pred,"\t",humiliate_acc,"\t",sentiment_pred,"\t",sentiment_acc, "\t",language_pred,"\t",language_acc)

# %%
with open(dataCSV, 'r') as f:
    reader = csv.reader(f)
    the_whole_file = list(reader)    
    
count = 0
while(count < (len(the_whole_file)-1)):
    count = count + 1
    text = the_whole_file[count][3]
# text = "ஓகே முடியும்"
#     print(text)


    try:
        NLU(text = text)

    except Exception as e:
        print(e)
# Out:
# inform 	 0.9997135996818542 	 general_ask_inform 	 0.9999984502792358 	 bank_account 	 0.9035294055938721 	 general 	 0.9998100399971008 	 no_signal 	 0.9999986886978149 	 account_closed 	 0.9583531618118286 	 no 	 1.0 	 no_humiliation 	 1.0 	 neutral 	 1.0 	 hindi 	 0.9999899864196777
# inform 	 0.9999948740005493 	 general_ask_inform 	 1.0 	 bank_account 	 0.6073880195617676 	 general 	 0.9966436624526978 	 no_signal 	 0.9999920129776001 	 account_closed 	 0.9997214674949646 	 no 	 1.0 	 no_humiliation 	 1.0 	 neutral 	 1.0 	 hindi 	 0.9999998807907104
# inform 	 0.9999946355819702 	 general_ask_inform 	 0.9999996423721313 	 bank_account 	 0.9534499645233154 	 general 	 0.9998712539672852 	 no_signal 	 0.999998927116394 	 account_closed 	 0.9754734039306641 	 no 	 1.0 	 no_humiliation 	 1.0 	 neutral 	 1.0 	 hindi 	 0.9998020529747009
# ...

# %% [markdown]
# # Rough

# %%
headers = {'Content-Type':'application/json'}    
payload = json.dumps ({

"text": "i cant pay"
                      })
response = requests.request("POST", EndPoint, headers=headers, data=payload).json()

pprint(response)



intent_pred = (response["response"]["intent"][0]["name"])
intent_acc = (response["response"]["intent"][0]["confidence"])

sub_intent_pred = (response["response"]["sub-intent"][0]["name"])
sub_intent_acc = (response["response"]["sub-intent"][0]["confidence"])

context_pred = (response["response"]["context"][0]["name"])
context_acc = (response["response"]["context"][0]["confidence"])

sub_context_pred = (response["response"]["sub-context"][0]["name"])
sub_context_acc = (response["response"]["sub-context"][0]["confidence"])

signal_pred = (response["response"]["signal"][0]["name"])
signal_acc = (response["response"]["signal"][0]["confidence"])

reason_pred = (response["response"]["reason"][0]["name"])
reason_acc = (response["response"]["reason"][0]["confidence"])

third_person_pred = (response["response"]["third_person"][0]["name"])
third_person_acc = (response["response"]["third_person"][0]["confidence"])

humiliate_pred = (response["response"]["humiliate"][0]["name"])
humiliate_acc = (response["response"]["humiliate"][0]["confidence"])

sentiment_pred = (response["response"]["sentiment"][0]["name"])
sentiment_acc = (response["response"]["sentiment"][0]["confidence"])


# pprint(response["response"]["response"])
print(response["response"]["context"])

print(intent_pred)
# Out:
# {'response': {'context': [{'confidence': 0.9999706745147705, 'name': 'payment'},
#                           {'confidence': 2.894958197430242e-05,
#                            'name': 'general'}],
#               'delay_reason': [{'confidence': 0.9999997615814209,
#                                 'name': 'no_delay_reason'},
#                                {'confidence': 2.715273978992627e-07,
#                                 'name': 'insufficient_funds'}],
#               'humiliate': [{'confidence': 1.0, 'name': 'no_humiliation'},
#                             {'confidence': 4.050321189552619e-11,
#                              'name': 'customer_frustration'}],
#               'intent': [{'confidence': 1.0, 'name': 'inform'},
#                          {'confidence': 2.3274593363709073e-09, 'name': 'ask'}],
#               'lang': [{'confidence': 0.9999998807907104, 'name': 'english'},
#                        {'confidence': 6.899569626739321e-08,
# ...
