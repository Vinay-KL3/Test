# %% [markdown]
# # Actual Code

# %%
#import the required modules

import requests
import json
import pandas as pd
from pprint import pprint
import csv
import time
import random

print("all required modules are imported successfully")
# Out:
# all required modules are imported successfully

# %%
#update the current (pushData endpoint & bot endpoint) along with "testset(dataCSV)"


pushData = "https://maiabot.saarthi.ai/fetch_customer_data_maia"
botEndPoint = "https://maiabot.saarthi.ai/orchestrator_maia/webhook_maia"
dataCSV = "/Users/vinay_kl/Downloads/Test357.csv"

#-----------------------------------------------------------------------------#

RPC_Sheet = "/Users/vinay_kl/Downloads/RPC_Sheet.csv"
PIC_Sheet = "/Users/vinay_kl/Downloads/PIC_Sheet.csv"
COUNSELLING_Sheet = "/Users/vinay_kl/Downloads/COUNSELLING_Sheet.csv"
Delay_Sheet = "/Users/vinay_kl/Downloads/Delay_Sheet.csv"
RPN_Sheet = "/Users/vinay_kl/Downloads/RPN_Sheet.csv"
CBN_Sheet = "/Users/vinay_kl/Downloads/CBN_Sheet.csv"

print("testset and endpoints are pushed to respective variables")
# Out:
# testset and endpoints are pushed to respective variables

# %%
#update required customer config details

agentName = "Sia"
customerName = "Vinay"
flow = "predue"
language = "english"

locality = "Urban"
gender = "M"
age = "56"
collared = "Blue"
typology = "WAOR"

dueDate = "07-04-2023"
emiAmount = "54321"
ptpDate = "31-03-2023"

print("required customer config details are updated")
# Out:
# required customer config details are updated

# %%
#update required agent config

agentConfig = "{\"language\":[{\"value\":\"Hindi\",\"displayValue\":\"Hindi\"},{\"value\":\"English\",\"displayValue\":\"English\"}],\"channel\":[\"Whatsapp\",\"Call\"],\"accountId\":\"6396c1beb1b7ed22b76cc6d6\",\"agentId\":\"MaiaBotTesting_Collections_UnsecuredPersonalLoan_General_9\",\"domainId\":\"61f21a2f9cf0e005bb91eaea\",\"bankName\":\"ICICI\",\"maleAgentName\":\"RamaKrishna\",\"femaleAgentName\":\"maia\",\"Call\":{\"partialPayment\":{\"dpd_1_3\":\"true\",\"dpd_4_7\":\"true\",\"dpd_8_15\":\"false\",\"dpd_16_30\":\"false\"},\"partialPaymentStage\":{\"dpd_1_3\":\"stage2\",\"dpd_4_7\":\"stage2\"},\"levelOfNegotiation\":{\"dpd_1_3\":\"1\",\"dpd_4_7\":\"1\"},\"minimumNegotiationPercentage\":{\"dpd_1_3\":\"50\",\"dpd_4_7\":\"50\"},\"paymentMode\":\"NACH\",\"paymentMethods\":{\"pay_via_online\":\"true\",\"pay_via_agent\":\"true\",\"pay_via_card\":\"true\",\"pay_via_upi\":\"true\",\"pay_via_netbanking\":\"false\",\"pay_via_wallet\":\"true\",\"pay_via_branch\":\"true\",\"pay_via_app\":\"true\"},\"thresholdPtpDays\":4,\"thresholdCallBackTime\":\"18:00\",\"thresholdCallBackDate\":\"25/09/2000\",\"latePaymentPolicy\":\"no policy\",\"sms\":\"true\"},\"Whatsapp\":{\"partialPayment\":{\"dpd_1_3\":\"true\",\"dpd_8_15\":\"true\",\"dpd_16_30\":\"false\",\"dpd_4_7\":\"false\"},\"partialPaymentStage\":{\"dpd_1_3\":\"stage2\",\"dpd_8_15\":\"stage2\"},\"levelOfNegotiation\":{\"dpd_1_3\":\"1\",\"dpd_8_15\":\"1\"},\"minimumNegotiationPercentage\":{\"dpd_1_3\":\"50\",\"dpd_8_15\":\"50\"},\"paymentMode\":\"NACH\",\"paymentMethods\":{\"pay_via_online\":\"true\",\"pay_via_agent\":\"true\",\"pay_via_netbanking\":\"false\",\"pay_via_wallet\":\"true\",\"pay_via_branch\":\"true\",\"pay_via_app\":\"true\",\"pay_via_upi\":\"false\",\"pay_via_card\":\"false\"},\"thresholdPtpDays\":4,\"latePaymentPolicy\":\"A 5 % late fee will be charged on the EMI amount. For more details ,Please call our toll free number.\",\"followUpTime\":{\"firstFollowup\":30,\"secondFollowup\":180}},\"createdAt\":\"2022-12-23T07:21:27.304Z\",\"updatedAt\":\"2022-12-23T07:54:34.497Z\",\"id\":\"63a556f775e5d53ef3e9b638\"}"

print("required agent config is updated")
# Out:
# required agent config is updated

# %%
#Push the data to DB

headers = {'Content-Type':'application/json'}


payload = json.dumps ({
    "data": [
        {
            "age": age,
            "agent_config": agentConfig,
            "agent_name": agentName,
            "clientName": "Maia Bot Testing",
            "client_name": "Maia Bot Testing",
            "collared": collared,
            "contactInfo.primary": "6305450418",
            "disposition_name": "Default",
            "email.primary": "r18r18@gmail.com",
            "gender": gender,
            "geographic_location": "bangalore",
            "interest_rate": "15",
            "late_fees": "100",
            "loanAccountDetails.emiAmount": emiAmount,
            "loanAccountDetails.emiDueDate": dueDate,
            "loanAccountDetails.loanId": "test1",
            "loanAccountDetails.noOfLoans": "1",
            "loan_amount_remaining": "40000",
            "loan_end_date": "02-10-2025",
            "loan_start_date": "02-06-2022",
            "primaryInfo.firstName": customerName,
            "primaryInfo.flow": flow,
            "primaryInfo.language": language,
            "primaryInfo.region": locality,
            "principal_amount": "456799",
            "region": locality,
            "tenure_left": "5",
            "total_loan_amount": "4566",
            "typology": typology,
            "payment_status": "Paid",
            "paid_date": ptpDate,
            "loan_type": "",
            "Audio_server": "False"
        }
    ]
})

response = requests.request("POST", pushData, headers=headers, data=payload).json()
print(response)
# Out:
# Data pushed successfully for maiaaaaaa

# %%
#functions(own)


def LC(TestCaseNo = None,Message = None):



    headers = {'Content-Type':'application/json'}    
    payload = json.dumps ({
        "user_id": "6305450418",
        "request_id": "requestcd1127",
        "sender": "saarthibajajvinay555"+str(TestCaseNo)+str(num),
        "message": Message
    })
    response = requests.request("POST", botEndPoint, headers=headers, data=payload).json()




    i = response["data"]

    for dicts in i:
        lastResponse = dicts["text"]
        print(lastResponse,"\t", end=' ')




    disposition = response["custom"]["disposition_id"]
    status = response["custom"]["status"]  

    print(disposition,'\t',status)
    
    
    
    
    
    
def LC_2(TestCaseNo = None,Message = None):


    headers = {'Content-Type':'application/json'}    
    payload = json.dumps ({
        "user_id": "6305450418",
        "request_id": "requestcd1127",
        "sender": "saarthibajajvinay555"+str(TestCaseNo)+str(num),
        "message": "can you speak any other languages"
    })
    response = requests.request("POST", botEndPoint, headers=headers, data=payload).json()



    headers = {'Content-Type':'application/json'}    
    payload = json.dumps ({
        "user_id": "6305450418",
        "request_id": "requestcd1127",
        "sender": "saarthibajajvinay555"+str(TestCaseNo)+str(num),
        "message": Message
    })
    response = requests.request("POST", botEndPoint, headers=headers, data=payload).json()




    i = response["data"]

    for dicts in i:
        lastResponse = dicts["text"]
        print(lastResponse,"\t", end=' ')




    disposition = response["custom"]["disposition_id"]
    status = response["custom"]["status"]  

    print(disposition,'\t',status)
    
    
    
    
    
    
    
def RPN(TestCaseNo = None,Message = None):


    headers = {'Content-Type':'application/json'}    
    payload = json.dumps ({
        "user_id": "6305450418",
        "request_id": "requestcd1127",
        "sender": "saarthibajajvinay555"+str(TestCaseNo)+str(num),
        "message": "he is currently not here"
    })
    response = requests.request("POST", botEndPoint, headers=headers, data=payload).json()


    headers = {'Content-Type':'application/json'}    
    payload = json.dumps ({
        "user_id": "6305450418",
        "request_id": "requestcd1127",
        "sender": "saarthibajajvinay555"+str(TestCaseNo)+str(num),
        "message": "please call him after 20 days"
    })
    response = requests.request("POST", botEndPoint, headers=headers, data=payload).json()


    headers = {'Content-Type':'application/json'}    
    payload = json.dumps ({
        "user_id": "6305450418",
        "request_id": "requestcd1127",
        "sender": "saarthibajajvinay555"+str(TestCaseNo)+str(num),
        "message": Message
    })
    response = requests.request("POST", botEndPoint, headers=headers, data=payload).json()




    i = response["data"]

    for dicts in i:
        lastResponse = dicts["text"]
        print(lastResponse,"\t", end=' ')




    disposition = response["custom"]["disposition_id"]
    status = response["custom"]["status"]  

    print(disposition,'\t',status)
    
    
    
    
    
    

def CBN(TestCaseNo = None,Message = None):


    headers = {'Content-Type':'application/json'}    
    payload = json.dumps ({
        "user_id": "6305450418",
        "request_id": "requestcd1127",
        "sender": "saarthibajajvinay555"+str(TestCaseNo)+str(num),
        "message": "please call me back later"
    })
    response = requests.request("POST", botEndPoint, headers=headers, data=payload).json()


    headers = {'Content-Type':'application/json'}    
    payload = json.dumps ({
        "user_id": "6305450418",
        "request_id": "requestcd1127",
        "sender": "saarthibajajvinay555"+str(TestCaseNo)+str(num),
        "message": "please call after 20 days"
    })
    response = requests.request("POST", botEndPoint, headers=headers, data=payload).json()


    headers = {'Content-Type':'application/json'}    
    payload = json.dumps ({
        "user_id": "6305450418",
        "request_id": "requestcd1127",
        "sender": "saarthibajajvinay555"+str(TestCaseNo)+str(num),
        "message": Message
    })
    response = requests.request("POST", botEndPoint, headers=headers, data=payload).json()




    i = response["data"]

    for dicts in i:
        lastResponse = dicts["text"]
        print(lastResponse,"\t", end=' ')




    disposition = response["custom"]["disposition_id"]
    status = response["custom"]["status"]  

    print(disposition,'\t',status)
    
    
    
    
    
    
    
def no_message_Threshold(TestCaseNo = None,Message = None):


    headers = {'Content-Type':'application/json'}    
    payload = json.dumps ({
        "user_id": "6305450418",
        "request_id": "requestcd1127",
        "sender": "saarthibajajvinay555"+str(TestCaseNo)+str(num),
        "message": Message
    })
    response = requests.request("POST", botEndPoint, headers=headers, data=payload).json()


    headers = {'Content-Type':'application/json'}    
    payload = json.dumps ({
        "user_id": "6305450418",
        "request_id": "requestcd1127",
        "sender": "saarthibajajvinay555"+str(TestCaseNo)+str(num),
        "message": Message
    })
    response = requests.request("POST", botEndPoint, headers=headers, data=payload).json()


    headers = {'Content-Type':'application/json'}    
    payload = json.dumps ({
        "user_id": "6305450418",
        "request_id": "requestcd1127",
        "sender": "saarthibajajvinay555"+str(TestCaseNo)+str(num),
        "message": Message
    })
    response = requests.request("POST", botEndPoint, headers=headers, data=payload).json()




    i = response["data"]

    for dicts in i:
        lastResponse = dicts["text"]
        print(lastResponse,"\t", end=' ')




    disposition = response["custom"]["disposition_id"]
    status = response["custom"]["status"]  

    print(disposition,'\t',status)

# %%
#functions(tweaked)


def LC(TestCaseNo = None,Message = None):



    headers = {'Content-Type':'application/json'}    
    payload = json.dumps ({
        "user_id": "6305450418",
        "request_id": "requestcd1127",
        "sender": "saarthibajajvinay555"+str(TestCaseNo)+str(num),
        "message": Message
    })
    response = requests.request("POST", botEndPoint, headers=headers, data=payload).json()




    i = response["data"]

    for dicts in i:
        lastResponse = dicts["text"]
        print(lastResponse,"\t", end=' ')




    disposition = response["custom"]["disposition_id"]
    status = response["custom"]["status"]  

    print(disposition,'\t',status)
    
    
    
    
    
    
def LC_2(TestCaseNo = None,Message = None):


    headers = {'Content-Type':'application/json'}    
    payload = json.dumps ({
        "user_id": "6305450418",
        "request_id": "requestcd1127",
        "sender": "saarthibajajvinay555"+str(TestCaseNo)+str(num),
        "message": "can you speak any other languages"
    })
    response = requests.request("POST", botEndPoint, headers=headers, data=payload).json()



    headers = {'Content-Type':'application/json'}    
    payload = json.dumps ({
        "user_id": "6305450418",
        "request_id": "requestcd1127",
        "sender": "saarthibajajvinay555"+str(TestCaseNo)+str(num),
        "message": Message
    })
    response = requests.request("POST", botEndPoint, headers=headers, data=payload).json()




    i = response["data"]

    for dicts in i:
        lastResponse = dicts["text"]
        print(lastResponse,"\t", end=' ')




    disposition = response["custom"]["disposition_id"]
    status = response["custom"]["status"]  

    print(disposition,'\t',status)
    
    
    
    
    
    
    
def RPN(TestCaseNo = None,Message = None):


    headers = {'Content-Type':'application/json'}    
    payload = json.dumps ({
        "user_id": "6305450418",
        "request_id": "requestcd1127",
        "sender": "saarthibajajvinay555"+str(TestCaseNo)+str(num),
        "message": "he is currently not here"
    })
    response = requests.request("POST", botEndPoint, headers=headers, data=payload).json()


    headers = {'Content-Type':'application/json'}    
    payload = json.dumps ({
        "user_id": "6305450418",
        "request_id": "requestcd1127",
        "sender": "saarthibajajvinay555"+str(TestCaseNo)+str(num),
        "message": "please call him after 20 days"
    })
    response = requests.request("POST", botEndPoint, headers=headers, data=payload).json()


    headers = {'Content-Type':'application/json'}    
    payload = json.dumps ({
        "user_id": "6305450418",
        "request_id": "requestcd1127",
        "sender": "saarthibajajvinay555"+str(TestCaseNo)+str(num),
        "message": Message
    })
    response = requests.request("POST", botEndPoint, headers=headers, data=payload).json()




    i = response["data"]

    for dicts in i:
        lastResponse = dicts["text"]
        print(lastResponse,"\t", end=' ')




    disposition = response["custom"]["disposition_id"]
    status = response["custom"]["status"]  

    print(disposition,'\t',status)
    
    
    
    
    
    

def CBN(TestCaseNo = None,Message = None):


    headers = {'Content-Type':'application/json'}    
    payload = json.dumps ({
        "user_id": "6305450418",
        "request_id": "requestcd1127",
        "sender": "saarthibajajvinay555"+str(TestCaseNo)+str(num),
        "message": "please call me back later"
    })
    response = requests.request("POST", botEndPoint, headers=headers, data=payload).json()


    headers = {'Content-Type':'application/json'}    
    payload = json.dumps ({
        "user_id": "6305450418",
        "request_id": "requestcd1127",
        "sender": "saarthibajajvinay555"+str(TestCaseNo)+str(num),
        "message": "please call after 20 days"
    })
    response = requests.request("POST", botEndPoint, headers=headers, data=payload).json()


    headers = {'Content-Type':'application/json'}    
    payload = json.dumps ({
        "user_id": "6305450418",
        "request_id": "requestcd1127",
        "sender": "saarthibajajvinay555"+str(TestCaseNo)+str(num),
        "message": Message
    })
    response = requests.request("POST", botEndPoint, headers=headers, data=payload).json()




    i = response["data"]

    for dicts in i:
        lastResponse = dicts["text"]
        print(lastResponse,"\t", end=' ')




    disposition = response["custom"]["disposition_id"]
    status = response["custom"]["status"]  

    print(disposition,'\t',status)
    
    
    
    
    
    
    
def no_message_Threshold(TestCaseNo = None,Message = None):


    headers = {'Content-Type':'application/json'}    
    payload = json.dumps ({
        "user_id": "6305450418",
        "request_id": "requestcd1127",
        "sender": "saarthibajajvinay555"+str(TestCaseNo)+str(num),
        "message": Message
    })
    response = requests.request("POST", botEndPoint, headers=headers, data=payload).json()


    headers = {'Content-Type':'application/json'}    
    payload = json.dumps ({
        "user_id": "6305450418",
        "request_id": "requestcd1127",
        "sender": "saarthibajajvinay555"+str(TestCaseNo)+str(num),
        "message": Message
    })
    response = requests.request("POST", botEndPoint, headers=headers, data=payload).json()


    headers = {'Content-Type':'application/json'}    
    payload = json.dumps ({
        "user_id": "6305450418",
        "request_id": "requestcd1127",
        "sender": "saarthibajajvinay555"+str(TestCaseNo)+str(num),
        "message": Message
    })
    response = requests.request("POST", botEndPoint, headers=headers, data=payload).json()




    i = response["data"]

    for dicts in i:
        lastResponse = dicts["text"]
        print(lastResponse,"\t", end=' ')




    disposition = response["custom"]["disposition_id"]
    status = response["custom"]["status"]  

    print(disposition,'\t',status)

# %%
#RPC_SLOT (run this block to check testset in RPC slot)

num = random.random()

with open(dataCSV, 'r') as f:
    reader = csv.reader(f)
    the_whole_file = list(reader)    
    
count = 0
while(count < len(the_whole_file)):
    count = count + 1
    TestCaseNo = the_whole_file[count][0]
    Message = the_whole_file[count][4]
    Category = the_whole_file[count][2]
    
    #print(TestCaseNo)
    #print(Message)
    #print(Category)
    #print(num)
    
    
    headers = {'Content-Type':'application/json'}    
    payload = json.dumps ({
        "user_id": "6305450418",
        "request_id": "requestcd1127",
        "sender": "saarthibajajvinay555"+str(TestCaseNo)+str(num),
        "message": "/initial_message"
    })
    response = requests.request("POST", botEndPoint, headers=headers, data=payload).json()
    
    
    if Category == "LC_2":
        try:

            LC_2(TestCaseNo,Message)
            time.sleep(0.5)

        except Exception as e:
            print(e)
            
            
            
            
    elif Category == "RPN":
        try:

            RPN(TestCaseNo,Message)
            time.sleep(0.5)

        except Exception as e:
            print(e)

            
            
    elif Category == "CBN":
        try:

            CBN(TestCaseNo,Message)
            time.sleep(0.5)

        except Exception as e:
            print(e)
            
            
            
    elif Category == ["no_message_Threshold", "wait_Threshold"]:
        try:

            no_message_Threshold(TestCaseNo,Message)
            time.sleep(0.5)

        except Exception as e:
            print(e)
            
            
            
    else:
        try:

            LC(TestCaseNo,Message)
            time.sleep(0.5)

        except Exception as e:
            print(e)
# Out:
# हेलो, क्या मेरी बात vinay सर से हो रही है?  	 ['General - Language Change - Supported', 'Initial'] 	 702
# Please confirm the language of your preference. I can only speak hindi english . 	 ['General - Language Change - Without Language'] 	 702
# Please confirm the language of your preference. I can only speak hindi english . 	 ['General - Language Change - Without Language'] 	 702
# Hello, am I speaking to vinay sir? 	 ['General - Language Change - Supported', 'Initial'] 	 702
# हेलो, क्या मेरी बात vinay सर से हो रही है?  	 ['General - Language Change - Supported', 'Initial'] 	 702
# Please confirm the language of your preference. I can only speak hindi english . 	 ['General - Language Change - Without Language'] 	 702
# Please confirm the language of your preference. I can only speak hindi english . 	 ['General - Language Change - Without Language'] 	 702
# Hello, am I speaking to vinay sir? 	 ['General - Language Change - Supported', 'Initial'] 	 702
# ...

# %%
#PIC_SLOT (run this block to check testset in PIC slot)

num = random.random()

with open(dataCSV, 'r') as f:
    reader = csv.reader(f)
    the_whole_file = list(reader)    
    
count = 0
while(count < len(the_whole_file)):
    count = count + 1
    TestCaseNo = the_whole_file[count][0]
    Message = the_whole_file[count][4]
    Category = the_whole_file[count][2]
    
    #print(TestCaseNo)
    #print(Message)
    #print(Category)
    #print(num)
    
    
    headers = {'Content-Type':'application/json'}    
    payload = json.dumps ({
        "user_id": "6305450418",
        "request_id": "requestcd1127",
        "sender": "saarthibajajvinay555"+str(TestCaseNo)+str(num),
        "message": "/initial_message"
    })
    response = requests.request("POST", botEndPoint, headers=headers, data=payload).json()
    
    
    
    headers = {'Content-Type':'application/json'}    
    payload = json.dumps ({
        "user_id": "6305450418",
        "request_id": "requestcd1127",
        "sender": "saarthibajajvinay555"+str(TestCaseNo)+str(num),
        "message": "yes"
    })
    response = requests.request("POST", botEndPoint, headers=headers, data=payload).json()
    
    
    
    
    if Category == "LC_2":
        try:

            LC_2(TestCaseNo,Message)
            time.sleep(0.5)

        except Exception as e:
            print(e)
            
            
            
            
    elif Category == "RPN":
        try:

            RPN(TestCaseNo,Message)
            time.sleep(0.5)

        except Exception as e:
            print(e)

            
            
    elif Category == "CBN":
        try:

            CBN(TestCaseNo,Message)
            time.sleep(0.5)

        except Exception as e:
            print(e)
            
            
            
    elif Category == "no_message_Threshold":
        try:

            no_message_Threshold(TestCaseNo,Message)
            time.sleep(0.5)

        except Exception as e:
            print(e)
            
            
            
    else:
        try:

            LC(TestCaseNo,Message)
            time.sleep(0.5)

        except Exception as e:
            print(e)

# %%
#COUNSELLING_SLOT (run this block to check testset in COUNSELLING slot)

num = random.random()

with open(dataCSV, 'r') as f:
    reader = csv.reader(f)
    the_whole_file = list(reader)    
    
count = 0
while(count < len(the_whole_file)):
    count = count + 1
    TestCaseNo = the_whole_file[count][0]
    Message = the_whole_file[count][4]
    Category = the_whole_file[count][2]
    
    #print(TestCaseNo)
    #print(Message)
    #print(Category)
    #print(num)
    
    
    headers = {'Content-Type':'application/json'}    
    payload = json.dumps ({
        "user_id": "6305450418",
        "request_id": "requestcd1127",
        "sender": "saarthibajajvinay555"+str(TestCaseNo)+str(num),
        "message": "/initial_message"
    })
    response = requests.request("POST", botEndPoint, headers=headers, data=payload).json()
    
    
    
    headers = {'Content-Type':'application/json'}    
    payload = json.dumps ({
        "user_id": "6305450418",
        "request_id": "requestcd1127",
        "sender": "saarthibajajvinay555"+str(TestCaseNo)+str(num),
        "message": "yes"
    })
    response = requests.request("POST", botEndPoint, headers=headers, data=payload).json()
    
    
    
    headers = {'Content-Type':'application/json'}    
    payload = json.dumps ({
        "user_id": "6305450418",
        "request_id": "requestcd1127",
        "sender": "saarthibajajvinay555"+str(TestCaseNo)+str(num),
        "message": "i wont do the payment"
    })
    response = requests.request("POST", botEndPoint, headers=headers, data=payload).json()
    
    
    
    
    if Category == "LC_2":
        try:

            LC_2(TestCaseNo,Message)
            time.sleep(0.5)

        except Exception as e:
            print(e)
            
            
            
            
    elif Category == "RPN":
        try:

            RPN(TestCaseNo,Message)
            time.sleep(0.5)

        except Exception as e:
            print(e)

            
            
    elif Category == "CBN":
        try:

            CBN(TestCaseNo,Message)
            time.sleep(0.5)

        except Exception as e:
            print(e)
            
            
            
    elif Category == "no_message_Threshold":
        try:

            no_message_Threshold(TestCaseNo,Message)
            time.sleep(0.5)

        except Exception as e:
            print(e)
            
            
            
    else:
        try:

            LC(TestCaseNo,Message)
            time.sleep(0.5)

        except Exception as e:
            print(e)

# %%
#ASK_DELAY_SLOT (run this block to check testset in ASK_DELAY slot)

num = random.random()

with open(dataCSV, 'r') as f:
    reader = csv.reader(f)
    the_whole_file = list(reader)    
    
count = 0
while(count < len(the_whole_file)):
    count = count + 1
    TestCaseNo = the_whole_file[count][0]
    Message = the_whole_file[count][4]
    Category = the_whole_file[count][2]
    
    #print(TestCaseNo)
    #print(Message)
    #print(Category)
    #print(num)
    
    
    headers = {'Content-Type':'application/json'}    
    payload = json.dumps ({
        "user_id": "6305450418",
        "request_id": "requestcd1127",
        "sender": "saarthibajajvinay555"+str(TestCaseNo)+str(num),
        "message": "/initial_message"
    })
    response = requests.request("POST", botEndPoint, headers=headers, data=payload).json()
    
    
    
    headers = {'Content-Type':'application/json'}    
    payload = json.dumps ({
        "user_id": "6305450418",
        "request_id": "requestcd1127",
        "sender": "saarthibajajvinay555"+str(TestCaseNo)+str(num),
        "message": "yes"
    })
    response = requests.request("POST", botEndPoint, headers=headers, data=payload).json()
    
    
    
    headers = {'Content-Type':'application/json'}    
    payload = json.dumps ({
        "user_id": "6305450418",
        "request_id": "requestcd1127",
        "sender": "saarthibajajvinay555"+str(TestCaseNo)+str(num),
        "message": "i dont want to pay"
    })
    response = requests.request("POST", botEndPoint, headers=headers, data=payload).json()
    
    
    
    headers = {'Content-Type':'application/json'}    
    payload = json.dumps ({
        "user_id": "6305450418",
        "request_id": "requestcd1127",
        "sender": "saarthibajajvinay555"+str(TestCaseNo)+str(num),
        "message": "i dont want to pay"
    })
    response = requests.request("POST", botEndPoint, headers=headers, data=payload).json()    
    
    
    if Category == "LC_2":
        try:

            LC_2(TestCaseNo,Message)
            time.sleep(0.5)

        except Exception as e:
            print(e)
            
            
            
            
    elif Category == "RPN":
        try:

            RPN(TestCaseNo,Message)
            time.sleep(0.5)

        except Exception as e:
            print(e)

            
            
    elif Category == "CBN":
        try:

            CBN(TestCaseNo,Message)
            time.sleep(0.5)

        except Exception as e:
            print(e)
            
            
            
    elif Category == "no_message_Threshold":
        try:

            no_message_Threshold(TestCaseNo,Message)
            time.sleep(0.5)

        except Exception as e:
            print(e)
            
            
            
    else:
        try:

            LC(TestCaseNo,Message)
            time.sleep(0.5)

        except Exception as e:
            print(e)

# %%
#RPN__SLOT (run this block to check testset in RPN_ slot)

num = random.random()

with open(dataCSV, 'r') as f:
    reader = csv.reader(f)
    the_whole_file = list(reader)    
    
count = 0
while(count < len(the_whole_file)):
    count = count + 1
    TestCaseNo = the_whole_file[count][0]
    Message = the_whole_file[count][4]
    Category = the_whole_file[count][2]
    
    #print(TestCaseNo)
    #print(Message)
    #print(Category)
    #print(num)
    
    
    headers = {'Content-Type':'application/json'}    
    payload = json.dumps ({
        "user_id": "6305450418",
        "request_id": "requestcd1127",
        "sender": "saarthibajajvinay555"+str(TestCaseNo)+str(num),
        "message": "/initial_message"
    })
    response = requests.request("POST", botEndPoint, headers=headers, data=payload).json()
    
    
    
    headers = {'Content-Type':'application/json'}    
    payload = json.dumps ({
        "user_id": "6305450418",
        "request_id": "requestcd1127",
        "sender": "saarthibajajvinay555"+str(TestCaseNo)+str(num),
        "message": "he is not available now"
    })
    response = requests.request("POST", botEndPoint, headers=headers, data=payload).json()
    
    
    
    headers = {'Content-Type':'application/json'}    
    payload = json.dumps ({
        "user_id": "6305450418",
        "request_id": "requestcd1127",
        "sender": "saarthibajajvinay555"+str(TestCaseNo)+str(num),
        "message": "you can connect with him after an year"
    })
    response = requests.request("POST", botEndPoint, headers=headers, data=payload).json()
    
    
    
    if Category == "LC_2":
        try:

            LC_2(TestCaseNo,Message)
            time.sleep(0.5)

        except Exception as e:
            print(e)
            
            
            
            
    elif Category == "RPN":
        print("RPN cannot be checked again within RPN")

            
            
    elif Category == "CBN":
        print("CBN cannot be checked again within RPN")
        
            
            
    elif Category == "no_message_Threshold":
        try:

            no_message_Threshold(TestCaseNo,Message)
            time.sleep(0.5)

        except Exception as e:
            print(e)
            
            
            
    else:
        try:

            LC(TestCaseNo,Message)
            time.sleep(0.5)

        except Exception as e:
            print(e)

# %%
#CBN__SLOT (run this block to check testset in CBN_ slot)

num = random.random()

with open(dataCSV, 'r') as f:
    reader = csv.reader(f)
    the_whole_file = list(reader)    
    
count = 0
while(count < len(the_whole_file)):
    count = count + 1
    TestCaseNo = the_whole_file[count][0]
    Message = the_whole_file[count][4]
    Category = the_whole_file[count][2]
    
    #print(TestCaseNo)
    #print(Message)
    #print(Category)
    #print(num)
    
    
    headers = {'Content-Type':'application/json'}    
    payload = json.dumps ({
        "user_id": "6305450418",
        "request_id": "requestcd1127",
        "sender": "saarthibajajvinay555"+str(TestCaseNo)+str(num),
        "message": "/initial_message"
    })
    response = requests.request("POST", botEndPoint, headers=headers, data=payload).json()
    
    
    
    headers = {'Content-Type':'application/json'}    
    payload = json.dumps ({
        "user_id": "6305450418",
        "request_id": "requestcd1127",
        "sender": "saarthibajajvinay555"+str(TestCaseNo)+str(num),
        "message": "i am busy, call me later"
    })
    response = requests.request("POST", botEndPoint, headers=headers, data=payload).json()
    
    
    
    headers = {'Content-Type':'application/json'}    
    payload = json.dumps ({
        "user_id": "6305450418",
        "request_id": "requestcd1127",
        "sender": "saarthibajajvinay555"+str(TestCaseNo)+str(num),
        "message": "you can call me after an year"
    })
    response = requests.request("POST", botEndPoint, headers=headers, data=payload).json()
    
    
    
    if Category == "LC_2":
        try:

            LC_2(TestCaseNo,Message)
            time.sleep(0.5)

        except Exception as e:
            print(e)
            
            
            
            
    elif Category == "RPN":
        print("RPN cannot be checked again within CBN")

            
            
    elif Category == "CBN":
        print("CBN cannot be checked again within CBN")
        
            
            
    elif Category == "no_message_Threshold":
        try:

            no_message_Threshold(TestCaseNo,Message)
            time.sleep(0.5)

        except Exception as e:
            print(e)
            
            
            
    else:
        try:

            LC(TestCaseNo,Message)
            time.sleep(0.5)

        except Exception as e:
            print(e)
# Out:
# [Errno Expecting value] Internal Server Error: 0
# [Errno Expecting value] Internal Server Error: 0
# [Errno Expecting value] Internal Server Error: 0
# [Errno Expecting value] Internal Server Error: 0
# [Errno Expecting value] Internal Server Error: 0
# [Errno Expecting value] Internal Server Error: 0
# [Errno Expecting value] Internal Server Error: 0
# [Errno Expecting value] Internal Server Error: 0
# RPN cannot be checked again within CBN
# RPN cannot be checked again within CBN
# RPN cannot be checked again within CBN
# RPN cannot be checked again within CBN
# CBN cannot be checked again within CBN
# CBN cannot be checked again within CBN
# CBN cannot be checked again within CBN
# CBN cannot be checked again within CBN
# [Errno Expecting value] Internal Server Error: 0
# [Errno Expecting value] Internal Server Error: 0
# [Errno Expecting value] Internal Server Error: 0
# [Errno Expecting value] Internal Server Error: 0
# [Errno Expecting value] Internal Server Error: 0
# ...

# %% [markdown]
# # Rough

# %%
import pandas as pd

df = pd.DataFrame()



num = random.random()
TestCaseNo = 1
Message = "i will pay today"

headers = {'Content-Type':'application/json'}    
payload = json.dumps ({
    "user_id": "6305450418",
    "request_id": "requestcd1127",
    "sender": "saarthibajajvinay555"+str(TestCaseNo)+str(num),
    "message": "/initial_message"
})
response = requests.request("POST", botEndPoint, headers=headers, data=payload).json()


headers = {'Content-Type':'application/json'}    
payload = json.dumps ({
    "user_id": "6305450418",
    "request_id": "requestcd1127",
    "sender": "saarthibajajvinay555"+str(TestCaseNo)+str(num),
    "message": "yes"
})
response = requests.request("POST", botEndPoint, headers=headers, data=payload).json()


headers = {'Content-Type':'application/json'}    
payload = json.dumps ({
    "user_id": "6305450418",
    "request_id": "requestcd1127",
    "sender": "saarthibajajvinay555"+str(TestCaseNo)+str(num),
    "message": Message
})
response = requests.request("POST", botEndPoint, headers=headers, data=payload).json()


def final_data(response):
    text_list = []
    response_1 = ["-"]
    response_2 = ["-"]
    #response_3 = ["-"]
    disposotion_list = []
    staus_list = []

    temp_status = response["custom"]["status"]
    temp_disp = response["custom"]["disposition_id"]
    temp_disp = ",".join(temp_disp)     #its like a text combining method with given delimeter

    val = response["data"]
    for i in range(0,len(val)):    
          temp_text = response["data"][i]["text"]
          text_list.append(temp_text)

    for i in range(0,len(text_list)):
        if i == 0:
            response_1 = [text_list[i]]
        if i == 1:
            response_2 = [text_list[i]]
        # if i == 2:
        #     response_3 = [text_list[i]]
        
    return response_1,response_2, [temp_disp], [temp_status]

final_response_1 = final_response_2 = final_disposition = final_status = []
response_1, response_2, disposition, status = final_data(response)

final_response_1.extend(response_1)
final_response_2.extend(response_2)
final_response_1.extend(response_1)
final_response_1.extend(response_1)
print(response_1, response_2, disposition, status)

# a = ["1"]
# b= ["2"]

# c = a.append(b) = ["1",["2"]]
# d = a.extend(b) = a+b = ["1","2"]




#print("vds",response_2)
df["response_1"] = response_1
df["response_2"] = response_2
#df["response_3"] = response_3
df["disposition"] = disposition
df["status"] = status



# df.to_csv("Temp.csv",index=False)

df.head(5)
# Out:
# ['Great. You can make the payment via online,agent,upi,card,wallet,branch,app , Thank you.'] ['-'] ['APTP'] [701]
#                                           response_1 response_2 disposition  \
# 0  Great. You can make the payment via online,age...          -        APTP
#
#    status
# 0     701

# %%
response_1=response_2=disposition=status = []


    RPC = pd.DataFrame()


    num = random.random()

    with open(dataCSV, 'r') as f:
        reader = csv.reader(f)
        the_whole_file = list(reader)    

    count = 0
    while(count < 6):
        count = count + 1
        TestCaseNo = the_whole_file[count][0]
        Message = the_whole_file[count][4]
        Category = the_whole_file[count][2]

        #print(TestCaseNo)
        #print(Message)
        #print(Category)
        #print(num)

        headers = {'Content-Type':'application/json'}    
        payload = json.dumps ({
            "user_id": "6305450418",
            "request_id": "requestcd1127",
            "sender": "saarthibajajvinay555"+str(TestCaseNo)+str(num),
            "message": "/initial_message"
        })
        response = requests.request("POST", botEndPoint, headers=headers, data=payload).json()


        headers = {'Content-Type':'application/json'}    
        payload = json.dumps ({
            "user_id": "6305450418",
            "request_id": "requestcd1127",
            "sender": "saarthibajajvinay555"+str(TestCaseNo)+str(num),
            "message": "yes"
        })
        response = requests.request("POST", botEndPoint, headers=headers, data=payload).json()


        headers = {'Content-Type':'application/json'}    
        payload = json.dumps ({
            "user_id": "6305450418",
            "request_id": "requestcd1127",
            "sender": "saarthibajajvinay555"+str(TestCaseNo)+str(num),
            "message": Message
        })
        response = requests.request("POST", botEndPoint, headers=headers, data=payload).json()



        text_list = []
        response_1 = ["-"]
        response_2 = ["-"]
        disposition_list = []
        status_list = []



        temp_status = response["custom"]["status"]
        temp_disp = response["custom"]["disposition_id"]
        temp_disp = ",".join(temp_disp)     #its like a text combining method with given delimeter



        val = response["data"]
        for i in range(0,len(val)):    
              temp_text = response["data"][i]["text"]
              text_list.append(temp_text)



        for i in range(0,len(text_list)):
            if i == 0:
                Response_1 = [text_list[i]]
            if i == 1:
                Response_2 = [text_list[i]]



        RPC["response_1"] = response_1.append(Response_1)
        RPC["response_2"] = response_2.append(Response_1)
        RPC["disposition"] = disposition_list.append([temp_disp])
        RPC["status"] = status_list.append([temp_status])



        RPC.to_csv(RPC_Sheet, index=False)


    RPC.head(2)
# Out:
# Empty DataFrame
# Columns: [response_1, response_2, disposition, status]
# Index: []

# %%
with open(dataCSV, 'r') as f:
    reader = csv.reader(f)
    the_whole_file = list(reader)
    print(len(the_whole_file))
# Out:
# 123
