# %%
#import the required dependencies

import requests
import json
import pandas as pd
from pprint import pprint
import csv
import time
import random
import datetime
import re

print("all required dependencies are imported successfully")
# Out:
# all required dependencies are imported successfully

# %%
#update the testset and final sheet's path. then run the block


language = "Marathi"

dataCSV = "/Users/vinay_kl/Downloads/QA _ PoliticalEdge - BOT_Testset (2).csv"

#stellantis
# botEndPoint = "https://poojafin.saarthi.ai/stellantis_english/webhook"
#PoliticalEdge
botEndPoint = "https://stage-threebot.saarthi.ai/politics_marathi/webhook"

v = datetime.datetime.now()
#print(v)

#pattern = '\d{4}-\d{2}-\d{2} (\d{2}:\d{2}:\d{2})\.\d{6}'
pattern = "[\d]+-[\d]+-[\d]+ ([\d]+:[\d]+:[\d]+)\.[\d]+"

required = re.findall(pattern,str(v))
#print(required)


#---------------------------------------------------------------------------------------#


Final_Sheet = "/Users/vinay_kl/Downloads/Final_Sheet_Stellantis_"+str(language)+"_"+str(required)+".csv"

print(Final_Sheet)

print("testset and final_sheet is pushed to respective variables")
# Out:
# /Users/vinay_kl/Downloads/Final_Sheet_Stellantis_Marathi_['20:50:38'].csv
# testset and final_sheet is pushed to respective variables

# %%
#functions



def BOT_FUNCTION(Final_T_NO = None,Final_Utterance = None,Flow = None,GRT = None,BRT = None):
    headers = {'Content-Type':'application/json'}    
    payload = json.dumps ({
    "user_id": "9482152447",
    "request_id": "request11j27",
    "sender": "tej-247657989"+str(Final_T_NO)+str(num),
    "message": Final_Utterance,
    "customerData": {
        "callId": "12345",
        "bargingCall": "True",
        "accessToken": "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VySWQiOiI2NDUwYjkyN2YzZGZlYzMyMDIxNDgxMzciLCJhY2NvdW50SWQiOiI2NDUwYjkyNmYzZGZlYzMyMDIxNDgxMmUiLCJyb2xlIjoiQWRtaW4iLCJpYXQiOjE2ODM1NDM5NDAsImV4cCI6MTY4MzYzMDM0MH0.slLTPbIA92IDfsZUJKR0rxFnVgDi7M5mtDLaWDmlJsc",
        "clientName": "Stellantis Testing",
        "callType": "Internal UAT",
        "telephonyName": "Epicode",
        "customerInfo": {
            "contactInfo": {
                "primary": "9354069780",
                "customerSupportNumber": "4233423434",
                "customerCareNumber": ""
            },
            "primaryInfo": {
                "firstName": "Tester",
                "vehicleIdentificationNumber": "KA20DI3857",
                "sellingDealerName": "Saarthi motors",
                "geographicLocation": "Bengaluru",
                "pincode": "500007",
                "lastServiceDealerCity": "Bengaluru",
                "lastServiceDealerName": "MJ Automobiles",
                "preferredAgentGender": "M",
                "agentname": "Stella",
                "serviceDueDate": "2023-06-18",
                "captured_date": "2023-05-25",
                "serviceNetworkName": "Jeep Salesforce Network",
                "flow": Flow,
                "status": "Appointment Confirmed",
                "channel": "Voice",
                "utter_sub_flow_slot": "main_flow",
                "generalRepeatThreshold": GRT,
                "businessIntentThreshold": BRT,
                "previousDisposition": "Campaign End",
                "language": "English",
                "age": "",
                "gender": "",
                "region": "",
                "collared": "",
                "customerUniqueId": ""
            },
            "loanAccountDetails": {
                "emiAmount": "",
                "emiDueDate": "",
                "loanApplicationDate": "",
                "loanEndingDate": "",
                "lateFee": "",
                "interestRate": "",
                "nextNachDate": "",
                "paidDate": "",
                "currentPaymentStatus": "",
                "noofemi": "",
                "noOfEmiPaid": "",
                "loanTenureLeft": "",
                "loanAmountRemaining": "",
                "loanStartDate": "",
                "principalAmount": "",
                "totalLoanAmount": "",
                "loanCategory": "",
                "loanId": "",
                "noOfLoans": "",
                "paymentMode": "",
                "cbCharges": "0",
                "penalCharges": "0"
            },
            "behaviourDetails": {
                "riskType": "",
                "typology": "",
                "callDisposition": ""
            },
            "email": {
                "primary": ""
            },
            "leadType": "Transactional"
        },
        "callingPartner": "epicode",
        "campaignId": "2345",
        "agentConfig": {
            "parentFlow": [
                {
                    "flow": "appointment_booking_flow",
                    "isParent": True,
                    "isChild": False,
                    "channel": [
                        "Call"
                    ],
                    "type": "Female",
                    "language": [
                        "English"
                    ],
                    "Call": {
                        "voice": "Saarthi TTS",
                        "thresholdDateCallBack": 2,
                        "thresholdTimeCallBack": 30
                    }
                }
            ],
            "callFlow": [
                {
                    "appointment_booking_flow": {
                        "slot1": [
                            {
                                "initial": {
                                    "label": "lg_rpc_form",
                                    "next": "subSlot1"
                                },
                                "subSlot1": [
                                    {
                                        "third_party_contact": {
                                            "initial": [
                                                {
                                                    "label": "third_party_contact_form",
                                                    "next": "subSlot1"
                                                }
                                            ],
                                            "subSlot1": [
                                                {
                                                    "label": "stop_conversation"
                                                }
                                            ]
                                        },
                                        "call_back": {
                                            "initial": [
                                                {
                                                    "label": "call_back_form",
                                                    "next": "subSlot1"
                                                }
                                            ],
                                            "subSlot1": [
                                                {
                                                    "label": "stop_conversation"
                                                }
                                            ]
                                        },
                                        "small_talk": {
                                            "initial": [
                                                {
                                                    "label": "small_talk_form",
                                                    "next": "subSlot1"
                                                }
                                            ],
                                            "subSlot1": [
                                                {
                                                    "label": "stop_conversation"
                                                }
                                            ]
                                        }
                                    }
                                ]
                            }
                        ],
                        "slot2": [
                            {
                                "label": "date_confirmation_form",
                                "next": "slot3"
                            }
                        ],
                        "slot3": [
                            {
                                "not_interested": {
                                    "initial": [
                                        {
                                            "label": "not_interested_form",
                                            "next": "subSlot1"
                                        }
                                    ],
                                    "subSlot1": [
                                        {
                                            "label": "stop_conversation"
                                        }
                                    ]
                                },
                                "interested_later": {
                                    "initial": [
                                        {
                                            "label": "interested_later_form",
                                            "next": "subSlot1"
                                        }
                                    ],
                                    "subSlot1": [
                                        {
                                            "label": "stop_conversation"
                                        }
                                    ]
                                },
                                "call_back": {
                                    "initial": [
                                        {
                                            "label": "call_back_form",
                                            "next": "subSlot1"
                                        }
                                    ],
                                    "subSlot1": [
                                        {
                                            "label": "stop_conversation"
                                        }
                                    ]
                                },
                                "date_capture": {
                                    "initial": [
                                        {
                                            "label": "date_capture_form",
                                            "next": "subSlot1"
                                        }
                                    ],
                                    "subSlot1": [
                                        {
                                            "dealership_capture": {
                                                "initial": [
                                                    {
                                                        "label": "dealership_capture_form",
                                                        "next": "sub1Slot1"
                                                    }
                                                ],
                                                "sub1Slot1": [
                                                    {
                                                        "deny": {
                                                            "initial": [
                                                                {
                                                                    "label": "deny_dealership_form",
                                                                    "next": "sub2Slot1"
                                                                }
                                                            ],
                                                            "sub2Slot1": [
                                                                {
                                                                    "label": "stop_conversation"
                                                                }
                                                            ]
                                                        },
                                                        "affirm": {
                                                            "initial": [
                                                                {
                                                                    "label": "pickup_drop_capture_form",
                                                                    "next": "sub2Slot1"
                                                                }
                                                            ],
                                                            "sub2Slot1": [
                                                                {
                                                                    "label": "stop_conversation"
                                                                }
                                                            ]
                                                        }
                                                    }
                                                ]
                                            }
                                        }
                                    ]
                                },
                                "dealership_capture": {
                                    "initial": [
                                        {
                                            "label": "dealership_capture_form",
                                            "next": "sub1Slot1"
                                        }
                                    ],
                                    "sub1Slot1": [
                                        {
                                            "deny": {
                                                "initial": [
                                                    {
                                                        "label": "deny_dealership_form",
                                                        "next": "sub2Slot1"
                                                    }
                                                ],
                                                "sub2Slot1": [
                                                    {
                                                        "label": "stop_conversation"
                                                    }
                                                ]
                                            },
                                            "affirm": {
                                                "initial": [
                                                    {
                                                        "label": "pickup_drop_capture_form",
                                                        "next": "sub2Slot1"
                                                    }
                                                ],
                                                "sub2Slot1": [
                                                    {
                                                        "label": "stop_conversation"
                                                    }
                                                ]
                                            }
                                        }
                                    ]
                                }
                            }
                        ]
                    },
                    "follow_up_flow": {
                        "slot1": [
                            {
                                "initial": {
                                    "label": "lg_rpc_form",
                                    "next": "subSlot1"
                                },
                                "subSlot1": [
                                    {
                                        "third_party_contact": {
                                            "initial": [
                                                {
                                                    "label": "third_party_contact_form",
                                                    "next": "subSlot1"
                                                }
                                            ],
                                            "subSlot1": [
                                                {
                                                    "label": "stop_conversation"
                                                }
                                            ]
                                        },
                                        "call_back": {
                                            "initial": [
                                                {
                                                    "label": "call_back_form",
                                                    "next": "subSlot1"
                                                }
                                            ],
                                            "subSlot1": [
                                                {
                                                    "label": "stop_conversation"
                                                }
                                            ]
                                        },
                                        "small_talk": {
                                            "initial": [
                                                {
                                                    "label": "small_talk_form",
                                                    "next": "subSlot1"
                                                }
                                            ],
                                            "subSlot1": [
                                                {
                                                    "label": "stop_conversation"
                                                }
                                            ]
                                        }
                                    }
                                ]
                            }
                        ],
                        "slot2": [
                            {
                                "label": "followup_dealership_capture_form",
                                "next": "slot3"
                            }
                        ],
                        "slot3": [
                            {
                                "not_interested": {
                                    "initial": [
                                        {
                                            "label": "not_interested_form",
                                            "next": "subSlot1"
                                        }
                                    ],
                                    "subSlot1": [
                                        {
                                            "label": "stop_conversation"
                                        }
                                    ]
                                },
                                "interested_later": {
                                    "initial": [
                                        {
                                            "label": "interested_later_form",
                                            "next": "subSlot1"
                                        }
                                    ],
                                    "subSlot1": [
                                        {
                                            "label": "stop_conversation"
                                        }
                                    ]
                                },
                                "call_back": {
                                    "initial": [
                                        {
                                            "label": "call_back_form",
                                            "next": "subSlot1"
                                        }
                                    ],
                                    "subSlot1": [
                                        {
                                            "label": "stop_conversation"
                                        }
                                    ]
                                },
                                "new_date_capture": {
                                    "initial": [
                                        {
                                            "label": "date_capture_form",
                                            "next": "subSlot1"
                                        }
                                    ],
                                    "subSlot1": [
                                        {
                                            "dealership_capture": {
                                                "initial": [
                                                    {
                                                        "label": "dealership_capture_form",
                                                        "next": "sub1Slot1"
                                                    }
                                                ],
                                                "sub1Slot1": [
                                                    {
                                                        "deny": {
                                                            "initial": [
                                                                {
                                                                    "label": "deny_dealership_form",
                                                                    "next": "sub2Slot1"
                                                                }
                                                            ],
                                                            "sub2Slot1": [
                                                                {
                                                                    "label": "stop_conversation"
                                                                }
                                                            ]
                                                        },
                                                        "affirm": {
                                                            "initial": [
                                                                {
                                                                    "label": "pickup_drop_capture_form",
                                                                    "next": "sub2Slot1"
                                                                }
                                                            ],
                                                            "sub2Slot1": [
                                                                {
                                                                    "label": "stop_conversation"
                                                                }
                                                            ]
                                                        }
                                                    }
                                                ]
                                            }
                                        }
                                    ]
                                },
                                "deny_dealership": {
                                    "initial": [
                                        {
                                            "label": "deny_dealership_form",
                                            "next": "sub2Slot1"
                                        }
                                    ],
                                    "sub2Slot1": [
                                        {
                                            "label": "stop_conversation"
                                        }
                                    ]
                                },
                                "pickup_drop_capture": {
                                    "initial": [
                                        {
                                            "label": "pickup_drop_capture_form",
                                            "next": "sub2Slot1"
                                        }
                                    ],
                                    "sub2Slot1": [
                                        {
                                            "label": "stop_conversation"
                                        }
                                    ]
                                }
                            }
                        ]
                    },
                    "remainder_flow": {
                        "slot1": [
                            {
                                "initial": {
                                    "label": "lg_rpc_form",
                                    "next": "subSlot1"
                                },
                                "subSlot1": [
                                    {
                                        "third_party_contact": {
                                            "initial": [
                                                {
                                                    "label": "third_party_contact_form",
                                                    "next": "subSlot1"
                                                }
                                            ],
                                            "subSlot1": [
                                                {
                                                    "label": "stop_conversation"
                                                }
                                            ]
                                        },
                                        "call_back": {
                                            "initial": [
                                                {
                                                    "label": "call_back_form",
                                                    "next": "subSlot1"
                                                }
                                            ],
                                            "subSlot1": [
                                                {
                                                    "label": "stop_conversation"
                                                }
                                            ]
                                        },
                                        "small_talk": {
                                            "initial": [
                                                {
                                                    "label": "small_talk_form",
                                                    "next": "subSlot1"
                                                }
                                            ],
                                            "subSlot1": [
                                                {
                                                    "label": "stop_conversation"
                                                }
                                            ]
                                        }
                                    }
                                ]
                            }
                        ],
                        "slot2": [
                            {
                                "label": "booking_confirmation_form",
                                "next": "slot3"
                            }
                        ],
                        "slot3": [
                            {
                                "interested_later": {
                                    "initial": [
                                        {
                                            "label": "interested_later_form",
                                            "next": "subSlot1"
                                        }
                                    ],
                                    "subSlot1": [
                                        {
                                            "label": "stop_conversation"
                                        }
                                    ]
                                },
                                "call_back": {
                                    "initial": [
                                        {
                                            "label": "call_back_form",
                                            "next": "subSlot1"
                                        }
                                    ],
                                    "subSlot1": [
                                        {
                                            "label": "stop_conversation"
                                        }
                                    ]
                                }
                            }
                        ]
                    },
                    "feedback_flow": {
                        "slot1": [
                            {
                                "initial": {
                                    "label": "lg_rpc_form",
                                    "next": "subSlot1"
                                },
                                "subSlot1": [
                                    {
                                        "third_party_contact": {
                                            "initial": [
                                                {
                                                    "label": "third_party_contact_form",
                                                    "next": "subSlot1"
                                                }
                                            ],
                                            "subSlot1": [
                                                {
                                                    "label": "stop_conversation"
                                                }
                                            ]
                                        },
                                        "call_back": {
                                            "initial": [
                                                {
                                                    "label": "call_back_form",
                                                    "next": "subSlot1"
                                                }
                                            ],
                                            "subSlot1": [
                                                {
                                                    "label": "stop_conversation"
                                                }
                                            ]
                                        },
                                        "small_talk": {
                                            "initial": [
                                                {
                                                    "label": "small_talk_form",
                                                    "next": "subSlot1"
                                                }
                                            ],
                                            "subSlot1": [
                                                {
                                                    "label": "stop_conversation"
                                                }
                                            ]
                                        }
                                    }
                                ]
                            }
                        ],
                        "slot2": [
                            {
                                "label": "rating_based_form",
                                "next": "slot3"
                            }
                        ],
                        "slot3": [
                            {
                                "call_back": {
                                    "initial": [
                                        {
                                            "label": "call_back_form",
                                            "next": "subSlot1"
                                        }
                                    ],
                                    "subSlot1": [
                                        {
                                            "label": "stop_conversation"
                                        }
                                    ]
                                }
                            }
                        ]
                    }
                }
            ],
            "accountId": "6450b926f3dfec320214812e",
            "agentName": "Stella",
            "domain": "Automobile",
            "subDomain": "General",
            "productType": "Four Wheeler",
            "agentId": "StellantisTesting_salesOnboarding_FourWheeler_01",
            "createdAt": "2023-05-05T06:11:54.021Z",
            "updatedAt": "2023-05-05T06:11:54.021Z",
            "id": "64549e2ac0e8415d50370c7c"
        },
        "useCaseId": "62c81c4a4a0affe91342aaaa",
        "accountId": "6450b926f3dfec320214812e",
        "isCampaignTesting": True
    }
    })
    response = requests.request("POST", botEndPoint, headers=headers, data=payload).json()

#     return(response)
    
    

# def final_data(response):
    text_list = []
    response_1 = ["-"]
    response_2 = ["-"]
    response_3 = ["-"]
    disposotion_list = []
    staus_list = []

    temp_status = response["custom"]["status"]
    temp_disp = response["custom"]["disposition_id"]
    temp_disp = ",".join(map(str, temp_disp))     #its like a text combining method with given delimeter.  map & str is added to reduce "sequence no N" error

    val = response["data"]
    for i in range(0,len(val)):    
          temp_text = response["data"][i]["text"]
          text_list.append(temp_text)

    for i in range(0,len(text_list)):
        if i == 0:
            response_1 = [text_list[i]]
        if i == 1:
            response_2 = [text_list[i]]
        if i == 2:
            response_3 = [text_list[i]]

    print(Final_T_NO, "\t", Final_Utterance, "\t", response_1, "\t", response_2, "\t", response_3, "\t", [temp_disp], "\t", [temp_status])        
    return Final_T_NO, Final_Utterance, response_1, response_2, response_3, [temp_disp], [temp_status]






print("all required functions are successfully called")
# Out:
# all required functions are successfully called

# %%
final_Tno = []
final_user_resp = []

final_response_1 = []
final_response_2 = []
final_response_3 = []
final_disposition = []
final_status = []

print("Empty lists created, --- Run next block")
# Out:
# Empty lists created, --- Run next block

# %%
num = random.random()

df = pd.read_csv(dataCSV)
df.head()


TestCase_No = df["T_N_O"]
Utterance_Coloum = df["Final_List"]
flow = df["Flow"]
grt = df["General_Intent_Threshold"]
brt = df["Business_Intent_Threshold"]


for i in range(0,len(Utterance_Coloum)):
# for i in range(885,len(Utterance_Coloum)):
    
    
    MID_T_NO = TestCase_No[i]
    Flow = flow[i]
    GRT = grt[i]
    BRT = brt[i]
    
#     print(MID_T_NO, Flow, GRT, BRT)
    
    Utterance_List = eval(Utterance_Coloum[i])
    for j in range(0,len(Utterance_List)):
        Final_Utterance = Utterance_List[j]
        Final_T_NO = MID_T_NO
#         print(Final_T_NO)
#         print(Final_Utterance)
        
                
        try:

#             response = BOT_FUNCTION(Final_T_NO,Final_Utterance)
#             print("TestCaseNo - ", Final_T_NO," Passed")
            Final_T_NO, Final_Utterance, response_1, response_2, response_3, disposition, status = BOT_FUNCTION(Final_T_NO,Final_Utterance,Flow,GRT,BRT)
          
            final_Tno.append(Final_T_NO)
            final_user_resp.append(Final_Utterance)        
            final_response_1.extend(response_1)
            final_response_2.extend(response_2)
            final_response_3.extend(response_3)            
            final_disposition.extend(disposition)
            final_status.extend(status)
            
#             time.sleep(1)

        except Exception as e:
#             print("TestCaseNo - ",Final_T_NO," failed ---> ",e)
            print(Final_T_NO, "\t", Final_Utterance, "\t", e, "\t", "error", "\t", "error", "\t", "error", "\t", "error")
    
            final_Tno.append(Final_T_NO)
            final_user_resp.append(Final_Utterance) 
            final_response_1.append(e)
            final_response_2.append("error")
            final_response_3.append("error")        
            final_disposition.append("error")
            final_status.append("error")
            
            
            
print("Testcases completed, --- Run next block")
# Out:
# 0 	 /initial_message 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 0 	 आपण हिंदी बोलू शकता? 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 1 	 /initial_message 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 1 	 मला मराठी माहित no 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 2 	 /initial_message 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 2 	 कृपया तमिळ मध्ये बोला 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 2 	 ठीक आहे हिंदी मध्ये बोला 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 3 	 /initial_message 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 3 	 कृपया बांगला मध्ये बोला 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 3 	 मला मराठी माहित no 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 4 	 /initial_message 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 4 	 कृपया ओरिया मध्ये बोला 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 4 	 ठीक आहे गुजराती मध्ये बोला 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 5 	 /initial_message 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 5 	 तुम्हीअजून कोणतीही भाषा बोलू शकता का? 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 5 	 ठीक आहे हिंदी मध्ये बोला 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 6 	 /initial_message 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 6 	 तुम्हीअजून कोणतीही भाषा बोलू शकता का? 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 6 	 ठीक आहे मराठी मध्ये बोला 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 7 	 /initial_message 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 7 	 तुम्हीअजून कोणतीही भाषा बोलू शकता का? 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 7 	 ठीक आहे गुजराती मध्ये बोला 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 8 	 /initial_message 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 8 	 मला नंतर कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 8 	 उद्या सकाळी पुन्हा कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 9 	 /initial_message 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 9 	 मला नंतर कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 9 	 ठीक आहे 30 दिवसांनंतर पुन्हा कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 9 	 ठीक आहे उद्या पुन्हा कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 10 	 /initial_message 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 10 	 मला नंतर कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 10 	 ठीक आहे 30 दिवसांनंतर पुन्हा कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 10 	 ठीक आहे 30 दिवसांनंतर पुन्हा कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 11 	 /initial_message 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 11 	 मला नंतर कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 11 	 ठीक आहे 30 दिवसांनंतर पुन्हा कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 11 	 कोणताही दिवस ठीक आहे 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 12 	 /initial_message 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 12 	 मला नंतर कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 12 	 उद्या रात्री 11 वाजता परत कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 12 	 ठीक आहे उद्या पुन्हा कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 13 	 /initial_message 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 13 	 मला नंतर कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 13 	 उद्या रात्री 11 वाजता परत कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 13 	 ठीक आहे 30 दिवसांनंतर पुन्हा कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 14 	 /initial_message 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 14 	 मला नंतर कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 14 	 उद्या रात्री 11 वाजता परत कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 14 	 कोणताही दिवस ठीक आहे 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 15 	 /initial_message 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 15 	 मला नंतर कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 15 	 पुढच्या वर्षी रात्री 11 वाजता पुन्हा कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 15 	 ठीक आहे उद्या पुन्हा कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 16 	 /initial_message 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 16 	 मला नंतर कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 16 	 पुढच्या वर्षी रात्री 11 वाजता पुन्हा कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 16 	 ठीक आहे 30 दिवसांनंतर पुन्हा कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 17 	 /initial_message 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 17 	 मला नंतर कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 17 	 पुढच्या वर्षी रात्री 11 वाजता पुन्हा कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 17 	 कोणताही दिवस ठीक आहे 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 18 	 /initial_message 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 18 	 मला नंतर कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 18 	 आज संध्याकाळी 5 वाजता कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 19 	 /initial_message 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 19 	 मला नंतर कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 19 	 5 मे ला पुन्हा कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 19 	 5 मे ला पुन्हा कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 20 	 /initial_message 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 20 	 मला नंतर कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 20 	 5 मे ला पुन्हा कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 20 	 आज संध्याकाळी 5 वाजता कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 21 	 /initial_message 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 21 	 मला नंतर कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 21 	 5 मे ला पुन्हा कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 21 	 उद्या सकाळी पुन्हा कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 22 	 /initial_message 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 22 	 मला नंतर कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 22 	 5 मे ला पुन्हा कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 22 	 ठीक आहे 30 दिवसांनंतर पुन्हा कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 23 	 /initial_message 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 23 	 मला नंतर कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 23 	 5 मे ला पुन्हा कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 23 	 उद्या रात्री 11 वाजता परत कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 24 	 /initial_message 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 24 	 मला नंतर कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 24 	 5 मे ला पुन्हा कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 24 	 पुढच्या वर्षी रात्री 11 वाजता पुन्हा कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 25 	 /initial_message 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 25 	 मला नंतर कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 25 	 5 मे ला पुन्हा कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 25 	 उद्या सकाळी पुन्हा कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 26 	 /initial_message 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 26 	 मला नंतर कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 26 	 5 मे ला पुन्हा कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 26 	 पुढच्या वर्षी रात्री 11 वाजता पुन्हा कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 27 	 /initial_message 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 27 	 मला नंतर कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 27 	 उद्या मला पुन्हा कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 27 	 उद्या मला पुन्हा कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 28 	 /initial_message 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 28 	 मला नंतर कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 28 	 उद्या मला पुन्हा कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 28 	 पुढच्या वर्षी मला पुन्हा कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 29 	 /initial_message 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 29 	 मला नंतर कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 29 	 उद्या मला पुन्हा कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 29 	 कोणतीही वेळ ठीक आहे 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 30 	 /initial_message 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 30 	 मला नंतर कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 30 	 पुढच्या वर्षी मला पुन्हा कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 30 	 उद्या मला पुन्हा कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 31 	 /initial_message 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 31 	 मला नंतर कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 31 	 पुढच्या वर्षी मला पुन्हा कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 31 	 पुढच्या वर्षी मला पुन्हा कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 32 	 /initial_message 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 32 	 मला नंतर कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 32 	 पुढच्या वर्षी मला पुन्हा कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 32 	 कोणतीही तारीख ठीक आहे 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 33 	 /initial_message 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 33 	 चुकीचा नंबर 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 34 	 /initial_message 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 34 	 नाही 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 34 	 /no_response 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 34 	 हो 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 35 	 /initial_message 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 35 	 नाही 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 35 	 wait 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 35 	 हो 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 35 	 हो 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 36 	 /initial_message 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 36 	 नाही 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 36 	 wait 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 36 	 wait 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 37 	 /initial_message 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 37 	 नाही 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 37 	 wait 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 37 	 हो 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 37 	 नाही 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 38 	 /initial_message 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 38 	 नाही 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 38 	 नाही 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 38 	 उद्या सकाळी पुन्हा कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 39 	 /initial_message 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 39 	 नाही 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 39 	 नाही 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 39 	 ठीक आहे 30 दिवसांनंतर पुन्हा कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 39 	 ठीक आहे उद्या पुन्हा कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 40 	 /initial_message 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 40 	 नाही 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 40 	 नाही 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 40 	 ठीक आहे 30 दिवसांनंतर पुन्हा कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 40 	 ठीक आहे 30 दिवसांनंतर पुन्हा कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 41 	 /initial_message 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 41 	 नाही 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 41 	 नाही 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 41 	 ठीक आहे 30 दिवसांनंतर पुन्हा कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 41 	 कोणताही दिवस ठीक आहे 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 42 	 /initial_message 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 42 	 नाही 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 42 	 नाही 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 42 	 उद्या रात्री 11 वाजता परत कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 42 	 ठीक आहे उद्या पुन्हा कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 43 	 /initial_message 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 43 	 नाही 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 43 	 नाही 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 43 	 उद्या रात्री 11 वाजता परत कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 43 	 ठीक आहे 30 दिवसांनंतर पुन्हा कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 44 	 /initial_message 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 44 	 नाही 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 44 	 नाही 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 44 	 उद्या रात्री 11 वाजता परत कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 44 	 कोणताही दिवस ठीक आहे 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 45 	 /initial_message 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 45 	 नाही 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 45 	 नाही 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 45 	 पुढच्या वर्षी रात्री 11 वाजता पुन्हा कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 45 	 ठीक आहे उद्या पुन्हा कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 46 	 /initial_message 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 46 	 नाही 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 46 	 नाही 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 46 	 पुढच्या वर्षी रात्री 11 वाजता पुन्हा कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 46 	 ठीक आहे 30 दिवसांनंतर पुन्हा कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 47 	 /initial_message 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 47 	 नाही 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 47 	 नाही 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 47 	 पुढच्या वर्षी रात्री 11 वाजता पुन्हा कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 47 	 कोणताही दिवस ठीक आहे 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 48 	 /initial_message 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 48 	 नाही 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 48 	 नाही 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 48 	 आज संध्याकाळी 5 वाजता कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 49 	 /initial_message 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 49 	 नाही 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 49 	 नाही 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 49 	 5 मे ला पुन्हा कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 49 	 5 मे ला पुन्हा कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 50 	 /initial_message 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 50 	 नाही 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 50 	 नाही 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 50 	 5 मे ला पुन्हा कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 50 	 आज संध्याकाळी 5 वाजता कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 51 	 /initial_message 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 51 	 नाही 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 51 	 नाही 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 51 	 5 मे ला पुन्हा कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 51 	 उद्या सकाळी पुन्हा कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 52 	 /initial_message 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 52 	 नाही 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 52 	 नाही 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 52 	 5 मे ला पुन्हा कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 52 	 ठीक आहे 30 दिवसांनंतर पुन्हा कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 53 	 /initial_message 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 53 	 नाही 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 53 	 नाही 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 53 	 5 मे ला पुन्हा कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 53 	 उद्या रात्री 11 वाजता परत कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 54 	 /initial_message 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 54 	 नाही 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 54 	 नाही 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 54 	 5 मे ला पुन्हा कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 54 	 पुढच्या वर्षी रात्री 11 वाजता पुन्हा कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 55 	 /initial_message 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 55 	 नाही 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 55 	 नाही 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 55 	 5 मे ला पुन्हा कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 55 	 उद्या सकाळी पुन्हा कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 56 	 /initial_message 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 56 	 नाही 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 56 	 नाही 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 56 	 5 मे ला पुन्हा कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 56 	 पुढच्या वर्षी रात्री 11 वाजता पुन्हा कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 57 	 /initial_message 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 57 	 नाही 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 57 	 नाही 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 57 	 उद्या मला पुन्हा कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 57 	 उद्या मला पुन्हा कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 58 	 /initial_message 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 58 	 नाही 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 58 	 नाही 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 58 	 उद्या मला पुन्हा कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 58 	 पुढच्या वर्षी मला पुन्हा कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 59 	 /initial_message 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 59 	 नाही 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 59 	 नाही 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 59 	 उद्या मला पुन्हा कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 59 	 कोणतीही वेळ ठीक आहे 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 60 	 /initial_message 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 60 	 नाही 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 60 	 नाही 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 60 	 पुढच्या वर्षी मला पुन्हा कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 60 	 उद्या मला पुन्हा कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 61 	 /initial_message 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 61 	 नाही 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 61 	 नाही 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 61 	 पुढच्या वर्षी मला पुन्हा कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 61 	 पुढच्या वर्षी मला पुन्हा कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 62 	 /initial_message 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 62 	 नाही 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 62 	 नाही 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 62 	 पुढच्या वर्षी मला पुन्हा कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 62 	 कोणतीही तारीख ठीक आहे 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 63 	 /initial_message 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 63 	 तू कसा आहे 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 63 	 मी पण मस्त 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 64 	 /initial_message 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 64 	 तू कसा आहे 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 64 	 ठीक नाही 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 65 	 /initial_message 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 65 	 तू कसा आहे 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 65 	 ठीक नाही पण आपण बोलू शकतो 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 66 	 /initial_message 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 66 	 आपण माझे नाव चुकीचे उच्चारले आहे 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 67 	 /initial_message 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 67 	 ते वारले 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 68 	 /initial_message 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 68 	 त्यांची तब्येत ठीक नाही, त्यांना हॉस्पिटल मध्ये एडमिट केले आहे 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 69 	 /initial_message 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 69 	 कृपया एक मिनिट थांबा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 69 	 कृपया एक मिनिट थांबा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 69 	 कृपया एक मिनिट थांबा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 69 	 कृपया एक मिनिट थांबा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 70 	 /initial_message 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 70 	 कृपया एक मिनिट थांबा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 70 	 /no_response 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 70 	 हो 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 71 	 /initial_message 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 71 	 तू कोण आहेस 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 72 	 /initial_message 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 72 	 या मोहिमेचे महत्त्व काय आहे? 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 73 	 /initial_message 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 73 	 ड्रग फ्री इंडिया म्हणजे काय? 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 74 	 /initial_message 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 74 	 मोहीम केवळ मुंबईपुरती मर्यादित असेल की ग्रामीण भागाचा यामध्ये समावेश असेल? 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 75 	 /initial_message 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 75 	 हेल्पलाइन नंबर किती काळ सक्रिय असेल? 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 76 	 /initial_message 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 76 	 तुला माझा नंबर कसा मिळाला? 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 77 	 /initial_message 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 77 	 कृपया आपण पुन्हा सांगू शकता का? 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 77 	 कृपया आपण पुन्हा सांगू शकता का? 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 78 	 /initial_message 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 78 	 कृपया आपण पुन्हा सांगू शकता का? 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 78 	 कृपया आपण पुन्हा सांगू शकता का? 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 78 	 कृपया आपण पुन्हा सांगू शकता का? 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 79 	 /initial_message 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 79 	 कृपया आपण पुन्हा सांगू शकता का? 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 79 	 कृपया आपण पुन्हा सांगू शकता का? 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 79 	 कृपया आपण पुन्हा सांगू शकता का? 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 79 	 कृपया आपण पुन्हा सांगू शकता का? 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 80 	 /initial_message 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 80 	 तुला माझा नंबर कसा मिळाला? 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 80 	 तुला माझा नंबर कसा मिळाला? 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 81 	 /initial_message 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 81 	 तुला माझा नंबर कसा मिळाला? 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 81 	 तुला माझा नंबर कसा मिळाला? 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 81 	 तुला माझा नंबर कसा मिळाला? 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 82 	 /initial_message 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 82 	 तुला माझा नंबर कसा मिळाला? 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 82 	 तुला माझा नंबर कसा मिळाला? 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 82 	 तुला माझा नंबर कसा मिळाला? 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 82 	 तुला माझा नंबर कसा मिळाला? 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 83 	 /initial_message 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 83 	 हेलो 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 84 	 /initial_message 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 84 	 सॉरी मॅम 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 85 	 /initial_message 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 85 	 तुम्ही कॉलवर आहात का? 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 86 	 /initial_message 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 86 	 मी त्यासाठी अवेलेबल आहे 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 87 	 /initial_message 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 87 	 मी सध्या बिझी आहे 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 88 	 /initial_message 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 88 	 मी सध्या बाहेरगावी आहे 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 89 	 /initial_message 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 89 	 आपण थोडे मोठ्याने बोलू शकता का? 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 90 	 /initial_message 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 90 	 मला तुमच्या एजंटशी बोलायचे आहे 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 91 	 /initial_message 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 91 	 आज माझी तब्येत ठीक नाही 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 92 	 /initial_message 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 92 	 सध्या मेडिकल इमरजेंसी आहे 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 93 	 /initial_message 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 93 	 अरे वेड्या 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 94 	 /initial_message 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 94 	 आपण वारंवार कॉल का करीत आहात? 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 95 	 /initial_message 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 95 	 हो 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 95 	 आपण हिंदी बोलू शकता? 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 96 	 /initial_message 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 96 	 हो 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 96 	 मला मराठी माहित no 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 97 	 /initial_message 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 97 	 हो 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 97 	 कृपया तमिळ मध्ये बोला 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 97 	 ठीक आहे हिंदी मध्ये बोला 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 98 	 /initial_message 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 98 	 हो 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 98 	 कृपया बांगला मध्ये बोला 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 98 	 मला मराठी माहित no 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 99 	 /initial_message 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 99 	 हो 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 99 	 कृपया ओरिया मध्ये बोला 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 99 	 ठीक आहे गुजराती मध्ये बोला 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 100 	 /initial_message 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 100 	 हो 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 100 	 तुम्हीअजून कोणतीही भाषा बोलू शकता का? 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 100 	 ठीक आहे हिंदी मध्ये बोला 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 101 	 /initial_message 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 101 	 हो 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 101 	 तुम्हीअजून कोणतीही भाषा बोलू शकता का? 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 101 	 ठीक आहे मराठी मध्ये बोला 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 102 	 /initial_message 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 102 	 हो 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 102 	 तुम्हीअजून कोणतीही भाषा बोलू शकता का? 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 102 	 ठीक आहे गुजराती मध्ये बोला 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 103 	 /initial_message 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 103 	 हो 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 103 	 मला नंतर कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 103 	 उद्या सकाळी पुन्हा कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 104 	 /initial_message 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 104 	 हो 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 104 	 मला नंतर कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 104 	 ठीक आहे 30 दिवसांनंतर पुन्हा कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 104 	 ठीक आहे उद्या पुन्हा कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 105 	 /initial_message 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 105 	 हो 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 105 	 मला नंतर कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 105 	 ठीक आहे 30 दिवसांनंतर पुन्हा कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 105 	 ठीक आहे 30 दिवसांनंतर पुन्हा कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 106 	 /initial_message 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 106 	 हो 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 106 	 मला नंतर कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 106 	 ठीक आहे 30 दिवसांनंतर पुन्हा कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 106 	 कोणताही दिवस ठीक आहे 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 107 	 /initial_message 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 107 	 हो 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 107 	 मला नंतर कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 107 	 उद्या रात्री 11 वाजता परत कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 107 	 ठीक आहे उद्या पुन्हा कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 108 	 /initial_message 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 108 	 हो 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 108 	 मला नंतर कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 108 	 उद्या रात्री 11 वाजता परत कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 108 	 ठीक आहे 30 दिवसांनंतर पुन्हा कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 109 	 /initial_message 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 109 	 हो 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 109 	 मला नंतर कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 109 	 उद्या रात्री 11 वाजता परत कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 109 	 कोणताही दिवस ठीक आहे 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 110 	 /initial_message 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 110 	 हो 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 110 	 मला नंतर कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 110 	 पुढच्या वर्षी रात्री 11 वाजता पुन्हा कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 110 	 ठीक आहे उद्या पुन्हा कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 111 	 /initial_message 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 111 	 हो 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 111 	 मला नंतर कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 111 	 पुढच्या वर्षी रात्री 11 वाजता पुन्हा कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 111 	 ठीक आहे 30 दिवसांनंतर पुन्हा कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 112 	 /initial_message 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 112 	 हो 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 112 	 मला नंतर कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 112 	 पुढच्या वर्षी रात्री 11 वाजता पुन्हा कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 112 	 कोणताही दिवस ठीक आहे 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 113 	 /initial_message 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 113 	 हो 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 113 	 मला नंतर कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 113 	 आज संध्याकाळी 5 वाजता कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 114 	 /initial_message 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 114 	 हो 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 114 	 मला नंतर कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 114 	 5 मे ला पुन्हा कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 114 	 5 मे ला पुन्हा कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 115 	 /initial_message 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 115 	 हो 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 115 	 मला नंतर कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 115 	 5 मे ला पुन्हा कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 115 	 आज संध्याकाळी 5 वाजता कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 116 	 /initial_message 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 116 	 हो 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 116 	 मला नंतर कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 116 	 5 मे ला पुन्हा कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 116 	 उद्या सकाळी पुन्हा कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 117 	 /initial_message 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 117 	 हो 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 117 	 मला नंतर कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 117 	 5 मे ला पुन्हा कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 117 	 ठीक आहे 30 दिवसांनंतर पुन्हा कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 118 	 /initial_message 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 118 	 हो 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 118 	 मला नंतर कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 118 	 5 मे ला पुन्हा कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 118 	 उद्या रात्री 11 वाजता परत कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 119 	 /initial_message 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 119 	 हो 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# ...
# 293 	 उद्या मला पुन्हा कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 293 	 पुढच्या वर्षी मला पुन्हा कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 294 	 /initial_message 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 294 	 हो 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 294 	 /no_response 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 294 	 नाही 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 294 	 मला नंतर कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 294 	 उद्या मला पुन्हा कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 294 	 कोणतीही वेळ ठीक आहे 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 295 	 /initial_message 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 295 	 हो 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 295 	 /no_response 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 295 	 नाही 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 295 	 मला नंतर कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 295 	 पुढच्या वर्षी मला पुन्हा कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 295 	 उद्या मला पुन्हा कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 296 	 /initial_message 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 296 	 हो 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 296 	 /no_response 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 296 	 नाही 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 296 	 मला नंतर कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 296 	 पुढच्या वर्षी मला पुन्हा कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 296 	 पुढच्या वर्षी मला पुन्हा कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 297 	 /initial_message 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 297 	 हो 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 297 	 /no_response 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 297 	 नाही 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 297 	 मला नंतर कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 297 	 पुढच्या वर्षी मला पुन्हा कॉल करा 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 297 	 कोणतीही तारीख ठीक आहे 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 298 	 /initial_message 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 298 	 हो 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 298 	 /no_response 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 298 	 नाही 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 298 	 या मोहिमेचे महत्त्व काय आहे? 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 299 	 /initial_message 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 299 	 हो 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 299 	 /no_response 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 299 	 नाही 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 299 	 ड्रग फ्री इंडिया म्हणजे काय? 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 300 	 /initial_message 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 300 	 हो 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 300 	 /no_response 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 300 	 नाही 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 300 	 मोहीम केवळ मुंबईपुरती मर्यादित असेल की ग्रामीण भागाचा यामध्ये समावेश असेल? 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 301 	 /initial_message 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 301 	 हो 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 301 	 /no_response 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 301 	 नाही 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 301 	 हेल्पलाइन नंबर किती काळ सक्रिय असेल? 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 302 	 /initial_message 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 302 	 हो 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 302 	 /no_response 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 302 	 नाही 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 302 	 तुला माझा नंबर कसा मिळाला? 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 303 	 /initial_message 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 303 	 हो 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 303 	 /no_response 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 303 	 नाही 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 303 	 कृपया आपण पुन्हा सांगू शकता का? 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 303 	 कृपया आपण पुन्हा सांगू शकता का? 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 304 	 /initial_message 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 304 	 हो 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 304 	 /no_response 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 304 	 नाही 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 304 	 कृपया आपण पुन्हा सांगू शकता का? 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 304 	 कृपया आपण पुन्हा सांगू शकता का? 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 304 	 कृपया आपण पुन्हा सांगू शकता का? 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 305 	 /initial_message 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 305 	 हो 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 305 	 /no_response 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 305 	 नाही 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 305 	 कृपया आपण पुन्हा सांगू शकता का? 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 305 	 कृपया आपण पुन्हा सांगू शकता का? 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 305 	 कृपया आपण पुन्हा सांगू शकता का? 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 305 	 कृपया आपण पुन्हा सांगू शकता का? 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 306 	 /initial_message 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 306 	 हो 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 306 	 /no_response 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 306 	 नाही 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 306 	 तुला माझा नंबर कसा मिळाला? 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 306 	 तुला माझा नंबर कसा मिळाला? 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 307 	 /initial_message 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 307 	 हो 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 307 	 /no_response 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 307 	 नाही 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 307 	 तुला माझा नंबर कसा मिळाला? 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 307 	 तुला माझा नंबर कसा मिळाला? 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 307 	 तुला माझा नंबर कसा मिळाला? 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 308 	 /initial_message 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 308 	 हो 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 308 	 /no_response 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 308 	 नाही 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 308 	 तुला माझा नंबर कसा मिळाला? 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 308 	 तुला माझा नंबर कसा मिळाला? 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 308 	 तुला माझा नंबर कसा मिळाला? 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 308 	 तुला माझा नंबर कसा मिळाला? 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 309 	 /initial_message 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 309 	 हो 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 309 	 /no_response 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 309 	 नाही 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 309 	 हेलो 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 310 	 /initial_message 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 310 	 हो 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 310 	 /no_response 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 310 	 नाही 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 310 	 सॉरी मॅम 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 311 	 /initial_message 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 311 	 हो 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 311 	 /no_response 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 311 	 नाही 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 311 	 तुम्ही कॉलवर आहात का? 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 312 	 /initial_message 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 312 	 हो 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 312 	 /no_response 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 312 	 नाही 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 312 	 मी त्यासाठी अवेलेबल आहे 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 313 	 /initial_message 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 313 	 हो 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 313 	 /no_response 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 313 	 नाही 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 313 	 मी सध्या बिझी आहे 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 314 	 /initial_message 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 314 	 हो 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 314 	 /no_response 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 314 	 नाही 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 314 	 मी सध्या बाहेरगावी आहे 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 315 	 /initial_message 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 315 	 हो 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 315 	 /no_response 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 315 	 नाही 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 315 	 आपण थोडे मोठ्याने बोलू शकता का? 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 316 	 /initial_message 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 316 	 हो 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 316 	 /no_response 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 316 	 नाही 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 316 	 मला तुमच्या एजंटशी बोलायचे आहे 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 317 	 /initial_message 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 317 	 हो 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 317 	 /no_response 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 317 	 नाही 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 317 	 आज माझी तब्येत ठीक नाही 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 318 	 /initial_message 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 318 	 हो 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 318 	 /no_response 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 318 	 नाही 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 318 	 सध्या मेडिकल इमरजेंसी आहे 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 319 	 /initial_message 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 319 	 हो 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 319 	 /no_response 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 319 	 नाही 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 319 	 अरे वेड्या 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 320 	 /initial_message 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 320 	 हो 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 320 	 /no_response 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 320 	 नाही 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# 320 	 आपण वारंवार कॉल का करीत आहात? 	 Object of type int64 is not JSON serializable 	 error 	 error 	 error 	 error
# Testcases completed, --- Run next block

# %%
df2 = pd.DataFrame()

df2["TestCase_No"] = final_Tno
df2["Utterance"] = final_user_resp

df2["Bot_Response_1"] = final_response_1
df2["Bot_Response_2"] = final_response_2
df2["Bot_Response_3"] = final_response_3
df2["Disposition"] = final_disposition
df2["Status_Code"] = final_status

# df3 = pd.concat([df,df2], axis=1, join='inner')

# df3.to_csv(Final_Sheet, index=False)

df2.to_csv(Final_Sheet, index=False)


print('\n','\n','\n')
print ("required data is downloaded as a CSV in path = .......",Final_Sheet)
print('\n','\n','\n')


#df3.head(5)
# Out:
#
#
#
# required data is downloaded as a CSV in path = ....... /Users/vinay_kl/Downloads/Final_Sheet_Stellantis_English_['13:26:52'].csv

# %%
print(len(final_Tno))
print(len(final_user_resp))
print(len(final_response_1))
print(len(final_response_2))
print(len(final_response_3))
print(len(final_disposition))
print(len(final_status))

# print(final_response_3)
# print(final_response_3)
# Out:
# 444
# 444
# 444
# 444
# 444
# 444
# 444

# %% [markdown]
# # Rough

# %%
headers = {'Content-Type':'application/json'}    
payload = json.dumps ({
    "user_id": "9482152447",
    "request_id": "request11jg27",
    "sender": "tej-24765798k96",
    "message": "हो",
    "customerData": {
        "callId": "12345",
        "bargingCall": "True",
        "accessToken": "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VySWQiOiI2NDUwYjkyN2YzZGZlYzMyMDIxNDgxMzciLCJhY2NvdW50SWQiOiI2NDUwYjkyNmYzZGZlYzMyMDIxNDgxMmUiLCJyb2xlIjoiQWRtaW4iLCJpYXQiOjE2ODM1NDM5NDAsImV4cCI6MTY4MzYzMDM0MH0.slLTPbIA92IDfsZUJKR0rxFnVgDi7M5mtDLaWDmlJsc",
        "clientName": "Stellantis Testing",
        "callType": "Internal UAT",
        "telephonyName": "Epicode",
        "customerInfo": {
            "contactInfo": {
                "primary": "9354069780",
                "customerSupportNumber": "4233423434",
                "customerCareNumber": ""
            },
            "primaryInfo": {
                "firstName": "ram",
                "vehicleIdentificationNumber": "dsfsdfsdfsdf",
                "sellingDealerName": "sdfsdf",
                "geographicLocation": "",
                "pincode": "",
                "lastServiceDealerCity": "sdfsdfsdf",
                "lastServiceDealerName": "lkjfsdklf",
                "preferredAgentGender": "M",
                "agentname": "kumar",
                "serviceDueDate": "2023-05-18",
                "captured_date": "2023-05-18",
                "serviceNetworkName": "dsfsfsdf",
                "flow": "political_edge_flow",
                "status": "Appointment Confirmed",
                "channel": "Voice",
                "utter_sub_flow_slot": "main_flow",
                "generalRepeatThreshold": "3",
                "businessIntentThreshold": "3",
                "previousDisposition": "Campaign End",
                "language": "English",
                "age": "",
                "gender": "",
                "region": "",
                "collared": "",
                "customerUniqueId": ""
            },
            "loanAccountDetails": {
                "emiAmount": "",
                "emiDueDate": "",
                "loanApplicationDate": "",
                "loanEndingDate": "",
                "lateFee": "",
                "interestRate": "",
                "nextNachDate": "",
                "paidDate": "",
                "currentPaymentStatus": "",
                "noofemi": "",
                "noOfEmiPaid": "",
                "loanTenureLeft": "",
                "loanAmountRemaining": "",
                "loanStartDate": "",
                "principalAmount": "",
                "totalLoanAmount": "",
                "loanCategory": "",
                "loanId": "",
                "noOfLoans": "",
                "paymentMode": "",
                "cbCharges": "0",
                "penalCharges": "0"
            },
            "behaviourDetails": {
                "riskType": "",
                "typology": "",
                "callDisposition": ""
            },
            "email": {
                "primary": ""
            },
            "leadType": "Transactional"
        },
        "callingPartner": "epicode",
        "campaignId": "2345",
        "agentConfig": {
            "parentFlow": [
                {
                    "flow": "appointment_booking_flow",
                    "isParent": True,
                    "isChild": False,
                    "channel": [
                        "Call"
                    ],
                    "type": "Female",
                    "language": [
                        "English"
                    ],
                    "Call": {
                        "voice": "Saarthi TTS",
                        "thresholdDateCallBack": 2,
                        "thresholdTimeCallBack": 30
                    }
                }
            ],
            "callFlow": [
                {
                    "appointment_booking_flow": {
                        "slot1": [
                            {
                                "initial": {
                                    "label": "lg_rpc_form",
                                    "next": "subSlot1"
                                },
                                "subSlot1": [
                                    {
                                        "third_party_contact": {
                                            "initial": [
                                                {
                                                    "label": "third_party_contact_form",
                                                    "next": "subSlot1"
                                                }
                                            ],
                                            "subSlot1": [
                                                {
                                                    "label": "stop_conversation"
                                                }
                                            ]
                                        },
                                        "call_back": {
                                            "initial": [
                                                {
                                                    "label": "call_back_form",
                                                    "next": "subSlot1"
                                                }
                                            ],
                                            "subSlot1": [
                                                {
                                                    "label": "stop_conversation"
                                                }
                                            ]
                                        },
                                        "small_talk": {
                                            "initial": [
                                                {
                                                    "label": "small_talk_form",
                                                    "next": "subSlot1"
                                                }
                                            ],
                                            "subSlot1": [
                                                {
                                                    "label": "stop_conversation"
                                                }
                                            ]
                                        }
                                    }
                                ]
                            }
                        ],
                        "slot2": [
                            {
                                "label": "date_confirmation_form",
                                "next": "slot3"
                            }
                        ],
                        "slot3": [
                            {
                                "not_interested": {
                                    "initial": [
                                        {
                                            "label": "not_interested_form",
                                            "next": "subSlot1"
                                        }
                                    ],
                                    "subSlot1": [
                                        {
                                            "label": "stop_conversation"
                                        }
                                    ]
                                },
                                "interested_later": {
                                    "initial": [
                                        {
                                            "label": "interested_later_form",
                                            "next": "subSlot1"
                                        }
                                    ],
                                    "subSlot1": [
                                        {
                                            "label": "stop_conversation"
                                        }
                                    ]
                                },
                                "call_back": {
                                    "initial": [
                                        {
                                            "label": "call_back_form",
                                            "next": "subSlot1"
                                        }
                                    ],
                                    "subSlot1": [
                                        {
                                            "label": "stop_conversation"
                                        }
                                    ]
                                },
                                "date_capture": {
                                    "initial": [
                                        {
                                            "label": "date_capture_form",
                                            "next": "subSlot1"
                                        }
                                    ],
                                    "subSlot1": [
                                        {
                                            "dealership_capture": {
                                                "initial": [
                                                    {
                                                        "label": "dealership_capture_form",
                                                        "next": "sub1Slot1"
                                                    }
                                                ],
                                                "sub1Slot1": [
                                                    {
                                                        "deny": {
                                                            "initial": [
                                                                {
                                                                    "label": "deny_dealership_form",
                                                                    "next": "sub2Slot1"
                                                                }
                                                            ],
                                                            "sub2Slot1": [
                                                                {
                                                                    "label": "stop_conversation"
                                                                }
                                                            ]
                                                        },
                                                        "affirm": {
                                                            "initial": [
                                                                {
                                                                    "label": "pickup_drop_capture_form",
                                                                    "next": "sub2Slot1"
                                                                }
                                                            ],
                                                            "sub2Slot1": [
                                                                {
                                                                    "label": "stop_conversation"
                                                                }
                                                            ]
                                                        }
                                                    }
                                                ]
                                            }
                                        }
                                    ]
                                },
                                "dealership_capture": {
                                    "initial": [
                                        {
                                            "label": "dealership_capture_form",
                                            "next": "sub1Slot1"
                                        }
                                    ],
                                    "sub1Slot1": [
                                        {
                                            "deny": {
                                                "initial": [
                                                    {
                                                        "label": "deny_dealership_form",
                                                        "next": "sub2Slot1"
                                                    }
                                                ],
                                                "sub2Slot1": [
                                                    {
                                                        "label": "stop_conversation"
                                                    }
                                                ]
                                            },
                                            "affirm": {
                                                "initial": [
                                                    {
                                                        "label": "pickup_drop_capture_form",
                                                        "next": "sub2Slot1"
                                                    }
                                                ],
                                                "sub2Slot1": [
                                                    {
                                                        "label": "stop_conversation"
                                                    }
                                                ]
                                            }
                                        }
                                    ]
                                }
                            }
                        ]
                    },
                    "follow_up_flow": {
                        "slot1": [
                            {
                                "initial": {
                                    "label": "lg_rpc_form",
                                    "next": "subSlot1"
                                },
                                "subSlot1": [
                                    {
                                        "third_party_contact": {
                                            "initial": [
                                                {
                                                    "label": "third_party_contact_form",
                                                    "next": "subSlot1"
                                                }
                                            ],
                                            "subSlot1": [
                                                {
                                                    "label": "stop_conversation"
                                                }
                                            ]
                                        },
                                        "call_back": {
                                            "initial": [
                                                {
                                                    "label": "call_back_form",
                                                    "next": "subSlot1"
                                                }
                                            ],
                                            "subSlot1": [
                                                {
                                                    "label": "stop_conversation"
                                                }
                                            ]
                                        },
                                        "small_talk": {
                                            "initial": [
                                                {
                                                    "label": "small_talk_form",
                                                    "next": "subSlot1"
                                                }
                                            ],
                                            "subSlot1": [
                                                {
                                                    "label": "stop_conversation"
                                                }
                                            ]
                                        }
                                    }
                                ]
                            }
                        ],
                        "slot2": [
                            {
                                "label": "followup_dealership_capture_form",
                                "next": "slot3"
                            }
                        ],
                        "slot3": [
                            {
                                "not_interested": {
                                    "initial": [
                                        {
                                            "label": "not_interested_form",
                                            "next": "subSlot1"
                                        }
                                    ],
                                    "subSlot1": [
                                        {
                                            "label": "stop_conversation"
                                        }
                                    ]
                                },
                                "interested_later": {
                                    "initial": [
                                        {
                                            "label": "interested_later_form",
                                            "next": "subSlot1"
                                        }
                                    ],
                                    "subSlot1": [
                                        {
                                            "label": "stop_conversation"
                                        }
                                    ]
                                },
                                "call_back": {
                                    "initial": [
                                        {
                                            "label": "call_back_form",
                                            "next": "subSlot1"
                                        }
                                    ],
                                    "subSlot1": [
                                        {
                                            "label": "stop_conversation"
                                        }
                                    ]
                                },
                                "new_date_capture": {
                                    "initial": [
                                        {
                                            "label": "date_capture_form",
                                            "next": "subSlot1"
                                        }
                                    ],
                                    "subSlot1": [
                                        {
                                            "dealership_capture": {
                                                "initial": [
                                                    {
                                                        "label": "dealership_capture_form",
                                                        "next": "sub1Slot1"
                                                    }
                                                ],
                                                "sub1Slot1": [
                                                    {
                                                        "deny": {
                                                            "initial": [
                                                                {
                                                                    "label": "deny_dealership_form",
                                                                    "next": "sub2Slot1"
                                                                }
                                                            ],
                                                            "sub2Slot1": [
                                                                {
                                                                    "label": "stop_conversation"
                                                                }
                                                            ]
                                                        },
                                                        "affirm": {
                                                            "initial": [
                                                                {
                                                                    "label": "pickup_drop_capture_form",
                                                                    "next": "sub2Slot1"
                                                                }
                                                            ],
                                                            "sub2Slot1": [
                                                                {
                                                                    "label": "stop_conversation"
                                                                }
                                                            ]
                                                        }
                                                    }
                                                ]
                                            }
                                        }
                                    ]
                                },
                                "deny_dealership": {
                                    "initial": [
                                        {
                                            "label": "deny_dealership_form",
                                            "next": "sub2Slot1"
                                        }
                                    ],
                                    "sub2Slot1": [
                                        {
                                            "label": "stop_conversation"
                                        }
                                    ]
                                },
                                "pickup_drop_capture": {
                                    "initial": [
                                        {
                                            "label": "pickup_drop_capture_form",
                                            "next": "sub2Slot1"
                                        }
                                    ],
                                    "sub2Slot1": [
                                        {
                                            "label": "stop_conversation"
                                        }
                                    ]
                                }
                            }
                        ]
                    },
                    "remainder_flow": {
                        "slot1": [
                            {
                                "initial": {
                                    "label": "lg_rpc_form",
                                    "next": "subSlot1"
                                },
                                "subSlot1": [
                                    {
                                        "third_party_contact": {
                                            "initial": [
                                                {
                                                    "label": "third_party_contact_form",
                                                    "next": "subSlot1"
                                                }
                                            ],
                                            "subSlot1": [
                                                {
                                                    "label": "stop_conversation"
                                                }
                                            ]
                                        },
                                        "call_back": {
                                            "initial": [
                                                {
                                                    "label": "call_back_form",
                                                    "next": "subSlot1"
                                                }
                                            ],
                                            "subSlot1": [
                                                {
                                                    "label": "stop_conversation"
                                                }
                                            ]
                                        },
                                        "small_talk": {
                                            "initial": [
                                                {
                                                    "label": "small_talk_form",
                                                    "next": "subSlot1"
                                                }
                                            ],
                                            "subSlot1": [
                                                {
                                                    "label": "stop_conversation"
                                                }
                                            ]
                                        }
                                    }
                                ]
                            }
                        ],
                        "slot2": [
                            {
                                "label": "booking_confirmation_form",
                                "next": "slot3"
                            }
                        ],
                        "slot3": [
                            {
                                "interested_later": {
                                    "initial": [
                                        {
                                            "label": "interested_later_form",
                                            "next": "subSlot1"
                                        }
                                    ],
                                    "subSlot1": [
                                        {
                                            "label": "stop_conversation"
                                        }
                                    ]
                                },
                                "call_back": {
                                    "initial": [
                                        {
                                            "label": "call_back_form",
                                            "next": "subSlot1"
                                        }
                                    ],
                                    "subSlot1": [
                                        {
                                            "label": "stop_conversation"
                                        }
                                    ]
                                }
                            }
                        ]
                    },
                    "feedback_flow": {
                        "slot1": [
                            {
                                "initial": {
                                    "label": "lg_rpc_form",
                                    "next": "subSlot1"
                                },
                                "subSlot1": [
                                    {
                                        "third_party_contact": {
                                            "initial": [
                                                {
                                                    "label": "third_party_contact_form",
                                                    "next": "subSlot1"
                                                }
                                            ],
                                            "subSlot1": [
                                                {
                                                    "label": "stop_conversation"
                                                }
                                            ]
                                        },
                                        "call_back": {
                                            "initial": [
                                                {
                                                    "label": "call_back_form",
                                                    "next": "subSlot1"
                                                }
                                            ],
                                            "subSlot1": [
                                                {
                                                    "label": "stop_conversation"
                                                }
                                            ]
                                        },
                                        "small_talk": {
                                            "initial": [
                                                {
                                                    "label": "small_talk_form",
                                                    "next": "subSlot1"
                                                }
                                            ],
                                            "subSlot1": [
                                                {
                                                    "label": "stop_conversation"
                                                }
                                            ]
                                        }
                                    }
                                ]
                            }
                        ],
                        "slot2": [
                            {
                                "label": "rating_based_form",
                                "next": "slot3"
                            }
                        ],
                        "slot3": [
                            {
                                "call_back": {
                                    "initial": [
                                        {
                                            "label": "call_back_form",
                                            "next": "subSlot1"
                                        }
                                    ],
                                    "subSlot1": [
                                        {
                                            "label": "stop_conversation"
                                        }
                                    ]
                                }
                            }
                        ]
                    }
                }
            ],
            "accountId": "6450b926f3dfec320214812e",
            "agentName": "Stella",
            "domain": "Automobile",
            "subDomain": "General",
            "productType": "Four Wheeler",
            "agentId": "StellantisTesting_salesOnboarding_FourWheeler_01",
            "createdAt": "2023-05-05T06:11:54.021Z",
            "updatedAt": "2023-05-05T06:11:54.021Z",
            "id": "64549e2ac0e8415d50370c7c"
        },
        "useCaseId": "62c81c4a4a0affe91342aaaa",
        "accountId": "6450b926f3dfec320214812e",
        "isCampaignTesting": True
    }
})


response = requests.request("POST", botEndPoint, headers=headers, data=payload).json()

# pprint(response)




#-------------------------#

text_list = []
response_1 = ["-"]
response_2 = ["-"]
response_3 = ["-"]
disposotion_list = []
staus_list = []

temp_status = response["custom"]["status"]
temp_disp = response["custom"]["disposition_id"]
temp_disp = ",".join(map(str, temp_disp))     #its like a text combining method with given delimeter.  map & str is added to reduce "sequence no N" error

val = response["data"]
for i in range(0,len(val)):    
      temp_text = response["data"][i]["text"]
      text_list.append(temp_text)

for i in range(0,len(text_list)):
    if i == 0:
        response_1 = [text_list[i]]
    if i == 1:
        response_2 = [text_list[i]]
    if i == 2:
        response_3 = [text_list[i]]

# return response_1,response_2,response_3, [temp_disp], [temp_status]



print(response_1,response_2,response_3, [temp_disp], [temp_status])
# Out:
# ['Error. response missing in D-B utter_MF_ask_area_political_edge_AD_awareness_PI_G_F'] ['-'] ['-'] ['Right Party Contact,Right Party Contact'] [702]

# %%
pprint(response["data"][0]["template_name"])

pprint(response["data"][0]["text"])

pprint(response["custom"]["disposition_id"])

pprint(response["custom"]["status"])
# Out:
# 'utter_RPC_initial_message_stellantis_AB_appointment_booking_flow_FW_G_F'
# "Hi, I'm kumar , calling from Jeep sdfsdfsdf . Am I talking to ram ??"
# ['initial_message']
# 702

# %%
text_list = []
response_1 = ["-"]
response_2 = ["-"]
#response_3 = ["-"]
disposotion_list = []
staus_list = []

temp_status = response["custom"]["status"]
temp_disp = response["custom"]["disposition_id"]
temp_disp = ",".join(map(str, temp_disp))     #its like a text combining method with given delimeter.  map & str is added to reduce "sequence no N" error

val = response["data"]
for i in range(0,len(val)):    
      temp_text = response["data"][i]["text"]
      text_list.append(temp_text)

for i in range(0,len(text_list)):
    if i == 0:
        response_1 = [text_list[i]]
    if i == 1:
        response_2 = [text_list[i]]

# %%
print(response_2)
# Out:
# ['-']
