# %% [markdown]
# # Actual Code

# %%
#import the required dependencies

import requests
import json
import pandas as pd
from pprint import pprint
import csv
import time
import random
import datetime
import re

print("all required dependencies are imported successfully")
# Out:
# all required dependencies are imported successfully

# %%
#update the current (pushData endpoint, bot endpoint & agent config)


pushData = "https://dsa.saarthi.ai/fetch_customer_data_maia"
botEndPoint = "https://dsa.saarthi.ai/maia_english/webhook_maia"

#-----------------------------------------------------------------------------#

agentConfig = "{\"accountName\":\"Piramal Finance Testing\",\"product\":\"Personal Loan\",\"productCategory\":\"Loan\",\"accountId\":\"64523cbf2d8b160676749986\",\"agentId\":\"PiramalFinanceTesting_Collections_UnsecuredPersonalLoan_General_01\",\"bankName\":\"Piramal Capital and Housing Finance\",\"maleAgentName\":\"Ashish\",\"femaleAgentName\":\"Kalpana\",\"displayName\":\"Sphot_Call_01\",\"Call\":{\"flowTypes\":[{\"displayValue\":\"dpd_1_3\",\"value\":\"dpd_1_3\",\"whatsAppValue\":\"dpd_1_3\",\"languages\":[\"Hindi\",\"English\"],\"showFields\":[\"Mobile Number\",\"Customer Name\",\"Flow\",\"Language\",\"Disposition\",\"Bank Name\",\"Agent Name\",\"EMI Amount\",\"Due Date\",\"region\",\"gender\",\"Age\",\"occupation\",\"typology\",\"Number of Loans\",\"Loan Type\",\"Number of Loans\",\"Payment Mode\"],\"showCategories\":[\"Calling Info\",\"Loan Info\",\"Customer Demography\",\"Typology\"]}],\"partialPayment\":{\"dpd_8_15\":false,\"dpd_1_3\":false,\"dpd_4_7\":false,\"dpd_16_30\":false,\"dpd_8_17\":false,\"dpd_18_25\":false,\"dpd_26_30\":false,\"dpd_31_45\":false,\"dpd_46_60\":false,\"dpd_61_90\":false,\"live_penal\":false},\"paymentMode\":[\"Manual payment\"],\"paymentMethods\":{\"pay_via_online\":true,\"pay_via_agent\":true,\"pay_via_card\":true,\"pay_via_upi\":true,\"pay_via_netbanking\":true,\"pay_via_wallet\":false,\"pay_via_branch\":true,\"pay_via_app\":true},\"thresholdPtpDays\":3,\"thresholdCallBackTime\":\"19:00\",\"thresholdCallBackDate\":\"25/09/2000\",\"latePaymentPolicy\":\"2% per month on overdue amount\",\"sms\":true},\"createdAt\":\"2023-05-04T07:18:18.671Z\",\"updatedAt\":\"2023-05-04T07:18:18.671Z\",\"id\":\"64535c3abe900069ef3626a9\"}"


print("agent config and endpoints are pushed to respective variables")
# Out:
# agent config and endpoints are pushed to respective variables

# %%
#update required customer config details

agentName = "Sia"
customerName = "Vinay"
flow = "dpd_1_3"
language = "hindi"

locality = "Urban"
gender = "F"
age = "27"
collared = "White"
typology = "DICE"

dueDate = "05-04-2023"
emiAmount = "54321"
ptpDate = "31-03-2023"

print("required customer config details are updated")
# Out:
# required customer config details are updated

# %%
#update the testset and final sheet's path. then run the block

v = datetime.datetime.now()
#print(v)

#pattern = '\d{4}-\d{2}-\d{2} (\d{2}:\d{2}:\d{2})\.\d{6}'
pattern = "[\d]+-[\d]+-[\d]+ ([\d]+:[\d]+:[\d]+)\.[\d]+"

required = re.findall(pattern,str(v))
#print(required)


#---------------------------------------------------------------------------------------#


if int(age) >= 18 and int(age) <= 30:
    final_age = "Y"
    #print(final_age)
    
elif int(age) >= 31 and int(age) <= 45:
    final_age = "M"
    #print(final_age)
    
elif int(age) >= 46 and int(age) <= 60:
    final_age = "O"
    #print(final_age)   
    
else:
    final_age = "given age is not valid"
    print(final_age)  

    
    
#---------------------------------------------------------------------------------------#
    
    

demography = locality[0]+gender+final_age+collared[0]+"_"+typology
# print(demography)


#------------------------------------------------------------------#


dataCSV = "/Users/vinay_kl/Downloads/Test357.csv"
Final_Sheet = "/Users/vinay_kl/Downloads/Final_Sheet_"+str(language)+"_"+str(demography)+"_"+str(required)+".csv"

# print(demography)
print(Final_Sheet)

print("testset and final_sheet is pushed to respective variables")
# Out:
# /Users/vinay_kl/Downloads/Final_Sheet_hindi_UFYW_DICE_['15:15:51'].csv
# testset and final_sheet is pushed to respective variables

# %%
#Push the data to DB

headers = {'Content-Type':'application/json'}


payload = json.dumps ({
    "data": [
        {
        "contactInfo.primary": "6305450418",
        "primaryInfo.language": "Hindi",
        "primaryInfo.flow": "dpd_1_3",
        "loanAccountDetails.emiDueDate": "03-05-2023",
        "primaryInfo.firstName": "Vinay_TEST",
        "disposition_name": "Default",
        "geographic_location": "bengalore",
        "loanAccountDetails.noOfLoans": "1",
        "clientName": "Piramal Finance Testing",
        "collared": "Blue",
        "age": "31",
        "loanAccountDetails.emiAmount": "5763",
        "loan_type": "",
        "auto_pay": "Manual Payment",
        "region": "Urban",
        "risk_type": "High",
        "primaryInfo.region": "Rural",
        "agent_config": "{\"accountName\":\"Piramal Finance Testing\",\"product\":\"Personal Loan\",\"productCategory\":\"Loan\",\"accountId\":\"64523cbf2d8b160676749986\",\"agentId\":\"PiramalFinanceTesting_Collections_UnsecuredPersonalLoan_General_01\",\"bankName\":\"Piramal Capital and Housing Finance\",\"maleAgentName\":\"Ashish\",\"femaleAgentName\":\"Kalpana\",\"displayName\":\"Sphot_Call_01\",\"Call\":{\"flowTypes\":[{\"displayValue\":\"dpd_1_3\",\"value\":\"dpd_1_3\",\"whatsAppValue\":\"dpd_1_3\",\"languages\":[\"Hindi\",\"English\"],\"showFields\":[\"Mobile Number\",\"Customer Name\",\"Flow\",\"Language\",\"Disposition\",\"Bank Name\",\"Agent Name\",\"EMI Amount\",\"Due Date\",\"region\",\"gender\",\"Age\",\"occupation\",\"typology\",\"Number of Loans\",\"Loan Type\",\"Number of Loans\",\"Payment Mode\"],\"showCategories\":[\"Calling Info\",\"Loan Info\",\"Customer Demography\",\"Typology\"]}],\"partialPayment\":{\"dpd_8_15\":false,\"dpd_1_3\":false,\"dpd_4_7\":false,\"dpd_16_30\":false,\"dpd_8_17\":false,\"dpd_18_25\":false,\"dpd_26_30\":false,\"dpd_31_45\":false,\"dpd_46_60\":false,\"dpd_61_90\":false,\"live_penal\":false},\"paymentMode\":[\"Manual payment\"],\"paymentMethods\":{\"pay_via_online\":true,\"pay_via_agent\":true,\"pay_via_card\":true,\"pay_via_upi\":true,\"pay_via_netbanking\":true,\"pay_via_wallet\":false,\"pay_via_branch\":true,\"pay_via_app\":true},\"thresholdPtpDays\":3,\"thresholdCallBackTime\":\"19:00\",\"thresholdCallBackDate\":\"25/09/2000\",\"latePaymentPolicy\":\"2% per month on overdue amount\",\"sms\":true},\"createdAt\":\"2023-05-04T07:18:18.671Z\",\"updatedAt\":\"2023-05-04T07:18:18.671Z\",\"id\":\"64535c3abe900069ef3626a9\"}",
        "client_name": "Piramal Finance Testing",
        "typology": "DICE",
        "ptp_date": "24-05-2023",
        "bank_name": "Piramal Capital and Housing Finance",
        "gender": "M"
       }
    ]
})

response = requests.request("POST", pushData, headers=headers, data=payload).json()
print(response)
# Out:
# Data pushed successfully to maia bot

# %%
#functions


def LC(TestCaseNo = None,Message = None):



    headers = {'Content-Type':'application/json'}    
    payload = json.dumps ({
        "user_id": "6305450418",
        "request_id": "requestcd1127",
        "sender": "saarthibajajvinay555"+str(TestCaseNo)+str(num),
        "message": Message
    })
    response = requests.request("POST", botEndPoint, headers=headers, data=payload).json()

    return response



#     i = response["data"]

#     for dicts in i:
#         lastResponse = dicts["text"]
#         print(lastResponse,"\t", end=' ')




#     disposition = response["custom"]["disposition_id"]
#     status = response["custom"]["status"]  

#     print(disposition,'\t',status)
    
    
    
    
    
    
def LC_2(TestCaseNo = None,Message = None):


    headers = {'Content-Type':'application/json'}    
    payload = json.dumps ({
        "user_id": "6305450418",
        "request_id": "requestcd1127",
        "sender": "saarthibajajvinay555"+str(TestCaseNo)+str(num),
        "message": "can you speak any other languages"
    })
    response = requests.request("POST", botEndPoint, headers=headers, data=payload).json()



    headers = {'Content-Type':'application/json'}    
    payload = json.dumps ({
        "user_id": "6305450418",
        "request_id": "requestcd1127",
        "sender": "saarthibajajvinay555"+str(TestCaseNo)+str(num),
        "message": Message
    })
    response = requests.request("POST", botEndPoint, headers=headers, data=payload).json()

    return response
    



#     i = response["data"]

#     for dicts in i:
#         lastResponse = dicts["text"]
#         print(lastResponse,"\t", end=' ')




#     disposition = response["custom"]["disposition_id"]
#     status = response["custom"]["status"]  

#     print(disposition,'\t',status)
    
    
    
    
    
    
    
def RPN(TestCaseNo = None,Message = None):


    headers = {'Content-Type':'application/json'}    
    payload = json.dumps ({
        "user_id": "6305450418",
        "request_id": "requestcd1127",
        "sender": "saarthibajajvinay555"+str(TestCaseNo)+str(num),
        "message": "he is currently not here"
    })
    response = requests.request("POST", botEndPoint, headers=headers, data=payload).json()


    headers = {'Content-Type':'application/json'}    
    payload = json.dumps ({
        "user_id": "6305450418",
        "request_id": "requestcd1127",
        "sender": "saarthibajajvinay555"+str(TestCaseNo)+str(num),
        "message": "please call him after 20 days"
    })
    response = requests.request("POST", botEndPoint, headers=headers, data=payload).json()


    headers = {'Content-Type':'application/json'}    
    payload = json.dumps ({
        "user_id": "6305450418",
        "request_id": "requestcd1127",
        "sender": "saarthibajajvinay555"+str(TestCaseNo)+str(num),
        "message": Message
    })
    response = requests.request("POST", botEndPoint, headers=headers, data=payload).json()
    
    return response





#     i = response["data"]

#     for dicts in i:
#         lastResponse = dicts["text"]
#         print(lastResponse,"\t", end=' ')




#     disposition = response["custom"]["disposition_id"]
#     status = response["custom"]["status"]  

#     print(disposition,'\t',status)
    
    
    
    
    
    

def CBN(TestCaseNo = None,Message = None):


    headers = {'Content-Type':'application/json'}    
    payload = json.dumps ({
        "user_id": "6305450418",
        "request_id": "requestcd1127",
        "sender": "saarthibajajvinay555"+str(TestCaseNo)+str(num),
        "message": "please call me back later"
    })
    response = requests.request("POST", botEndPoint, headers=headers, data=payload).json()


    headers = {'Content-Type':'application/json'}    
    payload = json.dumps ({
        "user_id": "6305450418",
        "request_id": "requestcd1127",
        "sender": "saarthibajajvinay555"+str(TestCaseNo)+str(num),
        "message": "please call after 20 days"
    })
    response = requests.request("POST", botEndPoint, headers=headers, data=payload).json()


    headers = {'Content-Type':'application/json'}    
    payload = json.dumps ({
        "user_id": "6305450418",
        "request_id": "requestcd1127",
        "sender": "saarthibajajvinay555"+str(TestCaseNo)+str(num),
        "message": Message
    })
    response = requests.request("POST", botEndPoint, headers=headers, data=payload).json()
    
    return response




#     i = response["data"]

#     for dicts in i:
#         lastResponse = dicts["text"]
#         print(lastResponse,"\t", end=' ')




#     disposition = response["custom"]["disposition_id"]
#     status = response["custom"]["status"]  

#     print(disposition,'\t',status)
    
    
    
    
    
    
    
def no_message_Threshold(TestCaseNo = None,Message = None):


    headers = {'Content-Type':'application/json'}    
    payload = json.dumps ({
        "user_id": "6305450418",
        "request_id": "requestcd1127",
        "sender": "saarthibajajvinay555"+str(TestCaseNo)+str(num),
        "message": Message
    })
    response = requests.request("POST", botEndPoint, headers=headers, data=payload).json()


    headers = {'Content-Type':'application/json'}    
    payload = json.dumps ({
        "user_id": "6305450418",
        "request_id": "requestcd1127",
        "sender": "saarthibajajvinay555"+str(TestCaseNo)+str(num),
        "message": Message
    })
    response = requests.request("POST", botEndPoint, headers=headers, data=payload).json()


    headers = {'Content-Type':'application/json'}    
    payload = json.dumps ({
        "user_id": "6305450418",
        "request_id": "requestcd1127",
        "sender": "saarthibajajvinay555"+str(TestCaseNo)+str(num),
        "message": Message
    })
    response = requests.request("POST", botEndPoint, headers=headers, data=payload).json()
    
    return response




#     i = response["data"]

#     for dicts in i:
#         lastResponse = dicts["text"]
#         print(lastResponse,"\t", end=' ')




#     disposition = response["custom"]["disposition_id"]
#     status = response["custom"]["status"]  

#     print(disposition,'\t',status)    







#-------------------------------------------------------------------#







def final_data(response):
    text_list = []
    response_1 = ["-"]
    response_2 = ["-"]
    #response_3 = ["-"]
    disposotion_list = []
    staus_list = []

    temp_status = response["custom"]["status"]
    temp_disp = response["custom"]["disposition_id"]
    temp_disp = ",".join(map(str, temp_disp))     #its like a text combining method with given delimeter.  map & str is added to reduce "sequence no N" error

    val = response["data"]
    for i in range(0,len(val)):    
          temp_text = response["data"][i]["text"]
          text_list.append(temp_text)

    for i in range(0,len(text_list)):
        if i == 0:
            response_1 = [text_list[i]]
        if i == 1:
            response_2 = [text_list[i]]
        # if i == 2:
        #     response_3 = [text_list[i]]
        
    return response_1,response_2, [temp_disp], [temp_status]






print("all required functions are successfully called")
# Out:
# all required functions are successfully called

# %%
# final_response_1 = []
# final_response_2 = []
# final_disposition = []
# final_status = []

# %%
#RPC_SLOT (run this block to check testset in RPC slot)







final_response_1 = []
final_response_2 = []
final_disposition = []
final_status = []







num = random.random()

with open(dataCSV, 'r') as f:
    reader = csv.reader(f)
    the_whole_file = list(reader)    
    
count = 0
while(count < (len(the_whole_file)-1)):
#while(count < 10):
    count = count + 1
    TestCaseNo = the_whole_file[count][0]
    Message = the_whole_file[count][4]
    Category = the_whole_file[count][2]
    
    #print(TestCaseNo)
    #print(Message)
    #print(Category)
    #print(num)
    
    
    headers = {'Content-Type':'application/json'}    
    payload = json.dumps ({
        "user_id": "6305450418",
        "request_id": "requestcd1127",
        "sender": "saarthibajajvinay555"+str(TestCaseNo)+str(num),
        "message": "/initial_message"
    })
    response = requests.request("POST", botEndPoint, headers=headers, data=payload).json()
    
    
    if Category == "LC_2":
        try:

            response = LC_2(TestCaseNo,Message)
            response_1, response_2, disposition, status = final_data(response)
            final_response_1.extend(response_1)
            final_response_2.extend(response_2)
            final_disposition.extend(disposition)
            final_status.extend(status)
            
            time.sleep(1)

        except Exception as e:
            print("TestCaseNo -",TestCaseNo,"in RPC slot failed --->",e)
            final_response_1.append(e)
            final_response_2.append("error")
            final_disposition.append("error")
            final_status.append("error")
            
            
            
            
    elif Category == "RPN":
        try:

            response = RPN(TestCaseNo,Message)
            response_1, response_2, disposition, status = final_data(response)
            final_response_1.extend(response_1)
            final_response_2.extend(response_2)
            final_disposition.extend(disposition)
            final_status.extend(status)
            
            time.sleep(1)

        except Exception as e:
            print("TestCaseNo -",TestCaseNo,"in RPC slot failed --->",e)
            final_response_1.append(e)
            final_response_2.append("error")
            final_disposition.append("error")
            final_status.append("error")

            
            
    elif Category == "CBN":
        try:

            response = CBN(TestCaseNo,Message)
            response_1, response_2, disposition, status = final_data(response)
            final_response_1.extend(response_1)
            final_response_2.extend(response_2)
            final_disposition.extend(disposition)
            final_status.extend(status)
            
            time.sleep(1)

        except Exception as e:
            print("TestCaseNo -",TestCaseNo,"in RPC slot failed --->",e)
            final_response_1.append(e)
            final_response_2.append("error")
            final_disposition.append("error")
            final_status.append("error")
            
            
            
    elif Category == ["no_message_Threshold", "wait_Threshold"]:
        try:

            response = no_message_Threshold(TestCaseNo,Message)
            response_1, response_2, disposition, status = final_data(response)
            final_response_1.extend(response_1)
            final_response_2.extend(response_2)
            final_disposition.extend(disposition)
            final_status.extend(status)
            time.sleep(1)

        except Exception as e:
            print("TestCaseNo -",TestCaseNo,"in RPC slot failed --->",e)
            final_response_1.append(e)
            final_response_2.append("error")
            final_disposition.append("error")
            final_status.append("error")
            
            
            
            
    else:
        try:

            response = LC(TestCaseNo,Message)
            response_1, response_2, disposition, status = final_data(response)
            final_response_1.extend(response_1)
            final_response_2.extend(response_2)
            final_disposition.extend(disposition)
            final_status.extend(status)
            time.sleep(1)

        except Exception as e:
            print("TestCaseNo -",TestCaseNo,"in RPC slot failed --->",e)
            final_response_1.append(e)
            final_response_2.append("error")
            final_disposition.append("error")
            final_status.append("error")


            
print('\n','\n','\n')
print("RPC block is Completed, --- Run next block")
# Out:
#
#
#
# RPC block is Completed, --- Run next block

# %%
time.sleep(5)

# %%
#PIC_SLOT (run this block to check testset in PIC slot)

num = random.random()

with open(dataCSV, 'r') as f:
    reader = csv.reader(f)
    the_whole_file = list(reader)    
    
count = 0
while(count < (len(the_whole_file)-1)):
    count = count + 1
    TestCaseNo = the_whole_file[count][0]
    Message = the_whole_file[count][4]
    Category = the_whole_file[count][2]
    
    #print(TestCaseNo)
    #print(Message)
    #print(Category)
    #print(num)
    
    
    headers = {'Content-Type':'application/json'}    
    payload = json.dumps ({
        "user_id": "6305450418",
        "request_id": "requestcd1127",
        "sender": "saarthibajajvinay555"+str(TestCaseNo)+str(num),
        "message": "/initial_message"
    })
    response = requests.request("POST", botEndPoint, headers=headers, data=payload).json()
    
    
    
    headers = {'Content-Type':'application/json'}    
    payload = json.dumps ({
        "user_id": "6305450418",
        "request_id": "requestcd1127",
        "sender": "saarthibajajvinay555"+str(TestCaseNo)+str(num),
        "message": "yes"
    })
    response = requests.request("POST", botEndPoint, headers=headers, data=payload).json()
    
    
    
    
    if Category == "LC_2":
        try:

            response = LC_2(TestCaseNo,Message)
            response_1, response_2, disposition, status = final_data(response)
            final_response_1.extend(response_1)
            final_response_2.extend(response_2)
            final_disposition.extend(disposition)
            final_status.extend(status)
            
            time.sleep(1)

        except Exception as e:
            print("TestCaseNo -",TestCaseNo,"in PIC slot failed --->",e)
            final_response_1.append(e)
            final_response_2.append("error")
            final_disposition.append("error")
            final_status.append("error")
            
            
            
            
    elif Category == "RPN":
        try:

            response = RPN(TestCaseNo,Message)
            response_1, response_2, disposition, status = final_data(response)
            final_response_1.extend(response_1)
            final_response_2.extend(response_2)
            final_disposition.extend(disposition)
            final_status.extend(status)
            
            time.sleep(1)

        except Exception as e:
            print("TestCaseNo -",TestCaseNo,"in PIC slot failed --->",e)
            final_response_1.append(e)
            final_response_2.append("error")
            final_disposition.append("error")
            final_status.append("error")
            
            
    elif Category == "CBN":
        try:

            response = CBN(TestCaseNo,Message)
            response_1, response_2, disposition, status = final_data(response)
            final_response_1.extend(response_1)
            final_response_2.extend(response_2)
            final_disposition.extend(disposition)
            final_status.extend(status)
            
            time.sleep(1)

        except Exception as e:
            print("TestCaseNo -",TestCaseNo,"in PIC slot failed --->",e)
            final_response_1.append(e)
            final_response_2.append("error")
            final_disposition.append("error")
            final_status.append("error")            
            
            
    elif Category == "no_message_Threshold":
        try:

            response = no_message_Threshold(TestCaseNo,Message)
            response_1, response_2, disposition, status = final_data(response)
            final_response_1.extend(response_1)
            final_response_2.extend(response_2)
            final_disposition.extend(disposition)
            final_status.extend(status)
            
            time.sleep(1)

        except Exception as e:
            print("TestCaseNo -",TestCaseNo,"in PIC slot failed --->",e)
            final_response_1.append(e)
            final_response_2.append("error")
            final_disposition.append("error")
            final_status.append("error")            
            
            
    else:
        try:

            response = LC(TestCaseNo,Message)
            response_1, response_2, disposition, status = final_data(response)
            final_response_1.extend(response_1)
            final_response_2.extend(response_2)
            final_disposition.extend(disposition)
            final_status.extend(status)
            
            time.sleep(1)

        except Exception as e:
            print("TestCaseNo -",TestCaseNo,"in PIC slot failed --->",e)
            final_response_1.append(e)
            final_response_2.append("error")
            final_disposition.append("error")
            final_status.append("error")
            
            
            
print('\n','\n','\n')
print("PIC block is Completed, --- Run next block")
# Out:
#
#
#
# PIC block is Completed, --- Run next block

# %%
time.sleep(5)

# %%
#COUNSELLING_SLOT (run this block to check testset in COUNSELLING slot)

num = random.random()

with open(dataCSV, 'r') as f:
    reader = csv.reader(f)
    the_whole_file = list(reader)    
    
count = 0
while(count < (len(the_whole_file)-1)):
    count = count + 1
    TestCaseNo = the_whole_file[count][0]
    Message = the_whole_file[count][4]
    Category = the_whole_file[count][2]
    
    #print(TestCaseNo)
    #print(Message)
    #print(Category)
    #print(num)
    
    
    headers = {'Content-Type':'application/json'}    
    payload = json.dumps ({
        "user_id": "6305450418",
        "request_id": "requestcd1127",
        "sender": "saarthibajajvinay555"+str(TestCaseNo)+str(num),
        "message": "/initial_message"
    })
    response = requests.request("POST", botEndPoint, headers=headers, data=payload).json()
    
    
    
    headers = {'Content-Type':'application/json'}    
    payload = json.dumps ({
        "user_id": "6305450418",
        "request_id": "requestcd1127",
        "sender": "saarthibajajvinay555"+str(TestCaseNo)+str(num),
        "message": "yes"
    })
    response = requests.request("POST", botEndPoint, headers=headers, data=payload).json()
    
    
    
    headers = {'Content-Type':'application/json'}    
    payload = json.dumps ({
        "user_id": "6305450418",
        "request_id": "requestcd1127",
        "sender": "saarthibajajvinay555"+str(TestCaseNo)+str(num),
        "message": "i wont do the payment"
    })
    response = requests.request("POST", botEndPoint, headers=headers, data=payload).json()
    
    
    
    
    if Category == "LC_2":
        try:

            response = LC_2(TestCaseNo,Message)
            response_1, response_2, disposition, status = final_data(response)
            final_response_1.extend(response_1)
            final_response_2.extend(response_2)
            final_disposition.extend(disposition)
            final_status.extend(status)
            
            time.sleep(1)

        except Exception as e:
            print("TestCaseNo -",TestCaseNo,"in COUNSELLING slot failed --->",e)
            final_response_1.append(e)
            final_response_2.append("error")
            final_disposition.append("error")
            final_status.append("error")            
            
            
            
    elif Category == "RPN":
        try:

            response = RPN(TestCaseNo,Message)
            response_1, response_2, disposition, status = final_data(response)
            final_response_1.extend(response_1)
            final_response_2.extend(response_2)
            final_disposition.extend(disposition)
            final_status.extend(status)
            
            time.sleep(1)

        except Exception as e:
            print("TestCaseNo -",TestCaseNo,"in COUNSELLING slot failed --->",e)
            final_response_1.append(e)
            final_response_2.append("error")
            final_disposition.append("error")
            final_status.append("error") 
            
            
    elif Category == "CBN":
        try:

            response = CBN(TestCaseNo,Message)
            response_1, response_2, disposition, status = final_data(response)
            final_response_1.extend(response_1)
            final_response_2.extend(response_2)
            final_disposition.extend(disposition)
            final_status.extend(status)
            
            time.sleep(1)

        except Exception as e:
            print("TestCaseNo -",TestCaseNo,"in COUNSELLING slot failed --->",e)
            final_response_1.append(e)
            final_response_2.append("error")
            final_disposition.append("error")
            final_status.append("error")             
            
            
    elif Category == "no_message_Threshold":
        try:

            response = no_message_Threshold(TestCaseNo,Message)
            response_1, response_2, disposition, status = final_data(response)
            final_response_1.extend(response_1)
            final_response_2.extend(response_2)
            final_disposition.extend(disposition)
            final_status.extend(status)
            
            time.sleep(1)

        except Exception as e:
            print("TestCaseNo -",TestCaseNo,"in COUNSELLING slot failed --->",e)
            final_response_1.append(e)
            final_response_2.append("error")
            final_disposition.append("error")
            final_status.append("error")             
            
            
    else:
        try:

            response = LC(TestCaseNo,Message)
            response_1, response_2, disposition, status = final_data(response)
            final_response_1.extend(response_1)
            final_response_2.extend(response_2)
            final_disposition.extend(disposition)
            final_status.extend(status)
            
            time.sleep(1)

        except Exception as e:
            print("TestCaseNo -",TestCaseNo,"in COUNSELLING slot failed --->",e)
            final_response_1.append(e)
            final_response_2.append("error")
            final_disposition.append("error")
            final_status.append("error") 
            
            
            
print('\n','\n','\n')
print("COUNSELLING block is Completed, --- Run next block")
# Out:
#
#
#
# COUNSELLING block is Completed, --- Run next block

# %%
time.sleep(5)

# %%
#ASK_DELAY_SLOT (run this block to check testset in ASK_DELAY slot)

num = random.random()

with open(dataCSV, 'r') as f:
    reader = csv.reader(f)
    the_whole_file = list(reader)    
    
count = 0
while(count < (len(the_whole_file)-1)):
    count = count + 1
    TestCaseNo = the_whole_file[count][0]
    Message = the_whole_file[count][4]
    Category = the_whole_file[count][2]
    
    #print(TestCaseNo)
    #print(Message)
    #print(Category)
    #print(num)
    
    
    headers = {'Content-Type':'application/json'}    
    payload = json.dumps ({
        "user_id": "6305450418",
        "request_id": "requestcd1127",
        "sender": "saarthibajajvinay555"+str(TestCaseNo)+str(num),
        "message": "/initial_message"
    })
    response = requests.request("POST", botEndPoint, headers=headers, data=payload).json()
    
    
    
    headers = {'Content-Type':'application/json'}    
    payload = json.dumps ({
        "user_id": "6305450418",
        "request_id": "requestcd1127",
        "sender": "saarthibajajvinay555"+str(TestCaseNo)+str(num),
        "message": "yes"
    })
    response = requests.request("POST", botEndPoint, headers=headers, data=payload).json()
    
    
    
    headers = {'Content-Type':'application/json'}    
    payload = json.dumps ({
        "user_id": "6305450418",
        "request_id": "requestcd1127",
        "sender": "saarthibajajvinay555"+str(TestCaseNo)+str(num),
        "message": "i dont want to pay"
    })
    response = requests.request("POST", botEndPoint, headers=headers, data=payload).json()
    
    
    
    headers = {'Content-Type':'application/json'}    
    payload = json.dumps ({
        "user_id": "6305450418",
        "request_id": "requestcd1127",
        "sender": "saarthibajajvinay555"+str(TestCaseNo)+str(num),
        "message": "i dont want to pay"
    })
    response = requests.request("POST", botEndPoint, headers=headers, data=payload).json()    
    
    
    if Category == "LC_2":
        try:

            response = LC_2(TestCaseNo,Message)
            response_1, response_2, disposition, status = final_data(response)
            final_response_1.extend(response_1)
            final_response_2.extend(response_2)
            final_disposition.extend(disposition)
            final_status.extend(status)
            
            time.sleep(1)

        except Exception as e:
            print("TestCaseNo -",TestCaseNo,"in ASK_DELAY slot failed --->",e)
            final_response_1.append(e)
            final_response_2.append("error")
            final_disposition.append("error")
            final_status.append("error")             
            
            
            
    elif Category == "RPN":
        try:

            response = RPN(TestCaseNo,Message)
            response_1, response_2, disposition, status = final_data(response)
            final_response_1.extend(response_1)
            final_response_2.extend(response_2)
            final_disposition.extend(disposition)
            final_status.extend(status)
            
            time.sleep(1)

        except Exception as e:
            print("TestCaseNo -",TestCaseNo,"in ASK_DELAY slot failed --->",e)
            final_response_1.append(e)
            final_response_2.append("error")
            final_disposition.append("error")
            final_status.append("error")
            
            
    elif Category == "CBN":
        try:

            response = CBN(TestCaseNo,Message)
            response_1, response_2, disposition, status = final_data(response)
            final_response_1.extend(response_1)
            final_response_2.extend(response_2)
            final_disposition.extend(disposition)
            final_status.extend(status)
            
            time.sleep(1)

        except Exception as e:
            print("TestCaseNo -",TestCaseNo,"in ASK_DELAY slot failed --->",e)
            final_response_1.append(e)
            final_response_2.append("error")
            final_disposition.append("error")
            final_status.append("error")            
            
            
    elif Category == "no_message_Threshold":
        try:

            response = no_message_Threshold(TestCaseNo,Message)
            response_1, response_2, disposition, status = final_data(response)
            final_response_1.extend(response_1)
            final_response_2.extend(response_2)
            final_disposition.extend(disposition)
            final_status.extend(status)
            
            time.sleep(1)

        except Exception as e:
            print("TestCaseNo -",TestCaseNo,"in ASK_DELAY slot failed --->",e)
            final_response_1.append(e)
            final_response_2.append("error")
            final_disposition.append("error")
            final_status.append("error")            
            
            
    else:
        try:

            response = LC(TestCaseNo,Message)
            response_1, response_2, disposition, status = final_data(response)
            final_response_1.extend(response_1)
            final_response_2.extend(response_2)
            final_disposition.extend(disposition)
            final_status.extend(status)
            
            time.sleep(1)

        except Exception as e:
            print("TestCaseNo -",TestCaseNo,"in ASK_DELAY slot failed --->",e)
            final_response_1.append(e)
            final_response_2.append("error")
            final_disposition.append("error")
            final_status.append("error")
            
            
            
            
print('\n','\n','\n')
print("ASK_DELAY block is Completed, --- Run next block")
# Out:
#
#
#
# ASK_DELAY block is Completed, --- Run next block

# %%
time.sleep(5)

# %%
#RPN__SLOT (run this block to check testset in RPN_ slot)

num = random.random()

with open(dataCSV, 'r') as f:
    reader = csv.reader(f)
    the_whole_file = list(reader)    
    
count = 0
while(count < (len(the_whole_file)-1)):
    count = count + 1
    TestCaseNo = the_whole_file[count][0]
    Message = the_whole_file[count][4]
    Category = the_whole_file[count][2]
    
    #print(TestCaseNo)
    #print(Message)
    #print(Category)
    #print(num)
    
    
    headers = {'Content-Type':'application/json'}    
    payload = json.dumps ({
        "user_id": "6305450418",
        "request_id": "requestcd1127",
        "sender": "saarthibajajvinay555"+str(TestCaseNo)+str(num),
        "message": "/initial_message"
    })
    response = requests.request("POST", botEndPoint, headers=headers, data=payload).json()
    
    
    
    headers = {'Content-Type':'application/json'}    
    payload = json.dumps ({
        "user_id": "6305450418",
        "request_id": "requestcd1127",
        "sender": "saarthibajajvinay555"+str(TestCaseNo)+str(num),
        "message": "he is not available now"
    })
    response = requests.request("POST", botEndPoint, headers=headers, data=payload).json()
    
    
    
    headers = {'Content-Type':'application/json'}    
    payload = json.dumps ({
        "user_id": "6305450418",
        "request_id": "requestcd1127",
        "sender": "saarthibajajvinay555"+str(TestCaseNo)+str(num),
        "message": "you can connect with him after an year"
    })
    response = requests.request("POST", botEndPoint, headers=headers, data=payload).json()
    
    
    
    if Category == "LC_2":
        try:

            response = LC_2(TestCaseNo,Message)
            response_1, response_2, disposition, status = final_data(response)
            final_response_1.extend(response_1)
            final_response_2.extend(response_2)
            final_disposition.extend(disposition)
            final_status.extend(status)
            
            time.sleep(1)

        except Exception as e:
            print("TestCaseNo -",TestCaseNo,"in RPN_ slot failed --->",e)
            final_response_1.append(e)
            final_response_2.append("error")
            final_disposition.append("error")
            final_status.append("error")            
            
            
            
    elif Category == "RPN":
        warn = ["RPN cannot be checked again within RPN"]
        err = ["error"]

        final_response_1.extend(warn)
        final_response_2.extend(err)
        final_disposition.extend(err)
        final_status.extend(err)

        time.sleep(1)

            
            
    elif Category == "CBN":
        warn = ["CBN cannot be checked again within RPN"]
        err = ["error"]
        
        final_response_1.extend(warn)
        final_response_2.extend(err)
        final_disposition.extend(err)
        final_status.extend(err)

        time.sleep(1)
        
            
            
    elif Category == "no_message_Threshold":
        try:

            response = no_message_Threshold(TestCaseNo,Message)
            response_1, response_2, disposition, status = final_data(response)
            final_response_1.extend(response_1)
            final_response_2.extend(response_2)
            final_disposition.extend(disposition)
            final_status.extend(status)
            
            time.sleep(1)

        except Exception as e:
            print("TestCaseNo -",TestCaseNo,"in RPN_ slot failed --->",e)
            final_response_1.append(e)
            final_response_2.append("error")
            final_disposition.append("error")
            final_status.append("error")            
            
            
    else:
        try:

            response = LC(TestCaseNo,Message)
            response_1, response_2, disposition, status = final_data(response)
            final_response_1.extend(response_1)
            final_response_2.extend(response_2)
            final_disposition.extend(disposition)
            final_status.extend(status)
            
            time.sleep(1)

        except Exception as e:
            print("TestCaseNo -",TestCaseNo,"in RPN_ slot failed --->",e)
            final_response_1.append(e)
            final_response_2.append("error")
            final_disposition.append("error")
            final_status.append("error")
            
            
            
            
print('\n','\n','\n')
print("RPN_ block is Completed, --- Run next block")
# Out:
# TestCaseNo - 1 in RPN_ slot failed ---> [Errno Expecting value] Internal Server Error: 0
# TestCaseNo - 2 in RPN_ slot failed ---> [Errno Expecting value] Internal Server Error: 0
# TestCaseNo - 3 in RPN_ slot failed ---> [Errno Expecting value] Internal Server Error: 0
# TestCaseNo - 4 in RPN_ slot failed ---> [Errno Expecting value] Internal Server Error: 0
# TestCaseNo - 5 in RPN_ slot failed ---> [Errno Expecting value] Internal Server Error: 0
# TestCaseNo - 6 in RPN_ slot failed ---> [Errno Expecting value] Internal Server Error: 0
# TestCaseNo - 7 in RPN_ slot failed ---> [Errno Expecting value] Internal Server Error: 0
# TestCaseNo - 8 in RPN_ slot failed ---> [Errno Expecting value] Internal Server Error: 0
# TestCaseNo - 17 in RPN_ slot failed ---> [Errno Expecting value] Internal Server Error: 0
# TestCaseNo - 18 in RPN_ slot failed ---> [Errno Expecting value] Internal Server Error: 0
# TestCaseNo - 19 in RPN_ slot failed ---> [Errno Expecting value] Internal Server Error: 0
# TestCaseNo - 20 in RPN_ slot failed ---> [Errno Expecting value] Internal Server Error: 0
# TestCaseNo - 21 in RPN_ slot failed ---> [Errno Expecting value] Internal Server Error: 0
# TestCaseNo - 22 in RPN_ slot failed ---> [Errno Expecting value] Internal Server Error: 0
# TestCaseNo - 23 in RPN_ slot failed ---> [Errno Expecting value] Internal Server Error: 0
# TestCaseNo - 24 in RPN_ slot failed ---> [Errno Expecting value] Internal Server Error: 0
# TestCaseNo - 25 in RPN_ slot failed ---> [Errno Expecting value] Internal Server Error: 0
# TestCaseNo - 26 in RPN_ slot failed ---> [Errno Expecting value] Internal Server Error: 0
# TestCaseNo - 27 in RPN_ slot failed ---> [Errno Expecting value] Internal Server Error: 0
# TestCaseNo - 28 in RPN_ slot failed ---> [Errno Expecting value] Internal Server Error: 0
# TestCaseNo - 29 in RPN_ slot failed ---> [Errno Expecting value] Internal Server Error: 0
# TestCaseNo - 30 in RPN_ slot failed ---> [Errno Expecting value] Internal Server Error: 0
# TestCaseNo - 31 in RPN_ slot failed ---> [Errno Expecting value] Internal Server Error: 0
# TestCaseNo - 32 in RPN_ slot failed ---> [Errno Expecting value] Internal Server Error: 0
# TestCaseNo - 33 in RPN_ slot failed ---> [Errno Expecting value] Internal Server Error: 0
# TestCaseNo - 34 in RPN_ slot failed ---> [Errno Expecting value] Internal Server Error: 0
# TestCaseNo - 35 in RPN_ slot failed ---> [Errno Expecting value] Internal Server Error: 0
# TestCaseNo - 36 in RPN_ slot failed ---> [Errno Expecting value] Internal Server Error: 0
# TestCaseNo - 37 in RPN_ slot failed ---> [Errno Expecting value] Internal Server Error: 0
# TestCaseNo - 38 in RPN_ slot failed ---> [Errno Expecting value] Internal Server Error: 0
# TestCaseNo - 39 in RPN_ slot failed ---> [Errno Expecting value] Internal Server Error: 0
# TestCaseNo - 40 in RPN_ slot failed ---> [Errno Expecting value] Internal Server Error: 0
# TestCaseNo - 41 in RPN_ slot failed ---> [Errno Expecting value] Internal Server Error: 0
# TestCaseNo - 42 in RPN_ slot failed ---> [Errno Expecting value] Internal Server Error: 0
# TestCaseNo - 43 in RPN_ slot failed ---> [Errno Expecting value] Internal Server Error: 0
# TestCaseNo - 44 in RPN_ slot failed ---> [Errno Expecting value] Internal Server Error: 0
# TestCaseNo - 45 in RPN_ slot failed ---> [Errno Expecting value] Internal Server Error: 0
# TestCaseNo - 46 in RPN_ slot failed ---> [Errno Expecting value] Internal Server Error: 0
# TestCaseNo - 47 in RPN_ slot failed ---> [Errno Expecting value] Internal Server Error: 0
# TestCaseNo - 48 in RPN_ slot failed ---> [Errno Expecting value] Internal Server Error: 0
# TestCaseNo - 49 in RPN_ slot failed ---> [Errno Expecting value] Internal Server Error: 0
# TestCaseNo - 50 in RPN_ slot failed ---> [Errno Expecting value] Internal Server Error: 0
# TestCaseNo - 51 in RPN_ slot failed ---> [Errno Expecting value] Internal Server Error: 0
# TestCaseNo - 52 in RPN_ slot failed ---> [Errno Expecting value] Internal Server Error: 0
# TestCaseNo - 53 in RPN_ slot failed ---> [Errno Expecting value] Internal Server Error: 0
# TestCaseNo - 54 in RPN_ slot failed ---> [Errno Expecting value] Internal Server Error: 0
# TestCaseNo - 55 in RPN_ slot failed ---> [Errno Expecting value] Internal Server Error: 0
# TestCaseNo - 56 in RPN_ slot failed ---> [Errno Expecting value] Internal Server Error: 0
# TestCaseNo - 57 in RPN_ slot failed ---> [Errno Expecting value] Internal Server Error: 0
# TestCaseNo - 58 in RPN_ slot failed ---> [Errno Expecting value] Internal Server Error: 0
# TestCaseNo - 59 in RPN_ slot failed ---> [Errno Expecting value] Internal Server Error: 0
# TestCaseNo - 60 in RPN_ slot failed ---> [Errno Expecting value] Internal Server Error: 0
# TestCaseNo - 61 in RPN_ slot failed ---> [Errno Expecting value] Internal Server Error: 0
# TestCaseNo - 62 in RPN_ slot failed ---> [Errno Expecting value] Internal Server Error: 0
# TestCaseNo - 63 in RPN_ slot failed ---> [Errno Expecting value] Internal Server Error: 0
# TestCaseNo - 64 in RPN_ slot failed ---> [Errno Expecting value] Internal Server Error: 0
# TestCaseNo - 65 in RPN_ slot failed ---> [Errno Expecting value] Internal Server Error: 0
# TestCaseNo - 66 in RPN_ slot failed ---> [Errno Expecting value] Internal Server Error: 0
# TestCaseNo - 67 in RPN_ slot failed ---> [Errno Expecting value] Internal Server Error: 0
# TestCaseNo - 68 in RPN_ slot failed ---> [Errno Expecting value] Internal Server Error: 0
# TestCaseNo - 69 in RPN_ slot failed ---> [Errno Expecting value] Internal Server Error: 0
# TestCaseNo - 70 in RPN_ slot failed ---> [Errno Expecting value] Internal Server Error: 0
# TestCaseNo - 71 in RPN_ slot failed ---> [Errno Expecting value] Internal Server Error: 0
# TestCaseNo - 72 in RPN_ slot failed ---> [Errno Expecting value] Internal Server Error: 0
# TestCaseNo - 73 in RPN_ slot failed ---> [Errno Expecting value] Internal Server Error: 0
# TestCaseNo - 74 in RPN_ slot failed ---> [Errno Expecting value] Internal Server Error: 0
# TestCaseNo - 75 in RPN_ slot failed ---> [Errno Expecting value] Internal Server Error: 0
# TestCaseNo - 76 in RPN_ slot failed ---> [Errno Expecting value] Internal Server Error: 0
# TestCaseNo - 77 in RPN_ slot failed ---> [Errno Expecting value] Internal Server Error: 0
# TestCaseNo - 78 in RPN_ slot failed ---> [Errno Expecting value] Internal Server Error: 0
# TestCaseNo - 79 in RPN_ slot failed ---> [Errno Expecting value] Internal Server Error: 0
# TestCaseNo - 80 in RPN_ slot failed ---> [Errno Expecting value] Internal Server Error: 0
# TestCaseNo - 81 in RPN_ slot failed ---> [Errno Expecting value] Internal Server Error: 0
# TestCaseNo - 82 in RPN_ slot failed ---> [Errno Expecting value] Internal Server Error: 0
# TestCaseNo - 83 in RPN_ slot failed ---> [Errno Expecting value] Internal Server Error: 0
# TestCaseNo - 84 in RPN_ slot failed ---> [Errno Expecting value] Internal Server Error: 0
# TestCaseNo - 85 in RPN_ slot failed ---> [Errno Expecting value] Internal Server Error: 0
# TestCaseNo - 86 in RPN_ slot failed ---> [Errno Expecting value] Internal Server Error: 0
# TestCaseNo - 87 in RPN_ slot failed ---> [Errno Expecting value] Internal Server Error: 0
# TestCaseNo - 88 in RPN_ slot failed ---> [Errno Expecting value] Internal Server Error: 0
# TestCaseNo - 89 in RPN_ slot failed ---> [Errno Expecting value] Internal Server Error: 0
# TestCaseNo - 90 in RPN_ slot failed ---> [Errno Expecting value] Internal Server Error: 0
# TestCaseNo - 91 in RPN_ slot failed ---> [Errno Expecting value] Internal Server Error: 0
# TestCaseNo - 92 in RPN_ slot failed ---> [Errno Expecting value] Internal Server Error: 0
# TestCaseNo - 93 in RPN_ slot failed ---> [Errno Expecting value] Internal Server Error: 0
# TestCaseNo - 94 in RPN_ slot failed ---> [Errno Expecting value] Internal Server Error: 0
# TestCaseNo - 95 in RPN_ slot failed ---> [Errno Expecting value] Internal Server Error: 0
# TestCaseNo - 96 in RPN_ slot failed ---> [Errno Expecting value] Internal Server Error: 0
# TestCaseNo - 97 in RPN_ slot failed ---> [Errno Expecting value] Internal Server Error: 0
# TestCaseNo - 98 in RPN_ slot failed ---> [Errno Expecting value] Internal Server Error: 0
# TestCaseNo - 99 in RPN_ slot failed ---> [Errno Expecting value] Internal Server Error: 0
# TestCaseNo - 100 in RPN_ slot failed ---> [Errno Expecting value] Internal Server Error: 0
# TestCaseNo - 101 in RPN_ slot failed ---> [Errno Expecting value] Internal Server Error: 0
# TestCaseNo - 102 in RPN_ slot failed ---> [Errno Expecting value] Internal Server Error: 0
# TestCaseNo - 103 in RPN_ slot failed ---> [Errno Expecting value] Internal Server Error: 0
# TestCaseNo - 104 in RPN_ slot failed ---> [Errno Expecting value] Internal Server Error: 0
# TestCaseNo - 105 in RPN_ slot failed ---> [Errno Expecting value] Internal Server Error: 0
# TestCaseNo - 106 in RPN_ slot failed ---> [Errno Expecting value] Internal Server Error: 0
# TestCaseNo - 107 in RPN_ slot failed ---> [Errno Expecting value] Internal Server Error: 0
# TestCaseNo - 108 in RPN_ slot failed ---> [Errno Expecting value] Internal Server Error: 0
# TestCaseNo - 109 in RPN_ slot failed ---> [Errno Expecting value] Internal Server Error: 0
# TestCaseNo - 110 in RPN_ slot failed ---> [Errno Expecting value] Internal Server Error: 0
# TestCaseNo - 111 in RPN_ slot failed ---> [Errno Expecting value] Internal Server Error: 0
# TestCaseNo - 112 in RPN_ slot failed ---> [Errno Expecting value] Internal Server Error: 0
# TestCaseNo - 113 in RPN_ slot failed ---> [Errno Expecting value] Internal Server Error: 0
# TestCaseNo - 114 in RPN_ slot failed ---> [Errno Expecting value] Internal Server Error: 0
# TestCaseNo - 115 in RPN_ slot failed ---> [Errno Expecting value] Internal Server Error: 0
# TestCaseNo - 116 in RPN_ slot failed ---> [Errno Expecting value] Internal Server Error: 0
# TestCaseNo - 117 in RPN_ slot failed ---> [Errno Expecting value] Internal Server Error: 0
# TestCaseNo - 118 in RPN_ slot failed ---> [Errno Expecting value] Internal Server Error: 0
# TestCaseNo - 119 in RPN_ slot failed ---> [Errno Expecting value] Internal Server Error: 0
# TestCaseNo - 120 in RPN_ slot failed ---> [Errno Expecting value] Internal Server Error: 0
# TestCaseNo - 121 in RPN_ slot failed ---> [Errno Expecting value] Internal Server Error: 0
# TestCaseNo - 122 in RPN_ slot failed ---> [Errno Expecting value] Internal Server Error: 0
#
#
#
#
# RPN_ block is Completed, --- Run next block

# %%
time.sleep(5)

# %%
#CBN__SLOT (run this block to check testset in CBN_ slot)

num = random.random()

with open(dataCSV, 'r') as f:
    reader = csv.reader(f)
    the_whole_file = list(reader)    
    
count = 0
while(count < (len(the_whole_file)-1)):
    count = count + 1
    TestCaseNo = the_whole_file[count][0]
    Message = the_whole_file[count][4]
    Category = the_whole_file[count][2]
    
    #print(TestCaseNo)
    #print(Message)
    #print(Category)
    #print(num)
    
    
    headers = {'Content-Type':'application/json'}    
    payload = json.dumps ({
        "user_id": "6305450418",
        "request_id": "requestcd1127",
        "sender": "saarthibajajvinay555"+str(TestCaseNo)+str(num),
        "message": "/initial_message"
    })
    response = requests.request("POST", botEndPoint, headers=headers, data=payload).json()
    
    
    
    headers = {'Content-Type':'application/json'}    
    payload = json.dumps ({
        "user_id": "6305450418",
        "request_id": "requestcd1127",
        "sender": "saarthibajajvinay555"+str(TestCaseNo)+str(num),
        "message": "i am busy, call me later"
    })
    response = requests.request("POST", botEndPoint, headers=headers, data=payload).json()
    
    
    
    headers = {'Content-Type':'application/json'}    
    payload = json.dumps ({
        "user_id": "6305450418",
        "request_id": "requestcd1127",
        "sender": "saarthibajajvinay555"+str(TestCaseNo)+str(num),
        "message": "you can call me after 1 year"
    })
    response = requests.request("POST", botEndPoint, headers=headers, data=payload).json()
    
    
    
    if Category == "LC_2":
        try:

            response = LC_2(TestCaseNo,Message)
            response_1, response_2, disposition, status = final_data(response)
            final_response_1.extend(response_1)
            final_response_2.extend(response_2)
            final_disposition.extend(disposition)
            final_status.extend(status)
            
            time.sleep(1)

        except Exception as e:
            print("TestCaseNo -",TestCaseNo,"in CBN_ slot failed --->",e)
            final_response_1.append(e)
            final_response_2.append("error")
            final_disposition.append("error")
            final_status.append("error")            
            
            
            
    elif Category == "RPN":
        warn = ["RPN cannot be checked again within CBN"]
        err = ["error"]

        final_response_1.extend(warn)
        final_response_2.extend(err)
        final_disposition.extend(err)
        final_status.extend(err)

        time.sleep(1)

            
            
    elif Category == "CBN":
        warn = ["CBN cannot be checked again within CBN"]
        err = ["error"]
        
        final_response_1.extend(warn)
        final_response_2.extend(err)
        final_disposition.extend(err)
        final_status.extend(err)

        time.sleep(1)
        
            
            
    elif Category == "no_message_Threshold":
        try:

            response = no_message_Threshold(TestCaseNo,Message)
            response_1, response_2, disposition, status = final_data(response)
            final_response_1.extend(response_1)
            final_response_2.extend(response_2)
            final_disposition.extend(disposition)
            final_status.extend(status)
            
            time.sleep(1)

        except Exception as e:
            print("TestCaseNo -",TestCaseNo,"in CBN_ slot failed --->",e)
            final_response_1.append(e)
            final_response_2.append("error")
            final_disposition.append("error")
            final_status.append("error")            
            
            
    else:
        try:

            response = LC(TestCaseNo,Message)
            response_1, response_2, disposition, status = final_data(response)
            final_response_1.extend(response_1)
            final_response_2.extend(response_2)
            final_disposition.extend(disposition)
            final_status.extend(status)
            
            time.sleep(1)

        except Exception as e:
            print("TestCaseNo -",TestCaseNo,"in CBN_ slot failed --->",e)
            final_response_1.append(e)
            final_response_2.append("error")
            final_disposition.append("error")
            final_status.append("error")
            
print('\n','\n','\n')
print("CBN block is Completed, --- Run next block")
# Out:
#
#
#
# CBN block is Completed, --- Run next block

# %%
time.sleep(5)

# %%
df = pd.DataFrame()
df["Bot_Response_1"] = final_response_1
df["Bot_Response_2"] = final_response_2
df["Disposition"] = final_disposition
df["Status_Code"] = final_status

df.to_csv(Final_Sheet, index=False)


print('\n','\n','\n')
print ("required data is downloaded as a CSV in path = .......",Final_Sheet)
print('\n','\n','\n')


#df.head(30)
# Out:
#
#
#
# required data is downloaded as a CSV in path = ....... /Users/vinay_kl/Downloads/Final_Sheet_hindi_UFYW_DICE_['15:15:51'].csv

# %%
#1:38 PM
#14:00:44
#24 minutes

# import datetime
# import re

# v = datetime.datetime.now()
# #print(v)

# #pattern = '\d{4}-\d{2}-\d{2} (\d{2}:\d{2}:\d{2})\.\d{6}'
# pattern = "[\d]+-[\d]+-[\d]+ ([\d]+:[\d]+:[\d]+)\.[\d]+"

# required = re.findall(pattern,str(v))
# #print(required)

# %%
# print(len(final_response_1))
# print(len(final_response_2))
# print(len(final_disposition))
# print(len(final_status))

# %%
# df1 = pd.DataFrame()
# df1["Disposition"] = final_disposition
# df1.to_csv(Final_Sheet, index=False)

# %% [markdown]
# # Rough

# %%
import pandas as pd

df = pd.DataFrame()



num = random.random()
TestCaseNo = 1
Message = "i will pay today"

headers = {'Content-Type':'application/json'}    
payload = json.dumps ({
    "user_id": "6305450418",
    "request_id": "requestcd1127",
    "sender": "saarthibajajvinay555"+str(TestCaseNo)+str(num),
    "message": "/initial_message"
})
response = requests.request("POST", botEndPoint, headers=headers, data=payload).json()


headers = {'Content-Type':'application/json'}    
payload = json.dumps ({
    "user_id": "6305450418",
    "request_id": "requestcd1127",
    "sender": "saarthibajajvinay555"+str(TestCaseNo)+str(num),
    "message": "yes"
})
response = requests.request("POST", botEndPoint, headers=headers, data=payload).json()


headers = {'Content-Type':'application/json'}    
payload = json.dumps ({
    "user_id": "6305450418",
    "request_id": "requestcd1127",
    "sender": "saarthibajajvinay555"+str(TestCaseNo)+str(num),
    "message": Message
})
response = requests.request("POST", botEndPoint, headers=headers, data=payload).json()


def final_data(response):
    text_list = []
    response_1 = ["-"]
    response_2 = ["-"]
    #response_3 = ["-"]
    disposotion_list = []
    staus_list = []

    temp_status = response["custom"]["status"]
    temp_disp = response["custom"]["disposition_id"]
    temp_disp = ",".join(temp_disp)     #its like a text combining method with given delimeter

    val = response["data"]
    for i in range(0,len(val)):    
          temp_text = response["data"][i]["text"]
          text_list.append(temp_text)

    for i in range(0,len(text_list)):
        if i == 0:
            response_1 = [text_list[i]]
        if i == 1:
            response_2 = [text_list[i]]
        # if i == 2:
        #     response_3 = [text_list[i]]
        
    return response_1,response_2, [temp_disp], [temp_status]

final_response_1 = final_response_2 = final_disposition = final_status = []
response_1, response_2, disposition, status = final_data(response)

final_response_1.extend(response_1)
final_response_2.extend(response_2)
final_response_1.extend(response_1)
final_response_1.extend(response_1)
print(response_1, response_2, disposition, status)

# a = ["1"]
# b= ["2"]

# c = a.append(b) = ["1",["2"]]
# d = a.extend(b) = a+b = ["1","2"]




#print("vds",response_2)
df["response_1"] = response_1
df["response_2"] = response_2
#df["response_3"] = response_3
df["disposition"] = disposition
df["status"] = status



# df.to_csv("Temp.csv",index=False)

df.head(5)

# %%
response_1=response_2=disposition=status = []


    RPC = pd.DataFrame()


    num = random.random()

    with open(dataCSV, 'r') as f:
        reader = csv.reader(f)
        the_whole_file = list(reader)    

    count = 0
    while(count < 6):
        count = count + 1
        TestCaseNo = the_whole_file[count][0]
        Message = the_whole_file[count][4]
        Category = the_whole_file[count][2]

        #print(TestCaseNo)
        #print(Message)
        #print(Category)
        #print(num)

        headers = {'Content-Type':'application/json'}    
        payload = json.dumps ({
            "user_id": "6305450418",
            "request_id": "requestcd1127",
            "sender": "saarthibajajvinay555"+str(TestCaseNo)+str(num),
            "message": "/initial_message"
        })
        response = requests.request("POST", botEndPoint, headers=headers, data=payload).json()


        headers = {'Content-Type':'application/json'}    
        payload = json.dumps ({
            "user_id": "6305450418",
            "request_id": "requestcd1127",
            "sender": "saarthibajajvinay555"+str(TestCaseNo)+str(num),
            "message": "yes"
        })
        response = requests.request("POST", botEndPoint, headers=headers, data=payload).json()


        headers = {'Content-Type':'application/json'}    
        payload = json.dumps ({
            "user_id": "6305450418",
            "request_id": "requestcd1127",
            "sender": "saarthibajajvinay555"+str(TestCaseNo)+str(num),
            "message": Message
        })
        response = requests.request("POST", botEndPoint, headers=headers, data=payload).json()



        text_list = []
        response_1 = ["-"]
        response_2 = ["-"]
        disposition_list = []
        status_list = []



        temp_status = response["custom"]["status"]
        temp_disp = response["custom"]["disposition_id"]
        temp_disp = ",".join(temp_disp)     #its like a text combining method with given delimeter



        val = response["data"]
        for i in range(0,len(val)):    
              temp_text = response["data"][i]["text"]
              text_list.append(temp_text)



        for i in range(0,len(text_list)):
            if i == 0:
                Response_1 = [text_list[i]]
            if i == 1:
                Response_2 = [text_list[i]]



        RPC["response_1"] = response_1.append(Response_1)
        RPC["response_2"] = response_2.append(Response_1)
        RPC["disposition"] = disposition_list.append([temp_disp])
        RPC["status"] = status_list.append([temp_status])



        RPC.to_csv(RPC_Sheet, index=False)


    RPC.head(2)

# %%
with open(dataCSV, 'r') as f:
    reader = csv.reader(f)
    the_whole_file = list(reader)
    print(len(the_whole_file))

# %%
a = ["0","1"]
b = "2"
c = ["3","4"]
d = [["4"],["5","6"]]

a.append(d)
print(a)

a = ["0","1"]
a.extend(d)
print(a)

# %%
TestCaseNo = 1,
num = random.random()
message_list = ["/initial_message","i am busy, call me later","you can call me after an year"]
for i in range(0,len(message_list)):
    print(i,message_list[i])
    message = message_list[i]
    headers = {'Content-Type':'application/json'}    
    payload = json.dumps ({
        "user_id": "6305450418",
        "request_id": "requestcd1127",
        "sender":"saarthadjvinfay555",
        "message": message
    })
    response = requests.request("POST", botEndPoint, headers=headers, data=payload).json()

# %%
num = random.random()
TestCaseNo = 2
Message = "/initial_message"
    
    
headers = {'Content-Type':'application/json'}    
payload = json.dumps ({
    "user_id": "6305450418",
    "request_id": "requestcd1127",
    "sender": "saarthibajajvinay555"+str(TestCaseNo)+str(num),
    "message": Message
})
response = requests.request("POST", botEndPoint, headers=headers, data=payload).json()

# return response

#print(response)

i = response["data"]

for dicts in i:
    lastResponse = dicts["text"]
    print(lastResponse,"\t", end=' ')




disposition = response["custom"]["disposition_id"]
status = response["custom"]["status"]  

print(disposition,'\t',status)

# %%
headers = {'Content-Type':'application/json'}    
payload = json.dumps ({
"user_id": "6305450418",
"request_id": "request11j27",
"sender": "Guru-5lklkkkkjkllkklllkkllkk",
"message": "/initial_message"
                      })
response = requests.request("POST", botEndPoint, headers=headers, data=payload).json()

pprint(response)
