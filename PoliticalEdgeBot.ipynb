# %%
#import the required dependencies

import requests
import json
import pandas as pd
from pprint import pprint
import csv
import time
import random
import datetime
import re

print("all required dependencies are imported successfully")
# Out:
# all required dependencies are imported successfully

# %%
#update the testset and final sheet's path. then run the block


language = "Marathi"

dataCSV = "/Users/vinay_kl/Downloads/QA _ PoliticalEdge - BOT_Testset (3).csv"

#stellantis
# botEndPoint = "https://poojafin.saarthi.ai/stellantis_english/webhook"
#PoliticalEdge
botEndPoint = "https://stage-threebot.saarthi.ai/politics_marathi/webhook"

v = datetime.datetime.now()
#print(v)

#pattern = '\d{4}-\d{2}-\d{2} (\d{2}:\d{2}:\d{2})\.\d{6}'
pattern = "[\d]+-[\d]+-[\d]+ ([\d]+:[\d]+:[\d]+)\.[\d]+"

required = re.findall(pattern,str(v))
#print(required)


#---------------------------------------------------------------------------------------#


Final_Sheet = "/Users/vinay_kl/Downloads/Final_Sheet_Stellantis_"+str(language)+"_"+str(required)+".csv"

print(Final_Sheet)

print("testset and final_sheet is pushed to respective variables")
# Out:
# /Users/vinay_kl/Downloads/Final_Sheet_Stellantis_Marathi_['10:11:42'].csv
# testset and final_sheet is pushed to respective variables

# %%
#functions



def BOT_FUNCTION(Final_T_NO = None,Final_Utterance = None,Flow = None,GRT = None,BRT = None):
    headers = {'Content-Type':'application/json'}    
    payload = json.dumps ({
    "user_id": "9482152445",
    "request_id": "request11j27",
    "sender": "tej-247657989"+str(Final_T_NO)+str(num),
    "message": Final_Utterance,
    "customerData": {
        "callId": "12345",
        "bargingCall": "True",
        "accessToken": "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VySWQiOiI2NDUwYjkyN2YzZGZlYzMyMDIxNDgxMzciLCJhY2NvdW50SWQiOiI2NDUwYjkyNmYzZGZlYzMyMDIxNDgxMmUiLCJyb2xlIjoiQWRtaW4iLCJpYXQiOjE2ODM1NDM5NDAsImV4cCI6MTY4MzYzMDM0MH0.slLTPbIA92IDfsZUJKR0rxFnVgDi7M5mtDLaWDmlJsc",
        "clientName": "Stellantis Testing",
        "callType": "Internal UAT",
        "telephonyName": "Epicode",
        "customerInfo": {
            "contactInfo": {
                "primary": "9354069780",
                "customerSupportNumber": "4233423434",
                "customerCareNumber": ""
            },
            "primaryInfo": {
                "firstName": "ram",
                "vehicleIdentificationNumber": "1223345667",
                "sellingDealerName": "sdfsdf",
                "geographicLocation": "",
                "pincode": "",
                "lastServiceDealerCity": "sdfsdfsdf",
                "lastServiceDealerName": "lkjfsdklf",
                "preferredAgentGender": "M",
                "agentname": "kumar",
                "serviceDueDate": "2023-05-18",
                "captured_date": "2023-05-18",
                "serviceNetworkName": "dsfsfsdf",
                "flow": "political_edge_flow",
                "status": "Appointment Confirmed",
                "channel": "Voice",
                "utter_sub_flow_slot": "main_flow",
                "generalRepeatThreshold": str(GRT),
                "businessIntentThreshold": str(BRT),
                "previousDisposition": "Campaign End",
                "language": "Marathi",
                "age": "",
                "gender": "",
                "region": "",
                "collared": "",
                "customerUniqueId": ""
            },
            "loanAccountDetails": {
                "emiAmount": "",
                "emiDueDate": "",
                "loanApplicationDate": "",
                "loanEndingDate": "",
                "lateFee": "",
                "interestRate": "",
                "nextNachDate": "",
                "paidDate": "",
                "currentPaymentStatus": "",
                "noofemi": "",
                "noOfEmiPaid": "",
                "loanTenureLeft": "",
                "loanAmountRemaining": "",
                "loanStartDate": "",
                "principalAmount": "",
                "totalLoanAmount": "",
                "loanCategory": "",
                "loanId": "",
                "noOfLoans": "",
                "paymentMode": "",
                "cbCharges": "0",
                "penalCharges": "0"
            },
            "behaviourDetails": {
                "riskType": "",
                "typology": "",
                "callDisposition": ""
            },
            "email": {
                "primary": ""
            },
            "leadType": "Transactional"
        },
        "callingPartner": "epicode",
        "campaignId": "2345",
        "agentConfig": {
            "parentFlow": [
                {
                    "flow": "appointment_booking_flow",
                    "isParent": True,
                    "isChild": False,
                    "channel": [
                        "Call"
                    ],
                    "type": "Female",
                    "language": [
                        "English",
                        "Hindi"
                    ],
                    "Call": {
                        "voice": "Saarthi TTS",
                        "thresholdDateCallBack": 2,
                        "thresholdTimeCallBack": 30
                    }
                }
            ],
            "callFlow": [
                {
                    "appointment_booking_flow": {
                        "slot1": [
                            {
                                "initial": {
                                    "label": "lg_rpc_form",
                                    "next": "subSlot1"
                                },
                                "subSlot1": [
                                    {
                                        "third_party_contact": {
                                            "initial": [
                                                {
                                                    "label": "third_party_contact_form",
                                                    "next": "subSlot1"
                                                }
                                            ],
                                            "subSlot1": [
                                                {
                                                    "label": "stop_conversation"
                                                }
                                            ]
                                        },
                                        "call_back": {
                                            "initial": [
                                                {
                                                    "label": "call_back_form",
                                                    "next": "subSlot1"
                                                }
                                            ],
                                            "subSlot1": [
                                                {
                                                    "label": "stop_conversation"
                                                }
                                            ]
                                        },
                                        "small_talk": {
                                            "initial": [
                                                {
                                                    "label": "small_talk_form",
                                                    "next": "subSlot1"
                                                }
                                            ],
                                            "subSlot1": [
                                                {
                                                    "label": "stop_conversation"
                                                }
                                            ]
                                        }
                                    }
                                ]
                            }
                        ],
                        "slot2": [
                            {
                                "label": "date_confirmation_form",
                                "next": "slot3"
                            }
                        ],
                        "slot3": [
                            {
                                "not_interested": {
                                    "initial": [
                                        {
                                            "label": "not_interested_form",
                                            "next": "subSlot1"
                                        }
                                    ],
                                    "subSlot1": [
                                        {
                                            "label": "stop_conversation"
                                        }
                                    ]
                                },
                                "interested_later": {
                                    "initial": [
                                        {
                                            "label": "interested_later_form",
                                            "next": "subSlot1"
                                        }
                                    ],
                                    "subSlot1": [
                                        {
                                            "label": "stop_conversation"
                                        }
                                    ]
                                },
                                "call_back": {
                                    "initial": [
                                        {
                                            "label": "call_back_form",
                                            "next": "subSlot1"
                                        }
                                    ],
                                    "subSlot1": [
                                        {
                                            "label": "stop_conversation"
                                        }
                                    ]
                                },
                                "date_capture": {
                                    "initial": [
                                        {
                                            "label": "date_capture_form",
                                            "next": "subSlot1"
                                        }
                                    ],
                                    "subSlot1": [
                                        {
                                            "dealership_capture": {
                                                "initial": [
                                                    {
                                                        "label": "dealership_capture_form",
                                                        "next": "sub1Slot1"
                                                    }
                                                ],
                                                "sub1Slot1": [
                                                    {
                                                        "deny": {
                                                            "initial": [
                                                                {
                                                                    "label": "deny_dealership_form",
                                                                    "next": "sub2Slot1"
                                                                }
                                                            ],
                                                            "sub2Slot1": [
                                                                {
                                                                    "label": "stop_conversation"
                                                                }
                                                            ]
                                                        },
                                                        "affirm": {
                                                            "initial": [
                                                                {
                                                                    "label": "pickup_drop_capture_form",
                                                                    "next": "sub2Slot1"
                                                                }
                                                            ],
                                                            "sub2Slot1": [
                                                                {
                                                                    "label": "stop_conversation"
                                                                }
                                                            ]
                                                        }
                                                    }
                                                ]
                                            }
                                        }
                                    ]
                                },
                                "dealership_capture": {
                                    "initial": [
                                        {
                                            "label": "dealership_capture_form",
                                            "next": "sub1Slot1"
                                        }
                                    ],
                                    "sub1Slot1": [
                                        {
                                            "deny": {
                                                "initial": [
                                                    {
                                                        "label": "deny_dealership_form",
                                                        "next": "sub2Slot1"
                                                    }
                                                ],
                                                "sub2Slot1": [
                                                    {
                                                        "label": "stop_conversation"
                                                    }
                                                ]
                                            },
                                            "affirm": {
                                                "initial": [
                                                    {
                                                        "label": "pickup_drop_capture_form",
                                                        "next": "sub2Slot1"
                                                    }
                                                ],
                                                "sub2Slot1": [
                                                    {
                                                        "label": "stop_conversation"
                                                    }
                                                ]
                                            }
                                        }
                                    ]
                                }
                            }
                        ]
                    },
                    "follow_up_flow": {
                        "slot1": [
                            {
                                "initial": {
                                    "label": "lg_rpc_form",
                                    "next": "subSlot1"
                                },
                                "subSlot1": [
                                    {
                                        "third_party_contact": {
                                            "initial": [
                                                {
                                                    "label": "third_party_contact_form",
                                                    "next": "subSlot1"
                                                }
                                            ],
                                            "subSlot1": [
                                                {
                                                    "label": "stop_conversation"
                                                }
                                            ]
                                        },
                                        "call_back": {
                                            "initial": [
                                                {
                                                    "label": "call_back_form",
                                                    "next": "subSlot1"
                                                }
                                            ],
                                            "subSlot1": [
                                                {
                                                    "label": "stop_conversation"
                                                }
                                            ]
                                        },
                                        "small_talk": {
                                            "initial": [
                                                {
                                                    "label": "small_talk_form",
                                                    "next": "subSlot1"
                                                }
                                            ],
                                            "subSlot1": [
                                                {
                                                    "label": "stop_conversation"
                                                }
                                            ]
                                        }
                                    }
                                ]
                            }
                        ],
                        "slot2": [
                            {
                                "label": "followup_dealership_capture_form",
                                "next": "slot3"
                            }
                        ],
                        "slot3": [
                            {
                                "not_interested": {
                                    "initial": [
                                        {
                                            "label": "not_interested_form",
                                            "next": "subSlot1"
                                        }
                                    ],
                                    "subSlot1": [
                                        {
                                            "label": "stop_conversation"
                                        }
                                    ]
                                },
                                "interested_later": {
                                    "initial": [
                                        {
                                            "label": "interested_later_form",
                                            "next": "subSlot1"
                                        }
                                    ],
                                    "subSlot1": [
                                        {
                                            "label": "stop_conversation"
                                        }
                                    ]
                                },
                                "call_back": {
                                    "initial": [
                                        {
                                            "label": "call_back_form",
                                            "next": "subSlot1"
                                        }
                                    ],
                                    "subSlot1": [
                                        {
                                            "label": "stop_conversation"
                                        }
                                    ]
                                },
                                "new_date_capture": {
                                    "initial": [
                                        {
                                            "label": "date_capture_form",
                                            "next": "subSlot1"
                                        }
                                    ],
                                    "subSlot1": [
                                        {
                                            "dealership_capture": {
                                                "initial": [
                                                    {
                                                        "label": "dealership_capture_form",
                                                        "next": "sub1Slot1"
                                                    }
                                                ],
                                                "sub1Slot1": [
                                                    {
                                                        "deny": {
                                                            "initial": [
                                                                {
                                                                    "label": "deny_dealership_form",
                                                                    "next": "sub2Slot1"
                                                                }
                                                            ],
                                                            "sub2Slot1": [
                                                                {
                                                                    "label": "stop_conversation"
                                                                }
                                                            ]
                                                        },
                                                        "affirm": {
                                                            "initial": [
                                                                {
                                                                    "label": "pickup_drop_capture_form",
                                                                    "next": "sub2Slot1"
                                                                }
                                                            ],
                                                            "sub2Slot1": [
                                                                {
                                                                    "label": "stop_conversation"
                                                                }
                                                            ]
                                                        }
                                                    }
                                                ]
                                            }
                                        }
                                    ]
                                },
                                "deny_dealership": {
                                    "initial": [
                                        {
                                            "label": "deny_dealership_form",
                                            "next": "sub2Slot1"
                                        }
                                    ],
                                    "sub2Slot1": [
                                        {
                                            "label": "stop_conversation"
                                        }
                                    ]
                                },
                                "pickup_drop_capture": {
                                    "initial": [
                                        {
                                            "label": "pickup_drop_capture_form",
                                            "next": "sub2Slot1"
                                        }
                                    ],
                                    "sub2Slot1": [
                                        {
                                            "label": "stop_conversation"
                                        }
                                    ]
                                }
                            }
                        ]
                    },
                    "remainder_flow": {
                        "slot1": [
                            {
                                "initial": {
                                    "label": "lg_rpc_form",
                                    "next": "subSlot1"
                                },
                                "subSlot1": [
                                    {
                                        "third_party_contact": {
                                            "initial": [
                                                {
                                                    "label": "third_party_contact_form",
                                                    "next": "subSlot1"
                                                }
                                            ],
                                            "subSlot1": [
                                                {
                                                    "label": "stop_conversation"
                                                }
                                            ]
                                        },
                                        "call_back": {
                                            "initial": [
                                                {
                                                    "label": "call_back_form",
                                                    "next": "subSlot1"
                                                }
                                            ],
                                            "subSlot1": [
                                                {
                                                    "label": "stop_conversation"
                                                }
                                            ]
                                        },
                                        "small_talk": {
                                            "initial": [
                                                {
                                                    "label": "small_talk_form",
                                                    "next": "subSlot1"
                                                }
                                            ],
                                            "subSlot1": [
                                                {
                                                    "label": "stop_conversation"
                                                }
                                            ]
                                        }
                                    }
                                ]
                            }
                        ],
                        "slot2": [
                            {
                                "label": "booking_confirmation_form",
                                "next": "slot3"
                            }
                        ],
                        "slot3": [
                            {
                                "interested_later": {
                                    "initial": [
                                        {
                                            "label": "interested_later_form",
                                            "next": "subSlot1"
                                        }
                                    ],
                                    "subSlot1": [
                                        {
                                            "label": "stop_conversation"
                                        }
                                    ]
                                },
                                "call_back": {
                                    "initial": [
                                        {
                                            "label": "call_back_form",
                                            "next": "subSlot1"
                                        }
                                    ],
                                    "subSlot1": [
                                        {
                                            "label": "stop_conversation"
                                        }
                                    ]
                                }
                            }
                        ]
                    },
                    "feedback_flow": {
                        "slot1": [
                            {
                                "initial": {
                                    "label": "lg_rpc_form",
                                    "next": "subSlot1"
                                },
                                "subSlot1": [
                                    {
                                        "third_party_contact": {
                                            "initial": [
                                                {
                                                    "label": "third_party_contact_form",
                                                    "next": "subSlot1"
                                                }
                                            ],
                                            "subSlot1": [
                                                {
                                                    "label": "stop_conversation"
                                                }
                                            ]
                                        },
                                        "call_back": {
                                            "initial": [
                                                {
                                                    "label": "call_back_form",
                                                    "next": "subSlot1"
                                                }
                                            ],
                                            "subSlot1": [
                                                {
                                                    "label": "stop_conversation"
                                                }
                                            ]
                                        },
                                        "small_talk": {
                                            "initial": [
                                                {
                                                    "label": "small_talk_form",
                                                    "next": "subSlot1"
                                                }
                                            ],
                                            "subSlot1": [
                                                {
                                                    "label": "stop_conversation"
                                                }
                                            ]
                                        }
                                    }
                                ]
                            }
                        ],
                        "slot2": [
                            {
                                "label": "rating_based_form",
                                "next": "slot3"
                            }
                        ],
                        "slot3": [
                            {
                                "call_back": {
                                    "initial": [
                                        {
                                            "label": "call_back_form",
                                            "next": "subSlot1"
                                        }
                                    ],
                                    "subSlot1": [
                                        {
                                            "label": "stop_conversation"
                                        }
                                    ]
                                }
                            }
                        ]
                    }
                }
            ],
            "accountId": "6450b926f3dfec320214812e",
            "agentName": "Stella",
            "domain": "Automobile",
            "subDomain": "General",
            "productType": "Four Wheeler",
            "agentId": "PoliticaledgeTesting_salesOnboarding_PoliticalInitiative_03",
            "createdAt": "2023-05-05T06:11:54.021Z",
            "updatedAt": "2023-05-05T06:11:54.021Z",
            "id": "64549e2ac0e8415d50370c7c"
        },
        "useCaseId": "62c81c4a4a0affe91342aaaa",
        "accountId": "6450b926f3dfec320214812e",
        "isCampaignTesting": True
    }
    }
    )
    response = requests.request("POST", botEndPoint, headers=headers, data=payload).json()

#     return(response)
    
    

# def final_data(response):
    text_list = []
    response_1 = ["-"]
    response_2 = ["-"]
    response_3 = ["-"]
    disposotion_list = []
    staus_list = []

    temp_status = response["custom"]["status"]
    temp_disp = response["custom"]["disposition_id"]
    temp_disp = ",".join(map(str, temp_disp))     #its like a text combining method with given delimeter.  map & str is added to reduce "sequence no N" error

    val = response["data"]
    for i in range(0,len(val)):    
          temp_text = response["data"][i]["text"]
          text_list.append(temp_text)

    for i in range(0,len(text_list)):
        if i == 0:
            response_1 = [text_list[i]]
        if i == 1:
            response_2 = [text_list[i]]
        if i == 2:
            response_3 = [text_list[i]]

    print(Final_T_NO, "\t", Final_Utterance, "\t", response_1, "\t", response_2, "\t", response_3, "\t", [temp_disp], "\t", [temp_status])        
    return Final_T_NO, Final_Utterance, response_1, response_2, response_3, [temp_disp], [temp_status]






print("all required functions are successfully called")
# Out:
# all required functions are successfully called

# %%
final_Tno = []
final_user_resp = []

final_response_1 = []
final_response_2 = []
final_response_3 = []
final_disposition = []
final_status = []

print("Empty lists created, --- Run next block")
# Out:
# Empty lists created, --- Run next block

# %%
num = random.random()

df = pd.read_csv(dataCSV)
df.head()


TestCase_No = df["T_N_O"]
Utterance_Coloum = df["Final_List"]
flow = df["Flow"]
grt = df["General_Intent_Threshold"]
brt = df["Business_Intent_Threshold"]


for i in range(0,len(Utterance_Coloum)):
# for i in range(885,len(Utterance_Coloum)):
    
    
    MID_T_NO = TestCase_No[i]
    Flow = flow[i]
    GRT = grt[i]
    BRT = brt[i]
    
#     print(MID_T_NO, Flow, GRT, BRT)
    
    Utterance_List = eval(Utterance_Coloum[i])
    for j in range(0,len(Utterance_List)):
        Final_Utterance = Utterance_List[j]
        Final_T_NO = MID_T_NO
#         print(Final_T_NO)
#         print(Final_Utterance)
        
                
        try:

#             response = BOT_FUNCTION(Final_T_NO,Final_Utterance)
#             print("TestCaseNo - ", Final_T_NO," Passed")
            Final_T_NO, Final_Utterance, response_1, response_2, response_3, disposition, status = BOT_FUNCTION(Final_T_NO,Final_Utterance,Flow,GRT,BRT)
          
            final_Tno.append(Final_T_NO)
            final_user_resp.append(Final_Utterance)        
            final_response_1.extend(response_1)
            final_response_2.extend(response_2)
            final_response_3.extend(response_3)            
            final_disposition.extend(disposition)
            final_status.extend(status)
            
#             time.sleep(1)

        except Exception as e:
#             print("TestCaseNo - ",Final_T_NO," failed ---> ",e)
            print(Final_T_NO, "\t", Final_Utterance, "\t", e, "\t", "error", "\t", "error", "\t", "error", "\t", "error")
    
            final_Tno.append(Final_T_NO)
            final_user_resp.append(Final_Utterance) 
            final_response_1.append(e)
            final_response_2.append("error")
            final_response_3.append("error")        
            final_disposition.append("error")
            final_status.append("error")
            
            
            
print("Testcases completed, --- Run next block")
# Out:
# 0 	 /initial_message 	 ["नमस्कार. मी, 'ड्रग फ्री इंडिया' या एन्जीओमधून Neha बोलत आहे. मी ram यांच्याशी बोलत आहे का?"] 	 ['-'] 	 ['-'] 	 ['initial_message'] 	 [702]
# 0 	 आपण हिंदी बोलू शकता? 	 ["मी हा कॉल महाराष्ट्राचे मुख्यमंत्री/ श्री. एकनाथ शिंदे यांच्या, 'मिशन थट्टी डेझ्' अंतर्गत 'मुंबई अगेंस्ट drugs' या महत्त्वपूर्ण उपक्रमाबद्दल, तुम्हाला माहिती देण्यासाठी/ केला आहे. तुम्ही मुंबईच्या कोणत्या एरियामध्ये राहता?"] 	 ['-'] 	 ['-'] 	 ['Right Party Contact,Right Party Contact'] 	 [702]
# 1 	 /initial_message 	 ["नमस्कार. मी, 'ड्रग फ्री इंडिया' या एन्जीओमधून Neha बोलत आहे. मी ram यांच्याशी बोलत आहे का?"] 	 ['-'] 	 ['-'] 	 ['initial_message'] 	 [702]
# 1 	 मला मराठी माहित no 	 ['मी ram यांच्याशी बोलत आहे का?'] 	 ['-'] 	 ['-'] 	 ['initial_message'] 	 [702]
# 2 	 /initial_message 	 ["नमस्कार. मी, 'ड्रग फ्री इंडिया' या एन्जीओमधून Neha बोलत आहे. मी ram यांच्याशी बोलत आहे का?"] 	 ['-'] 	 ['-'] 	 ['initial_message'] 	 [702]
# 2 	 कृपया तमिळ मध्ये बोला 	 ['ओके. मी तुम्हाला पुन्हा केव्हा कॉल करू शकते?'] 	 ['-'] 	 ['-'] 	 ['Callback,Callback Time Not Given'] 	 [702]
# 2 	 ठीक आहे हिंदी मध्ये बोला 	 ['-'] 	 ['-'] 	 ['-'] 	 [''] 	 [702]
# 3 	 /initial_message 	 ["नमस्कार. मी, 'ड्रग फ्री इंडिया' या एन्जीओमधून Neha बोलत आहे. मी ram यांच्याशी बोलत आहे का?"] 	 ['-'] 	 ['-'] 	 ['initial_message'] 	 [702]
# 3 	 कृपया बांगला मध्ये बोला 	 ['ठीक आहे. आमचे एजंट तुम्हाला लवकरच कॉन्टॅक्ट करतील.'] 	 ['-'] 	 ['-'] 	 [''] 	 [701]
# 3 	 मला मराठी माहित no 	 ['मी ram यांच्याशी बोलत आहे का?'] 	 ['-'] 	 ['-'] 	 ['initial_message'] 	 [702]
# 4 	 /initial_message 	 ["नमस्कार. मी, 'ड्रग फ्री इंडिया' या एन्जीओमधून Neha बोलत आहे. मी ram यांच्याशी बोलत आहे का?"] 	 ['-'] 	 ['-'] 	 ['initial_message'] 	 [702]
# 4 	 कृपया ओरिया मध्ये बोला 	 ['मी ram यांच्याशी बोलत आहे का?'] 	 ['-'] 	 ['-'] 	 ['initial_message'] 	 [702]
# 4 	 ठीक आहे गुजराती मध्ये बोला 	 ['मी ठीक आहे. तुम्ही कसे आहात.'] 	 ['-'] 	 ['-'] 	 ['Greet,Greet'] 	 [702]
# 5 	 /initial_message 	 ["नमस्कार. मी, 'ड्रग फ्री इंडिया' या एन्जीओमधून Neha बोलत आहे. मी ram यांच्याशी बोलत आहे का?"] 	 ['-'] 	 ['-'] 	 ['initial_message'] 	 [702]
# 5 	 तुम्हीअजून कोणतीही भाषा बोलू शकता का? 	 ['ओके. मी तुम्हाला पुन्हा केव्हा कॉल करू शकते?'] 	 ['-'] 	 ['-'] 	 ['Callback,Callback Time Not Given'] 	 [702]
# 5 	 ठीक आहे हिंदी मध्ये बोला 	 ['-'] 	 ['-'] 	 ['-'] 	 [''] 	 [702]
# 6 	 /initial_message 	 ["नमस्कार. मी, 'ड्रग फ्री इंडिया' या एन्जीओमधून Neha बोलत आहे. मी ram यांच्याशी बोलत आहे का?"] 	 ['-'] 	 ['-'] 	 ['initial_message'] 	 [702]
# 6 	 तुम्हीअजून कोणतीही भाषा बोलू शकता का? 	 ['ओके. मी तुम्हाला पुन्हा केव्हा कॉल करू शकते?'] 	 ['-'] 	 ['-'] 	 ['Callback,Callback Time Not Given'] 	 [702]
# 6 	 ठीक आहे मराठी मध्ये बोला 	 ['-'] 	 ['-'] 	 ['-'] 	 [''] 	 [702]
# 7 	 /initial_message 	 ["नमस्कार. मी, 'ड्रग फ्री इंडिया' या एन्जीओमधून Neha बोलत आहे. मी ram यांच्याशी बोलत आहे का?"] 	 ['-'] 	 ['-'] 	 ['initial_message'] 	 [702]
# 7 	 तुम्हीअजून कोणतीही भाषा बोलू शकता का? 	 ['ओके. मी तुम्हाला पुन्हा केव्हा कॉल करू शकते?'] 	 ['-'] 	 ['-'] 	 ['Callback,Callback Time Not Given'] 	 [702]
# 7 	 ठीक आहे गुजराती मध्ये बोला 	 ['मी ठीक आहे.'] 	 ['मी तुम्हाला पुन्हा केव्हा कॉल करू शकते?'] 	 ['-'] 	 ['GREET,Callback Time Not Given'] 	 [702]
# 8 	 /initial_message 	 ["नमस्कार. मी, 'ड्रग फ्री इंडिया' या एन्जीओमधून Neha बोलत आहे. मी ram यांच्याशी बोलत आहे का?"] 	 ['-'] 	 ['-'] 	 ['initial_message'] 	 [702]
# 8 	 मला नंतर कॉल करा 	 ['ओके. मी तुम्हाला पुन्हा केव्हा कॉल करू शकते?'] 	 ['-'] 	 ['-'] 	 ['Callback,Callback Time Not Given'] 	 [702]
# 8 	 उद्या सकाळी पुन्हा कॉल करा 	 ['ओके. मी तुम्हाला, त्याच वेळी कॉल करेन. धन्यवाद.'] 	 ['-'] 	 ['-'] 	 ['Callback - Valid Time'] 	 [701]
# 9 	 /initial_message 	 ["नमस्कार. मी, 'ड्रग फ्री इंडिया' या एन्जीओमधून Neha बोलत आहे. मी ram यांच्याशी बोलत आहे का?"] 	 ['-'] 	 ['-'] 	 ['initial_message'] 	 [702]
# 9 	 मला नंतर कॉल करा 	 ['ओके. मी तुम्हाला पुन्हा केव्हा कॉल करू शकते?'] 	 ['-'] 	 ['-'] 	 ['Callback,Callback Time Not Given'] 	 [702]
# 9 	 ठीक आहे 30 दिवसांनंतर पुन्हा कॉल करा 	 ['आत्ता, हे खूप उशीरा होईल. मी तुम्हाला 15 June च्या आधी, कधी कॉल करू शकते?'] 	 ['-'] 	 ['-'] 	 ['Date Threshold Mismatch,Callback - Date Above Threshold'] 	 [702]
# 9 	 ठीक आहे उद्या पुन्हा कॉल करा 	 ['ओके. मी तुम्हाला 14 June 2023 ला कॉल करेन. तुमचा दिवस छान जावो.'] 	 ['-'] 	 ['-'] 	 ['CallBack - Valid Date'] 	 [701]
# 10 	 /initial_message 	 ["नमस्कार. मी, 'ड्रग फ्री इंडिया' या एन्जीओमधून Neha बोलत आहे. मी ram यांच्याशी बोलत आहे का?"] 	 ['-'] 	 ['-'] 	 ['initial_message'] 	 [702]
# 10 	 मला नंतर कॉल करा 	 ['ओके. मी तुम्हाला पुन्हा केव्हा कॉल करू शकते?'] 	 ['-'] 	 ['-'] 	 ['Callback,Callback Time Not Given'] 	 [702]
# 10 	 ठीक आहे 30 दिवसांनंतर पुन्हा कॉल करा 	 ['आत्ता, हे खूप उशीरा होईल. मी तुम्हाला 15 June च्या आधी, कधी कॉल करू शकते?'] 	 ['-'] 	 ['-'] 	 ['Date Threshold Mismatch,Callback - Date Above Threshold'] 	 [702]
# 10 	 ठीक आहे 30 दिवसांनंतर पुन्हा कॉल करा 	 ['हे खूप उशीरा होईल. मी तुम्हाला नंतर कॉल करेन. धन्यवाद.'] 	 ['-'] 	 ['-'] 	 ['Callback - Date Above Threshold'] 	 [701]
# 11 	 /initial_message 	 ["नमस्कार. मी, 'ड्रग फ्री इंडिया' या एन्जीओमधून Neha बोलत आहे. मी ram यांच्याशी बोलत आहे का?"] 	 ['-'] 	 ['-'] 	 ['initial_message'] 	 [702]
# 11 	 मला नंतर कॉल करा 	 ['ओके. मी तुम्हाला पुन्हा केव्हा कॉल करू शकते?'] 	 ['-'] 	 ['-'] 	 ['Callback,Callback Time Not Given'] 	 [702]
# 11 	 ठीक आहे 30 दिवसांनंतर पुन्हा कॉल करा 	 ['आत्ता, हे खूप उशीरा होईल. मी तुम्हाला 15 June च्या आधी, कधी कॉल करू शकते?'] 	 ['-'] 	 ['-'] 	 ['Date Threshold Mismatch,Callback - Date Above Threshold'] 	 [702]
# 11 	 कोणताही दिवस ठीक आहे 	 ['ओके. मी तुम्हाला नंतर कॉल करेन. धन्यवाद.'] 	 ['-'] 	 ['-'] 	 ['Callback Time Not Given'] 	 [701]
# 12 	 /initial_message 	 ["नमस्कार. मी, 'ड्रग फ्री इंडिया' या एन्जीओमधून Neha बोलत आहे. मी ram यांच्याशी बोलत आहे का?"] 	 ['-'] 	 ['-'] 	 ['initial_message'] 	 [702]
# 12 	 मला नंतर कॉल करा 	 ['ओके. मी तुम्हाला पुन्हा केव्हा कॉल करू शकते?'] 	 ['-'] 	 ['-'] 	 ['Callback,Callback Time Not Given'] 	 [702]
# 12 	 उद्या रात्री 11 वाजता परत कॉल करा 	 ['ओके. पण मी 6 नंतर कॉल करू शकणार नाही. मी तुम्हाला किती वाजता कॉल करू?'] 	 ['-'] 	 ['-'] 	 ['Callback - Time Above Threshold,Callback - Time Above Threshold'] 	 [702]
# 12 	 ठीक आहे उद्या पुन्हा कॉल करा 	 ['ओके. पण मी 6 नंतर कॉल करू शकणार नाही. मी तुम्हाला किती वाजता कॉल करू?'] 	 ['-'] 	 ['-'] 	 ['CallBack - Valid Date,Callback - Time Above Threshold'] 	 [702]
# 13 	 /initial_message 	 ["नमस्कार. मी, 'ड्रग फ्री इंडिया' या एन्जीओमधून Neha बोलत आहे. मी ram यांच्याशी बोलत आहे का?"] 	 ['-'] 	 ['-'] 	 ['initial_message'] 	 [702]
# 13 	 मला नंतर कॉल करा 	 ['ओके. मी तुम्हाला पुन्हा केव्हा कॉल करू शकते?'] 	 ['-'] 	 ['-'] 	 ['Callback,Callback Time Not Given'] 	 [702]
# 13 	 उद्या रात्री 11 वाजता परत कॉल करा 	 ['ओके. पण मी 6 नंतर कॉल करू शकणार नाही. मी तुम्हाला किती वाजता कॉल करू?'] 	 ['-'] 	 ['-'] 	 ['Callback - Time Above Threshold,Callback - Time Above Threshold'] 	 [702]
# 13 	 ठीक आहे 30 दिवसांनंतर पुन्हा कॉल करा 	 ['हे खूप उशीरा होईल. मी लवकरच कॉल करेन. धन्यवाद.'] 	 ['-'] 	 ['-'] 	 ['Callback - Date Above Threshold'] 	 [701]
# 14 	 /initial_message 	 ["नमस्कार. मी, 'ड्रग फ्री इंडिया' या एन्जीओमधून Neha बोलत आहे. मी ram यांच्याशी बोलत आहे का?"] 	 ['-'] 	 ['-'] 	 ['initial_message'] 	 [702]
# 14 	 मला नंतर कॉल करा 	 ['ओके. मी तुम्हाला पुन्हा केव्हा कॉल करू शकते?'] 	 ['-'] 	 ['-'] 	 ['Callback,Callback Time Not Given'] 	 [702]
# 14 	 उद्या रात्री 11 वाजता परत कॉल करा 	 ['ओके. पण मी 6 नंतर कॉल करू शकणार नाही. मी तुम्हाला किती वाजता कॉल करू?'] 	 ['-'] 	 ['-'] 	 ['Callback - Time Above Threshold,Callback - Time Above Threshold'] 	 [702]
# 14 	 कोणताही दिवस ठीक आहे 	 ['ओके. मी तुम्हाला नंतर कॉल करेन. धन्यवाद.'] 	 ['-'] 	 ['-'] 	 ['Callback Time Not Given'] 	 [701]
# 15 	 /initial_message 	 ["नमस्कार. मी, 'ड्रग फ्री इंडिया' या एन्जीओमधून Neha बोलत आहे. मी ram यांच्याशी बोलत आहे का?"] 	 ['-'] 	 ['-'] 	 ['initial_message'] 	 [702]
# 15 	 मला नंतर कॉल करा 	 ['ओके. मी तुम्हाला पुन्हा केव्हा कॉल करू शकते?'] 	 ['-'] 	 ['-'] 	 ['Callback,Callback Time Not Given'] 	 [702]
# 15 	 पुढच्या वर्षी रात्री 11 वाजता पुन्हा कॉल करा 	 ['आत्ता, हे खूप उशीरा होईल. मी तुम्हाला 15 June च्या आधी, कधी कॉल करू शकते?'] 	 ['-'] 	 ['-'] 	 ['Callback - Date Above Threshold,Callback - Date Above Threshold'] 	 [702]
# 15 	 ठीक आहे उद्या पुन्हा कॉल करा 	 ['ओके. मी तुम्हाला 14 June 2023 ला कॉल करेन. तुमचा दिवस छान जावो.'] 	 ['-'] 	 ['-'] 	 ['CallBack - Valid Date'] 	 [701]
# 16 	 /initial_message 	 ["नमस्कार. मी, 'ड्रग फ्री इंडिया' या एन्जीओमधून Neha बोलत आहे. मी ram यांच्याशी बोलत आहे का?"] 	 ['-'] 	 ['-'] 	 ['initial_message'] 	 [702]
# 16 	 मला नंतर कॉल करा 	 ['ओके. मी तुम्हाला पुन्हा केव्हा कॉल करू शकते?'] 	 ['-'] 	 ['-'] 	 ['Callback,Callback Time Not Given'] 	 [702]
# 16 	 पुढच्या वर्षी रात्री 11 वाजता पुन्हा कॉल करा 	 ['आत्ता, हे खूप उशीरा होईल. मी तुम्हाला 15 June च्या आधी, कधी कॉल करू शकते?'] 	 ['-'] 	 ['-'] 	 ['Callback - Date Above Threshold,Callback - Date Above Threshold'] 	 [702]
# 16 	 ठीक आहे 30 दिवसांनंतर पुन्हा कॉल करा 	 ['हे खूप उशीरा होईल. मी तुम्हाला नंतर कॉल करेन. धन्यवाद.'] 	 ['-'] 	 ['-'] 	 ['Callback - Date Above Threshold'] 	 [701]
# 17 	 /initial_message 	 ["नमस्कार. मी, 'ड्रग फ्री इंडिया' या एन्जीओमधून Neha बोलत आहे. मी ram यांच्याशी बोलत आहे का?"] 	 ['-'] 	 ['-'] 	 ['initial_message'] 	 [702]
# 17 	 मला नंतर कॉल करा 	 ['ओके. मी तुम्हाला पुन्हा केव्हा कॉल करू शकते?'] 	 ['-'] 	 ['-'] 	 ['Callback,Callback Time Not Given'] 	 [702]
# 17 	 पुढच्या वर्षी रात्री 11 वाजता पुन्हा कॉल करा 	 ['आत्ता, हे खूप उशीरा होईल. मी तुम्हाला 15 June च्या आधी, कधी कॉल करू शकते?'] 	 ['-'] 	 ['-'] 	 ['Callback - Date Above Threshold,Callback - Date Above Threshold'] 	 [702]
# 17 	 कोणताही दिवस ठीक आहे 	 ['ओके. मी तुम्हाला नंतर कॉल करेन. धन्यवाद.'] 	 ['-'] 	 ['-'] 	 ['Callback Time Not Given'] 	 [701]
# 18 	 /initial_message 	 ["नमस्कार. मी, 'ड्रग फ्री इंडिया' या एन्जीओमधून Neha बोलत आहे. मी ram यांच्याशी बोलत आहे का?"] 	 ['-'] 	 ['-'] 	 ['initial_message'] 	 [702]
# 18 	 मला नंतर कॉल करा 	 ['ओके. मी तुम्हाला पुन्हा केव्हा कॉल करू शकते?'] 	 ['-'] 	 ['-'] 	 ['Callback,Callback Time Not Given'] 	 [702]
# 18 	 आज संध्याकाळी 5 वाजता कॉल करा 	 ['ओके. मी तुम्हाला, त्याच वेळी कॉल करेन. धन्यवाद.'] 	 ['-'] 	 ['-'] 	 ['Callback - Valid Time'] 	 [701]
# 19 	 /initial_message 	 ["नमस्कार. मी, 'ड्रग फ्री इंडिया' या एन्जीओमधून Neha बोलत आहे. मी ram यांच्याशी बोलत आहे का?"] 	 ['-'] 	 ['-'] 	 ['initial_message'] 	 [702]
# 19 	 मला नंतर कॉल करा 	 ['ओके. मी तुम्हाला पुन्हा केव्हा कॉल करू शकते?'] 	 ['-'] 	 ['-'] 	 ['Callback,Callback Time Not Given'] 	 [702]
# 19 	 5 मे ला पुन्हा कॉल करा 	 ['ओके. मी तुम्हाला पुन्हा केव्हा कॉल करू शकते?'] 	 ['-'] 	 ['-'] 	 ['Callback Time Not Given,Callback Time Not Given'] 	 [702]
# 19 	 5 मे ला पुन्हा कॉल करा 	 ['आपण दिलेल्या वेळेसाठी/ धन्यवाद. तुमचा दिवस छान जावो!'] 	 ['-'] 	 ['-'] 	 ['Callback Time Not Given,None'] 	 [701]
# 20 	 /initial_message 	 ["नमस्कार. मी, 'ड्रग फ्री इंडिया' या एन्जीओमधून Neha बोलत आहे. मी ram यांच्याशी बोलत आहे का?"] 	 ['-'] 	 ['-'] 	 ['initial_message'] 	 [702]
# 20 	 मला नंतर कॉल करा 	 ['ओके. मी तुम्हाला पुन्हा केव्हा कॉल करू शकते?'] 	 ['-'] 	 ['-'] 	 ['Callback,Callback Time Not Given'] 	 [702]
# 20 	 5 मे ला पुन्हा कॉल करा 	 ['ओके. मी तुम्हाला पुन्हा केव्हा कॉल करू शकते?'] 	 ['-'] 	 ['-'] 	 ['Callback Time Not Given,Callback Time Not Given'] 	 [702]
# 20 	 आज संध्याकाळी 5 वाजता कॉल करा 	 ['ओके. मी तुम्हाला, त्याच वेळी कॉल करेन. धन्यवाद.'] 	 ['-'] 	 ['-'] 	 ['Callback - Valid Time'] 	 [701]
# 21 	 /initial_message 	 ["नमस्कार. मी, 'ड्रग फ्री इंडिया' या एन्जीओमधून Neha बोलत आहे. मी ram यांच्याशी बोलत आहे का?"] 	 ['-'] 	 ['-'] 	 ['initial_message'] 	 [702]
# 21 	 मला नंतर कॉल करा 	 ['ओके. मी तुम्हाला पुन्हा केव्हा कॉल करू शकते?'] 	 ['-'] 	 ['-'] 	 ['Callback,Callback Time Not Given'] 	 [702]
# 21 	 5 मे ला पुन्हा कॉल करा 	 ['ओके. मी तुम्हाला पुन्हा केव्हा कॉल करू शकते?'] 	 ['-'] 	 ['-'] 	 ['Callback Time Not Given,Callback Time Not Given'] 	 [702]
# 21 	 उद्या सकाळी पुन्हा कॉल करा 	 ['ओके. मी तुम्हाला, त्याच वेळी कॉल करेन. धन्यवाद.'] 	 ['-'] 	 ['-'] 	 ['Callback - Valid Time'] 	 [701]
# 22 	 /initial_message 	 ["नमस्कार. मी, 'ड्रग फ्री इंडिया' या एन्जीओमधून Neha बोलत आहे. मी ram यांच्याशी बोलत आहे का?"] 	 ['-'] 	 ['-'] 	 ['initial_message'] 	 [702]
# 22 	 मला नंतर कॉल करा 	 ['ओके. मी तुम्हाला पुन्हा केव्हा कॉल करू शकते?'] 	 ['-'] 	 ['-'] 	 ['Callback,Callback Time Not Given'] 	 [702]
# 22 	 5 मे ला पुन्हा कॉल करा 	 ['ओके. मी तुम्हाला पुन्हा केव्हा कॉल करू शकते?'] 	 ['-'] 	 ['-'] 	 ['Callback Time Not Given,Callback Time Not Given'] 	 [702]
# 22 	 ठीक आहे 30 दिवसांनंतर पुन्हा कॉल करा 	 ['आत्ता, हे खूप उशीरा होईल. मी तुम्हाला 15 June च्या आधी, कधी कॉल करू शकते?'] 	 ['-'] 	 ['-'] 	 ['Date Threshold Mismatch,Callback - Date Above Threshold'] 	 [702]
# 23 	 /initial_message 	 ["नमस्कार. मी, 'ड्रग फ्री इंडिया' या एन्जीओमधून Neha बोलत आहे. मी ram यांच्याशी बोलत आहे का?"] 	 ['-'] 	 ['-'] 	 ['initial_message'] 	 [702]
# 23 	 मला नंतर कॉल करा 	 ['ओके. मी तुम्हाला पुन्हा केव्हा कॉल करू शकते?'] 	 ['-'] 	 ['-'] 	 ['Callback,Callback Time Not Given'] 	 [702]
# 23 	 5 मे ला पुन्हा कॉल करा 	 ['ओके. मी तुम्हाला पुन्हा केव्हा कॉल करू शकते?'] 	 ['-'] 	 ['-'] 	 ['Callback Time Not Given,Callback Time Not Given'] 	 [702]
# 23 	 उद्या रात्री 11 वाजता परत कॉल करा 	 ['ओके. पण मी 6 नंतर कॉल करू शकणार नाही. मी तुम्हाला किती वाजता कॉल करू?'] 	 ['-'] 	 ['-'] 	 ['Callback - Time Above Threshold,Callback - Time Above Threshold'] 	 [702]
# 24 	 /initial_message 	 ["नमस्कार. मी, 'ड्रग फ्री इंडिया' या एन्जीओमधून Neha बोलत आहे. मी ram यांच्याशी बोलत आहे का?"] 	 ['-'] 	 ['-'] 	 ['initial_message'] 	 [702]
# 24 	 मला नंतर कॉल करा 	 ['ओके. मी तुम्हाला पुन्हा केव्हा कॉल करू शकते?'] 	 ['-'] 	 ['-'] 	 ['Callback,Callback Time Not Given'] 	 [702]
# 24 	 5 मे ला पुन्हा कॉल करा 	 ['ओके. मी तुम्हाला पुन्हा केव्हा कॉल करू शकते?'] 	 ['-'] 	 ['-'] 	 ['Callback Time Not Given,Callback Time Not Given'] 	 [702]
# 24 	 पुढच्या वर्षी रात्री 11 वाजता पुन्हा कॉल करा 	 ['आत्ता, हे खूप उशीरा होईल. मी तुम्हाला 15 June च्या आधी, कधी कॉल करू शकते?'] 	 ['-'] 	 ['-'] 	 ['Callback - Date Above Threshold,Callback - Date Above Threshold'] 	 [702]
# 25 	 /initial_message 	 ["नमस्कार. मी, 'ड्रग फ्री इंडिया' या एन्जीओमधून Neha बोलत आहे. मी ram यांच्याशी बोलत आहे का?"] 	 ['-'] 	 ['-'] 	 ['initial_message'] 	 [702]
# 25 	 मला नंतर कॉल करा 	 ['ओके. मी तुम्हाला पुन्हा केव्हा कॉल करू शकते?'] 	 ['-'] 	 ['-'] 	 ['Callback,Callback Time Not Given'] 	 [702]
# 25 	 5 मे ला पुन्हा कॉल करा 	 ['ओके. मी तुम्हाला पुन्हा केव्हा कॉल करू शकते?'] 	 ['-'] 	 ['-'] 	 ['Callback Time Not Given,Callback Time Not Given'] 	 [702]
# 25 	 उद्या सकाळी पुन्हा कॉल करा 	 ['ओके. मी तुम्हाला, त्याच वेळी कॉल करेन. धन्यवाद.'] 	 ['-'] 	 ['-'] 	 ['Callback - Valid Time'] 	 [701]
# 26 	 /initial_message 	 ["नमस्कार. मी, 'ड्रग फ्री इंडिया' या एन्जीओमधून Neha बोलत आहे. मी ram यांच्याशी बोलत आहे का?"] 	 ['-'] 	 ['-'] 	 ['initial_message'] 	 [702]
# 26 	 मला नंतर कॉल करा 	 ['ओके. मी तुम्हाला पुन्हा केव्हा कॉल करू शकते?'] 	 ['-'] 	 ['-'] 	 ['Callback,Callback Time Not Given'] 	 [702]
# 26 	 5 मे ला पुन्हा कॉल करा 	 ['ओके. मी तुम्हाला पुन्हा केव्हा कॉल करू शकते?'] 	 ['-'] 	 ['-'] 	 ['Callback Time Not Given,Callback Time Not Given'] 	 [702]
# 26 	 पुढच्या वर्षी रात्री 11 वाजता पुन्हा कॉल करा 	 ['आत्ता, हे खूप उशीरा होईल. मी तुम्हाला 15 June च्या आधी, कधी कॉल करू शकते?'] 	 ['-'] 	 ['-'] 	 ['Callback - Date Above Threshold,Callback - Date Above Threshold'] 	 [702]
# 27 	 /initial_message 	 ["नमस्कार. मी, 'ड्रग फ्री इंडिया' या एन्जीओमधून Neha बोलत आहे. मी ram यांच्याशी बोलत आहे का?"] 	 ['-'] 	 ['-'] 	 ['initial_message'] 	 [702]
# 27 	 मला नंतर कॉल करा 	 ['ओके. मी तुम्हाला पुन्हा केव्हा कॉल करू शकते?'] 	 ['-'] 	 ['-'] 	 ['Callback,Callback Time Not Given'] 	 [702]
# 27 	 उद्या मला पुन्हा कॉल करा 	 ['नक्कीच. मी तुम्हाला नंतर कॉल करेन. मी तुम्हाला त्या दिवशी 6 च्या आधी, किती वाजता कॉल करू शकते?'] 	 ['-'] 	 ['-'] 	 ['CallBack - Valid Date,CallBack - Valid Date'] 	 [702]
# 27 	 उद्या मला पुन्हा कॉल करा 	 ['नक्कीच. मी तुम्हाला नंतर कॉल करेन. मी तुम्हाला त्या दिवशी 6 च्या आधी, किती वाजता कॉल करू शकते?'] 	 ['-'] 	 ['-'] 	 ['CallBack - Valid Date,CallBack - Valid Date'] 	 [702]
# 28 	 /initial_message 	 ["नमस्कार. मी, 'ड्रग फ्री इंडिया' या एन्जीओमधून Neha बोलत आहे. मी ram यांच्याशी बोलत आहे का?"] 	 ['-'] 	 ['-'] 	 ['initial_message'] 	 [702]
# 28 	 मला नंतर कॉल करा 	 ['ओके. मी तुम्हाला पुन्हा केव्हा कॉल करू शकते?'] 	 ['-'] 	 ['-'] 	 ['Callback,Callback Time Not Given'] 	 [702]
# 28 	 उद्या मला पुन्हा कॉल करा 	 ['नक्कीच. मी तुम्हाला नंतर कॉल करेन. मी तुम्हाला त्या दिवशी 6 च्या आधी, किती वाजता कॉल करू शकते?'] 	 ['-'] 	 ['-'] 	 ['CallBack - Valid Date,CallBack - Valid Date'] 	 [702]
# 28 	 पुढच्या वर्षी मला पुन्हा कॉल करा 	 ['ओके. मी तुम्हाला नंतर कॉल करेन. धन्यवाद.'] 	 ['-'] 	 ['-'] 	 ['Callback - Date Above Threshold'] 	 [701]
# 29 	 /initial_message 	 ["नमस्कार. मी, 'ड्रग फ्री इंडिया' या एन्जीओमधून Neha बोलत आहे. मी ram यांच्याशी बोलत आहे का?"] 	 ['-'] 	 ['-'] 	 ['initial_message'] 	 [702]
# 29 	 मला नंतर कॉल करा 	 ['ओके. मी तुम्हाला पुन्हा केव्हा कॉल करू शकते?'] 	 ['-'] 	 ['-'] 	 ['Callback,Callback Time Not Given'] 	 [702]
# 29 	 उद्या मला पुन्हा कॉल करा 	 ['नक्कीच. मी तुम्हाला नंतर कॉल करेन. मी तुम्हाला त्या दिवशी 6 च्या आधी, किती वाजता कॉल करू शकते?'] 	 ['-'] 	 ['-'] 	 ['CallBack - Valid Date,CallBack - Valid Date'] 	 [702]
# 29 	 कोणतीही वेळ ठीक आहे 	 ['ओके. मी तुम्हाला नंतर कॉल करेन. धन्यवाद.'] 	 ['-'] 	 ['-'] 	 ['Callback Time Not Given'] 	 [701]
# 30 	 /initial_message 	 ["नमस्कार. मी, 'ड्रग फ्री इंडिया' या एन्जीओमधून Neha बोलत आहे. मी ram यांच्याशी बोलत आहे का?"] 	 ['-'] 	 ['-'] 	 ['initial_message'] 	 [702]
# 30 	 मला नंतर कॉल करा 	 ['ओके. मी तुम्हाला पुन्हा केव्हा कॉल करू शकते?'] 	 ['-'] 	 ['-'] 	 ['Callback,Callback Time Not Given'] 	 [702]
# 30 	 पुढच्या वर्षी मला पुन्हा कॉल करा 	 ['आत्ता, हे खूप उशीरा होईल. मी तुम्हाला 15 June च्या आधी, कधी कॉल करू शकते?'] 	 ['-'] 	 ['-'] 	 ['Date Threshold Mismatch,Callback - Date Above Threshold'] 	 [702]
# 30 	 उद्या मला पुन्हा कॉल करा 	 ['ओके. मी तुम्हाला 14 June 2023 ला कॉल करेन. तुमचा दिवस छान जावो.'] 	 ['-'] 	 ['-'] 	 ['CallBack - Valid Date'] 	 [701]
# 31 	 /initial_message 	 ["नमस्कार. मी, 'ड्रग फ्री इंडिया' या एन्जीओमधून Neha बोलत आहे. मी ram यांच्याशी बोलत आहे का?"] 	 ['-'] 	 ['-'] 	 ['initial_message'] 	 [702]
# 31 	 मला नंतर कॉल करा 	 ['ओके. मी तुम्हाला पुन्हा केव्हा कॉल करू शकते?'] 	 ['-'] 	 ['-'] 	 ['Callback,Callback Time Not Given'] 	 [702]
# 31 	 पुढच्या वर्षी मला पुन्हा कॉल करा 	 ['आत्ता, हे खूप उशीरा होईल. मी तुम्हाला 15 June च्या आधी, कधी कॉल करू शकते?'] 	 ['-'] 	 ['-'] 	 ['Date Threshold Mismatch,Callback - Date Above Threshold'] 	 [702]
# 31 	 पुढच्या वर्षी मला पुन्हा कॉल करा 	 ['हे खूप उशीरा होईल. मी तुम्हाला नंतर कॉल करेन. धन्यवाद.'] 	 ['-'] 	 ['-'] 	 ['Callback - Date Above Threshold'] 	 [701]
# 32 	 /initial_message 	 ["नमस्कार. मी, 'ड्रग फ्री इंडिया' या एन्जीओमधून Neha बोलत आहे. मी ram यांच्याशी बोलत आहे का?"] 	 ['-'] 	 ['-'] 	 ['initial_message'] 	 [702]
# 32 	 मला नंतर कॉल करा 	 ['ओके. मी तुम्हाला पुन्हा केव्हा कॉल करू शकते?'] 	 ['-'] 	 ['-'] 	 ['Callback,Callback Time Not Given'] 	 [702]
# 32 	 पुढच्या वर्षी मला पुन्हा कॉल करा 	 ['आत्ता, हे खूप उशीरा होईल. मी तुम्हाला 15 June च्या आधी, कधी कॉल करू शकते?'] 	 ['-'] 	 ['-'] 	 ['Date Threshold Mismatch,Callback - Date Above Threshold'] 	 [702]
# 32 	 कोणतीही तारीख ठीक आहे 	 ['ओके. मी तुम्हाला नंतर कॉल करेन. धन्यवाद.'] 	 ['-'] 	 ['-'] 	 ['Callback Time Not Given'] 	 [701]
# 33 	 /initial_message 	 ["नमस्कार. मी, 'ड्रग फ्री इंडिया' या एन्जीओमधून Neha बोलत आहे. मी ram यांच्याशी बोलत आहे का?"] 	 ['-'] 	 ['-'] 	 ['initial_message'] 	 [702]
# 33 	 चुकीचा नंबर 	 ['आम्ही एक sarvey agency आहोत. तुमचा नंबर आमच्या data bess मध्ये आहे.'] 	 ['मी ram यांच्याशी बोलत आहे का?'] 	 ['-'] 	 ['Ask about Phone Number,initial_message'] 	 [702]
# 34 	 /initial_message 	 ["नमस्कार. मी, 'ड्रग फ्री इंडिया' या एन्जीओमधून Neha बोलत आहे. मी ram यांच्याशी बोलत आहे का?"] 	 ['-'] 	 ['-'] 	 ['initial_message'] 	 [702]
# 34 	 नाही 	 ["मी हा कॉल महाराष्ट्राचे मुख्यमंत्री/ श्री. एकनाथ शिंदे यांच्या, 'मिशन थट्टी डेझ्' अंतर्गत 'मुंबई अगेंस्ट drugs' या महत्त्वपूर्ण उपक्रमाबद्दल, तुम्हाला माहिती देण्यासाठी/ केला आहे. तुम्ही मुंबईच्या कोणत्या एरियामध्ये राहता?"] 	 ['-'] 	 ['-'] 	 ['Right Party Contact,Right Party Contact'] 	 [702]
# 34 	 /no_response 	 ['Drug Free India च्या वतीने, मी  Neha बोलत आहे.'] 	 ['हा कॉल \\"मुंबई अगेंस्ट drugs\\" या मोहिमेबद्दल आहे. तुम्ही मुंबईच्या कोणत्या एरियामध्ये राहता?'] 	 ['-'] 	 ['Greet,Right Party Contact'] 	 [702]
# 34 	 हो 	 ["महाराष्ट्राचे मुख्यमंत्री/ एकनाथ शिंदे यांनी/ मुंबईला drugs मुक्त करण्याच्या उद्दिष्टाने 'मुंबई अगेन्स्ट drugs' मोहीम सुरू केली आहे. drugs च्या धोक्याचा सामना करण्यासाठी/ 24 तास उपलब्ध आणि पूर्णपणे विनामूल्य असा / 112 हा हेल्प लाइन नंबर/ गरजू लोकांना व्यावसायिक मदत मिळवून देण्यासाठी/ कटि बद्धअ आहे. तुम्हाला या मोहिमेबद्दल अधिक जाणून घ्यायला/ आवडेल का?"] 	 ['-'] 	 ['-'] 	 ['Location Captured,Location Captured'] 	 [702]
#
	 /initial_message 	 ["नमस्कार. मी, 'ड्रग फ्री इंडिया' या एन्जीओमधून Neha बोलत आहे. मी ram यांच्याशी बोलत आहे का?"] 	 ['-'] 	 ['-'] 	 ['initial_message'] 	 [702]
# 38 	 नाही 	 ["मी हा कॉल महाराष्ट्राचे मुख्यमंत्री/ श्री. एकनाथ शिंदे यांच्या, 'मिशन थट्टी डेझ्' अंतर्गत 'मुंबई अगेंस्ट drugs' या महत्त्वपूर्ण उपक्रमाबद्दल, तुम्हाला माहिती देण्यासाठी/ केला आहे. तुम्ही मुंबईच्या कोणत्या एरियामध्ये राहता?"] 	 ['-'] 	 ['-'] 	 ['Right Party Contact,Right Party Contact'] 	 [702]
# 38 	 नाही 	 ["महाराष्ट्राचे मुख्यमंत्री/ एकनाथ शिंदे यांनी/ मुंबईला drugs मुक्त करण्याच्या उद्दिष्टाने 'मुंबई अगेन्स्ट drugs' मोहीम सुरू केली आहे. drugs च्या धोक्याचा सामना करण्यासाठी/ 24 तास उपलब्ध आणि पूर्णपणे विनामूल्य असा / 112 हा हेल्प लाइन नंबर/ गरजू लोकांना व्यावसायिक मदत मिळवून देण्यासाठी/ कटि बद्धअ आहे. तुम्हाला या मोहिमेबद्दल अधिक जाणून घ्यायला/ आवडेल का?"] 	 ['-'] 	 ['-'] 	 ['Location Captured,Location Captured'] 	 [702]
# 38 	 उद्या सकाळी पुन्हा कॉल करा 	 ['ओके. मी तुम्हाला, त्याच वेळी कॉल करेन. धन्यवाद.'] 	 ['-'] 	 ['-'] 	 ['Callback - Valid Time'] 	 [701]
# 39 	 /initial_message 	 ["नमस्कार. मी, 'ड्रग फ्री इंडिया' या एन्जीओमधून Neha बोलत आहे. मी ram यांच्याशी बोलत आहे का?"] 	 ['-'] 	 ['-'] 	 ['initial_message'] 	 [702]
# 39 	 नाही 	 ["मी हा कॉल महाराष्ट्राचे मुख्यमंत्री/ श्री. एकनाथ शिंदे यांच्या, 'मिशन थट्टी डेझ्' अंतर्गत 'मुंबई अगेंस्ट drugs' या महत्त्वपूर्ण उपक्रमाबद्दल, तुम्हाला माहिती देण्यासाठी/ केला आहे. तुम्ही मुंबईच्या कोणत्या एरियामध्ये राहता?"] 	 ['-'] 	 ['-'] 	 ['Right Party Contact,Right Party Contact'] 	 [702]
# 39 	 नाही 	 ["महाराष्ट्राचे मुख्यमंत्री/ एकनाथ शिंदे यांनी/ मुंबईला drugs मुक्त करण्याच्या उद्दिष्टाने 'मुंबई अगेन्स्ट drugs' मोहीम सुरू केली आहे. drugs च्या धोक्याचा सामना करण्यासाठी/ 24 तास उपलब्ध आणि पूर्णपणे विनामूल्य असा / 112 हा हेल्प लाइन नंबर/ गरजू लोकांना व्यावसायिक मदत मिळवून देण्यासाठी/ कटि बद्धअ आहे. तुम्हाला या मोहिमेबद्दल अधिक जाणून घ्यायला/ आवडेल का?"] 	 ['-'] 	 ['-'] 	 ['Location Captured,Location Captured'] 	 [702]
# 39 	 ठीक आहे 30 दिवसांनंतर पुन्हा कॉल करा 	 ['आत्ता, हे खूप उशीरा होईल. मी तुम्हाला 15 June च्या आधी, कधी कॉल करू शकते?'] 	 ['-'] 	 ['-'] 	 ['Date Threshold Mismatch,Callback - Date Above Threshold'] 	 [702]
# 39 	 ठीक आहे उद्या पुन्हा कॉल करा 	 ['ओके. मी तुम्हाला 14 June 2023 ला कॉल करेन. तुमचा दिवस छान जावो.'] 	 ['-'] 	 ['-'] 	 ['CallBack - Valid Date'] 	 [701]
# 40 	 /initial_message 	 ["नमस्कार. मी, 'ड्रग फ्री इंडिया' या एन्जीओमधून Neha बोलत आहे. मी ram यांच्याशी बोलत आहे का?"] 	 ['-'] 	 ['-'] 	 ['initial_message'] 	 [702]
# 40 	 नाही 	 ["मी हा कॉल महाराष्ट्राचे मुख्यमंत्री/ श्री. एकनाथ शिंदे यांच्या, 'मिशन थट्टी डेझ्' अंतर्गत 'मुंबई अगेंस्ट drugs' या महत्त्वपूर्ण उपक्रमाबद्दल, तुम्हाला माहिती देण्यासाठी/ केला आहे. तुम्ही मुंबईच्या कोणत्या एरियामध्ये राहता?"] 	 ['-'] 	 ['-'] 	 ['Right Party Contact,Right Party Contact'] 	 [702]
# 40 	 नाही 	 ["महाराष्ट्राचे मुख्यमंत्री/ एकनाथ शिंदे यांनी/ मुंबईला drugs मुक्त करण्याच्या उद्दिष्टाने 'मुंबई अगेन्स्ट drugs' मोहीम सुरू केली आहे. drugs च्या धोक्याचा सामना करण्यासाठी/ 24 तास उपलब्ध आणि पूर्णपणे विनामूल्य असा / 112 हा हेल्प लाइन नंबर/ गरजू लोकांना व्यावसायिक मदत मिळवून देण्यासाठी/ कटि बद्धअ आहे. तुम्हाला या मोहिमेबद्दल अधिक जाणून घ्यायला/ आवडेल का?"] 	 ['-'] 	 ['-'] 	 ['Location Captured,Location Captured'] 	 [702]
# 40 	 ठीक आहे 30 दिवसांनंतर पुन्हा कॉल करा 	 ['आत्ता, हे खूप उशीरा होईल. मी तुम्हाला 15 June च्या आधी, कधी कॉल करू शकते?'] 	 ['-'] 	 ['-'] 	 ['Date Threshold Mismatch,Callback - Date Above Threshold'] 	 [702]
# 40 	 ठीक आहे 30 दिवसांनंतर पुन्हा कॉल करा 	 ['हे खूप उशीरा होईल. मी तुम्हाला नंतर कॉल करेन. धन्यवाद.'] 	 ['-'] 	 ['-'] 	 ['Callback - Date Above Threshold'] 	 [701]
# 41 	 /initial_message 	 ["नमस्कार. मी, 'ड्रग फ्री इंडिया' या एन्जीओमधून Neha बोलत आहे. मी ram यांच्याशी बोलत आहे का?"] 	 ['-'] 	 ['-'] 	 ['initial_message'] 	 [702]
# 41 	 नाही 	 ["मी हा कॉल महाराष्ट्राचे मुख्यमंत्री/ श्री. एकनाथ शिंदे यांच्या, 'मिशन थट्टी डेझ्' अंतर्गत 'मुंबई अगेंस्ट drugs' या महत्त्वपूर्ण उपक्रमाबद्दल, तुम्हाला माहिती देण्यासाठी/ केला आहे. तुम्ही मुंबईच्या कोणत्या एरियामध्ये राहता?"] 	 ['-'] 	 ['-'] 	 ['Right Party Contact,Right Party Contact'] 	 [702]
# 41 	 नाही 	 ["महाराष्ट्राचे मुख्यमंत्री/ एकनाथ शिंदे यांनी/ मुंबईला drugs मुक्त करण्याच्या उद्दिष्टाने 'मुंबई अगेन्स्ट drugs' मोहीम सुरू केली आहे. drugs च्या धोक्याचा सामना करण्यासाठी/ 24 तास उपलब्ध आणि पूर्णपणे विनामूल्य असा / 112 हा हेल्प लाइन नंबर/ गरजू लोकांना व्यावसायिक मदत मिळवून देण्यासाठी/ कटि बद्धअ आहे. तुम्हाला या मोहिमेबद्दल अधिक जाणून घ्यायला/ आवडेल का?"] 	 ['-'] 	 ['-'] 	 ['Location Captured,Location Captured'] 	 [702]
# 41 	 ठीक आहे 30 दिवसांनंतर पुन्हा कॉल करा 	 ['आत्ता, हे खूप उशीरा होईल. मी तुम्हाला 15 June च्या आधी, कधी कॉल करू शकते?'] 	 ['-'] 	 ['-'] 	 ['Date Threshold Mismatch,Callback - Date Above Threshold'] 	 [702]
# 41 	 कोणताही दिवस ठीक आहे 	 ['ओके. मी तुम्हाला नंतर कॉल करेन. धन्यवाद.'] 	 ['-'] 	 ['-'] 	 ['Callback Time Not Given'] 	 [701]
# 42 	 /initial_message 	 ["नमस्कार. मी, 'ड्रग फ्री इंडिया' या एन्जीओमधून Neha बोलत आहे. मी ram यांच्याशी बोलत आहे का?"] 	 ['-'] 	 ['-'] 	 ['initial_message'] 	 [702]
# 42 	 नाही 	 ["मी हा कॉल महाराष्ट्राचे मुख्यमंत्री/ श्री. एकनाथ शिंदे यांच्या, 'मिशन थट्टी डेझ्' अंतर्गत 'मुंबई अगेंस्ट drugs' या महत्त्वपूर्ण उपक्रमाबद्दल, तुम्हाला माहिती देण्यासाठी/ केला आहे. तुम्ही मुंबईच्या कोणत्या एरियामध्ये राहता?"] 	 ['-'] 	 ['-'] 	 ['Right Party Contact,Right Party Contact'] 	 [702]
# 42 	 नाही 	 ["महाराष्ट्राचे मुख्यमंत्री/ एकनाथ शिंदे यांनी/ मुंबईला drugs मुक्त करण्याच्या उद्दिष्टाने 'मुंबई अगेन्स्ट drugs' मोहीम सुरू केली आहे. drugs च्या धोक्याचा सामना करण्यासाठी/ 24 तास उपलब्ध आणि पूर्णपणे विनामूल्य असा / 112 हा हेल्प लाइन नंबर/ गरजू लोकांना व्यावसायिक मदत मिळवून देण्यासाठी/ कटि बद्धअ आहे. तुम्हाला या मोहिमेबद्दल अधिक जाणून घ्यायला/ आवडेल का?"] 	 ['-'] 	 ['-'] 	 ['Location Captured,Location Captured'] 	 [702]
# 42 	 उद्या रात्री 11 वाजता परत कॉल करा 	 ['ओके. पण मी 6 नंतर कॉल करू शकणार नाही. मी तुम्हाला किती वाजता कॉल करू?'] 	 ['-'] 	 ['-'] 	 ['Callback - Time Above Threshold,Callback - Time Above Threshold'] 	 [702]
# 42 	 ठीक आहे उद्या पुन्हा कॉल करा 	 ['ओके. पण मी 6 नंतर कॉल करू शकणार नाही. मी तुम्हाला किती वाजता कॉल करू?'] 	 ['-'] 	 ['-'] 	 ['CallBack - Valid Date,Callback - Time Above Threshold'] 	 [702]
# 43 	 /initial_message 	 ["नमस्कार. मी, 'ड्रग फ्री इंडिया' या एन्जीओमधून Neha बोलत आहे. मी ram यांच्याशी बोलत आहे का?"] 	 ['-'] 	 ['-'] 	 ['initial_message'] 	 [702]
# 43 	 नाही 	 ["मी हा कॉल महाराष्ट्राचे मुख्यमंत्री/ श्री. एकनाथ शिंदे यांच्या, 'मिशन थट्टी डेझ्' अंतर्गत 'मुंबई अगेंस्ट drugs' या महत्त्वपूर्ण उपक्रमाबद्दल, तुम्हाला माहिती देण्यासाठी/ केला आहे. तुम्ही मुंबईच्या कोणत्या एरियामध्ये राहता?"] 	 ['-'] 	 ['-'] 	 ['Right Party Contact,Right Party Contact'] 	 [702]
# 43 	 नाही 	 ["महाराष्ट्राचे मुख्यमंत्री/ एकनाथ शिंदे यांनी/ मुंबईला drugs मुक्त करण्याच्या उद्दिष्टाने 'मुंबई अगेन्स्ट drugs' मोहीम सुरू केली आहे. drugs च्या धोक्याचा सामना करण्यासाठी/ 24 तास उपलब्ध आणि पूर्णपणे विनामूल्य असा / 112 हा हेल्प लाइन नंबर/ गरजू लोकांना व्यावसायिक मदत मिळवून देण्यासाठी/ कटि बद्धअ आहे. तुम्हाला या मोहिमेबद्दल अधिक जाणून घ्यायला/ आवडेल का?"] 	 ['-'] 	 ['-'] 	 ['Location Captured,Location Captured'] 	 [702]
# 43 	 उद्या रात्री 11 वाजता परत कॉल करा 	 ['ओके. पण मी 6 नंतर कॉल करू शकणार नाही. मी तुम्हाला किती वाजता कॉल करू?'] 	 ['-'] 	 ['-'] 	 ['Callback - Time Above Threshold,Callback - Time Above Threshold'] 	 [702]
# 43 	 ठीक आहे 30 दिवसांनंतर पुन्हा कॉल करा 	 ['हे खूप उशीरा होईल. मी लवकरच कॉल करेन. धन्यवाद.'] 	 ['-'] 	 ['-'] 	 ['Callback - Date Above Threshold'] 	 [701]
# 44 	 /initial_message 	 ["नमस्कार. मी, 'ड्रग फ्री इंडिया' या एन्जीओमधून Neha बोलत आहे. मी ram यांच्याशी बोलत आहे का?"] 	 ['-'] 	 ['-'] 	 ['initial_message'] 	 [702]
# 44 	 नाही 	 ["मी हा कॉल महाराष्ट्राचे मुख्यमंत्री/ श्री. एकनाथ शिंदे यांच्या, 'मिशन थट्टी डेझ्' अंतर्गत 'मुंबई अगेंस्ट drugs' या महत्त्वपूर्ण उपक्रमाबद्दल, तुम्हाला माहिती देण्यासाठी/ केला आहे. तुम्ही मुंबईच्या कोणत्या एरियामध्ये राहता?"] 	 ['-'] 	 ['-'] 	 ['Right Party Contact,Right Party Contact'] 	 [702]
# 44 	 नाही 	 ["महाराष्ट्राचे मुख्यमंत्री/ एकनाथ शिंदे यांनी/ मुंबईला drugs मुक्त करण्याच्या उद्दिष्टाने 'मुंबई अगेन्स्ट drugs' मोहीम सुरू केली आहे. drugs च्या धोक्याचा सामना करण्यासाठी/ 24 तास उपलब्ध आणि पूर्णपणे विनामूल्य असा / 112 हा हेल्प लाइन नंबर/ गरजू लोकांना व्यावसायिक मदत मिळवून देण्यासाठी/ कटि बद्धअ आहे. तुम्हाला या मोहिमेबद्दल अधिक जाणून घ्यायला/ आवडेल का?"] 	 ['-'] 	 ['-'] 	 ['Location Captured,Location Captured'] 	 [702]
# 44 	 उद्या रात्री 11 वाजता परत कॉल करा 	 ['ओके. पण मी 6 नंतर कॉल करू शकणार नाही. मी तुम्हाला किती वाजता कॉल करू?'] 	 ['-'] 	 ['-'] 	 ['Callback - Time Above Threshold,Callback - Time Above Threshold'] 	 [702]
# 44 	 कोणताही दिवस ठीक आहे 	 ['ओके. मी तुम्हाला नंतर कॉल करेन. धन्यवाद.'] 	 ['-'] 	 ['-'] 	 ['Callback Time Not Given'] 	 [701]
# 45 	 /initial_message 	 ["नमस्कार. मी, 'ड्रग फ्री इंडिया' या एन्जीओमधून Neha बोलत आहे. मी ram यांच्याशी बोलत आहे का?"] 	 ['-'] 	 ['-'] 	 ['initial_message'] 	 [702]
# 45 	 नाही 	 ["मी हा कॉल महाराष्ट्राचे मुख्यमंत्री/ श्री. एकनाथ शिंदे यांच्या, 'मिशन थट्टी डेझ्' अंतर्गत 'मुंबई अगेंस्ट drugs' या महत्त्वपूर्ण उपक्रमाबद्दल, तुम्हाला माहिती देण्यासाठी/ केला आहे. तुम्ही मुंबईच्या कोणत्या एरियामध्ये राहता?"] 	 ['-'] 	 ['-'] 	 ['Right Party Contact,Right Party Contact'] 	 [702]
# 45 	 नाही 	 ["महाराष्ट्राचे मुख्यमंत्री/ एकनाथ शिंदे यांनी/ मुंबईला drugs मुक्त करण्याच्या उद्दिष्टाने 'मुंबई अगेन्स्ट drugs' मोहीम सुरू केली आहे. drugs च्या धोक्याचा सामना करण्यासाठी/ 24 तास उपलब्ध आणि पूर्णपणे विनामूल्य असा / 112 हा हेल्प लाइन नंबर/ गरजू लोकांना व्यावसायिक मदत मिळवून देण्यासाठी/ कटि बद्धअ आहे. तुम्हाला या मोहिमेबद्दल अधिक जाणून घ्यायला/ आवडेल का?"] 	 ['-'] 	 ['-'] 	 ['Location Captured,Location Captured'] 	 [702]
# 45 	 पुढच्या वर्षी रात्री 11 वाजता पुन्हा कॉल करा 	 ['आत्ता, हे खूप उशीरा होईल. मी तुम्हाला 15 June च्या आधी, कधी कॉल करू शकते?'] 	 ['-'] 	 ['-'] 	 ['Callback - Date Above Threshold,Callback - Date Above Threshold'] 	 [702]
# 45 	 ठीक आहे उद्या पुन्हा कॉल करा 	 ['ओके. मी तुम्हाला 14 June 2023 ला कॉल करेन. तुमचा दिवस छान जावो.'] 	 ['-'] 	 ['-'] 	 ['CallBack - Valid Date'] 	 [701]
# 46 	 /initial_message 	 ["नमस्कार. मी, 'ड्रग फ्री इंडिया' या एन्जीओमधून Neha बोलत आहे. मी ram यांच्याशी बोलत आहे का?"] 	 ['-'] 	 ['-'] 	 ['initial_message'] 	 [702]
# 46 	 नाही 	 ["मी हा कॉल महाराष्ट्राचे मुख्यमंत्री/ श्री. एकनाथ शिंदे यांच्या, 'मिशन थट्टी डेझ्' अंतर्गत 'मुंबई अगेंस्ट drugs' या महत्त्वपूर्ण उपक्रमाबद्दल, तुम्हाला माहिती देण्यासाठी/ केला आहे. तुम्ही मुंबईच्या कोणत्या एरियामध्ये राहता?"] 	 ['-'] 	 ['-'] 	 ['Right Party Contact,Right Party Contact'] 	 [702]
# 46 	 नाही 	 ["महाराष्ट्राचे मुख्यमंत्री/ एकनाथ शिंदे यांनी/ मुंबईला drugs मुक्त करण्याच्या उद्दिष्टाने 'मुंबई अगेन्स्ट drugs' मोहीम सुरू केली आहे. drugs च्या धोक्याचा सामना करण्यासाठी/ 24 तास उपलब्ध आणि पूर्णपणे विनामूल्य असा / 112 हा हेल्प लाइन नंबर/ गरजू लोकांना व्यावसायिक मदत मिळवून देण्यासाठी/ कटि बद्धअ आहे. तुम्हाला या मोहिमेबद्दल अधिक जाणून घ्यायला/ आवडेल का?"] 	 ['-'] 	 ['-'] 	 ['Location Captured,Location Captured'] 	 [702]
# 46 	 पुढच्या वर्षी रात्री 11 वाजता पुन्हा कॉल करा 	 ['आत्ता, हे खूप उशीरा होईल. मी तुम्हाला 15 June च्या आधी, कधी कॉल करू शकते?'] 	 ['-'] 	 ['-'] 	 ['Callback - Date Above Threshold,Callback - Date Above Threshold'] 	 [702]
# 46 	 ठीक आहे 30 दिवसांनंतर पुन्हा कॉल करा 	 ['हे खूप उशीरा होईल. मी तुम्हाला नंतर कॉल करेन. धन्यवाद.'] 	 ['-'] 	 ['-'] 	 ['Callback - Date Above Threshold'] 	 [701]
# 47 	 /initial_message 	 ["नमस्कार. मी, 'ड्रग फ्री इंडिया' या एन्जीओमधून Neha बोलत आहे. मी ram यांच्याशी बोलत आहे का?"] 	 ['-'] 	 ['-'] 	 ['initial_message'] 	 [702]
# 47 	 नाही 	 ["मी हा कॉल महाराष्ट्राचे मुख्यमंत्री/ श्री. एकनाथ शिंदे यांच्या, 'मिशन थट्टी डेझ्' अंतर्गत 'मुंबई अगेंस्ट drugs' या महत्त्वपूर्ण उपक्रमाबद्दल, तुम्हाला माहिती देण्यासाठी/ केला आहे. तुम्ही मुंबईच्या कोणत्या एरियामध्ये राहता?"] 	 ['-'] 	 ['-'] 	 ['Right Party Contact,Right Party Contact'] 	 [702]
# 47 	 नाही 	 ["महाराष्ट्राचे मुख्यमंत्री/ एकनाथ शिंदे यांनी/ मुंबईला drugs मुक्त करण्याच्या उद्दिष्टाने 'मुंबई अगेन्स्ट drugs' मोहीम सुरू केली आहे. drugs च्या धोक्याचा सामना करण्यासाठी/ 24 तास उपलब्ध आणि पूर्णपणे विनामूल्य असा / 112 हा हेल्प लाइन नंबर/ गरजू लोकांना व्यावसायिक मदत मिळवून देण्यासाठी/ कटि बद्धअ आहे. तुम्हाला या मोहिमेबद्दल अधिक जाणून घ्यायला/ आवडेल का?"] 	 ['-'] 	 ['-'] 	 ['Location Captured,Location Captured'] 	 [702]
# 47 	 पुढच्या वर्षी रात्री 11 वाजता पुन्हा कॉल करा 	 ['आत्ता, हे खूप उशीरा होईल. मी तुम्हाला 15 June च्या आधी, कधी कॉल करू शकते?'] 	 ['-'] 	 ['-'] 	 ['Callback - Date Above Threshold,Callback - Date Above Threshold'] 	 [702]
# 47 	 कोणताही दिवस ठीक आहे 	 ['ओके. मी तुम्हाला नंतर कॉल करेन. धन्यवाद.'] 	 ['-'] 	 ['-'] 	 ['Callback Time Not Given'] 	 [701]
# 48 	 /initial_message 	 ["नमस्कार. मी, 'ड्रग फ्री इंडिया' या एन्जीओमधून Neha बोलत आहे. मी ram यांच्याशी बोलत आहे का?"] 	 ['-'] 	 ['-'] 	 ['initial_message'] 	 [702]
# 48 	 नाही 	 ["मी हा कॉल महाराष्ट्राचे मुख्यमंत्री/ श्री. एकनाथ शिंदे यांच्या, 'मिशन थट्टी डेझ्' अंतर्गत 'मुंबई अगेंस्ट drugs' या महत्त्वपूर्ण उपक्रमाबद्दल, तुम्हाला माहिती देण्यासाठी/ केला आहे. तुम्ही मुंबईच्या कोणत्या एरियामध्ये राहता?"] 	 ['-'] 	 ['-'] 	 ['Right Party Contact,Right Party Contact'] 	 [702]
# 48 	 नाही 	 ["महाराष्ट्राचे मुख्यमंत्री/ एकनाथ शिंदे यांनी/ मुंबईला drugs मुक्त करण्याच्या उद्दिष्टाने 'मुंबई अगेन्स्ट drugs' मोहीम सुरू केली आहे. drugs च्या धोक्याचा सामना करण्यासाठी/ 24 तास उपलब्ध आणि पूर्णपणे विनामूल्य असा / 112 हा हेल्प लाइन नंबर/ गरजू लोकांना व्यावसायिक मदत मिळवून देण्यासाठी/ कटि बद्धअ आहे. तुम्हाला या मोहिमेबद्दल अधिक जाणून घ्यायला/ आवडेल का?"] 	 ['-'] 	 ['-'] 	 ['Location Captured,Location Captured'] 	 [702]
# 48 	 आज संध्याकाळी 5 वाजता कॉल करा 	 ['ओके. मी तुम्हाला, त्याच वेळी कॉल करेन. धन्यवाद.'] 	 ['-'] 	 ['-'] 	 ['Callback - Valid Time'] 	 [701]
# 49 	 /initial_message 	 ["नमस्कार. मी, 'ड्रग फ्री इंडिया' या एन्जीओमधून Neha बोलत आहे. मी ram यांच्याशी बोलत आहे का?"] 	 ['-'] 	 ['-'] 	 ['initial_message'] 	 [702]
# 49 	 नाही 	 ["मी हा कॉल महाराष्ट्राचे मुख्यमंत्री/ श्री. एकनाथ शिंदे यांच्या, 'मिशन थट्टी डेझ्' अंतर्गत 'मुंबई अगेंस्ट drugs' या महत्त्वपूर्ण उपक्रमाबद्दल, तुम्हाला माहिती देण्यासाठी/ केला आहे. तुम्ही मुंबईच्या कोणत्या एरियामध्ये राहता?"] 	 ['-'] 	 ['-'] 	 ['Right Party Contact,Right Party Contact'] 	 [702]
# 49 	 नाही 	 ["महाराष्ट्राचे मुख्यमंत्री/ एकनाथ शिंदे यांनी/ मुंबईला drugs मुक्त करण्याच्या उद्दिष्टाने 'मुंबई अगेन्स्ट drugs' मोहीम सुरू केली आहे. drugs च्या धोक्याचा सामना करण्यासाठी/ 24 तास उपलब्ध आणि पूर्णपणे विनामूल्य असा / 112 हा हेल्प लाइन नंबर/ गरजू लोकांना व्यावसायिक मदत मिळवून देण्यासाठी/ कटि बद्धअ आहे. तुम्हाला या मोहिमेबद्दल अधिक जाणून घ्यायला/ आवडेल का?"] 	 ['-'] 	 ['-'] 	 ['Location Captured,Location Captured'] 	 [702]
# 49 	 5 मे ला पुन्हा कॉल करा 	 ['ओके. मी तुम्हाला पुन्हा केव्हा कॉल करू शकते?'] 	 ['-'] 	 ['-'] 	 ['Callback,Callback Time Not Given'] 	 [702]
# 49 	 5 मे ला पुन्हा कॉल करा 	 ['ओके. मी तुम्हाला पुन्हा केव्हा कॉल करू शकते?'] 	 ['-'] 	 ['-'] 	 ['Callback Time Not Given,Callback Time Not Given'] 	 [702]
# 50 	 /initial_message 	 ["नमस्कार. मी, 'ड्रग फ्री इंडिया' या एन्जीओमधून Neha बोलत आहे. मी ram यांच्याशी बोलत आहे का?"] 	 ['-'] 	 ['-'] 	 ['initial_message'] 	 [702]
# 50 	 नाही 	 ["मी हा कॉल महाराष्ट्राचे मुख्यमंत्री/ श्री. एकनाथ शिंदे यांच्या, 'मिशन थट्टी डेझ्' अंतर्गत 'मुंबई अगेंस्ट drugs' या महत्त्वपूर्ण उपक्रमाबद्दल, तुम्हाला माहिती देण्यासाठी/ केला आहे. तुम्ही मुंबईच्या कोणत्या एरियामध्ये राहता?"] 	 ['-'] 	 ['-'] 	 ['Right Party Contact,Right Party Contact'] 	 [702]
# 50 	 नाही 	 ["महाराष्ट्राचे मुख्यमंत्री/ एकनाथ शिंदे यांनी/ मुंबईला drugs मुक्त करण्याच्या उद्दिष्टाने 'मुंबई अगेन्स्ट drugs' मोहीम सुरू केली आहे. drugs च्या धोक्याचा सामना करण्यासाठी/ 24 तास उपलब्ध आणि पूर्णपणे विनामूल्य असा / 112 हा हेल्प लाइन नंबर/ गरजू लोकांना व्यावसायिक मदत मिळवून देण्यासाठी/ कटि बद्धअ आहे. तुम्हाला या मोहिमेबद्दल अधिक जाणून घ्यायला/ आवडेल का?"] 	 ['-'] 	 ['-'] 	 ['Location Captured,Location Captured'] 	 [702]
# 50 	 5 मे ला पुन्हा कॉल करा 	 ['ओके. मी तुम्हाला पुन्हा केव्हा कॉल करू शकते?'] 	 ['-'] 	 ['-'] 	 ['Callback,Callback Time Not Given'] 	 [702]
# 50 	 आज संध्याकाळी 5 वाजता कॉल करा 	 ['ओके. मी तुम्हाला, त्याच वेळी कॉल करेन. धन्यवाद.'] 	 ['-'] 	 ['-'] 	 ['Callback - Valid Time'] 	 [701]
# 51 	 /initial_message 	 ["नमस्कार. मी, 'ड्रग फ्री इंडिया' या एन्जीओमधून Neha बोलत आहे. मी ram यांच्याशी बोलत आहे का?"] 	 ['-'] 	 ['-'] 	 ['initial_message'] 	 [702]
# 51 	 नाही 	 ["मी हा कॉल महाराष्ट्राचे मुख्यमंत्री/ श्री. एकनाथ शिंदे यांच्या, 'मिशन थट्टी डेझ्' अंतर्गत 'मुंबई अगेंस्ट drugs' या महत्त्वपूर्ण उपक्रमाबद्दल, तुम्हाला माहिती देण्यासाठी/ केला आहे. तुम्ही मुंबईच्या कोणत्या एरियामध्ये राहता?"] 	 ['-'] 	 ['-'] 	 ['Right Party Contact,Right Party Contact'] 	 [702]
# 51 	 नाही 	 ["महाराष्ट्राचे मुख्यमंत्री/ एकनाथ शिंदे यांनी/ मुंबईला drugs मुक्त करण्याच्या उद्दिष्टाने 'मुंबई अगेन्स्ट drugs' मोहीम सुरू केली आहे. drugs च्या धोक्याचा सामना करण्यासाठी/ 24 तास उपलब्ध आणि पूर्णपणे विनामूल्य असा / 112 हा हेल्प लाइन नंबर/ गरजू लोकांना व्यावसायिक मदत मिळवून देण्यासाठी/ कटि बद्धअ आहे. तुम्हाला या मोहिमेबद्दल अधिक जाणून घ्यायला/ आवडेल का?"] 	 ['-'] 	 ['-'] 	 ['Location Captured,Location Captured'] 	 [702]
# 51 	 5 मे ला पुन्हा कॉल करा 	 ['ओके. मी तुम्हाला पुन्हा केव्हा कॉल करू शकते?'] 	 ['-'] 	 ['-'] 	 ['Callback,Callback Time Not Given'] 	 [702]
# 51 	 उद्या सकाळी पुन्हा कॉल करा 	 ['ओके. मी तुम्हाला, त्याच वेळी कॉल करेन. धन्यवाद.'] 	 ['-'] 	 ['-'] 	 ['Callback - Valid Time'] 	 [701]
# 52 	 /initial_message 	 ["नमस्कार. मी, 'ड्रग फ्री इंडिया' या एन्जीओमधून Neha बोलत आहे. मी ram यांच्याशी बोलत आहे का?"] 	 ['-'] 	 ['-'] 	 ['initial_message'] 	 [702]
# 52 	 नाही 	 ["मी हा कॉल महाराष्ट्राचे मुख्यमंत्री/ श्री. एकनाथ शिंदे यांच्या, 'मिशन थट्टी डेझ्' अंतर्गत 'मुंबई अगेंस्ट drugs' या महत्त्वपूर्ण उपक्रमाबद्दल, तुम्हाला माहिती देण्यासाठी/ केला आहे. तुम्ही मुंबईच्या कोणत्या एरियामध्ये राहता?"] 	 ['-'] 	 ['-'] 	 ['Right Party Contact,Right Party Contact'] 	 [702]
# 52 	 नाही 	 ["महाराष्ट्राचे मुख्यमंत्री/ एकनाथ शिंदे यांनी/ मुंबईला drugs मुक्त करण्याच्या उद्दिष्टाने 'मुंबई अगेन्स्ट drugs' मोहीम सुरू केली आहे. drugs च्या धोक्याचा सामना करण्यासाठी/ 24 तास उपलब्ध आणि पूर्णपणे विनामूल्य असा / 112 हा हेल्प लाइन नंबर/ गरजू लोकांना व्यावसायिक मदत मिळवून देण्यासाठी/ कटि बद्धअ आहे. तुम्हाला या मोहिमेबद्दल अधिक जाणून घ्यायला/ आवडेल का?"] 	 ['-'] 	 ['-'] 	 ['Location Captured,Location Captured'] 	 [702]
# 52 	 5 मे ला पुन्हा कॉल करा 	 ['ओके. मी तुम्हाला पुन्हा केव्हा कॉल करू शकते?'] 	 ['-'] 	 ['-'] 	 ['Callback,Callback Time Not Given'] 	 [702]
# 52 	 ठीक आहे 30 दिवसांनंतर पुन्हा कॉल करा 	 ['आत्ता, हे खूप उशीरा होईल. मी तुम्हाला 15 June च्या आधी, कधी कॉल करू शकते?'] 	 ['-'] 	 ['-'] 	 ['Date Threshold Mismatch,Callback - Date Above Threshold'] 	 [702]
# 53 	 /initial_message 	 ["नमस्कार. मी, 'ड्रग फ्री इंडिया' या एन्जीओमधून Neha बोलत आहे. मी ram यांच्याशी बोलत आहे का?"] 	 ['-'] 	 ['-'] 	 ['initial_message'] 	 [702]
# 53 	 नाही 	 ["मी हा कॉल महाराष्ट्राचे मुख्यमंत्री/ श्री. एकनाथ शिंदे यांच्या, 'मिशन थट्टी डेझ्' अंतर्गत 'मुंबई अगेंस्ट drugs' या महत्त्वपूर्ण उपक्रमाबद्दल, तुम्हाला माहिती देण्यासाठी/ केला आहे. तुम्ही मुंबईच्या कोणत्या एरियामध्ये राहता?"] 	 ['-'] 	 ['-'] 	 ['Right Party Contact,Right Party Contact'] 	 [702]
# 53 	 नाही 	 ["महाराष्ट्राचे मुख्यमंत्री/ एकनाथ शिंदे यांनी/ मुंबईला drugs मुक्त करण्याच्या उद्दिष्टाने 'मुंबई अगेन्स्ट drugs' मोहीम सुरू केली आहे. drugs च्या धोक्याचा सामना करण्यासाठी/ 24 तास उपलब्ध आणि पूर्णपणे विनामूल्य असा / 112 हा हेल्प लाइन नंबर/ गरजू लोकांना व्यावसायिक मदत मिळवून देण्यासाठी/ कटि बद्धअ आहे. तुम्हाला या मोहिमेबद्दल अधिक जाणून घ्यायला/ आवडेल का?"] 	 ['-'] 	 ['-'] 	 ['Location Captured,Location Captured'] 	 [702]
# 53 	 5 मे ला पुन्हा कॉल करा 	 ['ओके. मी तुम्हाला पुन्हा केव्हा कॉल करू शकते?'] 	 ['-'] 	 ['-'] 	 ['Callback,Callback Time Not Given'] 	 [702]
# 53 	 उद्या रात्री 11 वाजता परत कॉल करा 	 ['ओके. पण मी 6 नंतर कॉल करू शकणार नाही. मी तुम्हाला किती वाजता कॉल करू?'] 	 ['-'] 	 ['-'] 	 ['Callback - Time Above Threshold,Callback - Time Above Threshold'] 	 [702]
# 54 	 /initial_message 	 ["नमस्कार. मी, 'ड्रग फ्री इंडिया' या एन्जीओमधून Neha बोलत आहे. मी ram यांच्याशी बोलत आहे का?"] 	 ['-'] 	 ['-'] 	 ['initial_message'] 	 [702]
# 54 	 नाही 	 ["मी हा कॉल महाराष्ट्राचे मुख्यमंत्री/ श्री. एकनाथ शिंदे यांच्या, 'मिशन थट्टी डेझ्' अंतर्गत 'मुंबई अगेंस्ट drugs' या महत्त्वपूर्ण उपक्रमाबद्दल, तुम्हाला माहिती देण्यासाठी/ केला आहे. तुम्ही मुंबईच्या कोणत्या एरियामध्ये राहता?"] 	 ['-'] 	 ['-'] 	 ['Right Party Contact,Right Party Contact'] 	 [702]
# 54 	 नाही 	 ["महाराष्ट्राचे मुख्यमंत्री/ एकनाथ शिंदे यांनी/ मुंबईला drugs मुक्त करण्याच्या उद्दिष्टाने 'मुंबई अगेन्स्ट drugs' मोहीम सुरू केली आहे. drugs च्या धोक्याचा सामना करण्यासाठी/ 24 तास उपलब्ध आणि पूर्णपणे विनामूल्य असा / 112 हा हेल्प लाइन नंबर/ गरजू लोकांना व्यावसायिक मदत मिळवून देण्यासाठी/ कटि बद्धअ आहे. तुम्हाला या मोहिमेबद्दल अधिक जाणून घ्यायला/ आवडेल का?"] 	 ['-'] 	 ['-'] 	 ['Location Captured,Location Captured'] 	 [702]
# 54 	 5 मे ला पुन्हा कॉल करा 	 ['ओके. मी तुम्हाला पुन्हा केव्हा कॉल करू शकते?'] 	 ['-'] 	 ['-'] 	 ['Callback,Callback Time Not Given'] 	 [702]
# 54 	 पुढच्या वर्षी रात्री 11 वाजता पुन्हा कॉल करा 	 ['आत्ता, हे खूप उशीरा होईल. मी तुम्हाला 15 June च्या आधी, कधी कॉल करू शकते?'] 	 ['-'] 	 ['-'] 	 ['Callback - Date Above Threshold,Callback - Date Above Threshold'] 	 [702]
# 55 	 /initial_message 	 ["नमस्कार. मी, 'ड्रग फ्री इंडिया' या एन्जीओमधून Neha बोलत आहे. मी ram यांच्याशी बोलत आहे का?"] 	 ['-'] 	 ['-'] 	 ['initial_message'] 	 [702]
# 55 	 नाही 	 ["मी हा कॉल महाराष्ट्राचे मुख्यमंत्री/ श्री. एकनाथ शिंदे यांच्या, 'मिशन थट्टी डेझ्' अंतर्गत 'मुंबई अगेंस्ट drugs' या महत्त्वपूर्ण उपक्रमाबद्दल, तुम्हाला माहिती देण्यासाठी/ केला आहे. तुम्ही मुंबईच्या कोणत्या एरियामध्ये राहता?"] 	 ['-'] 	 ['-'] 	 ['Right Party Contact,Right Party Contact'] 	 [702]
# 55 	 नाही 	 ["महाराष्ट्राचे मुख्यमंत्री/ एकनाथ शिंदे यांनी/ मुंबईला drugs मुक्त करण्याच्या उद्दिष्टाने 'मुंबई अगेन्स्ट drugs' मोहीम सुरू केली आहे. drugs च्या धोक्याचा सामना करण्यासाठी/ 24 तास उपलब्ध आणि पूर्णपणे विनामूल्य असा / 112 हा हेल्प लाइन नंबर/ गरजू लोकांना व्यावसायिक मदत मिळवून देण्यासाठी/ कटि बद्धअ आहे. तुम्हाला या मोहिमेबद्दल अधिक जाणून घ्यायला/ आवडेल का?"] 	 ['-'] 	 ['-'] 	 ['Location Captured,Location Captured'] 	 [702]
# 55 	 5 मे ला पुन्हा कॉल करा 	 ['ओके. मी तुम्हाला पुन्हा केव्हा कॉल करू शकते?'] 	 ['-'] 	 ['-'] 	 ['Callback,Callback Time Not Given'] 	 [702]
# 55 	 उद्या सकाळी पुन्हा कॉल करा 	 ['ओके. मी तुम्हाला, त्याच वेळी कॉल करेन. धन्यवाद.'] 	 ['-'] 	 ['-'] 	 ['Callback - Valid Time'] 	 [701]
# 56 	 /initial_message 	 ["नमस्कार. मी, 'ड्रग फ्री इंडिया' या एन्जीओमधून Neha बोलत आहे. मी ram यांच्याशी बोलत आहे का?"] 	 ['-'] 	 ['-'] 	 ['initial_message'] 	 [702]
# 56 	 नाही 	 ["मी हा कॉल महाराष्ट्राचे मुख्यमंत्री/ श्री. एकनाथ शिंदे यांच्या, 'मिशन थट्टी डेझ्' अंतर्गत 'मुंबई अगेंस्ट drugs' या महत्त्वपूर्ण उपक्रमाबद्दल, तुम्हाला माहिती देण्यासाठी/ केला आहे. तुम्ही मुंबईच्या कोणत्या एरियामध्ये राहता?"] 	 ['-'] 	 ['-'] 	 ['Right Party Contact,Right Party Contact'] 	 [702]
# ...
# 310 	 सॉरी मॅम 	 ['Drug Free India च्या वतीने, मी  Neha बोलत आहे.'] 	 ["मुंबई अगेंस्ट drugs' मोहिमेच्या अंतर्गत 112 हा हेल्प लाइन नंबर सुरू करण्यात आला आहे. मोहिमेबद्दल अधिक जाणून घ्यायला/ आवडेल का?"] 	 ['-'] 	 ['Greet,Location Captured'] 	 [702]
# 311 	 /initial_message 	 ["नमस्कार. मी, 'ड्रग फ्री इंडिया' या एन्जीओमधून Neha बोलत आहे. मी ram यांच्याशी बोलत आहे का?"] 	 ['-'] 	 ['-'] 	 ['initial_message'] 	 [702]
# 311 	 हो 	 ["मी हा कॉल महाराष्ट्राचे मुख्यमंत्री/ श्री. एकनाथ शिंदे यांच्या, 'मिशन थट्टी डेझ्' अंतर्गत 'मुंबई अगेंस्ट drugs' या महत्त्वपूर्ण उपक्रमाबद्दल, तुम्हाला माहिती देण्यासाठी/ केला आहे. तुम्ही मुंबईच्या कोणत्या एरियामध्ये राहता?"] 	 ['-'] 	 ['-'] 	 ['Right Party Contact,Right Party Contact'] 	 [702]
# 311 	 /no_response 	 ['Drug Free India च्या वतीने, मी  Neha बोलत आहे.'] 	 ['हा कॉल \\"मुंबई अगेंस्ट drugs\\" या मोहिमेबद्दल आहे. तुम्ही मुंबईच्या कोणत्या एरियामध्ये राहता?'] 	 ['-'] 	 ['Greet,Right Party Contact'] 	 [702]
# 311 	 नाही 	 ["महाराष्ट्राचे मुख्यमंत्री/ एकनाथ शिंदे यांनी/ मुंबईला drugs मुक्त करण्याच्या उद्दिष्टाने 'मुंबई अगेन्स्ट drugs' मोहीम सुरू केली आहे. drugs च्या धोक्याचा सामना करण्यासाठी/ 24 तास उपलब्ध आणि पूर्णपणे विनामूल्य असा / 112 हा हेल्प लाइन नंबर/ गरजू लोकांना व्यावसायिक मदत मिळवून देण्यासाठी/ कटि बद्धअ आहे. तुम्हाला या मोहिमेबद्दल अधिक जाणून घ्यायला/ आवडेल का?"] 	 ['-'] 	 ['-'] 	 ['Location Captured,Location Captured'] 	 [702]
# 311 	 तुम्ही कॉलवर आहात का? 	 ['व्यसन मुक्तीशी झुंजत असलेल्या/ तुमच्या ओळखी च्या/ किंवा तुमच्या प्रिय व्यक्तीबद्दल/ तुम्हाला काळजी वाटत असल्यास, कृपया 112 या हेल्प लाइन नंबरवर कॉल करण्यास/ अजिबात संकोच करू नका. व्यक्तीची ओळख गोपनीय ठेवली जाईल. तुमचा एक कॉल, उज्ज्वल भविष्याच्या दिशेने/ टाकलेले पहिले पाऊल ठरू शक्तो. आपण्ण या महत्त्वपूर्ण मोहिमेत/ आदरणीय मुख्यमंत्री एकनाथ शिंदे साहेबांना/ साथ देणार का?'] 	 ['-'] 	 ['-'] 	 ['Know More - Yes,Know More - Yes'] 	 [702]
# 312 	 /initial_message 	 ["नमस्कार. मी, 'ड्रग फ्री इंडिया' या एन्जीओमधून Neha बोलत आहे. मी ram यांच्याशी बोलत आहे का?"] 	 ['-'] 	 ['-'] 	 ['initial_message'] 	 [702]
# 312 	 हो 	 ["मी हा कॉल महाराष्ट्राचे मुख्यमंत्री/ श्री. एकनाथ शिंदे यांच्या, 'मिशन थट्टी डेझ्' अंतर्गत 'मुंबई अगेंस्ट drugs' या महत्त्वपूर्ण उपक्रमाबद्दल, तुम्हाला माहिती देण्यासाठी/ केला आहे. तुम्ही मुंबईच्या कोणत्या एरियामध्ये राहता?"] 	 ['-'] 	 ['-'] 	 ['Right Party Contact,Right Party Contact'] 	 [702]
# 312 	 /no_response 	 ['Drug Free India च्या वतीने, मी  Neha बोलत आहे.'] 	 ['हा कॉल \\"मुंबई अगेंस्ट drugs\\" या मोहिमेबद्दल आहे. तुम्ही मुंबईच्या कोणत्या एरियामध्ये राहता
# 320 	 आपण वारंवार कॉल का करीत आहात? 	 ['व्यसन मुक्तीशी झुंजत असलेल्या/ तुमच्या ओळखी च्या/ किंवा तुमच्या प्रिय व्यक्तीबद्दल/ तुम्हाला काळजी वाटत असल्यास, कृपया 112 या हेल्प लाइन नंबरवर कॉल करण्यास/ अजिबात संकोच करू नका. व्यक्तीची ओळख गोपनीय ठेवली जाईल. तुमचा एक कॉल, उज्ज्वल भविष्याच्या दिशेने/ टाकलेले पहिले पाऊल ठरू शक्तो. आपण्ण या महत्त्वपूर्ण मोहिमेत/ आदरणीय मुख्यमंत्री एकनाथ शिंदे साहेबांना/ साथ देणार का?'] 	 ['-'] 	 ['-'] 	 ['Know More - Yes,Know More - Yes'] 	 [702]
# Testcases completed, --- Run next block

# %%
df2 = pd.DataFrame()

df2["TestCase_No"] = final_Tno
df2["Utterance"] = final_user_resp

df2["Bot_Response_1"] = final_response_1
df2["Bot_Response_2"] = final_response_2
df2["Bot_Response_3"] = final_response_3
df2["Disposition"] = final_disposition
df2["Status_Code"] = final_status

# df3 = pd.concat([df,df2], axis=1, join='inner')

# df3.to_csv(Final_Sheet, index=False)

df2.to_csv(Final_Sheet, index=False)


print('\n','\n','\n')
print ("required data is downloaded as a CSV in path = .......",Final_Sheet)
print('\n','\n','\n')


#df3.head(5)
# Out:
#
#
#
# required data is downloaded as a CSV in path = ....... /Users/vinay_kl/Downloads/Final_Sheet_Stellantis_Marathi_['10:11:42'].csv

# %%
print(len(final_Tno))
print(len(final_user_resp))
print(len(final_response_1))
print(len(final_response_2))
print(len(final_response_3))
print(len(final_disposition))
print(len(final_status))

# print(final_response_3)
# print(final_response_3)
# Out:
# 1835
# 1835
# 1835
# 1835
# 1835
# 1835
# 1835

# %% [markdown]
# # Rough

# %%
headers = {'Content-Type':'application/json'}    
payload = json.dumps ({
    "user_id": "9482152445",
    "request_id": "request11j27",
    "sender": "GS-klewllkdfgfhlnkkpk3",
    "message": "/initial_message",
    "customerData": {
        "callId": "12345",
        "bargingCall": "True",
        "accessToken": "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VySWQiOiI2NDUwYjkyN2YzZGZlYzMyMDIxNDgxMzciLCJhY2NvdW50SWQiOiI2NDUwYjkyNmYzZGZlYzMyMDIxNDgxMmUiLCJyb2xlIjoiQWRtaW4iLCJpYXQiOjE2ODM1NDM5NDAsImV4cCI6MTY4MzYzMDM0MH0.slLTPbIA92IDfsZUJKR0rxFnVgDi7M5mtDLaWDmlJsc",
        "clientName": "Stellantis Testing",
        "callType": "Internal UAT",
        "telephonyName": "Epicode",
        "customerInfo": {
            "contactInfo": {
                "primary": "9354069780",
                "customerSupportNumber": "4233423434",
                "customerCareNumber": ""
            },
            "primaryInfo": {
                "firstName": "ram",
                "vehicleIdentificationNumber": "1223345667",
                "sellingDealerName": "sdfsdf",
                "geographicLocation": "",
                "pincode": "",
                "lastServiceDealerCity": "sdfsdfsdf",
                "lastServiceDealerName": "lkjfsdklf",
                "preferredAgentGender": "M",
                "agentname": "kumar",
                "serviceDueDate": "2023-05-18",
                "captured_date": "2023-05-18",
                "serviceNetworkName": "dsfsfsdf",
                "flow": "political_edge_flow",
                "status": "Appointment Confirmed",
                "channel": "Voice",
                "utter_sub_flow_slot": "main_flow",
                "generalRepeatThreshold": "3",
                "businessIntentThreshold": "3",
                "previousDisposition": "Campaign End",
                "language": "Marathi",
                "age": "",
                "gender": "",
                "region": "",
                "collared": "",
                "customerUniqueId": ""
            },
            "loanAccountDetails": {
                "emiAmount": "",
                "emiDueDate": "",
                "loanApplicationDate": "",
                "loanEndingDate": "",
                "lateFee": "",
                "interestRate": "",
                "nextNachDate": "",
                "paidDate": "",
                "currentPaymentStatus": "",
                "noofemi": "",
                "noOfEmiPaid": "",
                "loanTenureLeft": "",
                "loanAmountRemaining": "",
                "loanStartDate": "",
                "principalAmount": "",
                "totalLoanAmount": "",
                "loanCategory": "",
                "loanId": "",
                "noOfLoans": "",
                "paymentMode": "",
                "cbCharges": "0",
                "penalCharges": "0"
            },
            "behaviourDetails": {
                "riskType": "",
                "typology": "",
                "callDisposition": ""
            },
            "email": {
                "primary": ""
            },
            "leadType": "Transactional"
        },
        "callingPartner": "epicode",
        "campaignId": "2345",
        "agentConfig": {
            "parentFlow": [
                {
                    "flow": "appointment_booking_flow",
                    "isParent": True,
                    "isChild": False,
                    "channel": [
                        "Call"
                    ],
                    "type": "Female",
                    "language": [
                        "English",
                        "Hindi"
                    ],
                    "Call": {
                        "voice": "Saarthi TTS",
                        "thresholdDateCallBack": 2,
                        "thresholdTimeCallBack": 30
                    }
                }
            ],
            "callFlow": [
                {
                    "appointment_booking_flow": {
                        "slot1": [
                            {
                                "initial": {
                                    "label": "lg_rpc_form",
                                    "next": "subSlot1"
                                },
                                "subSlot1": [
                                    {
                                        "third_party_contact": {
                                            "initial": [
                                                {
                                                    "label": "third_party_contact_form",
                                                    "next": "subSlot1"
                                                }
                                            ],
                                            "subSlot1": [
                                                {
                                                    "label": "stop_conversation"
                                                }
                                            ]
                                        },
                                        "call_back": {
                                            "initial": [
                                                {
                                                    "label": "call_back_form",
                                                    "next": "subSlot1"
                                                }
                                            ],
                                            "subSlot1": [
                                                {
                                                    "label": "stop_conversation"
                                                }
                                            ]
                                        },
                                        "small_talk": {
                                            "initial": [
                                                {
                                                    "label": "small_talk_form",
                                                    "next": "subSlot1"
                                                }
                                            ],
                                            "subSlot1": [
                                                {
                                                    "label": "stop_conversation"
                                                }
                                            ]
                                        }
                                    }
                                ]
                            }
                        ],
                        "slot2": [
                            {
                                "label": "date_confirmation_form",
                                "next": "slot3"
                            }
                        ],
                        "slot3": [
                            {
                                "not_interested": {
                                    "initial": [
                                        {
                                            "label": "not_interested_form",
                                            "next": "subSlot1"
                                        }
                                    ],
                                    "subSlot1": [
                                        {
                                            "label": "stop_conversation"
                                        }
                                    ]
                                },
                                "interested_later": {
                                    "initial": [
                                        {
                                            "label": "interested_later_form",
                                            "next": "subSlot1"
                                        }
                                    ],
                                    "subSlot1": [
                                        {
                                            "label": "stop_conversation"
                                        }
                                    ]
                                },
                                "call_back": {
                                    "initial": [
                                        {
                                            "label": "call_back_form",
                                            "next": "subSlot1"
                                        }
                                    ],
                                    "subSlot1": [
                                        {
                                            "label": "stop_conversation"
                                        }
                                    ]
                                },
                                "date_capture": {
                                    "initial": [
                                        {
                                            "label": "date_capture_form",
                                            "next": "subSlot1"
                                        }
                                    ],
                                    "subSlot1": [
                                        {
                                            "dealership_capture": {
                                                "initial": [
                                                    {
                                                        "label": "dealership_capture_form",
                                                        "next": "sub1Slot1"
                                                    }
                                                ],
                                                "sub1Slot1": [
                                                    {
                                                        "deny": {
                                                            "initial": [
                                                                {
                                                                    "label": "deny_dealership_form",
                                                                    "next": "sub2Slot1"
                                                                }
                                                            ],
                                                            "sub2Slot1": [
                                                                {
                                                                    "label": "stop_conversation"
                                                                }
                                                            ]
                                                        },
                                                        "affirm": {
                                                            "initial": [
                                                                {
                                                                    "label": "pickup_drop_capture_form",
                                                                    "next": "sub2Slot1"
                                                                }
                                                            ],
                                                            "sub2Slot1": [
                                                                {
                                                                    "label": "stop_conversation"
                                                                }
                                                            ]
                                                        }
                                                    }
                                                ]
                                            }
                                        }
                                    ]
                                },
                                "dealership_capture": {
                                    "initial": [
                                        {
                                            "label": "dealership_capture_form",
                                            "next": "sub1Slot1"
                                        }
                                    ],
                                    "sub1Slot1": [
                                        {
                                            "deny": {
                                                "initial": [
                                                    {
                                                        "label": "deny_dealership_form",
                                                        "next": "sub2Slot1"
                                                    }
                                                ],
                                                "sub2Slot1": [
                                                    {
                                                        "label": "stop_conversation"
                                                    }
                                                ]
                                            },
                                            "affirm": {
                                                "initial": [
                                                    {
                                                        "label": "pickup_drop_capture_form",
                                                        "next": "sub2Slot1"
                                                    }
                                                ],
                                                "sub2Slot1": [
                                                    {
                                                        "label": "stop_conversation"
                                                    }
                                                ]
                                            }
                                        }
                                    ]
                                }
                            }
                        ]
                    },
                    "follow_up_flow": {
                        "slot1": [
                            {
                                "initial": {
                                    "label": "lg_rpc_form",
                                    "next": "subSlot1"
                                },
                                "subSlot1": [
                                    {
                                        "third_party_contact": {
                                            "initial": [
                                                {
                                                    "label": "third_party_contact_form",
                                                    "next": "subSlot1"
                                                }
                                            ],
                                            "subSlot1": [
                                                {
                                                    "label": "stop_conversation"
                                                }
                                            ]
                                        },
                                        "call_back": {
                                            "initial": [
                                                {
                                                    "label": "call_back_form",
                                                    "next": "subSlot1"
                                                }
                                            ],
                                            "subSlot1": [
                                                {
                                                    "label": "stop_conversation"
                                                }
                                            ]
                                        },
                                        "small_talk": {
                                            "initial": [
                                                {
                                                    "label": "small_talk_form",
                                                    "next": "subSlot1"
                                                }
                                            ],
                                            "subSlot1": [
                                                {
                                                    "label": "stop_conversation"
                                                }
                                            ]
                                        }
                                    }
                                ]
                            }
                        ],
                        "slot2": [
                            {
                                "label": "followup_dealership_capture_form",
                                "next": "slot3"
                            }
                        ],
                        "slot3": [
                            {
                                "not_interested": {
                                    "initial": [
                                        {
                                            "label": "not_interested_form",
                                            "next": "subSlot1"
                                        }
                                    ],
                                    "subSlot1": [
                                        {
                                            "label": "stop_conversation"
                                        }
                                    ]
                                },
                                "interested_later": {
                                    "initial": [
                                        {
                                            "label": "interested_later_form",
                                            "next": "subSlot1"
                                        }
                                    ],
                                    "subSlot1": [
                                        {
                                            "label": "stop_conversation"
                                        }
                                    ]
                                },
                                "call_back": {
                                    "initial": [
                                        {
                                            "label": "call_back_form",
                                            "next": "subSlot1"
                                        }
                                    ],
                                    "subSlot1": [
                                        {
                                            "label": "stop_conversation"
                                        }
                                    ]
                                },
                                "new_date_capture": {
                                    "initial": [
                                        {
                                            "label": "date_capture_form",
                                            "next": "subSlot1"
                                        }
                                    ],
                                    "subSlot1": [
                                        {
                                            "dealership_capture": {
                                                "initial": [
                                                    {
                                                        "label": "dealership_capture_form",
                                                        "next": "sub1Slot1"
                                                    }
                                                ],
                                                "sub1Slot1": [
                                                    {
                                                        "deny": {
                                                            "initial": [
                                                                {
                                                                    "label": "deny_dealership_form",
                                                                    "next": "sub2Slot1"
                                                                }
                                                            ],
                                                            "sub2Slot1": [
                                                                {
                                                                    "label": "stop_conversation"
                                                                }
                                                            ]
                                                        },
                                                        "affirm": {
                                                            "initial": [
                                                                {
                                                                    "label": "pickup_drop_capture_form",
                                                                    "next": "sub2Slot1"
                                                                }
                                                            ],
                                                            "sub2Slot1": [
                                                                {
                                                                    "label": "stop_conversation"
                                                                }
                                                            ]
                                                        }
                                                    }
                                                ]
                                            }
                                        }
                                    ]
                                },
                                "deny_dealership": {
                                    "initial": [
                                        {
                                            "label": "deny_dealership_form",
                                            "next": "sub2Slot1"
                                        }
                                    ],
                                    "sub2Slot1": [
                                        {
                                            "label": "stop_conversation"
                                        }
                                    ]
                                },
                                "pickup_drop_capture": {
                                    "initial": [
                                        {
                                            "label": "pickup_drop_capture_form",
                                            "next": "sub2Slot1"
                                        }
                                    ],
                                    "sub2Slot1": [
                                        {
                                            "label": "stop_conversation"
                                        }
                                    ]
                                }
                            }
                        ]
                    },
                    "remainder_flow": {
                        "slot1": [
                            {
                                "initial": {
                                    "label": "lg_rpc_form",
                                    "next": "subSlot1"
                                },
                                "subSlot1": [
                                    {
                                        "third_party_contact": {
                                            "initial": [
                                                {
                                                    "label": "third_party_contact_form",
                                                    "next": "subSlot1"
                                                }
                                            ],
                                            "subSlot1": [
                                                {
                                                    "label": "stop_conversation"
                                                }
                                            ]
                                        },
                                        "call_back": {
                                            "initial": [
                                                {
                                                    "label": "call_back_form",
                                                    "next": "subSlot1"
                                                }
                                            ],
                                            "subSlot1": [
                                                {
                                                    "label": "stop_conversation"
                                                }
                                            ]
                                        },
                                        "small_talk": {
                                            "initial": [
                                                {
                                                    "label": "small_talk_form",
                                                    "next": "subSlot1"
                                                }
                                            ],
                                            "subSlot1": [
                                                {
                                                    "label": "stop_conversation"
                                                }
                                            ]
                                        }
                                    }
                                ]
                            }
                        ],
                        "slot2": [
                            {
                                "label": "booking_confirmation_form",
                                "next": "slot3"
                            }
                        ],
                        "slot3": [
                            {
                                "interested_later": {
                                    "initial": [
                                        {
                                            "label": "interested_later_form",
                                            "next": "subSlot1"
                                        }
                                    ],
                                    "subSlot1": [
                                        {
                                            "label": "stop_conversation"
                                        }
                                    ]
                                },
                                "call_back": {
                                    "initial": [
                                        {
                                            "label": "call_back_form",
                                            "next": "subSlot1"
                                        }
                                    ],
                                    "subSlot1": [
                                        {
                                            "label": "stop_conversation"
                                        }
                                    ]
                                }
                            }
                        ]
                    },
                    "feedback_flow": {
                        "slot1": [
                            {
                                "initial": {
                                    "label": "lg_rpc_form",
                                    "next": "subSlot1"
                                },
                                "subSlot1": [
                                    {
                                        "third_party_contact": {
                                            "initial": [
                                                {
                                                    "label": "third_party_contact_form",
                                                    "next": "subSlot1"
                                                }
                                            ],
                                            "subSlot1": [
                                                {
                                                    "label": "stop_conversation"
                                                }
                                            ]
                                        },
                                        "call_back": {
                                            "initial": [
                                                {
                                                    "label": "call_back_form",
                                                    "next": "subSlot1"
                                                }
                                            ],
                                            "subSlot1": [
                                                {
                                                    "label": "stop_conversation"
                                                }
                                            ]
                                        },
                                        "small_talk": {
                                            "initial": [
                                                {
                                                    "label": "small_talk_form",
                                                    "next": "subSlot1"
                                                }
                                            ],
                                            "subSlot1": [
                                                {
                                                    "label": "stop_conversation"
                                                }
                                            ]
                                        }
                                    }
                                ]
                            }
                        ],
                        "slot2": [
                            {
                                "label": "rating_based_form",
                                "next": "slot3"
                            }
                        ],
                        "slot3": [
                            {
                                "call_back": {
                                    "initial": [
                                        {
                                            "label": "call_back_form",
                                            "next": "subSlot1"
                                        }
                                    ],
                                    "subSlot1": [
                                        {
                                            "label": "stop_conversation"
                                        }
                                    ]
                                }
                            }
                        ]
                    }
                }
            ],
            "accountId": "6450b926f3dfec320214812e",
            "agentName": "Stella",
            "domain": "Automobile",
            "subDomain": "General",
            "productType": "Four Wheeler",
            "agentId": "StellantisTesting_salesOnboarding_FourWheeler_01",
            "createdAt": "2023-05-05T06:11:54.021Z",
            "updatedAt": "2023-05-05T06:11:54.021Z",
            "id": "64549e2ac0e8415d50370c7c"
        },
        "useCaseId": "62c81c4a4a0affe91342aaaa",
        "accountId": "6450b926f3dfec320214812e",
        "isCampaignTesting": True
    }
}
)


response = requests.request("POST", botEndPoint, headers=headers, data=payload).json()

# pprint(response)




#-------------------------#

text_list = []
response_1 = ["-"]
response_2 = ["-"]
response_3 = ["-"]
disposotion_list = []
staus_list = []

temp_status = response["custom"]["status"]
temp_disp = response["custom"]["disposition_id"]
temp_disp = ",".join(map(str, temp_disp))     #its like a text combining method with given delimeter.  map & str is added to reduce "sequence no N" error

val = response["data"]
for i in range(0,len(val)):    
      temp_text = response["data"][i]["text"]
      text_list.append(temp_text)

for i in range(0,len(text_list)):
    if i == 0:
        response_1 = [text_list[i]]
    if i == 1:
        response_2 = [text_list[i]]
    if i == 2:
        response_3 = [text_list[i]]

# return response_1,response_2,response_3, [temp_disp], [temp_status]



print(response_1,response_2,response_3, [temp_disp], [temp_status])
# Out:
# ["नमस्कार. मी, 'ड्रग फ्री इंडिया' या एन्जीओमधून kumar बोलत आहे. मी ram यांच्याशी बोलत आहे का?"] ['-'] ['-'] ['initial_message'] [702]

# %%
pprint(response["data"][0]["template_name"])

pprint(response["data"][0]["text"])

pprint(response["custom"]["disposition_id"])

pprint(response["custom"]["status"])
# Out:
# 'utter_RPC_initial_message_stellantis_AB_appointment_booking_flow_FW_G_F'
# "Hi, I'm kumar , calling from Jeep sdfsdfsdf . Am I talking to ram ??"
# ['initial_message']
# 702

# %%
text_list = []
response_1 = ["-"]
response_2 = ["-"]
#response_3 = ["-"]
disposotion_list = []
staus_list = []

temp_status = response["custom"]["status"]
temp_disp = response["custom"]["disposition_id"]
temp_disp = ",".join(map(str, temp_disp))     #its like a text combining method with given delimeter.  map & str is added to reduce "sequence no N" error

val = response["data"]
for i in range(0,len(val)):    
      temp_text = response["data"][i]["text"]
      text_list.append(temp_text)

for i in range(0,len(text_list)):
    if i == 0:
        response_1 = [text_list[i]]
    if i == 1:
        response_2 = [text_list[i]]

# %%
print(response_2)
# Out:
# ['-']
