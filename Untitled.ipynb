# %%
from pydub import AudioSegment
import csv
import os
#audio generator
def multiplier(sourceAudioPath,outPath,responseID,audioID,path):
    #print("source path ", sourceAudioPath)
    #print("out path ", outPath)
    #generate or export new audios to the given output path
    #fileName = response ID
    #status=False
    sourceAudio=sourceAudioPath+audioID+".wav"   
    print("The source AUdo",path)
    files = list(os.listdir(path))
    if audioID in files:
        audio = AudioSegment.from_wav(sourceAudio)
        audio.export(outPath+responseID+".wav", format="wav")
        print('exported ',responseID+".wav")
        #status=True
    else:
        print(audioID+".wav does not exist so ",responseID+".wav not exported or created.")


def duplicator(sourceAudioPath, filePath, outPath, entity=False):
    # function: read response IDs and makes duplicate audios from assigned unique audio
    # filePath = csv file path of a template of the all duplicate responses
    finalOutPath=''
    count = 0
    static_or_ent=''
    if entity == True:
        static_or_ent= 'entity'
        print("is within entity.")
    else:
        static_or_ent = 'static'
        print('within non entity')

    # sourceAudioPath='/Users/kkabikhanganba/Downloads/SourcePrimaryResponses/'+entityPath
    path = sourceAudioPath
    sourceAudioPath = sourceAudioPath + static_or_ent + '/'
    
    with open(filePath) as csv_file:
        csv_reader = csv.reader(csv_file)
        for col in csv_reader:
            print("final out path is: ", finalOutPath)
            audioID = col[0]  # audio id
            responseID = col[1]  # responseID as fileName
            #gender = col[3]  # if gender is not required, assign gender with empty string. gender = ''
            gender=''
            finalOutPath = outPath + static_or_ent + '/' #static or entity
            count += 1
            print(audioID, "out path", outPath,responseID)
            print('source path ',sourceAudioPath)
            multiplier(sourceAudioPath, finalOutPath, responseID, audioID,path)
    print('total responses count ', count)

sourceAudioPath='/Users/vinay_kl/Downloads/Emi_date_not_confirmed_Hindi_Unique/'# path of unique audios/responses
templatePath='/Users/vinay_kl/Downloads/1.csv'# template path
outPutPath='/Users/vinay_kl/Downloads/output_d/'# out path where to export
#entity should be set as True while making duplicates for entity responses
duplicator(sourceAudioPath,templatePath,outPutPath,entity=False)
# Out:
# within non entity
# final out path is:
# H130 out path /Users/vinay_kl/Downloads/output_d/ utter_EMI_date_not_confirmed_predue_UMYB_WAOR_F
# source path  /Users/vinay_kl/Downloads/Emi_date_not_confirmed_Hindi_Unique/static/
# The source AUdo /Users/vinay_kl/Downloads/Emi_date_not_confirmed_Hindi_Unique/
# H130.wav does not exist so  utter_EMI_date_not_confirmed_predue_UMYB_WAOR_F.wav not exported or created.
# final out path is:  /Users/vinay_kl/Downloads/output_d/static/
# H130 out path /Users/vinay_kl/Downloads/output_d/ utter_EMI_date_not_confirmed_predue_UMYB_WACR_F
# source path  /Users/vinay_kl/Downloads/Emi_date_not_confirmed_Hindi_Unique/static/
# The source AUdo /Users/vinay_kl/Downloads/Emi_date_not_confirmed_Hindi_Unique/
# H130.wav does not exist so  utter_EMI_date_not_confirmed_predue_UMYB_WACR_F.wav not exported or created.
# final out path is:  /Users/vinay_kl/Downloads/output_d/static/
# H130 out path /Users/vinay_kl/Downloads/output_d/ utter_EMI_date_not_confirmed_predue_UMYB_WIOR_F
# source path  /Users/vinay_kl/Downloads/Emi_date_not_confirmed_Hindi_Unique/static/
# The source AUdo /Users/vinay_kl/Downloads/Emi_date_not_confirmed_Hindi_Unique/
# H130.wav does not exist so  utter_EMI_date_not_confirmed_predue_UMYB_WIOR_F.wav not exported or created.
# final out path is:  /Users/vinay_kl/Downloads/output_d/static/
# H130 out path /Users/vinay_kl/Downloads/output_d/ utter_EMI_date_not_confirmed_predue_UMYB_WAOE_F
# source path  /Users/vinay_kl/Downloads/Emi_date_not_confirmed_Hindi_Unique/static/
# The source AUdo /Users/vinay_kl/Downloads/Emi_date_not_confirmed_Hindi_Unique/
# H130.wav does not exist so  utter_EMI_date_not_confirmed_predue_UMYB_WAOE_F.wav not exported or created.
# final out path is:  /Users/vinay_kl/Downloads/output_d/static/
# H130 out path /Users/vinay_kl/Downloads/output_d/ utter_EMI_date_not_confirmed_predue_UMYB_WIOE_F
# source path  /Users/vinay_kl/Downloads/Emi_date_not_confirmed_Hindi_Unique/static/
# The source AUdo /Users/vinay_kl/Downloads/Emi_date_not_confirmed_Hindi_Unique/
# H130.wav does not exist so  utter_EMI_date_not_confirmed_predue_UMYB_WIOE_F.wav not exported or created.
# final out path is:  /Users/vinay_kl/Downloads/output_d/static/
# H133 out path /Users/vinay_kl/Downloads/output_d/ utter_EMI_date_not_confirmed_predue_UMYB_WACE_F
# source path  /Users/vinay_kl/Downloads/Emi_date_not_confirmed_Hindi_Unique/static/
# The source AUdo /Users/vinay_kl/Downloads/Emi_date_not_confirmed_Hindi_Unique/
# H133.wav does not exist so  utter_EMI_date_not_confirmed_predue_UMYB_WACE_F.wav not exported or created.
# final out path is:  /Users/vinay_kl/Downloads/output_d/static/
# H133 out path /Users/vinay_kl/Downloads/output_d/ utter_EMI_date_not_confirmed_predue_UMYB_DAOR_F
# source path  /Users/vinay_kl/Downloads/Emi_date_not_confirmed_Hindi_Unique/static/
# The source AUdo /Users/vinay_kl/Downloads/Emi_date_not_confirmed_Hindi_Unique/
# H133.wav does not exist so  utter_EMI_date_not_confirmed_predue_UMYB_DAOR_F.wav not exported or created.
# final out path is:  /Users/vinay_kl/Downloads/output_d/static/
# H133 out path /Users/vinay_kl/Downloads/output_d/ utter_EMI_date_not_confirmed_predue_UMYB_WICR_F
# source path  /Users/vinay_kl/Downloads/Emi_date_not_confirmed_Hindi_Unique/static/
# The source AUdo /Users/vinay_kl/Downloads/Emi_date_not_confirmed_Hindi_Unique/
# H133.wav does not exist so  utter_EMI_date_not_confirmed_predue_UMYB_WICR_F.wav not exported or created.
# final out path is:  /Users/vinay_kl/Downloads/output_d/static/
# H133 out path /Users/vinay_kl/Downloads/output_d/ utter_EMI_date_not_confirmed_predue_UMYB_WICE_F
# source path  /Users/vinay_kl/Downloads/Emi_date_not_confirmed_Hindi_Unique/static/
# The source AUdo /Users/vinay_kl/Downloads/Emi_date_not_confirmed_Hindi_Unique/
# H133.wav does not exist so  utter_EMI_date_not_confirmed_predue_UMYB_WICE_F.wav not exported or created.
# final out path is:  /Users/vinay_kl/Downloads/output_d/static/
# H133 out path /Users/vinay_kl/Downloads/output_d/ utter_EMI_date_not_confirmed_predue_UMYB_DAOE_F
# source path  /Users/vinay_kl/Downloads/Emi_date_not_confirmed_Hindi_Unique/static/
# The source AUdo /Users/vinay_kl/Downloads/Emi_date_not_confirmed_Hindi_Unique/
# H133.wav does not exist so  utter_EMI_date_not_confirmed_predue_UMYB_DAOE_F.wav not exported or created.
# final out path is:  /Users/vinay_kl/Downloads/output_d/static/
# H133 out path /Users/vinay_kl/Downloads/output_d/ utter_EMI_date_not_confirmed_predue_UMYB_DACR_F
# source path  /Users/vinay_kl/Downloads/Emi_date_not_confirmed_Hindi_Unique/static/
# The source AUdo /Users/vinay_kl/Downloads/Emi_date_not_confirmed_Hindi_Unique/
# H133.wav does not exist so  utter_EMI_date_not_confirmed_predue_UMYB_DACR_F.wav not exported or created.
# final out path is:  /Users/vinay_kl/Downloads/output_d/static/
# H136 out path /Users/vinay_kl/Downloads/output_d/ utter_EMI_date_not_confirmed_predue_UMYB_DIOR_F
# source path  /Users/vinay_kl/Downloads/Emi_date_not_confirmed_Hindi_Unique/static/
# The source AUdo /Users/vinay_kl/Downloads/Emi_date_not_confirmed_Hindi_Unique/
# H136.wav does not exist so  utter_EMI_date_not_confirmed_predue_UMYB_DIOR_F.wav not exported or created.
# final out path is:  /Users/vinay_kl/Downloads/output_d/static/
# H136 out path /Users/vinay_kl/Downloads/output_d/ utter_EMI_date_not_confirmed_predue_UMYB_DACE_F
# source path  /Users/vinay_kl/Downloads/Emi_date_not_confirmed_Hindi_Unique/static/
# The source AUdo /Users/vinay_kl/Downloads/Emi_date_not_confirmed_Hindi_Unique/
# H136.wav does not exist so  utter_EMI_date_not_confirmed_predue_UMYB_DACE_F.wav not exported or created.
# final out path is:  /Users/vinay_kl/Downloads/output_d/static/
# H136 out path /Users/vinay_kl/Downloads/output_d/ utter_EMI_date_not_confirmed_predue_UMYB_DIOE_F
# source path  /Users/vinay_kl/Downloads/Emi_date_not_confirmed_Hindi_Unique/static/
# The source AUdo /Users/vinay_kl/Downloads/Emi_date_not_confirmed_Hindi_Unique/
# H136.wav does not exist so  utter_EMI_date_not_confirmed_predue_UMYB_DIOE_F.wav not exported or created.
# final out path is:  /Users/vinay_kl/Downloads/output_d/static/
# H136 out path /Users/vinay_kl/Downloads/output_d/ utter_EMI_date_not_confirmed_predue_UMYB_DICR_F
# source path  /Users/vinay_kl/Downloads/Emi_date_not_confirmed_Hindi_Unique/static/
# The source AUdo /Users/vinay_kl/Downloads/Emi_date_not_confirmed_Hindi_Unique/
# H136.wav does not exist so  utter_EMI_date_not_confirmed_predue_UMYB_DICR_F.wav not exported or created.
# final out path is:  /Users/vinay_kl/Downloads/output_d/static/
# H136 out path /Users/vinay_kl/Downloads/output_d/ utter_EMI_date_not_confirmed_predue_UMYB_DICE_F
# source path  /Users/vinay_kl/Downloads/Emi_date_not_confirmed_Hindi_Unique/static/
# The source AUdo /Users/vinay_kl/Downloads/Emi_date_not_confirmed_Hindi_Unique/
# H136.wav does not exist so  utter_EMI_date_not_confirmed_predue_UMYB_DICE_F.wav not exported or created.
# final out path is:  /Users/vinay_kl/Downloads/output_d/static/
# H130 out path /Users/vinay_kl/Downloads/output_d/ utter_EMI_date_not_confirmed_predue_UMYW_WAOR_F
# source path  /Users/vinay_kl/Downloads/Emi_date_not_confirmed_Hindi_Unique/static/
# The source AUdo /Users/vinay_kl/Downloads/Emi_date_not_confirmed_Hindi_Unique/
# H130.wav does not exist so  utter_EMI_date_not_confirmed_predue_UMYW_WAOR_F.wav not exported or created.
# final out path is:  /Users/vinay_kl/Downloads/output_d/static/
# H130 out path /Users/vinay_kl/Downloads/output_d/ utter_EMI_date_not_confirmed_predue_UMYW_WACR_F
# source path  /Users/vinay_kl/Downloads/Emi_date_not_confirmed_Hindi_Unique/static/
# The source AUdo /Users/vinay_kl/Downloads/Emi_date_not_confirmed_Hindi_Unique/
# H130.wav does not exist so  utter_EMI_date_not_confirmed_predue_UMYW_WACR_F.wav not exported or created.
# final out path is:  /Users/vinay_kl/Downloads/output_d/static/
# H130 out path /Users/vinay_kl/Downloads/output_d/ utter_EMI_date_not_confirmed_predue_UMYW_WIOR_F
# source path  /Users/vinay_kl/Downloads/Emi_date_not_confirmed_Hindi_Unique/static/
# The source AUdo /Users/vinay_kl/Downloads/Emi_date_not_confirmed_Hindi_Unique/
# H130.wav does not exist so  utter_EMI_date_not_confirmed_predue_UMYW_WIOR_F.wav not exported or created.
# final out path is:  /Users/vinay_kl/Downloads/output_d/static/
# H130 out path /Users/vinay_kl/Downloads/output_d/ utter_EMI_date_not_confirmed_predue_UMYW_WAOE_F
# source path  /Users/vinay_kl/Downloads/Emi_date_not_confirmed_Hindi_Unique/static/
# The source AUdo /Users/vinay_kl/Downloads/Emi_date_not_confirmed_Hindi_Unique/
# H130.wav does not exist so  utter_EMI_date_not_confirmed_predue_UMYW_WAOE_F.wav not exported or created.
# final out path is:  /Users/vinay_kl/Downloads/output_d/static/
# H130 out path /Users/vinay_kl/Downloads/output_d/ utter_EMI_date_not_confirmed_predue_UMYW_WIOE_F
# source path  /Users/vinay_kl/Downloads/Emi_date_not_confirmed_Hindi_Unique/static/
# The source AUdo /Users/vinay_kl/Downloads/Emi_date_not_confirmed_Hindi_Unique/
# H130.wav does not exist so  utter_EMI_date_not_confirmed_predue_UMYW_WIOE_F.wav not exported or created.
# final out path is:  /Users/vinay_kl/Downloads/output_d/static/
# H133 out path /Users/vinay_kl/Downloads/output_d/ utter_EMI_date_not_confirmed_predue_UMYW_WACE_F
# source path  /Users/vinay_kl/Downloads/Emi_date_not_confirmed_Hindi_Unique/static/
# The source AUdo /Users/vinay_kl/Downloads/Emi_date_not_confirmed_Hindi_Unique/
#
F.wav not exported or created.
# final out path is:  /Users/vinay_kl/Downloads/output_d/static/
# H138 out path /Users/vinay_kl/Downloads/output_d/ utter_EMI_date_not_confirmed_predue_UMOW_DICE_F
# source path  /Users/vinay_kl/Downloads/Emi_date_not_confirmed_Hindi_Unique/static/
# The source AUdo /Users/vinay_kl/Downloads/Emi_date_not_confirmed_Hindi_Unique/
# H138.wav does not exist so  utter_EMI_date_not_confirmed_predue_UMOW_DICE_F.wav not exported or created.
# final out path is:  /Users/vinay_kl/Downloads/output_d/static/
# H42 out path /Users/vinay_kl/Downloads/output_d/ utter_EMI_date_not_confirmed_predue_UFYB_WAOR_M
# source path  /Users/vinay_kl/Downloads/Emi_date_not_confirmed_Hindi_Unique/static/
# The source AUdo /Users/vinay_kl/Downloads/Emi_date_not_confirmed_Hindi_Unique/
# H42.wav does not exist so  utter_EMI_date_not_confirmed_predue_UFYB_WAOR_M.wav not exported or created.
# final out path is:  /Users/vinay_kl/Downloads/output_d/static/
# H42 out path /Users/vinay_kl/Downloads/output_d/ utter_EMI_date_not_confirmed_predue_UFYB_WACR_M
# source path  /Users/vinay_kl/Downloads/Emi_date_not_confirmed_Hindi_Unique/static/
# The source AUdo /Users/vinay_kl/Downloads/Emi_date_not_confirmed_Hindi_Unique/
# H42.wav does not exist so  utter_EMI_date_not_confirmed_predue_UFYB_WACR_M.wav not exported or created.
# final out path is:  /Users/vinay_kl/Downloads/output_d/static/
# H42 out path /Users/vinay_kl/Downloads/output_d/ utter_EMI_date_not_confirmed_predue_UFYB_WIOR_M
# source path  /Users/vinay_kl/Downloads/Emi_date_not_confirmed_Hindi_Unique/static/
# The source AUdo /Users/vinay_kl/Downloads/Emi_date_not_confirmed_Hindi_Unique/
# H42.wav does not exist so  utter_EMI_date_not_confirmed_predue_UFYB_WIOR_M.wav not exported or created.
# final out path is:  /Users/vinay_kl/Downloads/output_d/static/
# H42 out path /Users/vinay_kl/Downloads/output_d/ utter_EMI_date_not_confirmed_predue_UFYB_WAOE_M
# source path  /Users/vinay_kl/Downloads/Emi_date_not_confirmed_Hindi_Unique/static/
# The source AUdo /Users/vinay_kl/Downloads/Emi_date_not_confirmed_Hindi_Unique/
# H42.wav does not exist so  utter_EMI_date_not_confirmed_predue_UFYB_WAOE_M.wav not exported or created.
# final out path is:  /Users/vinay_kl/Downloads/output_d/static/
# H42 out path /Users/vinay_kl/Downloads/output_d/ utter_EMI_date_not_confirmed_predue_UFYB_WIOE_M
# source path  /Users/vinay_kl/Downloads/Emi_date_not_confirmed_Hindi_Unique/static/
# The source AUdo /Users/vinay_kl/Downloads/Emi_date_not_confirmed_Hindi_Unique/
# H42.wav does not exist so  utter_EMI_date_not_confirmed_predue_UFYB_WIOE_M.wav not exported or created.
# final out path is:  /Users/vinay_kl/Downloads/output_d/static/
# H45 out path /Users/vinay_kl/Downloads/output_d/ utter_EMI_date_not_confirmed_predue_UFYB_WACE_M
# source path  /Users/vinay_kl/Downloads/Emi_date_not_confirmed_Hindi_Unique/static/
# The source AUdo /Users/vinay_kl/Downloads/Emi_date_not_confirmed_Hindi_Unique/
# H45.wav does not exist so  utter_EMI_date_not_confirmed_predue_UFYB_WACE_M.wav not exported or created.
# final out path is:  /Users/vinay_kl/Downloads/output_d/static/
# H45 out path /Users/vinay_kl/Downloads/output_d/ utter_EMI_date_not_confirmed_predue_UFYB_DAOR_M
# source path  /Users/vinay_kl/Downloads/Emi_date_not_confirmed_Hindi_Unique/static/
# The source AUdo /Users/vinay_kl/Downloads/Emi_date_not_confirmed_Hindi_Unique/
# H45.wav does not exist so  utter_EMI_date_not_confirmed_predue_UFYB_DAOR_M.wav not exported or created.
# final out path is:  /Users/vinay_kl/Downloads/output_d/static/
# H45 out path /Users/vinay_kl/Downloads/output_d/ utter_EMI_date_not_confirmed_predue_UFYB_WICR_M
# source path  /Users/vinay_kl/Downloads/Emi_date_not_confirmed_Hindi_Unique/static/
# The source AUdo /Users/vinay_kl/Downloads/Emi_date_not_confirmed_Hindi_Unique/
# H45.wav does not exist so  utter_EMI_date_not_confirmed_predue_UFYB_WICR_M.wav not exported or created.
# final out path is:  /Users/vinay_kl/Downloads/output_d/static/
# H45 out path /Users/vinay_kl/Downloads/output_d/ utter_EMI_date_not_confirmed_predue_UFYB_WICE_M
# source path  /Users/vinay_kl/Downloads/Emi_date_not_confirmed_Hindi_Unique/static/
# The source AUdo /Users/vinay_kl/Downloads/Emi_date_not_confirmed_Hindi_Unique/
# H45.wav does not exist so  utter_EMI_date_not_confirmed_predue_UFYB_WICE_M.wav not exported or created.
# final out path is:  /Users/vinay_kl/Downloads/output_d/static/
# H45 out path /Users/vinay_kl/Downloads/output_d/ utter_EMI_date_not_confirmed_predue_UFYB_DAOE_M
# source path  /Users/vinay_kl/Downloads/Emi_date_not_confirmed_Hindi_Unique/static/
# The source AUdo /Users/vinay_kl/Downloads/Emi_date_not_confirmed_Hindi_Unique/
# H45.wav does not exist so  utter_EMI_date_not_confirmed_predue_UFYB_DAOE_M.wav not exported or created.
# final out path is:  /Users/vinay_kl/Downloads/output_d/static/
# H45 out path /Users/vinay_kl/Downloads/output_d/ utter_EMI_date_not_confirmed_predue_UFYB_DACR_M
# source path  /Users/vinay_kl/Downloads/Emi_date_not_confirmed_Hindi_Unique/static/
# The source AUdo /Users/vinay_kl/Downloads/Emi_date_not_confirmed_Hindi_Unique/
# H45.wav does not exist so  utter_EMI_date_not_confirmed_predue_UFYB_DACR_M.wav not exported or created.
# final out path is:  /Users/vinay_kl/Downloads/output_d/static/
# H48 out path /Users/vinay_kl/Downloads/output_d/ utter_EMI_date_not_confirmed_predue_UFYB_DIOR_M
# source path  /Users/vinay_kl/Downloads/Emi_date_not_confirmed_Hindi_Unique/static/
# The source AUdo /Users/vinay_kl/Downloads/Emi_date_not_confirmed_Hindi_Unique/
# H48.wav does not exist so  utter_EMI_date_not_confirmed_predue_UFYB_DIOR_M.wav not exported or created.
# final out path is:  /Users/vinay_kl/Downloads/output_d/static/
# H48 out path /Users/vinay_kl/Downloads/output_d/ utter_EMI_date_not_confirmed_predue_UFYB_DACE_M
# source path  /Users/vinay_kl/Downloads/Emi_date_not_confirmed_Hindi_Unique/static/
# The source AUdo /Users/vinay_kl/Downloads/Emi_date_not_confirmed_Hindi_Unique/
# H48.wav does not exist so  utter_EMI_date_not_confirmed_predue_UFYB_DACE_M.wav not exported or created.
# final out path is:  /Users/vinay_kl/Downloads/output_d/static/
# H48 out path /Users/vinay_kl/Downloads/output_d/ utter_EMI_date_not_confirmed_predue_UFYB_DIOE_M
# source path  /Users/vinay_kl/Downloads/Emi_date_not_confirmed_Hindi_Unique/static/
# The source AUdo /Users/vinay_kl/Downloads/Emi_date_not_confirmed_Hindi_Unique/
# H48.wav does not exist so  utter_EMI_date_not_confirmed_predue_UFYB_DIOE_M.wav not exported or created.
# final out path is:  /Users/vinay_kl/Downloads/output_d/static/
# H48 out path /Users/vinay_kl/Downloads/output_d/ utter_EMI_date_not_confirmed_predue_UFYB_DICR_M
# source path  /Users/vinay_kl/Downloads/Emi_date_not_confirmed_Hindi_Unique/static/
# The source AUdo /Users/vinay_kl/Downloads/Emi_date_not_confirmed_Hindi_Unique/
# H48.wav does not exist so  utter_EMI_date_not_confirmed_predue_UFYB_DICR_M.wav not exported or created.
# final out path is:  /Users/vinay_kl/Downloads/output_d/static/
# H48 out path /Users/vinay_kl/Downloads/output_d/ utter_EMI_date_not_confirmed_predue_UFYB_DICE_M
# source path  /Users/vinay_kl/Downloads/Emi_date_not_confirmed_Hindi_Unique/static/
# The source AUdo /Users/vinay_kl/Downloads/Emi_date_not_confirmed_Hindi_Unique/
# H48.wav does not exist so  utter_EMI_date_not_confirmed_predue_UFYB_DICE_M.wav not exported or created.
# final out path is:  /Users/vinay_kl/Downloads/output_d/static/
# ...
# The source AUdo /Users/vinay_kl/Downloads/Emi_date_not_confirmed_Hindi_Unique/
# H46.wav does not exist so  utter_EMI_date_not_confirmed_predue_RFMW_DACR_M.wav not exported or created.
# final out path is:  /Users/vinay_kl/Downloads/output_d/static/
# H49 out path /Users/vinay_kl/Downloads/output_d/ utter_EMI_date_not_confirmed_predue_RFMW_DIOR_M
# source path  /Users/vinay_kl/Downloads/Emi_date_not_confirmed_Hindi_Unique/static/
# The source AUdo /Users/vinay_kl/Downloads/Emi_date_not_confirmed_Hindi_Unique/
# H49.wav does not exist so  utter_EMI_date_not_confirmed_predue_RFMW_DIOR_M.wav not exported or created.
# final out path is:  /Users/vinay_kl/Downloads/output_d/static/
# H49 out path /Users/vinay_kl/Downloads/output_d/ utter_EMI_date_not_confirmed_predue_RFMW_DACE_M
# source path  /Users/vinay_kl/Downloads/Emi_date_not_confirmed_Hindi_Unique/static/
# The source AUdo /Users/vinay_kl/Downloads/Emi_date_not_confirmed_Hindi_Unique/
# H49.wav does not exist so  utter_EMI_date_not_confirmed_predue_RFMW_DACE_M.wav not exported or created.
# final out path is:  /Users/vinay_kl/Downloads/output_d/static/
# H49 out path /Users/vinay_kl/Downloads/output_d/ utter_EMI_date_not_confirmed_predue_RFMW_DIOE_M
# source path  /Users/vinay_kl/Downloads/Emi_date_not_confirmed_Hindi_Unique/static/
# The source AUdo /Users/vinay_kl/Downloads/Emi_date_not_confirmed_Hindi_Unique/
# H49.wav does not exist so  utter_EMI_date_not_confirmed_predue_RFMW_DIOE_M.wav not exported or created.
# final out path is:  /Users/vinay_kl/Downloads/output_d/static/
# H49 out path /Users/vinay_kl/Downloads/output_d/ utter_EMI_date_not_confirmed_predue_RFMW_DICR_M
# source path  /Users/vinay_kl/Downloads/Emi_date_not_confirmed_Hindi_Unique/static/
# The source AUdo /Users/vinay_kl/Downloads/Emi_date_not_confirmed_Hindi_Unique/
# H49.wav does not exist so  utter_EMI_date_not_confirmed_predue_RFMW_DICR_M.wav not exported or created.
# final out path is:  /Users/vinay_kl/Downloads/output_d/static/
# H49 out path /Users/vinay_kl/Downloads/output_d/ utter_EMI_date_not_confirmed_predue_RFMW_DICE_M
# source path  /Users/vinay_kl/Downloads/Emi_date_not_confirmed_Hindi_Unique/static/
# The source AUdo /Users/vinay_kl/Downloads/Emi_date_not_confirmed_Hindi_Unique/
# H49.wav does not exist so  utter_EMI_date_not_confirmed_predue_RFMW_DICE_M.wav not exported or created.
# final out path is:  /Users/vinay_kl/Downloads/output_d/static/
# H44 out path /Users/vinay_kl/Downloads/output_d/ utter_EMI_date_not_confirmed_predue_RFOB_WAOR_M
# source path  /Users/vinay_kl/Downloads/Emi_date_not_confirmed_Hindi_Unique/static/
# The source AUdo /Users/vinay_kl/Downloads/Emi_date_not_confirmed_Hindi_Unique/
# H44.wav does not exist so  utter_EMI_date_not_confirmed_predue_RFOB_WAOR_M.wav not exported or created.
# final out path is:  /Users/vinay_kl/Downloads/output_d/static/
# H44 out path /Users/vinay_kl/Downloads/output_d/ utter_EMI_date_not_confirmed_predue_RFOB_WACR_M
# source path  /Users/vinay_kl/Downloads/Emi_date_not_confirmed_Hindi_Unique/static/
# The source AUdo /Users/vinay_kl/Downloads/Emi_date_not_confirmed_Hindi_Unique/
# H44.wav does not exist so  utter_EMI_date_not_confirmed_predue_RFOB_WACR_M.wav not exported or created.
# final out path is:  /Users/vinay_kl/Downloads/output_d/static/
# H44 out path /Users/vinay_kl/Downloads/output_d/ utter_EMI_date_not_confirmed_predue_RFOB_WIOR_M
# source path  /Users/vinay_kl/Downloads/Emi_date_not_confirmed_Hindi_Unique/static/
# The source AUdo /Users/vinay_kl/Downloads/Emi_date_not_confirmed_Hindi_Unique/
# H44.wav does not exist so  utter_EMI_date_not_confirmed_predue_RFOB_WIOR_M.wav not exported or created.
# final out path is:  /Users/vinay_kl/Downloads/output_d/static/
# H44 out path /Users/vinay_kl/Downloads/output_d/ utter_EMI_date_not_confirmed_predue_RFOB_WAOE_M
# source path  /Users/vinay_kl/Downloads/Emi_date_not_confirmed_Hindi_Unique/static/
# The source AUdo /Users/vinay_kl/Downloads/Emi_date_not_confirmed_Hindi_Unique/
# H44.wav does not exist so  utter_EMI_date_not_confirmed_predue_RFOB_WAOE_M.wav not exported or created.
# final out path is:  /Users/vinay_kl/Downloads/output_d/static/
# H44 out path /Users/vinay_kl/Downloads/output_d/ utter_EMI_date_not_confirmed_predue_RFOB_WIOE_M
# source path  /Users/vinay_kl/Downloads/Emi_date_not_confirmed_Hindi_Unique/static/
# The source AUdo /Users/vinay_kl/Downloads/Emi_date_not_confirmed_Hindi_Unique/
# H44.wav does not exist so  utter_EMI_date_not_confirmed_predue_RFOB_WIOE_M.wav not exported or created.
# final out path is:  /Users/vinay_kl/Downloads/output_d/static/
# H47 out path /Users/vinay_kl/Downloads/output_d/ utter_EMI_date_not_confirmed_predue_RFOB_WACE_M
# source path  /Users/vinay_kl/Downloads/Emi_date_not_confirmed_Hindi_Unique/static/
# The source AUdo /Users/vinay_kl/Downloads/Emi_date_not_confirmed_Hindi_Unique/
# H47.wav does not exist so  utter_EMI_date_not_confirmed_predue_RFOB_WACE_M.wav not exported or created.
# final out path is:  /Users/vinay_kl/Downloads/output_d/static/
# H47 out path /Users/vinay_kl/Downloads/output_d/ utter_EMI_date_not_confirmed_predue_RFOB_DAOR_M
# source path  /Users/vinay_kl/Downloads/Emi_date_not_confirmed_Hindi_Unique/static/
# The source AUdo /Users/vinay_kl/Downloads/Emi_date_not_confirmed_Hindi_Unique/
# H47.wav does not exist so  utter_EMI_date_not_confirmed_predue_RFOB_DAOR_M.wav not exported or created.
# final out path is:  /Users/vinay_kl/Downloads/output_d/static/
# H47 out path /Users/vinay_kl/Downloads/output_d/ utter_EMI_date_not_confirmed_predue_RFOB_WICR_M
# source path  /Users/vinay_kl/Downloads/Emi_date_not_confirmed_Hindi_Unique/static/
# The source AUdo /Users/vinay_kl/Downloads/Emi_date_not_confirmed_Hindi_Unique/
# H47.wav does not exist so  utter_EMI_date_not_confirmed_predue_RFOB_WICR_M.wav not exported or created.
# final out path is:  /Users/vinay_kl/Downloads/output_d/static/
# H47 out path /Users/vinay_kl/Downloads/output_d/ utter_EMI_date_not_confirmed_predue_RFOB_WICE_M
# source path  /Users/vinay_kl/Downloads/Emi_date_not_confirmed_Hindi_Unique/static/
# The source AUdo /Users/vinay_kl/Downloads/Emi_date_not_confirmed_Hindi_Unique/
# H47.wav does not exist so  utter_EMI_date_not_confirmed_predue_RFOB_WICE_M.wav not exported or created.
# final out path is:  /Users/vinay_kl/Downloads/output_d/static/
# H47 out path /Users/vinay_kl/Downloads/output_d/ utter_EMI_date_not_confirmed_predue_RFOB_DAOE_M
# source path  /Users/vinay_kl/Downloads/Emi_date_not_confirmed_Hindi_Unique/static/
# The source AUdo /Users/vinay_kl/Downloads/Emi_date_not_confirmed_Hindi_Unique/
# H47.wav does not exist so  utter_EMI_date_not_confirmed_predue_RFOB_DAOE_M.wav not exported or created.
# final out path is:  /Users/vinay_kl/Downloads/output_d/static/
# H47 out path /Users/vinay_kl/Downloads/output_d/ utter_EMI_date_not_confirmed_predue_RFOB_DACR_M
# source path  /Users/vinay_kl/Downloads/Emi_date_not_confirmed_Hindi_Unique/static/
# The source AUdo /Users/vinay_kl/Downloads/Emi_date_not_confirmed_Hindi_Unique/
# H47.wav does not exist so  utter_EMI_date_not_confirmed_predue_RFOB_DACR_M.wav not exported or created.
# final out path is:  /Users/vinay_kl/Downloads/output_d/static/
# H50 out path /Users/vinay_kl/Downloads/output_d/ utter_EMI_date_not_confirmed_predue_RFOB_DIOR_M
# source path  /Users/vinay_kl/Downloads/Emi_date_not_confirmed_Hindi_Unique/static/
# The source AUdo /Users/vinay_kl/Downloads/Emi_date_not_confirmed_Hindi_Unique/
# H50.wav does not exist so  utter_EMI_date_not_confirmed_predue_RFOB_DIOR_M.wav not exported or created.
# final out path is:  /Users/vinay_kl/Downloads/output_d/static/
# H50 out path /Users/vinay_kl/Downloads/output_d/ utter_EMI_date_not_confirmed_predue_RFOB_DACE_M
# source path  /Users/vinay_kl/Downloads/Emi_date_not_confirmed_Hindi_Unique/static/
# The source AUdo /Users/vinay_kl/Downloads/Emi_date_not_confirmed_Hindi_Unique/
# H50.wav does not exist so  utter_EMI_date_not_confirmed_predue_RFOB_DACE_M.wav not exported or created.
# final out path is:  /Users/vinay_kl/Downloads/output_d/static/
# H50 out path /Users/vinay_kl/Downloads/output_d/ utter_EMI_date_not_confirmed_predue_RFOB_DIOE_M
# source path  /Users/vinay_kl/Downloads/Emi_date_not_confirmed_Hindi_Unique/static/
# The source AUdo /Users/vinay_kl/Downloads/Emi_date_not_confirmed_Hindi_Unique/
# H50.wav does not exist so  utter_EMI_date_not_confirmed_predue_RFOB_DIOE_M.wav not exported or created.
# final out path is:  /Users/vinay_kl/Downloads/output_d/static/
# H50 out path /Users/vinay_kl/Downloads/output_d/ utter_EMI_date_not_confirmed_predue_RFOB_DICR_M
# source path  /Users/vinay_kl/Downloads/Emi_date_not_confirmed_Hindi_Unique/static/
# The source AUdo /Users/vinay_kl/Downloads/Emi_date_not_confirmed_Hindi_Unique/
# H50.wav does not exist so  utter_EMI_date_not_confirmed_predue_RFOB_DICR_M.wav not exported or created.
# final out path is:  /Users/vinay_kl/Downloads/output_d/static/
# H50 out path /Users/vinay_kl/Downloads/output_d/ utter_EMI_date_not_confirmed_predue_RFOB_DICE_M
# source path  /Users/vinay_kl/Downloads/Emi_date_not_confirmed_Hindi_Unique/static/
# The source AUdo /Users/vinay_kl/Downloads/Emi_date_not_confirmed_Hindi_Unique/
# H50.wav does not exist so  utter_EMI_date_not_confirmed_predue_RFOB_DICE_M.wav not exported or created.
# final out path is:  /Users/vinay_kl/Downloads/output_d/static/
# H44 out path /Users/vinay_kl/Downloads/output_d/ utter_EMI_date_not_confirmed_predue_RFOW_WAOR_M
# source path  /Users/vinay_kl/Downloads/Emi_date_not_confirmed_Hindi_Unique/static/
# The source AUdo /Users/vinay_kl/Downloads/Emi_date_not_confirmed_Hindi_Unique/
# H44.wav does not exist so  utter_EMI_date_not_confirmed_predue_RFOW_WAOR_M.wav not exported or created.
# final out path is:  /Users/vinay_kl/Downloads/output_d/static/
# H44 out path /Users/vinay_kl/Downloads/output_d/ utter_EMI_date_not_confirmed_predue_RFOW_WACR_M
# source path  /Users/vinay_kl/Downloads/Emi_date_not_confirmed_Hindi_Unique/static/
# The source AUdo /Users/vinay_kl/Downloads/Emi_date_not_confirmed_Hindi_Unique/
# H44.wav does not exist so  utter_EMI_date_not_confirmed_predue_RFOW_WACR_M.wav not exported or created.
# final out path is:  /Users/vinay_kl/Downloads/output_d/static/
# H44 out path /Users/vinay_kl/Downloads/output_d/ utter_EMI_date_not_confirmed_predue_RFOW_WIOR_M
# source path  /Users/vinay_kl/Downloads/Emi_date_not_confirmed_Hindi_Unique/static/
# The source AUdo /Users/vinay_kl/Downloads/Emi_date_not_confirmed_Hindi_Unique/
# H44.wav does not exist so  utter_EMI_date_not_confirmed_predue_RFOW_WIOR_M.wav not exported or created.
# final out path is:  /Users/vinay_kl/Downloads/output_d/static/
# H44 out path /Users/vinay_kl/Downloads/output_d/ utter_EMI_date_not_confirmed_predue_RFOW_WAOE_M
# source path  /Users/vinay_kl/Downloads/Emi_date_not_confirmed_Hindi_Unique/static/
# The source AUdo /Users/vinay_kl/Downloads/Emi_date_not_confirmed_Hindi_Unique/
# H44.wav does not exist so  utter_EMI_date_not_confirmed_predue_RFOW_WAOE_M.wav not exported or created.
# final out path is:  /Users/vinay_kl/Downloads/output_d/static/
# H44 out path /Users/vinay_kl/Downloads/output_d/ utter_EMI_date_not_confirmed_predue_RFOW_WIOE_M
# source path  /Users/vinay_kl/Downloads/Emi_date_not_confirmed_Hindi_Unique/static/
# The source AUdo /Users/vinay_kl/Downloads/Emi_date_not_confirmed_Hindi_Unique/
# H44.wav does not exist so  utter_EMI_date_not_confirmed_predue_RFOW_WIOE_M.wav not exported or created.
# final out path is:  /Users/vinay_kl/Downloads/output_d/static/
# H47 out path /Users/vinay_kl/Downloads/output_d/ utter_EMI_date_not_confirmed_predue_RFOW_WACE_M
# source path  /Users/vinay_kl/Downloads/Emi_date_not_confirmed_Hindi_Unique/static/
# The source AUdo /Users/vinay_kl/Downloads/Emi_date_not_confirmed_Hindi_Unique/
# H47.wav does not exist so  utter_EMI_date_not_confirmed_predue_RFOW_WACE_M.wav not exported or created.
# final out path is:  /Users/vinay_kl/Downloads/output_d/static/
# H47 out path /Users/vinay_kl/Downloads/output_d/ utter_EMI_date_not_confirmed_predue_RFOW_DAOR_M
# source path  /Users/vinay_kl/Downloads/Emi_date_not_confirmed_Hindi_Unique/static/
# The source AUdo /Users/vinay_kl/Downloads/Emi_date_not_confirmed_Hindi_Unique/
# H47.wav does not exist so  utter_EMI_date_not_confirmed_predue_RFOW_DAOR_M.wav not exported or created.
# final out path is:  /Users/vinay_kl/Downloads/output_d/static/
# H47 out path /Users/vinay_kl/Downloads/output_d/ utter_EMI_date_not_confirmed_predue_RFOW_WICR_M
# source path  /Users/vinay_kl/Downloads/Emi_date_not_confirmed_Hindi_Unique/static/
# The source AUdo /Users/vinay_kl/Downloads/Emi_date_not_confirmed_Hindi_Unique/
# H47.wav does not exist so  utter_EMI_date_not_confirmed_predue_RFOW_WICR_M.wav not exported or created.
# final out path is:  /Users/vinay_kl/Downloads/output_d/static/
# H47 out path /Users/vinay_kl/Downloads/output_d/ utter_EMI_date_not_confirmed_predue_RFOW_WICE_M
# source path  /Users/vinay_kl/Downloads/Emi_date_not_confirmed_Hindi_Unique/static/
# The source AUdo /Users/vinay_kl/Downloads/Emi_date_not_confirmed_Hindi_Unique/
# H47.wav does not exist so  utter_EMI_date_not_confirmed_predue_RFOW_WICE_M.wav not exported or created.
# final out path is:  /Users/vinay_kl/Downloads/output_d/static/
# H47 out path /Users/vinay_kl/Downloads/output_d/ utter_EMI_date_not_confirmed_predue_RFOW_DAOE_M
# source path  /Users/vinay_kl/Downloads/Emi_date_not_confirmed_Hindi_Unique/static/
# The source AUdo /Users/vinay_kl/Downloads/Emi_date_not_confirmed_Hindi_Unique/
# H47.wav does not exist so  utter_EMI_date_not_confirmed_predue_RFOW_DAOE_M.wav not exported or created.
# final out path is:  /Users/vinay_kl/Downloads/output_d/static/
# H47 out path /Users/vinay_kl/Downloads/output_d/ utter_EMI_date_not_confirmed_predue_RFOW_DACR_M
# source path  /Users/vinay_kl/Downloads/Emi_date_not_confirmed_Hindi_Unique/static/
# The source AUdo /Users/vinay_kl/Downloads/Emi_date_not_confirmed_Hindi_Unique/
# H47.wav does not exist so  utter_EMI_date_not_confirmed_predue_RFOW_DACR_M.wav not exported or created.
# final out path is:  /Users/vinay_kl/Downloads/output_d/static/
# H50 out path /Users/vinay_kl/Downloads/output_d/ utter_EMI_date_not_confirmed_predue_RFOW_DIOR_M
# source path  /Users/vinay_kl/Downloads/Emi_date_not_confirmed_Hindi_Unique/static/
# The source AUdo /Users/vinay_kl/Downloads/Emi_date_not_confirmed_Hindi_Unique/
# H50.wav does not exist so  utter_EMI_date_not_confirmed_predue_RFOW_DIOR_M.wav not exported or created.
# final out path is:  /Users/vinay_kl/Downloads/output_d/static/
# H50 out path /Users/vinay_kl/Downloads/output_d/ utter_EMI_date_not_confirmed_predue_RFOW_DACE_M
# source path  /Users/vinay_kl/Downloads/Emi_date_not_confirmed_Hindi_Unique/static/
# The source AUdo /Users/vinay_kl/Downloads/Emi_date_not_confirmed_Hindi_Unique/
# H50.wav does not exist so  utter_EMI_date_not_confirmed_predue_RFOW_DACE_M.wav not exported or created.
# final out path is:  /Users/vinay_kl/Downloads/output_d/static/
# H50 out path /Users/vinay_kl/Downloads/output_d/ utter_EMI_date_not_confirmed_predue_RFOW_DIOE_M
# source path  /Users/vinay_kl/Downloads/Emi_date_not_confirmed_Hindi_Unique/static/
# The source AUdo /Users/vinay_kl/Downloads/Emi_date_not_confirmed_Hindi_Unique/
# H50.wav does not exist so  utter_EMI_date_not_confirmed_predue_RFOW_DIOE_M.wav not exported or created.
# final out path is:  /Users/vinay_kl/Downloads/output_d/static/
# H50 out path /Users/vinay_kl/Downloads/output_d/ utter_EMI_date_not_confirmed_predue_RFOW_DICR_M
# source path  /Users/vinay_kl/Downloads/Emi_date_not_confirmed_Hindi_Unique/static/
# The source AUdo /Users/vinay_kl/Downloads/Emi_date_not_confirmed_Hindi_Unique/
# H50.wav does not exist so  utter_EMI_date_not_confirmed_predue_RFOW_DICR_M.wav not exported or created.
# final out path is:  /Users/vinay_kl/Downloads/output_d/static/
# H50 out path /Users/vinay_kl/Downloads/output_d/ utter_EMI_date_not_confirmed_predue_RFOW_DICE_M
# source path  /Users/vinay_kl/Downloads/Emi_date_not_confirmed_Hindi_Unique/static/
# The source AUdo /Users/vinay_kl/Downloads/Emi_date_not_confirmed_Hindi_Unique/
# H50.wav does not exist so  utter_EMI_date_not_confirmed_predue_RFOW_DICE_M.wav not exported or created.
# total responses count  384
