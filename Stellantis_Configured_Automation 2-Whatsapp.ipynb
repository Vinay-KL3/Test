# %%
#import the required dependencies

import requests
import json
import pandas as pd
from pprint import pprint
import csv
import time
import random
import datetime
import re

print("all required dependencies are imported successfully")
# Out:
# all required dependencies are imported successfully

# %%
#update the testset and final sheet's path. then run the block


language = "English"

dataCSV = "/Users/vinay_kl/Downloads/LOC.csv"

#stellantis
botEndPoint = "https://stage-threebot.saarthi.ai/stellantisw_english/webhook"
#PoliticalEdge
# botEndPoint = "https://stage-threebot.saarthi.ai/politics_marathi/webhook"

v = datetime.datetime.now()
#print(v)

#pattern = '\d{4}-\d{2}-\d{2} (\d{2}:\d{2}:\d{2})\.\d{6}'
pattern = "[\d]+-[\d]+-[\d]+ ([\d]+:[\d]+:[\d]+)\.[\d]+"

required = re.findall(pattern,str(v))
#print(required)


#---------------------------------------------------------------------------------------#


Final_Sheet = "/Users/vinay_kl/Downloads/Final_Sheet_Stellantis_"+str(language)+"_"+str(required)+".csv"

print(Final_Sheet)

print("testset and final_sheet is pushed to respective variables")
# Out:
# /Users/vinay_kl/Downloads/Final_Sheet_Stellantis_English_['12:04:08'].csv
# testset and final_sheet is pushed to respective variables

# %%
#functions



def BOT_FUNCTION(Final_T_NO = None,Final_Utterance = None,Flow = None,GRT = None,BRT = None,Language = None):
    headers = {'Content-Type':'application/json'}    
    payload = json.dumps ({
    "user_id": "9482152445",
    "request_id": "request11127",
    "sender": "te3selkul"+str(Final_T_NO)+str(num),
    "message": Final_Utterance,

    "customerData": {
         "customerInfo": {
                    "others": {},
                    "primaryInfo": {
                        "age": "",
                        "gender": "",
                        "geographicLocation": "Bangalore",
                        "region": "",
                        "collared": "",
                        "flow": "appointment_booking_flow",
                        "language": "English",
                        "firstName": "Manikandan",
                        "clientName": "",
                        "agentName": "Stella",
                        "customerUniqueId": "",
                        "vehicleIdentificationNumber": "KA52MC1507",
                        "sellingDealerName": "MJ Motors - Coimbatore",
                        "pincode": "637102",
                        "lastServiceDealerCity": "Coimbatore",
                        "lastServiceDealerName": "MJ Motors - Coimbatore",
                        "preferredAgentGender": "F",
                        "serviceNetworkName": "Jeep Aftersales Network",
                        "channel": "Voice",
                        "generalRepeatThreshold": "2",
                        "businessIntentThreshold": "2",
                        "previousDisposition": "Bot Call Back",
                        "status": "",
                        "utter_sub_flow_slot": "",
                        "serviceDueDate": "2023-07-23",
                        "captured_date": ""
                    },
                    "contactInfo": {
                        "primary": "7989476228",
                        "customerSupportNumber": "18002665337"
                    },
                    "loanAccountDetails": {
                        "emiAmount": "",
                        "emiDueDate": "",
                        "loanId": "",
                        "noOfLoans": "",
                        "totalLoanAmount": "",
                        "interestRate": "",
                        "principalAmount": "",
                        "lateFee": "",
                        "loanApplicationDate": "",
                        "loanEndingDate": "",
                        "loanAmountRemaining": "",
                        "loanTenureLeft": "",
                        "noofemi": "",
                        "noOfLoanTaken": "",
                        "noOfEmiPaid": ""
                    },
                    "behaviourDetails": {
                        "typology": "",
                        "riskType": "",
                        "callDisposition": ""
                    },
                    "address": {
                        "dealerAddressList": [
                            {
                                "dealerName": "Kalyan Automart Private Limited - Agra",
                                "msgFormatDealer": "Kalyan Automart - Agra",
                                "dealerCode": "0700024-3S",
                                "remarks": "Operational",
                                "address": "Near Mango Hotel, Opp Bhagwati Dhaba Sikandra, Bye Pass Road, Agra - 282007.",
                                "lat": 27.22088533,
                                "long": 77.93028885,
                                "name": "Agra",
                                "state": "Uttar Pradesh",
                                "pincode": 282007,
                                "contactNumber": 9837040814
                            },
                            {
                                "dealerName": "Landmark Lifestyle Cars Pvt Ltd(South Delhi)- Okhla - New Delhi",
                                "msgFormatDealer": "Landmark Lifestyle Okhla - New Delhi",
                                "dealerCode": "0700004-2S",
                                "remarks": "Operational",
                                "address": "B-238, Phase-1, Okhla, New Delhi-110020.",
                                "lat": 28.55448,
                                "long": 77.267662,
                                "name": "South Delhi",
                                "state": "NCR",
                                "pincode": 110020,
                                "contactNumber": 9711191575
                            },
                            {
                                "dealerName": "Landmark Lifestyle Cars Pvt Ltd - Gurugram",
                                "msgFormatDealer": "Landmark Lifestyle  - Gurugram",
                                "dealerCode": "0700016-2S",
                                "remarks": "Operational",
                                "address": "Plot No-10, Sector 34, Gurugram.",
                                "lat": 28.432393,
                                "long": 77.0108403,
                                "name": "Gurugram",
                                "state": "NCR",
                                "pincode": "",
                                "contactNumber": 9999384277
                            }
                        ],
                        "cityCapture": "Agra"
                    },
                    "email": {
                        "primary": ""
                    }
                },
                "agentConfig": {
                    "parentFlow": [
                        {
                            "flow": "main_flow",
                            "isParent": True,
                            "isChild": False,
                            "channel": [
                                "Whatsapp"
                            ],
                            "type": "Female",
                            "language": [
                                "English"
                            ],
                            "Whatsapp": {
                                "slotReminder": [
                                    {
                                        "slot0": 120,
                                        "slot1": 300
                                    }
                                ]
                            }
                        },
                        {
                            "flow": "follow_up",
                            "isParent": True,
                            "isChild": False,
                            "channel": [
                                "Whatsapp"
                            ],
                            "type": "Female",
                            "language": [
                                "English"
                            ],
                            "Whatsapp": {
                                "slotReminder": [
                                    {
                                        "slot0": 120,
                                        "slot1": 300
                                    }
                                ]
                            }
                        },
                        {
                            "flow": "reminder_flow",
                            "isParent": True,
                            "isChild": False,
                            "channel": [
                                "Whatsapp"
                            ],
                            "type": "Female",
                            "language": [
                                "English"
                            ],
                            "Whatsapp": {
                                "slotReminder": [
                                    {
                                        "slot0": 120,
                                        "slot1": 300
                                    }
                                ]
                            }
                        },
                        {
                            "flow": "feedback_flow",
                            "isParent": True,
                            "isChild": False,
                            "channel": [
                                "Whatsapp"
                            ],
                            "type": "Female",
                            "language": [
                                "English"
                            ],
                            "Whatsapp": {
                                "slotReminder": [
                                    {
                                        "slot0": 120,
                                        "slot1": 300
                                    }
                                ]
                            }
                        },
                        {
                            "flow": "location_flow",
                            "isParent": True,
                            "isChild": False,
                            "channel": [
                                "Whatsapp"
                            ],
                            "type": "Female",
                            "language": [
                                "English"
                            ],
                            "Whatsapp": {
                                "slotReminder": [
                                    {
                                        "slot0": 120,
                                        "slot1": 300
                                    }
                                ]
                            }
                        }
                    ],
                    "callFlow": {
                        "main_flow": {
                            "initial_message": {
                                "initial_message": "lg_rpc_form"
                            },
                            "lg_rpc_form": {
                                "deny": "date_capture_form",
                                "dealership_capture": "dealership_capture_form",
                                "not_interested": "not_interested_form"
                            },
                            "date_capture_form": {
                                "dealership_capture": "dealership_capture_form",
                                "not_interested": "not_interested_form"
                            },
                            "dealership_capture_form": {
                                "deny_dealership": "deny_dealership_flow_form",
                                "pickup_drop_capture": "pickup_drop_capture_form",
                                "not_interested": "not_interested_form"
                            },
                            "deny_dealership_flow_form": {
                                "pickup_drop_capture": "pickup_drop_capture_form",
                                "not_interested": "not_interested_form"
                            },
                            "pickup_drop_capture_form": {
                                "not_interested": "not_interested_form",
                                "deny": "stop_conversation_form"
                            },
                            "not_interested_form": {
                                "deny": "stop_conversation_form"
                            }
                        },
                        "follow_up": {
                            "spm_followup_form": {
                                "deny_dealership": "deny_dealership_flow_form",
                                "pickup_drop_capture": "pickup_drop_capture_form"
                            },
                            "deny_dealership_flow_form": {
                                "pickup_drop_capture": "pickup_drop_capture_form"
                            },
                            "pickup_drop_capture_form": {
                                "deny": "stop_conversation_form"
                            }
                        },
                        "reminder_flow": {
                            "spm_reminder_form": {
                                "deny": "date_capture_form"
                            },
                            "date_capture_form": {
                                "deny": "stop_conversation_form"
                            }
                        },
                        "feedback_flow": {
                            "spm_feedback_form": {
                                "deny": "stop_conversation_form"
                            }
                        },
                        "location_flow": {
                            "location_form": {
                                "pickup_drop_capture": "pickup_drop_capture_form"
                            },
                            "pickup_drop_capture_form": {
                                "deny": "stop_conversation_form"
                            }
                        }
                    },
                    "whatsappFlow": [],
                    "accountId": "6450b926f3dfec320214812e",
                    "agentName": "Stella",
                    "domain": "Automobile",
                    "subDomain": "General",
                    "productType": "Four Wheeler",
                    "agentId": "StellantisTesting_salesOnboarding_FourWheeler_12",
                    "createdAt": "2023-06-08T17:25:08.410Z",
                    "updatedAt": "2023-06-08T17:25:08.410Z",
                    "id": "64820ef4a496607073a7c3a1"
                }
        }
        }
       )
#     response = requests.request("POST", botEndPoint, headers=headers, data=payload).json()
    response = requests.request("POST", botEndPoint, headers=headers, data=payload).json()

#     return(response)
    
    

# def final_data(response):
    text_list = []
    response_1 = ["-"]
    response_2 = ["-"]
    response_3 = ["-"]
    disposotion_list = []
    staus_list = []

    temp_status = response["custom"]["status"]
    temp_disp = response["custom"]["disposition_id"]
    temp_disp = ",".join(map(str, temp_disp))     #its like a text combining method with given delimeter.  map & str is added to reduce "sequence no N" error

    val = response["data"]
    for i in range(0,len(val)):    
          temp_text = response["data"][i]["text"]
          text_list.append(temp_text)

    for i in range(0,len(text_list)):
        if i == 0:
            response_1 = [text_list[i]]
        if i == 1:
            response_2 = [text_list[i]]
        if i == 2:
            response_3 = [text_list[i]]

    print(Final_T_NO, "\t", Final_Utterance, "\t", response_1, "\t", response_2, "\t", response_3, "\t", [temp_disp], "\t", [temp_status])        
    return Final_T_NO, Final_Utterance, response_1, response_2, response_3, [temp_disp], [temp_status]






print("all required functions are successfully called")
# Out:
# all required functions are successfully called

# %%
final_Tno = []
final_user_resp = []

final_response_1 = []
final_response_2 = []
final_response_3 = []
final_disposition = []
final_status = []

print("Empty lists created, --- Run next block")
# Out:
# Empty lists created, --- Run next block

# %%
num = random.random()

df = pd.read_csv(dataCSV)
df.head()


TestCase_No = df["T_N_O"]
Utterance_Coloum = df["Final_List"]
# flow = df["Flow"]
# grt = df["General_Intent_Threshold"]
# brt = df["Business_Intent_Threshold"]
# lang = df["Language"]

# for i in range(0,3132):
for i in range(0, len(Utterance_Coloum)):
    
    
    MID_T_NO = TestCase_No[i]
#     Flow = flow[i]
#     GRT = grt[i]
#     BRT = brt[i]
#     Language = lang[i]
    
#     print(MID_T_NO, Flow, GRT, BRT, Language)
    
    Utterance_List = eval(Utterance_Coloum[i])
    for j in range(0,len(Utterance_List)):
        Final_Utterance = Utterance_List[j]
        Final_T_NO = MID_T_NO
#         print(Final_T_NO)
#         print(Final_Utterance)
        
                
        try:

#             response = BOT_FUNCTION(Final_T_NO,Final_Utterance)
#             print("TestCaseNo - ", Final_T_NO," Passed")
            Final_T_NO, Final_Utterance, response_1, response_2, response_3, disposition, status = BOT_FUNCTION(Final_T_NO,Final_Utterance)
            final_Tno.append(Final_T_NO)
            final_user_resp.append(Final_Utterance)        
            final_response_1.extend(response_1)
            final_response_2.extend(response_2)
            final_response_3.extend(response_3)            
            final_disposition.extend(disposition)
            final_status.extend(status)
            
#             time.sleep(1)

        except Exception as e:
#             print("TestCaseNo - ",Final_T_NO," failed ---> ",e)
            print(Final_T_NO, "\t", Final_Utterance, "\t", e, "\t", "error", "\t", "error", "\t", "error", "\t", "error")
    
            final_Tno.append(Final_T_NO)
            final_user_resp.append(Final_Utterance) 
            final_response_1.append(e)
            final_response_2.append("error")
            final_response_3.append("error")        
            final_disposition.append("error")
            final_status.append("error")
            
            
            
print("Testcases completed, --- Run next block")
# Out:
# 1 	 /initial_message 	 ["👋 Hi, Manikandan!\n \nI'm stella from Jeep Coimbatore Your vehicle number  is due for service on 23 July 2023\n \nWould you like to book an appointment on the same day?"] 	 ['-'] 	 ['-'] 	 ['initial_message'] 	 [702]
# 1 	 yes, i would 	 ['Perfect, Would you like to get your service done from MJ Motors - Coimbatore?'] 	 ['-'] 	 ['-'] 	 ['Service Due Date Accepted,Dealership Pitched'] 	 [702]
# 1 	 No, i wouldnt 	 ['Okay, could you tell us in which city you would prefer to get your vehicle serviced?'] 	 ['-'] 	 ['-'] 	 ['Not Intrested,Available City Options Shared'] 	 [702]
# 1 	 Agra 	 ['These are the dealerships closest to you. Please choose your preferred option.\n \n1. \n2. \n3. '] 	 ['-'] 	 ['-'] 	 ['Selected City Captured,Available Dealership Options Shared'] 	 [702]
# 2 	 /initial_message 	 ["👋 Hi, Manikandan!\n \nI'm stella from Jeep Coimbatore Your vehicle number  is due for service on 23 July 2023\n \nWould you like to book an appointment on the same day?"] 	 ['-'] 	 ['-'] 	 ['initial_message'] 	 [702]
# 2 	 yes, i would 	 ['Perfect, Would you like to get your service done from MJ Motors - Coimbatore?'] 	 ['-'] 	 ['-'] 	 ['Service Due Date Accepted,Dealership Pitched'] 	 [702]
# 2 	 No, i wouldnt 	 ['Okay, could you tell us in which city you would prefer to get your vehicle serviced?'] 	 ['-'] 	 ['-'] 	 ['Not Intrested,Available City Options Shared'] 	 [702]
# 2 	 Ahmedabad 	 ['These are the dealerships closest to you. Please choose your preferred option.\n \n1. \n2. \n3. '] 	 ['-'] 	 ['-'] 	 ['Selected City Captured,Available Dealership Options Shared'] 	 [702]
# 3 	 /initial_message 	 ["👋 Hi, Manikandan!\n \nI'm stella from Jeep Coimbatore Your vehicle number  is due for service on 23 July 2023\n \nWould you like to book an appointment on the same day?"] 	 ['-'] 	 ['-'] 	 ['initial_message'] 	 [702]
# 3 	 yes, i would 	 ['Perfect, Would you like to get your service done from MJ Motors - Coimbatore?'] 	 ['-'] 	 ['-'] 	 ['Service Due Date Accepted,Dealership Pitched'] 	 [702]
# 3 	 No, i wouldnt 	 ['Okay, could you tell us in which city you would prefer to get your vehicle serviced?'] 	 ['-'] 	 ['-'] 	 ['Not Intrested,Available City Options Shared'] 	 [702]
# 3 	 Bangalore 	 ['These are the dealerships closest to you. Please choose your preferred option.\n \n1. KHTAgencies Yeshwantpur - Bangalore\n2. KHT Agencies Devasandra - Bangalore\n3. MPS Motors Hosur Road - Bangalore'] 	 ['-'] 	 ['-'] 	 ['Selected City Captured,Available Dealership Options Shared'] 	 [702]
# 4 	 /initial_message 	 ["👋 Hi, Manikandan!\n \nI'm stella from Jeep Coimbatore Your vehicle number  is due for service on 23 July 2023\n \nWould you like to book an appointment on the same day?"] 	 ['-'] 	 ['-'] 	 ['initial_message'] 	 [702]
# 4 	 yes, i would 	 ['Perfect, Would you like to get your service done from MJ Motors - Coimbatore?'] 	 ['-'] 	 ['-'] 	 ['Service Due Date Accepted,Dealership Pitched'] 	 [702]
# 4 	 No, i wouldnt 	 ['Okay, could you tell us in which city you would prefer to get your vehicle serviced?'] 	 ['-'] 	 ['-'] 	 ['Not Intrested,Available City Options Shared'] 	 [702]
# 4 	 Bhopal 	 ['These are the dealerships closest to you. Please choose your preferred option.\n \n1. Success Hoshangabad Road - Bhopal\n2. Satguru Engitech Lasudia - Indore\n3. Mundra Automobiles - Kota'] 	 ['-'] 	 ['-'] 	 ['Selected City Captured,Available Dealership Options Shared'] 	 [702]
# 5 	 /initial_message 	 ["👋 Hi, Manikandan!\n \nI'm stella from Jeep Coimbatore Your vehicle number  is due for service on 23 July 2023\n \nWould you like to book an appointment on the same day?"] 	 ['-'] 	 ['-'] 	 ['initial_message'] 	 [702]
# 5 	 yes, i would 	 ['Perfect, Would you like to get your service done from MJ Motors - Coimbatore?'] 	 ['-'] 	 ['-'] 	 ['Service Due Date Accepted,Dealership Pitched'] 	 [702]
# 5 	 No, i wouldnt 	 ['Okay, could you tell us in which city you would prefer to get your vehicle serviced?'] 	 ['-'] 	 ['-'] 	 ['Not Intrested,Available City Options Shared'] 	 [702]
# 5 	 Bhubaneswar 	 ['These are the dealerships closest to you. Please choose your preferred option.\n \n1. Shree Bharat Motors Pahal - Bhubaneshwar\n2. K. P. Automobiles - Ranchi\n3. Celica Automobiles East Topsia Road - Kolkata'] 	 ['-'] 	 ['-'] 	 ['Selected City Captured,Available Dealership Options Shared'] 	 [702]
# 6 	 /initial_message 	 ["👋 Hi, Manikandan!\n \nI'm stella from Jeep Coimbatore Your vehicle number  is due for service on 23 July 2023\n \nWould you like to book an appointment on the same day?"] 	 ['-'] 	 ['-'] 	 ['initial_message'] 	 [702]
# 6 	 yes, i would 	 ['Perfect, Would you like to get your service done from MJ Motors - Coimbatore?'] 	 ['-'] 	 ['-'] 	 ['Service Due Date Accepted,Dealership Pitched'] 	 [702]
# 6 	 No, i wouldnt 	 ['Okay, could you tell us in which city you would prefer to get your vehicle serviced?'] 	 ['-'] 	 ['-'] 	 ['Not Intrested,Available City Options Shared'] 	 [702]
# 6 	 Calicut 	 ['These are the dealerships closest to you. Please choose your preferred option.\n \n1. \n2. \n3. '] 	 ['-'] 	 ['-'] 	 ['Selected City Captured,Available Dealership Options Shared'] 	 [702]
# 7 	 /initial_message 	 ["👋 Hi, Manikandan!\n \nI'm stella from Jeep Coimbatore Your vehicle number  is due for service on 23 July 2023\n \nWould you like to book an appointment on the same day?"] 	 ['-'] 	 ['-'] 	 ['initial_message'] 	 [702]
# 7 	 yes, i would 	 ['Perfect, Would you like to get your service done from MJ Motors - Coimbatore?'] 	 ['-'] 	 ['-'] 	 ['Service Due Date Accepted,Dealership Pitched'] 	 [702]
# 7 	 No, i wouldnt 	 ['Okay, could you tell us in which city you would prefer to get your vehicle serviced?'] 	 ['-'] 	 ['-'] 	 ['Not Intrested,Available City Options Shared'] 	 [702]
# 7 	 Chandigarh 	 ['These are the dealerships closest to you. Please choose your preferred option.\n \n1. WSL Automobiles - Chandigarh\n2. WSL Automobiles - Mohali\n3. Tapan Industries -  Solan'] 	 ['-'] 	 ['-'] 	 ['Selected City Captured,Available Dealership Options Shared'] 	 [702]
# 8 	 /initial_message 	 ["👋 Hi, Manikandan!\n \nI'm stella from Jeep Coimbatore Your vehicle number  is due for service on 23 July 2023\n \nWould you like to book an appointment on the same day?"] 	 ['-'] 	 ['-'] 	 ['initial_message'] 	 [702]
# 8 	 yes, i would 	 ['Perfect, Would you like to get your service done from MJ Motors - Coimbatore?'] 	 ['-'] 	 ['-'] 	 ['Service Due Date Accepted,Dealership Pitched'] 	 [702]
# 8 	 No, i wouldnt 	 ['Okay, could you tell us in which city you would prefer to get your vehicle serviced?'] 	 ['-'] 	 ['-'] 	 ['Not Intrested,Available City Options Shared'] 	 [702]
# 8 	 Chennai 	 ['These are the dealerships closest to you. Please choose your preferred option.\n \n1. VTK Automobiles Kattupakkam - Chennai\n2. VTK Automobiles Sholinganallur - Chennai\n3. The True Sai Motors - Salem'] 	 ['-'] 	 ['-'] 	 ['Selected City Captured,Available Dealership Options Shared'] 	 [702]
# 9 	 /initial_message 	 ["👋 Hi, Manikandan!\n \nI'm stella from Jeep Coimbatore Your vehicle number  is due for service on 23 July 2023\n \nWould you like to book an appointment on the same day?"] 	 ['-'] 	 ['-'] 	 ['initial_message'] 	 [702]
# 9 	 yes, i would 	 ['Perfect, Would you like to get your service done from MJ Motors - Coimbatore?'] 	 ['-'] 	 ['-'] 	 ['Service Due Date Accepted,Dealership Pitched'] 	 [702]
# 9 	 No, i wouldnt 	 ['Okay, could you tell us in which city you would prefer to get your vehicle serviced?'] 	 ['-'] 	 ['-'] 	 ['Not Intrested,Available City Options Shared'] 	 [702]
# 9 	 Cochin 	 ['These are the dealerships closest to you. Please choose your preferred option.\n \n1. GMA Pinnacle Thrikkakara P.O, Kakkanad, Ernakulam - Cochin\n2. GMA Pinnacle Thaikkattukara-P O, Ernakula  - Cochin\n3. Hyson Auto M C Road - Kottayam'] 	 ['-'] 	 ['-'] 	 ['Selected City Captured,Available Dealership Options Shared'] 	 [702]
# 10 	 /initial_message 	 ["👋 Hi, Manikandan!\n \nI'm stella from Jeep Coimbatore Your vehicle number  is due for service on 23 July 2023\n \nWould you like to book an appointment on the same day?"] 	 ['-'] 	 ['-'] 	 ['initial_message'] 	 [702]
# 10 	 yes, i would 	 ['Perfect, Would you like to get your service done from MJ Motors - Coimbatore?'] 	 ['-'] 	 ['-'] 	 ['Service Due Date Accepted,Dealership Pitched'] 	 [702]
# 10 	 No, i wouldnt 	 ['Okay, could you tell us in which city you would prefer to get your vehicle serviced?'] 	 ['-'] 	 ['-'] 	 ['Not Intrested,Available City Options Shared'] 	 [702]
# 10 	 Coimbatore 	 ['These are the dealerships closest to you. Please choose your preferred option.\n \n1. \n2. \n3. '] 	 ['-'] 	 ['-'] 	 ['Selected City Captured,Available Dealership Options Shared'] 	 [702]
# 11 	 /initial_message 	 ["👋 Hi, Manikandan!\n \nI'm stella from Jeep Coimbatore Your vehicle number  is due for service on 23 July 2023\n \nWould you like to book an appointment on the same day?"] 	 ['-'] 	 ['-'] 	 ['initial_message'] 	 [702]
# 11 	 yes, i would 	 ['Perfect, Would you like to get your service done from MJ Motors - Coimbatore?'] 	 ['-'] 	 ['-'] 	 ['Service Due Date Accepted,Dealership Pitched'] 	 [702]
# 11 	 No, i wouldnt 	 ['Okay, could you tell us in which city you would prefer to get your vehicle serviced?'] 	 ['-'] 	 ['-'] 	 ['Not Intrested,Available City Options Shared'] 	 [702]
# 11 	 Dehradun 	 ['These are the dealerships closest to you. Please choose your preferred option.\n \n1. \n2. \n3. '] 	 ['-'] 	 ['-'] 	 ['Selected City Captured,Available Dealership Options Shared'] 	 [702]
# 12 	 /initial_message 	 ["👋 Hi, Manikandan!\n \nI'm stella from Jeep Coimbatore Your vehicle number  is due for service on 23 July 2023\n \nWould you like to book an appointment on the same day?"] 	 ['-'] 	 ['-'] 	 ['initial_message'] 	 [702]
# 12 	 yes, i would 	 ['Perfect, Would you like to get your service done from MJ Motors - Coimbatore?'] 	 ['-'] 	 ['-'] 	 ['Service Due Date Accepted,Dealership Pitched'] 	 [702]
# 12 	 No, i wouldnt 	 ['Okay, could you tell us in which city you would prefer to get your vehicle serviced?'] 	 ['-'] 	 ['-'] 	 ['Not Intrested,Available City Options Shared'] 	 [702]
# 12 	 Gurugram 	 ['These are the dealerships closest to you. Please choose your preferred option.\n \n1. \n2. \n3. '] 	 ['-'] 	 ['-'] 	 ['Selected City Captured,Available Dealership Options Shared'] 	 [702]
# 13 	 /initial_message 	 ["👋 Hi, Manikandan!\n \nI'm stella from Jeep Coimbatore Your vehicle number  is due for service on 23 July 2023\n \nWould you like to book an appointment on the same day?"] 	 ['-'] 	 ['-'] 	 ['initial_message'] 	 [702]
# 13 	 yes, i would 	 ['Perfect, Would you like to get your service done from MJ Motors - Coimbatore?'] 	 ['-'] 	 ['-'] 	 ['Service Due Date Accepted,Dealership Pitched'] 	 [702]
# 13 	 No, i wouldnt 	 ['Okay, could you tell us in which city you would prefer to get your vehicle serviced?'] 	 ['-'] 	 ['-'] 	 ['Not Intrested,Available City Options Shared'] 	 [702]
# 13 	 Guwahati 	 ['These are the dealerships closest to you. Please choose your preferred option.\n \n1. \n2. \n3. '] 	 ['-'] 	 ['-'] 	 ['Selected City Captured,Available Dealership Options Shared'] 	 [702]
# 14 	 /initial_message 	 ["👋 Hi, Manikandan!\n \nI'm stella from Jeep Coimbatore Your vehicle number  is due for service on 23 July 2023\n \nWould you like to book an appointment on the same day?"] 	 ['-'] 	 ['-'] 	 ['initial_message'] 	 [702]
# 14 	 yes, i would 	 ['Perfect, Would you like to get your service done from MJ Motors - Coimbatore?'] 	 ['-'] 	 ['-'] 	 ['Service Due Date Accepted,Dealership Pitched'] 	 [702]
# 14 	 No, i wouldnt 	 ['Okay, could you tell us in which city you would prefer to get your vehicle serviced?'] 	 ['-'] 	 ['-'] 	 ['Not Intrested,Available City Options Shared'] 	 [702]
# 14 	 Haryana 	 ['These are the dealerships closest to you. Please choose your preferred option.\n \n1. \n2. \n3. '] 	 ['-'] 	 ['-'] 	 ['Selected City Captured,Available Dealership Options Shared'] 	 [702]
# 15 	 /initial_message 	 ["👋 Hi, Manikandan!\n \nI'm stella from Jeep Coimbatore Your vehicle number  is due for service on 23 July 2023\n \nWould you like to book an appointment on the same day?"] 	 ['-'] 	 ['-'] 	 ['initial_message'] 	 [702]
# 15 	 yes, i would 	 ['Perfect, Would you like to get your service done from MJ Motors - Coimbatore?'] 	 ['-'] 	 ['-'] 	 ['Service Due Date Accepted,Dealership Pitched'] 	 [702]
# 15 	 No, i wouldnt 	 ['Okay, could you tell us in which city you would prefer to get your vehicle serviced?'] 	 ['-'] 	 ['-'] 	 ['Not Intrested,Available City Options Shared'] 	 [702]
# 15 	 Hubli 	 ['These are the dealerships closest to you. Please choose your preferred option.\n \n1. Bellad Enterprises Hubli\n2. Aaron Wheels - Kolhapur\n3. Krishna - Satara'] 	 ['-'] 	 ['-'] 	 ['Selected City Captured,Available Dealership Options Shared'] 	 [702]
# 16 	 /initial_message 	 ["👋 Hi, Manikandan!\n \nI'm stella from Jeep Coimbatore Your vehicle number  is due for service on 23 July 2023\n \nWould you like to book an appointment on the same day?"] 	 ['-'] 	 ['-'] 	 ['initial_message'] 	 [702]
# 16 	 yes, i would 	 ['Perfect, Would you like to get your service done from MJ Motors - Coimbatore?'] 	 ['-'] 	 ['-'] 	 ['Service Due Date Accepted,Dealership Pitched'] 	 [702]
# 16 	 No, i wouldnt 	 ['Okay, could you tell us in which city you would prefer to get your vehicle serviced?'] 	 ['-'] 	 ['-'] 	 ['Not Intrested,Available City Options Shared'] 	 [702]
# 16 	 Hyderabad 	 ['These are the dealerships closest to you. Please choose your preferred option.\n \n1. Sree Krishna Automotives Nagole - Hyderabad\n2. VSN Commercials Balanagar - Hyderabad\n3. Sree Krishna Automotives Madinaguda - Hyderabad'] 	 ['-'] 	 ['-'] 	 ['Selected City Captured,Available Dealership Options Shared'] 	 [702]
# 17 	 /initial_message 	 ["👋 Hi, Manikandan!\n \nI'm stella from Jeep Coimbatore Your vehicle number  is due for service on 23 July 2023\n \nWould you like to book an appointment on the same day?"] 	 ['-'] 	 ['-'] 	 ['initial_message'] 	 [702]
# 17 	 yes, i would 	 ['Perfect, Would you like to get your service done from MJ Motors - Coimbatore?'] 	 ['-'] 	 ['-'] 	 ['Service Due Date Accepted,Dealership Pitched'] 	 [702]
# 17 	 No, i wouldnt 	 ['Okay, could you tell us in which city you would prefer to get your vehicle serviced?'] 	 ['-'] 	 ['-'] 	 ['Not Intrested,Available City Options Shared'] 	 [702]
# 17 	 Imphal 	 ['These are the dealerships closest to you. Please choose your preferred option.\n \n1. \n2. \n3. '] 	 ['-'] 	 ['-'] 	 ['Selected City Captured,Available Dealership Options Shared'] 	 [702]
# 18 	 /initial_message 	 ["👋 Hi, Manikandan!\n \nI'm stella from Jeep Coimbatore Your vehicle number  is due for service on 23 July 2023\n \nWould you like to book an appointment on the same day?"] 	 ['-'] 	 ['-'] 	 ['initial_message'] 	 [702]
# 18 	 yes, i would 	 ['Perfect, Would you like to get your service done from MJ Motors - Coimbatore?'] 	 ['-'] 	 ['-'] 	 ['Service Due Date Accepted,Dealership Pitched'] 	 [702]
# 18 	 No, i wouldnt 	 ['Okay, could you tell us in which city you would prefer to get your vehicle serviced?'] 	 ['-'] 	 ['-'] 	 ['Not Intrested,Available City Options Shared'] 	 [702]
# 18 	 Indore 	 ['These are the dealerships closest to you. Please choose your preferred option.\n \n1. \n2. \n3. '] 	 ['-'] 	 ['-'] 	 ['Selected City Captured,Available Dealership Options Shared'] 	 [702]
# 19 	 /initial_message 	 ["👋 Hi, Manikandan!\n \nI'm stella from Jeep Coimbatore Your vehicle number  is due for service on 23 July 2023\n \nWould you like to book an appointment on the same day?"] 	 ['-'] 	 ['-'] 	 ['initial_message'] 	 [702]
# 19 	 yes, i would 	 ['Perfect, Would you like to get your service done from MJ Motors - Coimbatore?'] 	 ['-'] 	 ['-'] 	 ['Service Due Date Accepted,Dealership Pitched'] 	 [702]
# 19 	 No, i wouldnt 	 ['Okay, could you tell us in which city you would prefer to get your vehicle serviced?'] 	 ['-'] 	 ['-'] 	 ['Not Intrested,Available City Options Shared'] 	 [702]
# 19 	 Jaipur 	 ['These are the dealerships closest to you. Please choose your preferred option.\n \n1. PRATAP VOITURES Sitapur - Jaipur\n2. Mundra Automobiles - Kota\n3. Landmark Lifestyle  - Gurugram'] 	 ['-'] 	 ['-'] 	 ['Selected City Captured,Available Dealership Options Shared'] 	 [702]
# 20 	 /initial_message 	 ["👋 Hi, Manikandan!\n \nI'm stella from Jeep Coimbatore Your vehicle number  is due for service on 23 July 2023\n \nWould you like to book an appointment on the same day?"] 	 ['-'] 	 ['-'] 	 ['initial_message'] 	 [702]
# 20 	 yes, i would 	 ['Perfect, Would you like to get your service done from MJ Motors - Coimbatore?'] 	 ['-'] 	 ['-'] 	 ['Service Due Date Accepted,Dealership Pitched'] 	 [702]
# 20 	 No, i wouldnt 	 ['Okay, could you tell us in which city you would prefer to get your vehicle serviced?'] 	 ['-'] 	 ['-'] 	 ['Not Intrested,Available City Options Shared'] 	 [702]
# 20 	 Jalandhar 	 ['These are the dealerships closest to you. Please choose your preferred option.\n \n1. \n2. \n3. '] 	 ['-'] 	 ['-'] 	 ['Selected City Captured,Available Dealership Options Shared'] 	 [702]
# 21 	 /initial_message 	 ["👋 Hi, Manikandan!\n \nI'm stella from Jeep Coimbatore Your vehicle number  is due for service on 23 July 2023\n \nWould you like to book an appointment on the same day?"] 	 ['-'] 	 ['-'] 	 ['initial_message'] 	 [702]
# 21 	 yes, i would 	 ['Perfect, Would you like to get your service done from MJ Motors - Coimbatore?'] 	 ['-'] 	 ['-'] 	 ['Service Due Date Accepted,Dealership Pitched'] 	 [702]
# 21 	 No, i wouldnt 	 ['Okay, could you tell us in which city you would prefer to get your vehicle serviced?'] 	 ['-'] 	 ['-'] 	 ['Not Intrested,Available City Options Shared'] 	 [702]
# 21 	 Jodhpur 	 ['These are the dealerships closest to you. Please choose your preferred option.\n \n1. \n2. \n3. '] 	 ['-'] 	 ['-'] 	 ['Selected City Captured,Available Dealership Options Shared'] 	 [702]
# 22 	 /initial_message 	 ["👋 Hi, Manikandan!\n \nI'm stella from Jeep Coimbatore Your vehicle number  is due for service on 23 July 2023\n \nWould you like to book an appointment on the same day?"] 	 ['-'] 	 ['-'] 	 ['initial_message'] 	 [702]
# 22 	 yes, i would 	 ['Perfect, Would you like to get your service done from MJ Motors - Coimbatore?'] 	 ['-'] 	 ['-'] 	 ['Service Due Date Accepted,Dealership Pitched'] 	 [702]
# 22 	 No, i wouldnt 	 ['Okay, could you tell us in which city you would prefer to get your vehicle serviced?'] 	 ['-'] 	 ['-'] 	 ['Not Intrested,Available City Options Shared'] 	 [702]
# 22 	 Kanpur 	 ['These are the dealerships closest to you. Please choose your preferred option.\n \n1. \n2. \n3. '] 	 ['-'] 	 ['-'] 	 ['Selected City Captured,Available Dealership Options Shared'] 	 [702]
# 23 	 /initial_message 	 ["👋 Hi, Manikandan!\n \nI'm stella from Jeep Coimbatore Your vehicle number  is due for service on 23 July 2023\n \nWould you like to book an appointment on the same day?"] 	 ['-'] 	 ['-'] 	 ['initial_message'] 	 [702]
# 23 	 yes, i would 	 ['Perfect, Would you like to get your service done from MJ Motors - Coimbatore?'] 	 ['-'] 	 ['-'] 	 ['Service Due Date Accepted,Dealership Pitched'] 	 [702]
# 23 	 No, i wouldnt 	 ['Okay, could you tell us in which city you would prefer to get your vehicle serviced?'] 	 ['-'] 	 ['-'] 	 ['Not Intrested,Available City Options Shared'] 	 [702]
# 23 	 Karnal 	 ['These are the dealerships closest to you. Please choose your preferred option.\n \n1. \n2. \n3. '] 	 ['-'] 	 ['-'] 	 ['Selected City Captured,Available Dealership Options Shared'] 	 [702]
# 24 	 /initial_message 	 ["👋 Hi, Manikandan!\n \nI'm stella from Jeep Coimbatore Your vehicle number  is due for service on 23 July 2023\n \nWould you like to book an appointment on the same day?"] 	 ['-'] 	 ['-'] 	 ['initial_message'] 	 [702]
# 24 	 yes, i would 	 ['Perfect, Would you like to get your service done from MJ Motors - Coimbatore?'] 	 ['-'] 	 ['-'] 	 ['Service Due Date Accepted,Dealership Pitched'] 	 [702]
# 24 	 No, i wouldnt 	 ['Okay, could you tell us in which city you would prefer to get your vehicle serviced?'] 	 ['-'] 	 ['-'] 	 ['Not Intrested,Available City Options Shared'] 	 [702]
# 24 	 Kolhapur 	 ['These are the dealerships closest to you. Please choose your preferred option.\n \n1. \n2. \n3. '] 	 ['-'] 	 ['-'] 	 ['Selected City Captured,Available Dealership Options Shared'] 	 [702]
# 25 	 /initial_message 	 ["👋 Hi, Manikandan!\n \nI'm stella from Jeep Coimbatore Your vehicle number  is due for service on 23 July 2023\n \nWould you like to book an appointment on the same day?"] 	 ['-'] 	 ['-'] 	 ['initial_message'] 	 [702]
# 25 	 yes, i would 	 ['Perfect, Would you like to get your service done from MJ Motors - Coimbatore?'] 	 ['-'] 	 ['-'] 	 ['Service Due Date Accepted,Dealership Pitched'] 	 [702]
# 25 	 No, i wouldnt 	 ['Okay, could you tell us in which city you would prefer to get your vehicle serviced?'] 	 ['-'] 	 ['-'] 	 ['Not Intrested,Available City Options Shared'] 	 [702]
# 25 	 Kolkata 	 ['These are the dealerships closest to you. Please choose your preferred option.\n \n1. \n2. \n3. '] 	 ['-'] 	 ['-'] 	 ['Selected City Captured,Available Dealership Options Shared'] 	 [702]
# 26 	 /initial_message 	 ["👋 Hi, Manikandan!\n \nI'm stella from Jeep Coimbatore Your vehicle number  is due for service on 23 July 2023\n \nWould you like to book an appointment on the same day?"] 	 ['-'] 	 ['-'] 	 ['initial_message'] 	 [702]
# 26 	 yes, i would 	 ['Perfect, Would you like to get your service done from MJ Motors - Coimbatore?'] 	 ['-'] 	 ['-'] 	 ['Service Due Date Accepted,Dealership Pitched'] 	 [702]
# 26 	 No, i wouldnt 	 ['Okay, could you tell us in which city you would prefer to get your vehicle serviced?'] 	 ['-'] 	 ['-'] 	 ['Not Intrested,Available City Options Shared'] 	 [702]
# 26 	 Kota 	 ['These are the dealerships closest to you. Please choose your preferred option.\n \n1. \n2. \n3. '] 	 ['-'] 	 ['-'] 	 ['Selected City Captured,Available Dealership Options Shared'] 	 [702]
# 27 	 /initial_message 	 ["👋 Hi, Manikandan!\n \nI'm stella from Jeep Coimbatore Your vehicle number  is due for service on 23 July 2023\n \nWould you like to book an appointment on the same day?"] 	 ['-'] 	 ['-'] 	 ['initial_message'] 	 [702]
# 27 	 yes, i would 	 ['Perfect, Would you like to get your service done from MJ Motors - Coimbatore?'] 	 ['-'] 	 ['-'] 	 ['Service Due Date Accepted,Dealership Pitched'] 	 [702]
# 27 	 No, i wouldnt 	 ['Okay, could you tell us in which city you would prefer to get your vehicle serviced?'] 	 ['-'] 	 ['-'] 	 ['Not Intrested,Available City Options Shared'] 	 [702]
# 27 	 Kottayam 	 ['These are the dealerships closest to you. Please choose your preferred option.\n \n1. \n2. \n3. '] 	 ['-'] 	 ['-'] 	 ['Selected City Captured,Available Dealership Options Shared'] 	 [702]
# 28 	 /initial_message 	 ["👋 Hi, Manikandan!\n \nI'm stella from Jeep Coimbatore Your vehicle number  is due for service on 23 July 2023\n \nWould you like to book an appointment on the same day?"] 	 ['-'] 	 ['-'] 	 ['initial_message'] 	 [702]
# 28 	 yes, i would 	 ['Perfect, Would you like to get your service done from MJ Motors - Coimbatore?'] 	 ['-'] 	 ['-'] 	 ['Service Due Date Accepted,Dealership Pitched'] 	 [702]
# 28 	 No, i wouldnt 	 ['Okay, could you tell us in which city you would prefer to get your vehicle serviced?'] 	 ['-'] 	 ['-'] 	 ['Not Intrested,Available City Options Shared'] 	 [702]
# 28 	 Lucknow 	 ['These are the dealerships closest to you. Please choose your preferred option.\n \n1. S G Infracars - Lucknow\n2. SG Infracare - Kanpur\n3. Kalyan Automart - Agra'] 	 ['-'] 	 ['-'] 	 ['Selected City Captured,Available Dealership Options Shared'] 	 [702]
# 29 	 /initial_message 	 ["👋 Hi, Manikandan!\n \nI'm stella from Jeep Coimbatore Your vehicle number  is due for service on 23 July 2023\n \nWould you like to book an appointment on the same day?"] 	 ['-'] 	 ['-'] 	 ['initial_message'] 	 [702]
# 29 	 yes, i would 	 ['Perfect, Would you like to get your service done from MJ Motors - Coimbatore?'] 	 ['-'] 	 ['-'] 	 ['Service Due Date Accepted,Dealership Pitched'] 	 [702]
# 29 	 No, i wouldnt 	 ['Okay, could you tell us in which city you would prefer to get your vehicle serviced?'] 	 ['-'] 	 ['-'] 	 ['Not Intrested,Available City Options Shared'] 	 [702]
# 29 	 Ludhiana 	 ['These are the dealerships closest to you. Please choose your preferred option.\n \n1. \n2. \n3. '] 	 ['-'] 	 ['-'] 	 ['Selected City Captured,Available Dealership Options Shared'] 	 [702]
# 30 	 /initial_message 	 ["👋 Hi, Manikandan!\n \nI'm stella from Jeep Coimbatore Your vehicle number  is due for service on 23 July 2023\n \nWould you like to book an appointment on the same day?"] 	 ['-'] 	 ['-'] 	 ['initial_message'] 	 [702]
# 30 	 yes, i would 	 ['Perfect, Would you like to get your service done from MJ Motors - Coimbatore?'] 	 ['-'] 	 ['-'] 	 ['Service Due Date Accepted,Dealership Pitched'] 	 [702]
# 30 	 No, i wouldnt 	 ['Okay, could you tell us in which city you would prefer to get your vehicle serviced?'] 	 ['-'] 	 ['-'] 	 ['Not Intrested,Available City Options Shared'] 	 [702]
# 30 	 Madurai 	 ['These are the dealerships closest to you. Please choose your preferred option.\n \n1. \n2. \n3. '] 	 ['-'] 	 ['-'] 	 ['Selected City Captured,Available Dealership Options Shared'] 	 [702]
# 31 	 /initial_message 	 ["👋 Hi, Manikandan!\n \nI'm stella from Jeep Coimbatore Your vehicle number  is due for service on 23 July 2023\n \nWould you like to book an appointment on the same day?"] 	 ['-'] 	 ['-'] 	 ['initial_message'] 	 [702]
# 31 	 yes, i would 	 ['Perfect, Would you like to get your service done from MJ Motors - Coimbatore?'] 	 ['-'] 	 ['-'] 	 ['Service Due Date Accepted,Dealership Pitched'] 	 [702]
# 31 	 No, i wouldnt 	 ['Okay, could you tell us in which city you would prefer to get your vehicle serviced?'] 	 ['-'] 	 ['-'] 	 ['Not Intrested,Available City Options Shared'] 	 [702]
# 31 	 Mumbai 	 ['These are the dealerships closest to you. Please choose your preferred option.\n \n1. Landmark Lifestyle Pasrsi Panchayat - Mumbai\n2. Landmark Lifestyle Trubhe - Navi Mumbai\n3. Landmark Lifestyle Kajupada - Thane'] 	 ['-'] 	 ['-'] 	 ['Selected City Captured,Available Dealership Options Shared'] 	 [702]
# 32 	 /initial_message 	 ["👋 Hi, Manikandan!\n \nI'm stella from Jeep Coimbatore Your vehicle number  is due for service on 23 July 2023\n \nWould you like to book an appointment on the same day?"] 	 ['-'] 	 ['-'] 	 ['initial_message'] 	 [702]
# 32 	 yes, i would 	 ['Perfect, Would you like to get your service done from MJ Motors - Coimbatore?'] 	 ['-'] 	 ['-'] 	 ['Service Due Date Accepted,Dealership Pitched'] 	 [702]
# 32 	 No, i wouldnt 	 ['Okay, could you tell us in which city you would prefer to get your vehicle serviced?'] 	 ['-'] 	 ['-'] 	 ['Not Intrested,Available City Options Shared'] 	 [702]
# 32 	 Nagpur 	 ['These are the dealerships closest to you. Please choose your preferred option.\n \n1. \n2. \n3. '] 	 ['-'] 	 ['-'] 	 ['Selected City Captured,Available Dealership Options Shared'] 	 [702]
# 33 	 /initial_message 	 ["👋 Hi, Manikandan!\n \nI'm stella from Jeep Coimbatore Your vehicle number  is due for service on 23 July 2023\n \nWould you like to book an appointment on the same day?"] 	 ['-'] 	 ['-'] 	 ['initial_message'] 	 [702]
# 33 	 yes, i would 	 ['Perfect, Would you like to get your service done from MJ Motors - Coimbatore?'] 	 ['-'] 	 ['-'] 	 ['Service Due Date Accepted,Dealership Pitched'] 	 [702]
# 33 	 No, i wouldnt 	 ['Okay, could you tell us in which city you would prefer to get your vehicle serviced?'] 	 ['-'] 	 ['-'] 	 ['Not Intrested,Available City Options Shared'] 	 [702]
# 33 	 Nashik 	 ['These are the dealerships closest to you. Please choose your preferred option.\n \n1. \n2. \n3. '] 	 ['-'] 	 ['-'] 	 ['Selected City Captured,Available Dealership Options Shared'] 	 [702]
# 34 	 /initial_message 	 ["👋 Hi, Manikandan!\n \nI'm stella from Jeep Coimbatore Your vehicle number  is due for service on 23 July 2023\n \nWould you like to book an appointment on the same day?"] 	 ['-'] 	 ['-'] 	 ['initial_message'] 	 [702]
# 34 	 yes, i would 	 ['Perfect, Would you like to get your service done from MJ Motors - Coimbatore?'] 	 ['-'] 	 ['-'] 	 ['Service Due Date Accepted,Dealership Pitched'] 	 [702]
# 34 	 No, i wouldnt 	 ['Okay, could you tell us in which city you would prefer to get your vehicle serviced?'] 	 ['-'] 	 ['-'] 	 ['Not Intrested,Available City Options Shared'] 	 [702]
# 34 	 Navi Mumbai 	 ['These are the dealerships closest to you. Please choose your preferred option.\n \n1. Landmark Lifestyle Trubhe - Navi Mumbai\n2. Landmark Lifestyle Pasrsi Panchayat - Mumbai\n3. Landmark Lifestyle Kajupada - Thane'] 	 ['-'] 	 ['-'] 	 ['Selected City Captured,Available Dealership Options Shared'] 	 [702]
# 35 	 /initial_message 	 ["👋 Hi, Manikandan!\n \nI'm stella from Jeep Coimbatore Your vehicle number  is due for service on 23 July 2023\n \nWould you like to book an appointment on the same day?"] 	 ['-'] 	 ['-'] 	 ['initial_message'] 	 [702]
# 35 	 yes, i would 	 ['Perfect, Would you like to get your service done from MJ Motors - Coimbatore?'] 	 ['-'] 	 ['-'] 	 ['Service Due Date Accepted,Dealership Pitched'] 	 [702]
# 35 	 No, i wouldnt 	 ['Okay, could you tell us in which city you would prefer to get your vehicle serviced?'] 	 ['-'] 	 ['-'] 	 ['Not Intrested,Available City Options Shared'] 	 [702]
# 35 	 Pune 	 ['These are the dealerships closest to you. Please choose your preferred option.\n \n1. \n2. \n3. '] 	 ['-'] 	 ['-'] 	 ['Selected City Captured,Available Dealership Options Shared'] 	 [702]
# 36 	 /initial_message 	 ["👋 Hi, Manikandan!\n \nI'm stella from Jeep Coimbatore Your vehicle number  is due for service on 23 July 2023\n \nWould you like to book an appointment on the same day?"] 	 ['-'] 	 ['-'] 	 ['initial_message'] 	 [702]
# 36 	 yes, i would 	 ['Perfect, Would you like to get your service done from MJ Motors - Coimbatore?'] 	 ['-'] 	 ['-'] 	 ['Service Due Date Accepted,Dealership Pitched'] 	 [702]
# 36 	 No, i wouldnt 	 ['Okay, could you tell us in which city you would prefer to get your vehicle serviced?'] 	 ['-'] 	 ['-'] 	 ['Not Intrested,Available City Options Shared'] 	 [702]
# 36 	 Rajkot 	 ['These are the dealerships closest to you. Please choose your preferred option.\n \n1. \n2. \n3. '] 	 ['-'] 	 ['-'] 	 ['Selected City Captured,Available Dealership Options Shared'] 	 [702]
# 37 	 /initial_message 	 ["👋 Hi, Manikandan!\n \nI'm stella from Jeep Coimbatore Your vehicle number  is due for service on 23 July 2023\n \nWould you like to book an appointment on the same day?"] 	 ['-'] 	 ['-'] 	 ['initial_message'] 	 [702]
# 37 	 yes, i would 	 ['Perfect, Would you like to get your service done from MJ Motors - Coimbatore?'] 	 ['-'] 	 ['-'] 	 ['Service Due Date Accepted,Dealership Pitched'] 	 [702]
# 37 	 No, i wouldnt 	 ['Okay, could you tell us in which city you would prefer to get your vehicle serviced?'] 	 ['-'] 	 ['-'] 	 ['Not Intrested,Available City Options Shared'] 	 [702]
# 37 	 Ranchi 	 ['These are the dealerships closest to you. Please choose your preferred option.\n \n1. \n2. \n3. '] 	 ['-'] 	 ['-'] 	 ['Selected City Captured,Available Dealership Options Shared'] 	 [702]
# 38 	 /initial_message 	 ["👋 Hi, Manikandan!\n \nI'm stella from Jeep Coimbatore Your vehicle number  is due for service on 23 July 2023\n \nWould you like to book an appointment on the same day?"] 	 ['-'] 	 ['-'] 	 ['initial_message'] 	 [702]
# 38 	 yes, i would 	 ['Perfect, Would you like to get your service done from MJ Motors - Coimbatore?'] 	 ['-'] 	 ['-'] 	 ['Service Due Date Accepted,Dealership Pitched'] 	 [702]
# 38 	 No, i wouldnt 	 ['Okay, could you tell us in which city you would prefer to get your vehicle serviced?'] 	 ['-'] 	 ['-'] 	 ['Not Intrested,Available City Options Shared'] 	 [702]
# 38 	 Salem 	 ['These are the dealerships closest to you. Please choose your preferred option.\n \n1. \n2. \n3. '] 	 ['-'] 	 ['-'] 	 ['Selected City Captured,Available Dealership Options Shared'] 	 [702]
# 39 	 /initial_message 	 ["👋 Hi, Manikandan!\n \nI'm stella from Jeep Coimbatore Your vehicle number  is due for service on 23 July 2023\n \nWould you like to book an appointment on the same day?"] 	 ['-'] 	 ['-'] 	 ['initial_message'] 	 [702]
# 39 	 yes, i would 	 ['Perfect, Would you like to get your service done from MJ Motors - Coimbatore?'] 	 ['-'] 	 ['-'] 	 ['Service Due Date Accepted,Dealership Pitched'] 	 [702]
# 39 	 No, i wouldnt 	 ['Okay, could you tell us in which city you would prefer to get your vehicle serviced?'] 	 ['-'] 	 ['-'] 	 ['Not Intrested,Available City Options Shared'] 	 [702]
# 39 	 Satara 	 ['These are the dealerships closest to you. Please choose your preferred option.\n \n1. \n2. \n3. '] 	 ['-'] 	 ['-'] 	 ['Selected City Captured,Available Dealership Options Shared'] 	 [702]
# 40 	 /initial_message 	 ["👋 Hi, Manikandan!\n \nI'm stella from Jeep Coimbatore Your vehicle number  is due for service on 23 July 2023\n \nWould you like to book an appointment on the same day?"] 	 ['-'] 	 ['-'] 	 ['initial_message'] 	 [702]
# 40 	 yes, i would 	 ['Perfect, Would you like to get your service done from MJ Motors - Coimbatore?'] 	 ['-'] 	 ['-'] 	 ['Service Due Date Accepted,Dealership Pitched'] 	 [702]
# 40 	 No, i wouldnt 	 ['Okay, could you tell us in which city you would prefer to get your vehicle serviced?'] 	 ['-'] 	 ['-'] 	 ['Not Intrested,Available City Options Shared'] 	 [702]
# 40 	 Siliguri 	 ['These are the dealerships closest to you. Please choose your preferred option.\n \n1. Celica Automobiles - Siliguri\n2. Mahesh Motors - Guwahati\n3. Celica Automobiles East Topsia Road - Kolkata'] 	 ['-'] 	 ['-'] 	 ['Selected City Captured,Available Dealership Options Shared'] 	 [702]
# 41 	 /initial_message 	 ["👋 Hi, Manikandan!\n \nI'm stella from Jeep Coimbatore Your vehicle number  is due for service on 23 July 2023\n \nWould you like to book an appointment on the same day?"] 	 ['-'] 	 ['-'] 	 ['initial_message'] 	 [702]
# 41 	 yes, i would 	 ['Perfect, Would you like to get your service done from MJ Motors - Coimbatore?'] 	 ['-'] 	 ['-'] 	 ['Service Due Date Accepted,Dealership Pitched'] 	 [702]
# 41 	 No, i wouldnt 	 ['Okay, could you tell us in which city you would prefer to get your vehicle serviced?'] 	 ['-'] 	 ['-'] 	 ['Not Intrested,Available City Options Shared'] 	 [702]
# 41 	 Solan 	 ['These are the dealerships closest to you. Please choose your preferred option.\n \n1. \n2. \n3. '] 	 ['-'] 	 ['-'] 	 ['Selected City Captured,Available Dealership Options Shared'] 	 [702]
# 42 	 /initial_message 	 ["👋 Hi, Manikandan!\n \nI'm stella from Jeep Coimbatore Your vehicle number  is due for service on 23 July 2023\n \nWould you like to book an appointment on the same day?"] 	 ['-'] 	 ['-'] 	 ['initial_message'] 	 [702]
# 42 	 yes, i would 	 ['Perfect, Would you like to get your service done from MJ Motors - Coimbatore?'] 	 ['-'] 	 ['-'] 	 ['Service Due Date Accepted,Dealership Pitched'] 	 [702]
# 42 	 No, i wouldnt 	 ['Okay, could you tell us in which city you would prefer to get your vehicle serviced?'] 	 ['-'] 	 ['-'] 	 ['Not Intrested,Available City Options Shared'] 	 [702]
# 42 	 Sonipat 	 ['These are the dealerships closest to you. Please choose your preferred option.\n \n1. Sahil Automobile - Sonipat\n2. Landmark Lifestyle Motinagar - New Delhi\n3. Landmark Lifestyle Okhla - New Delhi'] 	 ['-'] 	 ['-'] 	 ['Selected City Captured,Available Dealership Options Shared'] 	 [702]
# 43 	 /initial_message 	 ["👋 Hi, Manikandan!\n \nI'm stella from Jeep Coimbatore Your vehicle number  is due for service on 23 July 2023\n \nWould you like to book an appointment on the same day?"] 	 ['-'] 	 ['-'] 	 ['initial_message'] 	 [702]
# 43 	 yes, i would 	 ['Perfect, Would you like to get your service done from MJ Motors - Coimbatore?'] 	 ['-'] 	 ['-'] 	 ['Service Due Date Accepted,Dealership Pitched'] 	 [702]
# 43 	 No, i wouldnt 	 ['Okay, could you tell us in which city you would prefer to get your vehicle serviced?'] 	 ['-'] 	 ['-'] 	 ['Not Intrested,Available City Options Shared'] 	 [702]
# 43 	 South Delhi 	 ['These are the dealerships closest to you. Please choose your preferred option.\n \n1. Landmark Lifestyle Okhla - New Delhi\n2. Landmark Lifestyle Motinagar - New Delhi\n3. Landmark Lifestyle  - Gurugram'] 	 ['-'] 	 ['-'] 	 ['Selected City Captured,Available Dealership Options Shared'] 	 [702]
# 44 	 /initial_message 	 ["👋 Hi, Manikandan!\n \nI'm stella from Jeep Coimbatore Your vehicle number  is due for service on 23 July 2023\n \nWould you like to book an appointment on the same day?"] 	 ['-'] 	 ['-'] 	 ['initial_message'] 	 [702]
# 44 	 yes, i would 	 ['Perfect, Would you like to get your service done from MJ Motors - Coimbatore?'] 	 ['-'] 	 ['-'] 	 ['Service Due Date Accepted,Dealership Pitched'] 	 [702]
# 44 	 No, i wouldnt 	 ['Okay, could you tell us in which city you would prefer to get your vehicle serviced?'] 	 ['-'] 	 ['-'] 	 ['Not Intrested,Available City Options Shared'] 	 [702]
# 44 	 Srinagar 	 ['These are the dealerships closest to you. Please choose your preferred option.\n \n1. ARG Automobiles - Srinagar\n2. Four A Automobiles Bye pass Road - Jammu\n3. Landmark Lifestyle GT Road - Jalandhar'] 	 ['-'] 	 ['-'] 	 ['Selected City Captured,Available Dealership Options Shared'] 	 [702]
# 45 	 /initial_message 	 ["👋 Hi, Manikandan!\n \nI'm stella from Jeep Coimbatore Your vehicle number  is due for service on 23 July 2023\n \nWould you like to book an appointment on the same day?"] 	 ['-'] 	 ['-'] 	 ['initial_message'] 	 [702]
# 45 	 yes, i would 	 ['Perfect, Would you like to get your service done from MJ Motors - Coimbatore?'] 	 ['-'] 	 ['-'] 	 ['Service Due Date Accepted,Dealership Pitched'] 	 [702]
# 45 	 No, i wouldnt 	 ['Okay, could you tell us in which city you would prefer to get your vehicle serviced?'] 	 ['-'] 	 ['-'] 	 ['Not Intrested,Available City Options Shared'] 	 [702]
# 45 	 Surat 	 ['These are the dealerships closest to you. Please choose your preferred option.\n \n1. \n2. \n3. '] 	 ['-'] 	 ['-'] 	 ['Selected City Captured,Available Dealership Options Shared'] 	 [702]
# 46 	 /initial_message 	 ["👋 Hi, Manikandan!\n \nI'm stella from Jeep Coimbatore Your vehicle number  is due for service on 23 July 2023\n \nWould you like to book an appointment on the same day?"] 	 ['-'] 	 ['-'] 	 ['initial_message'] 	 [702]
# 46 	 yes, i would 	 ['Perfect, Would you like to get your service done from MJ Motors - Coimbatore?'] 	 ['-'] 	 ['-'] 	 ['Service Due Date Accepted,Dealership Pitched'] 	 [702]
# 46 	 No, i wouldnt 	 ['Okay, could you tell us in which city you would prefer to get your vehicle serviced?'] 	 ['-'] 	 ['-'] 	 ['Not Intrested,Available City Options Shared'] 	 [702]
# 46 	 Thane 	 ['These are the dealerships closest to you. Please choose your preferred option.\n \n1. Landmark Lifestyle Kajupada - Thane\n2. Landmark Lifestyle Pasrsi Panchayat - Mumbai\n3. Landmark Lifestyle Trubhe - Navi Mumbai'] 	 ['-'] 	 ['-'] 	 ['Selected City Captured,Available Dealership Options Shared'] 	 [702]
# 47 	 /initial_message 	 ["👋 Hi, Manikandan!\n \nI'm stella from Jeep Coimbatore Your vehicle number  is due for service on 23 July 2023\n \nWould you like to book an appointment on the same day?"] 	 ['-'] 	 ['-'] 	 ['initial_message'] 	 [702]
# 47 	 yes, i would 	 ['Perfect, Would you like to get your service done from MJ Motors - Coimbatore?'] 	 ['-'] 	 ['-'] 	 ['Service Due Date Accepted,Dealership Pitched'] 	 [702]
# 47 	 No, i wouldnt 	 ['Okay, could you tell us in which city you would prefer to get your vehicle serviced?'] 	 ['-'] 	 ['-'] 	 ['Not Intrested,Available City Options Shared'] 	 [702]
# 47 	 Thrissur 	 ['These are the dealerships closest to you. Please choose your preferred option.\n \n1. \n2. \n3. '] 	 ['-'] 	 ['-'] 	 ['Selected City Captured,Available Dealership Options Shared'] 	 [702]
# 48 	 /initial_message 	 ["👋 Hi, Manikandan!\n \nI'm stella from Jeep Coimbatore Your vehicle number  is due for service on 23 July 2023\n \nWould you like to book an appointment on the same day?"] 	 ['-'] 	 ['-'] 	 ['initial_message'] 	 [702]
# 48 	 yes, i would 	 ['Perfect, Would you like to get your service done from MJ Motors - Coimbatore?'] 	 ['-'] 	 ['-'] 	 ['Service Due Date Accepted,Dealership Pitched'] 	 [702]
# 48 	 No, i wouldnt 	 ['Okay, could you tell us in which city you would prefer to get your vehicle serviced?'] 	 ['-'] 	 ['-'] 	 ['Not Intrested,Available City Options Shared'] 	 [702]
# 48 	 Trichy 	 ['These are the dealerships closest to you. Please choose your preferred option.\n \n1. \n2. \n3. '] 	 ['-'] 	 ['-'] 	 ['Selected City Captured,Available Dealership Options Shared'] 	 [702]
# 49 	 /initial_message 	 ["👋 Hi, Manikandan!\n \nI'm stella from Jeep Coimbatore Your vehicle number  is due for service on 23 July 2023\n \nWould you like to book an appointment on the same day?"] 	 ['-'] 	 ['-'] 	 ['initial_message'] 	 [702]
# 49 	 yes, i would 	 ['Perfect, Would you like to get your service done from MJ Motors - Coimbatore?'] 	 ['-'] 	 ['-'] 	 ['Service Due Date Accepted,Dealership Pitched'] 	 [702]
# 49 	 No, i wouldnt 	 ['Okay, could you tell us in which city you would prefer to get your vehicle serviced?'] 	 ['-'] 	 ['-'] 	 ['Not Intrested,Available City Options Shared'] 	 [702]
# 49 	 Trivandrum 	 ['These are the dealerships closest to you. Please choose your preferred option.\n \n1. Deedi Motors NH Bypass - Trivandrum\n2. Hyson Auto M C Road - Kottayam\n3. GMA Pinnacle Thrikkakara P.O, Kakkanad, Ernakulam - Cochin'] 	 ['-'] 	 ['-'] 	 ['Selected City Captured,Available Dealership Options Shared'] 	 [702]
# 50 	 /initial_message 	 ["👋 Hi, Manikandan!\n \nI'm stella from Jeep Coimbatore Your vehicle number  is due for service on 23 July 2023\n \nWould you like to book an appointment on the same day?"] 	 ['-'] 	 ['-'] 	 ['initial_message'] 	 [702]
# 50 	 yes, i would 	 ['Perfect, Would you like to get your service done from MJ Motors - Coimbatore?'] 	 ['-'] 	 ['-'] 	 ['Service Due Date Accepted,Dealership Pitched'] 	 [702]
# 50 	 No, i wouldnt 	 ['Okay, could you tell us in which city you would prefer to get your vehicle serviced?'] 	 ['-'] 	 ['-'] 	 ['Not Intrested,Available City Options Shared'] 	 [702]
# 50 	 Vadodara 	 ['These are the dealerships closest to you. Please choose your preferred option.\n \n1. \n2. \n3. '] 	 ['-'] 	 ['-'] 	 ['Selected City Captured,Available Dealership Options Shared'] 	 [702]
# 51 	 /initial_message 	 ["👋 Hi, Manikandan!\n \nI'm stella from Jeep Coimbatore Your vehicle number  is due for service on 23 July 2023\n \nWould you like to book an appointment on the same day?"] 	 ['-'] 	 ['-'] 	 ['initial_message'] 	 [702]
# 51 	 yes, i would 	 ['Perfect, Would you like to get your service done from MJ Motors - Coimbatore?'] 	 ['-'] 	 ['-'] 	 ['Service Due Date Accepted,Dealership Pitched'] 	 [702]
# 51 	 No, i wouldnt 	 ['Okay, could you tell us in which city you would prefer to get your vehicle serviced?'] 	 ['-'] 	 ['-'] 	 ['Not Intrested,Available City Options Shared'] 	 [702]
# 51 	 Vijayawada 	 ['These are the dealerships closest to you. Please choose your preferred option.\n \n1. Turbo Automotives NH 5 - Vijaywada\n2. Sree Krishna Automotives Hunter Road - Warangal\n3. Sree Krishna Automotives Nagole - Hyderabad'] 	 ['-'] 	 ['-'] 	 ['Selected City Captured,Available Dealership Options Shared'] 	 [702]
# 52 	 /initial_message 	 ["👋 Hi, Manikandan!\n \nI'm stella from Jeep Coimbatore Your vehicle number  is due for service on 23 July 2023\n \nWould you like to book an appointment on the same day?"] 	 ['-'] 	 ['-'] 	 ['initial_message'] 	 [702]
# 52 	 yes, i would 	 ['Perfect, Would you like to get your service done from MJ Motors - Coimbatore?'] 	 ['-'] 	 ['-'] 	 ['Service Due Date Accepted,Dealership Pitched'] 	 [702]
# 52 	 No, i wouldnt 	 ['Okay, could you tell us in which city you would prefer to get your vehicle serviced?'] 	 ['-'] 	 ['-'] 	 ['Not Intrested,Available City Options Shared'] 	 [702]
# 52 	 Visakhapatnam 	 ['These are the dealerships closest to you. Please choose your preferred option.\n \n1. Orange Auto Industrial Area - Vishakhapatnam\n2. Turbo Automotives NH 5 - Vijaywada\n3. Sree Krishna Automotives Hunter Road - Warangal'] 	 ['-'] 	 ['-'] 	 ['Selected City Captured,Available Dealership Options Shared'] 	 [702]
# 53 	 /initial_message 	 ["👋 Hi, Manikandan!\n \nI'm stella from Jeep Coimbatore Your vehicle number  is due for service on 23 July 2023\n \nWould you like to book an appointment on the same day?"] 	 ['-'] 	 ['-'] 	 ['initial_message'] 	 [702]
# 53 	 yes, i would 	 ['Perfect, Would you like to get your service done from MJ Motors - Coimbatore?'] 	 ['-'] 	 ['-'] 	 ['Service Due Date Accepted,Dealership Pitched'] 	 [702]
# 53 	 No, i wouldnt 	 ['Okay, could you tell us in which city you would prefer to get your vehicle serviced?'] 	 ['-'] 	 ['-'] 	 ['Not Intrested,Available City Options Shared'] 	 [702]
# 53 	 Warangal 	 ['These are the dealerships closest to you. Please choose your preferred option.\n \n1. \n2. \n3. '] 	 ['-'] 	 ['-'] 	 ['Selected City Captured,Available Dealership Options Shared'] 	 [702]
# 54 	 /initial_message 	 ["👋 Hi, Manikandan!\n \nI'm stella from Jeep Coimbatore Your vehicle number  is due for service on 23 July 2023\n \nWould you like to book an appointment on the same day?"] 	 ['-'] 	 ['-'] 	 ['initial_message'] 	 [702]
# 54 	 yes, i would 	 ['Perfect, Would you like to get your service done from MJ Motors - Coimbatore?'] 	 ['-'] 	 ['-'] 	 ['Service Due Date Accepted,Dealership Pitched'] 	 [702]
# 54 	 No, i wouldnt 	 ['Okay, could you tell us in which city you would prefer to get your vehicle serviced?'] 	 ['-'] 	 ['-'] 	 ['Not Intrested,Available City Options Shared'] 	 [702]
# 54 	 West Delhi 	 ['These are the dealerships closest to you. Please choose your preferred option.\n \n1. Landmark Lifestyle Motinagar - New Delhi\n2. Landmark Lifestyle Okhla - New Delhi\n3. Landmark Lifestyle  - Gurugram'] 	 ['-'] 	 ['-'] 	 ['Selected City Captured,Available Dealership Options Shared'] 	 [702]
# 55 	 /initial_message 	 ["👋 Hi, Manikandan!\n \nI'm stella from Jeep Coimbatore Your vehicle number  is due for service on 23 July 2023\n \nWould you like to book an appointment on the same day?"] 	 ['-'] 	 ['-'] 	 ['initial_message'] 	 [702]
# 55 	 yes, i would 	 ['Perfect, Would you like to get your service done from MJ Motors - Coimbatore?'] 	 ['-'] 	 ['-'] 	 ['Service Due Date Accepted,Dealership Pitched'] 	 [702]
# 55 	 No, i wouldnt 	 ['Okay, could you tell us in which city you would prefer to get your vehicle serviced?'] 	 ['-'] 	 ['-'] 	 ['Not Intrested,Available City Options Shared'] 	 [702]
# 55 	 Jammu Kashmir 	 ['These are the dealerships closest to you. Please choose your preferred option.\n \n1. \n2. \n3. '] 	 ['-'] 	 ['-'] 	 ['Selected City Captured,Available Dealership Options Shared'] 	 [702]
# 56 	 /initial_message 	 ["👋 Hi, Manikandan!\n \nI'm stella from Jeep Coimbatore Your vehicle number  is due for service on 23 July 2023\n \nWould you like to book an appointment on the same day?"] 	 ['-'] 	 ['-'] 	 ['initial_message'] 	 [702]
# 56 	 yes, i would 	 ['Perfect, Would you like to get your service done from MJ Motors - Coimbatore?'] 	 ['-'] 	 ['-'] 	 ['Service Due Date Accepted,Dealership Pitched'] 	 [702]
# 56 	 No, i wouldnt 	 ['Okay, could you tell us in which city you would prefer to get your vehicle serviced?'] 	 ['-'] 	 ['-'] 	 ['Not Intrested,Available City Options Shared'] 	 [702]
# 56 	 Jammu and Kashmir 	 ['These are the dealerships closest to you. Please choose your preferred option.\n \n1. ARG Automobiles - Srinagar\n2. Four A Automobiles Bye pass Road - Jammu\n3. Landmark Lifestyle GT Road - Jalandhar'] 	 ['-'] 	 ['-'] 	 ['Selected City Captured,Available Dealership Options Shared'] 	 [702]
# 57 	 /initial_message 	 ["👋 Hi, Manikandan!\n \nI'm stella from Jeep Coimbatore Your vehicle number  is due for service on 23 July 2023\n \nWould you like to book an appointment on the same day?"] 	 ['-'] 	 ['-'] 	 ['initial_message'] 	 [702]
# ...
# 59 	 yes, i would 	 ['Perfect, Would you like to get your service done from MJ Motors - Coimbatore?'] 	 ['-'] 	 ['-'] 	 ['Service Due Date Accepted,Dealership Pitched'] 	 [702]
# 59 	 No, i wouldnt 	 ['Okay, could you tell us in which city you would prefer to get your vehicle serviced?'] 	 ['-'] 	 ['-'] 	 ['Not Intrested,Available City Options Shared'] 	 [702]
# 59 	 Uttar Pradesh 	 ['These are the dealerships closest to you. Please choose your preferred option.\n \n1. S G Infracars - Lucknow\n2. SG Infracare - Kanpur\n3. Kalyan Automart - Agra'] 	 ['-'] 	 ['-'] 	 ['Selected City Captured,Available Dealership Options Shared'] 	 [702]
# 60 	 /initial_message 	 ["👋 Hi, Manikandan!\n \nI'm stella from Jeep Coimbatore Your vehicle number  is due for service on 23 July 2023\n \nWould you like to book an appointment on the same day?"] 	 ['-'] 	 ['-'] 	 ['initial_message'] 	 [702]
# 60 	 yes, i would 	 ['Perfect, Would you like to get your service done from MJ Motors - Coimbatore?'] 	 ['-'] 	 ['-'] 	 ['Service Due Date Accepted,Dealership Pitched'] 	 [702]
# 60 	 No, i wouldnt 	 ['Okay, could you tell us in which city you would prefer to get your vehicle serviced?'] 	 ['-'] 	 ['-'] 	 ['Not Intrested,Available City Options Shared'] 	 [702]
# 60 	 Gujarat 	 ['These are the dealerships closest to you. Please choose your preferred option.\n \n1. \n2. \n3. '] 	 ['-'] 	 ['-'] 	 ['Selected City Captured,Available Dealership Options Shared'] 	 [702]
# 61 	 /initial_message 	 ["👋 Hi, Manikandan!\n \nI'm stella from Jeep Coimbatore Your vehicle number  is due for service on 23 July 2023\n \nWould you like to book an appointment on the same day?"] 	 ['-'] 	 ['-'] 	 ['initial_message'] 	 [702]
# 61 	 yes, i would 	 ['Perfect, Would you like to get your service done from MJ Motors - Coimbatore?'] 	 ['-'] 	 ['-'] 	 ['Service Due Date Accepted,Dealership Pitched'] 	 [702]
# 61 	 No, i wouldnt 	 ['Okay, could you tell us in which city you would prefer to get your vehicle serviced?'] 	 ['-'] 	 ['-'] 	 ['Not Intrested,Available City Options Shared'] 	 [702]
# 61 	 Karnataka 	 ['These are the dealerships closest to you. Please choose your preferred option.\n \n1. KHTAgencies Yeshwantpur - Bangalore\n2. KHT Agencies Devasandra - Bangalore\n3. MPS Motors Hosur Road - Bangalore'] 	 ['-'] 	 ['-'] 	 ['Selected City Captured,Available Dealership Options Shared'] 	 [702]
# 62 	 /initial_message 	 ["👋 Hi, Manikandan!\n \nI'm stella from Jeep Coimbatore Your vehicle number  is due for service on 23 July 2023\n \nWould you like to book an appointment on the same day?"] 	 ['-'] 	 ['-'] 	 ['initial_message'] 	 [702]
# 62 	 yes, i would 	 ['Perfect, Would you like to get your service done from MJ Motors - Coimbatore?'] 	 ['-'] 	 ['-'] 	 ['Service Due Date Accepted,Dealership Pitched'] 	 [702]
# 62 	 No, i wouldnt 	 ['Okay, could you tell us in which city you would prefer to get your vehicle serviced?'] 	 ['-'] 	 ['-'] 	 ['Not Intrested,Available City Options Shared'] 	 [702]
# 62 	 Madhya Pradesh 	 ['These are the dealerships closest to you. Please choose your preferred option.\n \n1. \n2. \n3. '] 	 ['-'] 	 ['-'] 	 ['Selected City Captured,Available Dealership Options Shared'] 	 [702]
# 63 	 /initial_message 	 ["👋 Hi, Manikandan!\n \nI'm stella from Jeep Coimbatore Your vehicle number  is due for service on 23 July 2023\n \nWould you like to book an appointment on the same day?"] 	 ['-'] 	 ['-'] 	 ['initial_message'] 	 [702]
# 63 	 yes, i would 	 ['Perfect, Would you like to get your service done from MJ Motors - Coimbatore?'] 	 ['-'] 	 ['-'] 	 ['Service Due Date Accepted,Dealership Pitched'] 	 [702]
# 63 	 No, i wouldnt 	 ['Okay, could you tell us in which city you would prefer to get your vehicle serviced?'] 	 ['-'] 	 ['-'] 	 ['Not Intrested,Available City Options Shared'] 	 [702]
# 63 	 odisha 	 ['These are the dealerships closest to you. Please choose your preferred option.\n \n1. Shree Bharat Motors Pahal - Bhubaneshwar\n2. K. P. Automobiles - Ranchi\n3. Celica Automobiles East Topsia Road - Kolkata'] 	 ['-'] 	 ['-'] 	 ['Selected City Captured,Available Dealership Options Shared'] 	 [702]
# 64 	 /initial_message 	 ["👋 Hi, Manikandan!\n \nI'm stella from Jeep Coimbatore Your vehicle number  is due for service on 23 July 2023\n \nWould you like to book an appointment on the same day?"] 	 ['-'] 	 ['-'] 	 ['initial_message'] 	 [702]
# 64 	 yes, i would 	 ['Perfect, Would you like to get your service done from MJ Motors - Coimbatore?'] 	 ['-'] 	 ['-'] 	 ['Service Due Date Accepted,Dealership Pitched'] 	 [702]
# 64 	 No, i wouldnt 	 ['Okay, could you tell us in which city you would prefer to get your vehicle serviced?'] 	 ['-'] 	 ['-'] 	 ['Not Intrested,Available City Options Shared'] 	 [702]
# 64 	 Kerala 	 ['These are the dealerships closest to you. Please choose your preferred option.\n \n1. Deedi Motors NH Bypass - Trivandrum\n2. Hyson Auto M C Road - Kottayam\n3. GMA Pinnacle Thrikkakara P.O, Kakkanad, Ernakulam - Cochin'] 	 ['-'] 	 ['-'] 	 ['Selected City Captured,Available Dealership Options Shared'] 	 [702]
# 65 	 /initial_message 	 ["👋 Hi, Manikandan!\n \nI'm stella from Jeep Coimbatore Your vehicle number  is due for service on 23 July 2023\n \nWould you like to book an appointment on the same day?"] 	 ['-'] 	 ['-'] 	 ['initial_message'] 	 [702]
# 65 	 yes, i would 	 ['Perfect, Would you like to get your service done from MJ Motors - Coimbatore?'] 	 ['-'] 	 ['-'] 	 ['Service Due Date Accepted,Dealership Pitched'] 	 [702]
# 65 	 No, i wouldnt 	 ['Okay, could you tell us in which city you would prefer to get your vehicle serviced?'] 	 ['-'] 	 ['-'] 	 ['Not Intrested,Available City Options Shared'] 	 [702]
# 65 	 Punjab 	 ['These are the dealerships closest to you. Please choose your preferred option.\n \n1. \n2. \n3. '] 	 ['-'] 	 ['-'] 	 ['Selected City Captured,Available Dealership Options Shared'] 	 [702]
# 66 	 /initial_message 	 ["👋 Hi, Manikandan!\n \nI'm stella from Jeep Coimbatore Your vehicle number  is due for service on 23 July 2023\n \nWould you like to book an appointment on the same day?"] 	 ['-'] 	 ['-'] 	 ['initial_message'] 	 [702]
# 66 	 yes, i would 	 ['Perfect, Would you like to get your service done from MJ Motors - Coimbatore?'] 	 ['-'] 	 ['-'] 	 ['Service Due Date Accepted,Dealership Pitched'] 	 [702]
# 66 	 No, i wouldnt 	 ['Okay, could you tell us in which city you would prefer to get your vehicle serviced?'] 	 ['-'] 	 ['-'] 	 ['Not Intrested,Available City Options Shared'] 	 [702]
# 66 	 Tamilnadu 	 ['These are the dealerships closest to you. Please choose your preferred option.\n \n1. VTK Automobiles Kattupakkam - Chennai\n2. VTK Automobiles Sholinganallur - Chennai\n3. The True Sai Motors - Salem'] 	 ['-'] 	 ['-'] 	 ['Selected City Captured,Available Dealership Options Shared'] 	 [702]
# 67 	 /initial_message 	 ["👋 Hi, Manikandan!\n \nI'm stella from Jeep Coimbatore Your vehicle number  is due for service on 23 July 2023\n \nWould you like to book an appointment on the same day?"] 	 ['-'] 	 ['-'] 	 ['initial_message'] 	 [702]
# 67 	 yes, i would 	 ['Perfect, Would you like to get your service done from MJ Motors - Coimbatore?'] 	 ['-'] 	 ['-'] 	 ['Service Due Date Accepted,Dealership Pitched'] 	 [702]
# 67 	 No, i wouldnt 	 ['Okay, could you tell us in which city you would prefer to get your vehicle serviced?'] 	 ['-'] 	 ['-'] 	 ['Not Intrested,Available City Options Shared'] 	 [702]
# 67 	 Uttarakhand 	 ['These are the dealerships closest to you. Please choose your preferred option.\n \n1. LSC Autowheels - Dehradun\n2. Tapan Industries -  Solan\n3. WSL Automobiles - Chandigarh'] 	 ['-'] 	 ['-'] 	 ['Selected City Captured,Available Dealership Options Shared'] 	 [702]
# 68 	 /initial_message 	 ["👋 Hi, Manikandan!\n \nI'm stella from Jeep Coimbatore Your vehicle number  is due for service on 23 July 2023\n \nWould you like to book an appointment on the same day?"] 	 ['-'] 	 ['-'] 	 ['initial_message'] 	 [702]
# 68 	 yes, i would 	 ['Perfect, Would you like to get your service done from MJ Motors - Coimbatore?'] 	 ['-'] 	 ['-'] 	 ['Service Due Date Accepted,Dealership Pitched'] 	 [702]
# 68 	 No, i wouldnt 	 ['Okay, could you tell us in which city you would prefer to get your vehicle serviced?'] 	 ['-'] 	 ['-'] 	 ['Not Intrested,Available City Options Shared'] 	 [702]
# 68 	 Assam 	 ['These are the dealerships closest to you. Please choose your preferred option.\n \n1. \n2. \n3. '] 	 ['-'] 	 ['-'] 	 ['Selected City Captured,Available Dealership Options Shared'] 	 [702]
# 69 	 /initial_message 	 ["👋 Hi, Manikandan!\n \nI'm stella from Jeep Coimbatore Your vehicle number  is due for service on 23 July 2023\n \nWould you like to book an appointment on the same day?"] 	 ['-'] 	 ['-'] 	 ['initial_message'] 	 [702]
# 69 	 yes, i would 	 ['Perfect, Would you like to get your service done from MJ Motors - Coimbatore?'] 	 ['-'] 	 ['-'] 	 ['Service Due Date Accepted,Dealership Pitched'] 	 [702]
# 69 	 No, i wouldnt 	 ['Okay, could you tell us in which city you would prefer to get your vehicle serviced?'] 	 ['-'] 	 ['-'] 	 ['Not Intrested,Available City Options Shared'] 	 [702]
# 69 	 Andhra Pradesh 	 ['These are the dealerships closest to you. Please choose your preferred option.\n \n1. Sree Krishna Automotives Nagole - Hyderabad\n2. VSN Commercials Balanagar - Hyderabad\n3. Sree Krishna Automotives Madinaguda - Hyderabad'] 	 ['-'] 	 ['-'] 	 ['Selected City Captured,Available Dealership Options Shared'] 	 [702]
# 70 	 /initial_message 	 ["👋 Hi, Manikandan!\n \nI'm stella from Jeep Coimbatore Your vehicle number  is due for service on 23 July 2023\n \nWould you like to book an appointment on the same day?"] 	 ['-'] 	 ['-'] 	 ['initial_message'] 	 [702]
# 70 	 yes, i would 	 ['Perfect, Would you like to get your service done from MJ Motors - Coimbatore?'] 	 ['-'] 	 ['-'] 	 ['Service Due Date Accepted,Dealership Pitched'] 	 [702]
# 70 	 No, i wouldnt 	 ['Okay, could you tell us in which city you would prefer to get your vehicle serviced?'] 	 ['-'] 	 ['-'] 	 ['Not Intrested,Available City Options Shared'] 	 [702]
# 70 	 Telangana 	 ['These are the dealerships closest to you. Please choose your preferred option.\n \n1. Sree Krishna Automotives Nagole - Hyderabad\n2. VSN Commercials Balanagar - Hyderabad\n3. Sree Krishna Automotives Madinaguda - Hyderabad'] 	 ['-'] 	 ['-'] 	 ['Selected City Captured,Available Dealership Options Shared'] 	 [702]
# 71 	 /initial_message 	 ["👋 Hi, Manikandan!\n \nI'm stella from Jeep Coimbatore Your vehicle number  is due for service on 23 July 2023\n \nWould you like to book an appointment on the same day?"] 	 ['-'] 	 ['-'] 	 ['initial_message'] 	 [702]
# 71 	 yes, i would 	 ['Perfect, Would you like to get your service done from MJ Motors - Coimbatore?'] 	 ['-'] 	 ['-'] 	 ['Service Due Date Accepted,Dealership Pitched'] 	 [702]
# 71 	 No, i wouldnt 	 ['Okay, could you tell us in which city you would prefer to get your vehicle serviced?'] 	 ['-'] 	 ['-'] 	 ['Not Intrested,Available City Options Shared'] 	 [702]
# 71 	 Manipur 	 ['Which city would you prefer to have your vehicle serviced in?'] 	 ['-'] 	 ['-'] 	 ['Out of Context,Available City Options Shared'] 	 [702]
# 72 	 /initial_message 	 ["👋 Hi, Manikandan!\n \nI'm stella from Jeep Coimbatore Your vehicle number  is due for service on 23 July 2023\n \nWould you like to book an appointment on the same day?"] 	 ['-'] 	 ['-'] 	 ['initial_message'] 	 [702]
# 72 	 yes, i would 	 ['Perfect, Would you like to get your service done from MJ Motors - Coimbatore?'] 	 ['-'] 	 ['-'] 	 ['Service Due Date Accepted,Dealership Pitched'] 	 [702]
# 72 	 No, i wouldnt 	 ['Okay, could you tell us in which city you would prefer to get your vehicle serviced?'] 	 ['-'] 	 ['-'] 	 ['Not Intrested,Available City Options Shared'] 	 [702]
# 72 	 Rajasthan 	 ['Which city would you prefer to have your vehicle serviced in?'] 	 ['-'] 	 ['-'] 	 ['Out of Context,Available City Options Shared'] 	 [702]
# 73 	 /initial_message 	 ["👋 Hi, Manikandan!\n \nI'm stella from Jeep Coimbatore Your vehicle number  is due for service on 23 July 2023\n \nWould you like to book an appointment on the same day?"] 	 ['-'] 	 ['-'] 	 ['initial_message'] 	 [702]
# 73 	 yes, i would 	 ['Perfect, Would you like to get your service done from MJ Motors - Coimbatore?'] 	 ['-'] 	 ['-'] 	 ['Service Due Date Accepted,Dealership Pitched'] 	 [702]
# 73 	 No, i wouldnt 	 ['Okay, could you tell us in which city you would prefer to get your vehicle serviced?'] 	 ['-'] 	 ['-'] 	 ['Not Intrested,Available City Options Shared'] 	 [702]
# 73 	 Maharashtra 	 ['Which city would you prefer to have your vehicle serviced in?'] 	 ['-'] 	 ['-'] 	 ['Out of Context,Available City Options Shared'] 	 [702]
# 74 	 /initial_message 	 ["👋 Hi, Manikandan!\n \nI'm stella from Jeep Coimbatore Your vehicle number  is due for service on 23 July 2023\n \nWould you like to book an appointment on the same day?"] 	 ['-'] 	 ['-'] 	 ['initial_message'] 	 [702]
# 74 	 yes, i would 	 ['Perfect, Would you like to get your service done from MJ Motors - Coimbatore?'] 	 ['-'] 	 ['-'] 	 ['Service Due Date Accepted,Dealership Pitched'] 	 [702]
# 74 	 No, i wouldnt 	 ['Okay, could you tell us in which city you would prefer to get your vehicle serviced?'] 	 ['-'] 	 ['-'] 	 ['Not Intrested,Available City Options Shared'] 	 [702]
# 74 	 West Bengal 	 ['Which city would you prefer to have your vehicle serviced in?'] 	 ['-'] 	 ['-'] 	 ['Out of Context,Available City Options Shared'] 	 [702]
# 75 	 /initial_message 	 ["👋 Hi, Manikandan!\n \nI'm stella from Jeep Coimbatore Your vehicle number  is due for service on 23 July 2023\n \nWould you like to book an appointment on the same day?"] 	 ['-'] 	 ['-'] 	 ['initial_message'] 	 [702]
# 75 	 yes, i would 	 ['Perfect, Would you like to get your service done from MJ Motors - Coimbatore?'] 	 ['-'] 	 ['-'] 	 ['Service Due Date Accepted,Dealership Pitched'] 	 [702]
# 75 	 No, i wouldnt 	 ['Okay, could you tell us in which city you would prefer to get your vehicle serviced?'] 	 ['-'] 	 ['-'] 	 ['Not Intrested,Available City Options Shared'] 	 [702]
# 75 	 Jharkhand 	 ['Which city would you prefer to have your vehicle serviced in?'] 	 ['-'] 	 ['-'] 	 ['Out of Context,Available City Options Shared'] 	 [702]
# 76 	 /initial_message 	 ["👋 Hi, Manikandan!\n \nI'm stella from Jeep Coimbatore Your vehicle number  is due for service on 23 July 2023\n \nWould you like to book an appointment on the same day?"] 	 ['-'] 	 ['-'] 	 ['initial_message'] 	 [702]
# 76 	 yes, i would 	 ['Perfect, Would you like to get your service done from MJ Motors - Coimbatore?'] 	 ['-'] 	 ['-'] 	 ['Service Due Date Accepted,Dealership Pitched'] 	 [702]
# 76 	 No, i wouldnt 	 ['Okay, could you tell us in which city you would prefer to get your vehicle serviced?'] 	 ['-'] 	 ['-'] 	 ['Not Intrested,Available City Options Shared'] 	 [702]
# 76 	 Himachal Pradesh 	 ["Sorry, I didn't get you. Could you repeat?"] 	 ['Which city would you prefer to have your vehicle serviced in?'] 	 ['-'] 	 ['Not understood,Available City Options Shared'] 	 [702]
# 77 	 /initial_message 	 ["👋 Hi, Manikandan!\n \nI'm stella from Jeep Coimbatore Your vehicle number  is due for service on 23 July 2023\n \nWould you like to book an appointment on the same day?"] 	 ['-'] 	 ['-'] 	 ['initial_message'] 	 [702]
# 77 	 yes, i would 	 ['Perfect, Would you like to get your service done from MJ Motors - Coimbatore?'] 	 ['-'] 	 ['-'] 	 ['Service Due Date Accepted,Dealership Pitched'] 	 [702]
# 77 	 No, i wouldnt 	 ['Okay, could you tell us in which city you would prefer to get your vehicle serviced?'] 	 ['-'] 	 ['-'] 	 ['Not Intrested,Available City Options Shared'] 	 [702]
# 77 	 Jammu & Kashmir 	 ['These are the dealerships closest to you. Please choose your preferred option.\n \n1. \n2. \n3. '] 	 ['-'] 	 ['-'] 	 ['Selected City Captured,Available Dealership Options Shared'] 	 [702]
# Testcases completed, --- Run next block

# %%
df2 = pd.DataFrame()

df2["TestCase_No"] = final_Tno
df2["Utterance"] = final_user_resp

df2["Bot_Response_1"] = final_response_1
df2["Bot_Response_2"] = final_response_2
df2["Bot_Response_3"] = final_response_3
df2["Disposition"] = final_disposition
df2["Status_Code"] = final_status

# df3 = pd.concat([df,df2], axis=1, join='inner')

# df3.to_csv(Final_Sheet, index=False)

df2.to_csv(Final_Sheet, index=False)


print('\n','\n','\n')
print ("required data is downloaded as a CSV in path = .......",Final_Sheet)
print('\n','\n','\n')


#df3.head(5)
# Out:
#
#
#
# required data is downloaded as a CSV in path = ....... /Users/vinay_kl/Downloads/Final_Sheet_Stellantis_English_['12:04:08'].csv

# %%
print(len(final_Tno))
print(len(final_user_resp))
print(len(final_response_1))
print(len(final_response_2))
print(len(final_response_3))
print(len(final_disposition))
print(len(final_status))

# print(final_response_3)
# print(final_response_3)
# Out:
# 308
# 308
# 308
# 308
# 308
# 308
# 308

# %% [markdown]
# # Rough

# %%
headers = {'Content-Type':'application/json'}    
payload = json.dumps ({
    "user_id" : "9482152445",
    "request_id" : "request11j27",
    "sender" : "tej-24765798u89",
    "message" :  "/initial_message",

    "customerData" : {
        "callId": "12345",
        "bargingCall": "True",
        "accessToken": "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VySWQiOiI2NDUwYjkyN2YzZGZlYzMyMDIxNDgxMzciLCJhY2NvdW50SWQiOiI2NDUwYjkyNmYzZGZlYzMyMDIxNDgxMmUiLCJyb2xlIjoiQWRtaW4iLCJpYXQiOjE2ODM1NDM5NDAsImV4cCI6MTY4MzYzMDM0MH0.slLTPbIA92IDfsZUJKR0rxFnVgDi7M5mtDLaWDmlJsc",
        "clientName": "Stellantis Testing",
        "callType": "Internal UAT",
        "telephonyName": "Epicode",
        "customerInfo": {
            "contactInfo": {
                "primary": "9354069780",
                "customerSupportNumber": "4233423434",
                "customerCareNumber": ""
            },
            "primaryInfo": {
                "firstName": "tester",
                "vehicleIdentificationNumber": "KA 12 AD 2790",
                "sellingDealerName": "Saarthi motors - Banglore",
                "geographicLocation": "",
                "pincode": "",
                "lastServiceDealerCity": "Banglore",
                "lastServiceDealerName": "Saarthi motors",
                "preferredAgentGender": "F",
                "agentname": "Stella",
                "serviceDueDate":"2023-06-18",
                "captured_date":"2023-06-12",
                "serviceNetworkName": "dsfsfsdf",
                "flow": "follow_up_flow",
                "status": "Appointment Confirmed",
                "channel": "Voice",
                "utter_sub_flow_slot": "main_flow",
                "generalRepeatThreshold": "3",
                "businessIntentThreshold": "3",
                "previousDisposition": "Campaign End",
                "language": "Hindi",
                "age": "",
                "gender": "",
                "region": "",
                "collared": "",
                "customerUniqueId": ""
            },
            "loanAccountDetails": {
                "emiAmount": "",
                "emiDueDate": "",
                "loanApplicationDate": "",
                "loanEndingDate": "",
                "lateFee": "",
                "interestRate": "",
                "nextNachDate": "",
                "paidDate": "",
                "currentPaymentStatus": "",
                "noofemi": "",
                "noOfEmiPaid": "",
                "loanTenureLeft": "",
                "loanAmountRemaining": "",
                "loanStartDate": "",
                "principalAmount": "",
                "totalLoanAmount": "",
                "loanCategory": "",
                "loanId": "",
                "noOfLoans": "",
                "paymentMode": "",
                "cbCharges": "0",
                "penalCharges": "0"
            },
            "behaviourDetails": {
                "riskType": "",
                "typology": "",
                "callDisposition": ""
            },
            "email": {
                "primary": ""
            },
            "leadType": "Transactional"
        },
        "callingPartner": "epicode",
        "campaignId": "2345",
        "agentConfig": {
            "parentFlow": [
                {
                    "flow": "appointment_booking_flow",
                    "isParent": True,
                    "isChild": False,
                    "channel": [
                        "Call"
                    ],
                    "type": "Female",
                    "language": [
                        "English","Hindi"
                    ],
                    "Call": {
                        "voice": "Saarthi TTS",
                        "thresholdDateCallBack": 2,
                        "thresholdTimeCallBack": 30
                    }
                }
            ],
            "callFlow": [
                {
                    "appointment_booking_flow": {
                        "slot1": [
                            {
                                "initial": {
                                    "label": "lg_rpc_form",
                                    "next": "subSlot1"
                                },
                                "subSlot1": [
                                    {
                                        "third_party_contact": {
                                            "initial": [
                                                {
                                                    "label": "third_party_contact_form",
                                                    "next": "subSlot1"
                                                }
                                            ],
                                            "subSlot1": [
                                                {
                                                    "label": "stop_conversation"
                                                }
                                            ]
                                        },
                                        "call_back": {
                                            "initial": [
                                                {
                                                    "label": "call_back_form",
                                                    "next": "subSlot1"
                                                }
                                            ],
                                            "subSlot1": [
                                                {
                                                    "label": "stop_conversation"
                                                }
                                            ]
                                        },
                                        "small_talk": {
                                            "initial": [
                                                {
                                                    "label": "small_talk_form",
                                                    "next": "subSlot1"
                                                }
                                            ],
                                            "subSlot1": [
                                                {
                                                    "label": "stop_conversation"
                                                }
                                            ]
                                        }
                                    }
                                ]
                            }
                        ],
                        "slot2": [
                            {
                                "label": "date_confirmation_form",
                                "next": "slot3"
                            }
                        ],
                        "slot3": [
                            {
                                "not_interested": {
                                    "initial": [
                                        {
                                            "label": "not_interested_form",
                                            "next": "subSlot1"
                                        }
                                    ],
                                    "subSlot1": [
                                        {
                                            "label": "stop_conversation"
                                        }
                                    ]
                                },
                                "interested_later": {
                                    "initial": [
                                        {
                                            "label": "interested_later_form",
                                            "next": "subSlot1"
                                        }
                                    ],
                                    "subSlot1": [
                                        {
                                            "label": "stop_conversation"
                                        }
                                    ]
                                },
                                "call_back": {
                                    "initial": [
                                        {
                                            "label": "call_back_form",
                                            "next": "subSlot1"
                                        }
                                    ],
                                    "subSlot1": [
                                        {
                                            "label": "stop_conversation"
                                        }
                                    ]
                                },
                                "date_capture": {
                                    "initial": [
                                        {
                                            "label": "date_capture_form",
                                            "next": "subSlot1"
                                        }
                                    ],
                                    "subSlot1": [
                                        {
                                            "dealership_capture": {
                                                "initial": [
                                                    {
                                                        "label": "dealership_capture_form",
                                                        "next": "sub1Slot1"
                                                    }
                                                ],
                                                "sub1Slot1": [
                                                    {
                                                        "deny": {
                                                            "initial": [
                                                                {
                                                                    "label": "deny_dealership_form",
                                                                    "next": "sub2Slot1"
                                                                }
                                                            ],
                                                            "sub2Slot1": [
                                                                {
                                                                    "label": "stop_conversation"
                                                                }
                                                            ]
                                                        },
                                                        "affirm": {
                                                            "initial": [
                                                                {
                                                                    "label": "pickup_drop_capture_form",
                                                                    "next": "sub2Slot1"
                                                                }
                                                            ],
                                                            "sub2Slot1": [
                                                                {
                                                                    "label": "stop_conversation"
                                                                }
                                                            ]
                                                        }
                                                    }
                                                ]
                                            }
                                        }
                                    ]
                                },
                                "dealership_capture": {
                                    "initial": [
                                        {
                                            "label": "dealership_capture_form",
                                            "next": "sub1Slot1"
                                        }
                                    ],
                                    "sub1Slot1": [
                                        {
                                            "deny": {
                                                "initial": [
                                                    {
                                                        "label": "deny_dealership_form",
                                                        "next": "sub2Slot1"
                                                    }
                                                ],
                                                "sub2Slot1": [
                                                    {
                                                        "label": "stop_conversation"
                                                    }
                                                ]
                                            },
                                            "affirm": {
                                                "initial": [
                                                    {
                                                        "label": "pickup_drop_capture_form",
                                                        "next": "sub2Slot1"
                                                    }
                                                ],
                                                "sub2Slot1": [
                                                    {
                                                        "label": "stop_conversation"
                                                    }
                                                ]
                                            }
                                        }
                                    ]
                                }
                            }
                        ]
                    },
                    "follow_up_flow": {
                        "slot1": [
                            {
                                "initial": {
                                    "label": "lg_rpc_form",
                                    "next": "subSlot1"
                                },
                                "subSlot1": [
                                    {
                                        "third_party_contact": {
                                            "initial": [
                                                {
                                                    "label": "third_party_contact_form",
                                                    "next": "subSlot1"
                                                }
                                            ],
                                            "subSlot1": [
                                                {
                                                    "label": "stop_conversation"
                                                }
                                            ]
                                        },
                                        "call_back": {
                                            "initial": [
                                                {
                                                    "label": "call_back_form",
                                                    "next": "subSlot1"
                                                }
                                            ],
                                            "subSlot1": [
                                                {
                                                    "label": "stop_conversation"
                                                }
                                            ]
                                        },
                                        "small_talk": {
                                            "initial": [
                                                {
                                                    "label": "small_talk_form",
                                                    "next": "subSlot1"
                                                }
                                            ],
                                            "subSlot1": [
                                                {
                                                    "label": "stop_conversation"
                                                }
                                            ]
                                        }
                                    }
                                ]
                            }
                        ],
                        "slot2": [
                            {
                                "label": "followup_dealership_capture_form",
                                "next": "slot3"
                            }
                        ],
                        "slot3": [
                            {
                                "not_interested": {
                                    "initial": [
                                        {
                                            "label": "not_interested_form",
                                            "next": "subSlot1"
                                        }
                                    ],
                                    "subSlot1": [
                                        {
                                            "label": "stop_conversation"
                                        }
                                    ]
                                },
                                "interested_later": {
                                    "initial": [
                                        {
                                            "label": "interested_later_form",
                                            "next": "subSlot1"
                                        }
                                    ],
                                    "subSlot1": [
                                        {
                                            "label": "stop_conversation"
                                        }
                                    ]
                                },
                                "call_back": {
                                    "initial": [
                                        {
                                            "label": "call_back_form",
                                            "next": "subSlot1"
                                        }
                                    ],
                                    "subSlot1": [
                                        {
                                            "label": "stop_conversation"
                                        }
                                    ]
                                },
                                "new_date_capture": {
                                    "initial": [
                                        {
                                            "label": "date_capture_form",
                                            "next": "subSlot1"
                                        }
                                    ],
                                    "subSlot1": [
                                        {
                                            "dealership_capture": {
                                                "initial": [
                                                    {
                                                        "label": "dealership_capture_form",
                                                        "next": "sub1Slot1"
                                                    }
                                                ],
                                                "sub1Slot1": [
                                                    {
                                                        "deny": {
                                                            "initial": [
                                                                {
                                                                    "label": "deny_dealership_form",
                                                                    "next": "sub2Slot1"
                                                                }
                                                            ],
                                                            "sub2Slot1": [
                                                                {
                                                                    "label": "stop_conversation"
                                                                }
                                                            ]
                                                        },
                                                        "affirm": {
                                                            "initial": [
                                                                {
                                                                    "label": "pickup_drop_capture_form",
                                                                    "next": "sub2Slot1"
                                                                }
                                                            ],
                                                            "sub2Slot1": [
                                                                {
                                                                    "label": "stop_conversation"
                                                                }
                                                            ]
                                                        }
                                                    }
                                                ]
                                            }
                                        }
                                    ]
                                },
                                "deny_dealership": {
                                    "initial": [
                                        {
                                            "label": "deny_dealership_form",
                                            "next": "sub2Slot1"
                                        }
                                    ],
                                    "sub2Slot1": [
                                        {
                                            "label": "stop_conversation"
                                        }
                                    ]
                                },
                                "pickup_drop_capture": {
                                    "initial": [
                                        {
                                            "label": "pickup_drop_capture_form",
                                            "next": "sub2Slot1"
                                        }
                                    ],
                                    "sub2Slot1": [
                                        {
                                            "label": "stop_conversation"
                                        }
                                    ]
                                }
                            }
                        ]
                    },
                    "remainder_flow": {
                        "slot1": [
                            {
                                "initial": {
                                    "label": "lg_rpc_form",
                                    "next": "subSlot1"
                                },
                                "subSlot1": [
                                    {
                                        "third_party_contact": {
                                            "initial": [
                                                {
                                                    "label": "third_party_contact_form",
                                                    "next": "subSlot1"
                                                }
                                            ],
                                            "subSlot1": [
                                                {
                                                    "label": "stop_conversation"
                                                }
                                            ]
                                        },
                                        "call_back": {
                                            "initial": [
                                                {
                                                    "label": "call_back_form",
                                                    "next": "subSlot1"
                                                }
                                            ],
                                            "subSlot1": [
                                                {
                                                    "label": "stop_conversation"
                                                }
                                            ]
                                        },
                                        "small_talk": {
                                            "initial": [
                                                {
                                                    "label": "small_talk_form",
                                                    "next": "subSlot1"
                                                }
                                            ],
                                            "subSlot1": [
                                                {
                                                    "label": "stop_conversation"
                                                }
                                            ]
                                        }
                                    }
                                ]
                            }
                        ],
                        "slot2": [
                            {
                                "label": "booking_confirmation_form",
                                "next": "slot3"
                            }
                        ],
                        "slot3": [
                            {
                                "interested_later": {
                                    "initial": [
                                        {
                                            "label": "interested_later_form",
                                            "next": "subSlot1"
                                        }
                                    ],
                                    "subSlot1": [
                                        {
                                            "label": "stop_conversation"
                                        }
                                    ]
                                },
                                "call_back": {
                                    "initial": [
                                        {
                                            "label": "call_back_form",
                                            "next": "subSlot1"
                                        }
                                    ],
                                    "subSlot1": [
                                        {
                                            "label": "stop_conversation"
                                        }
                                    ]
                                }
                            }
                        ]
                    },
                    "feedback_flow": {
                        "slot1": [
                            {
                                "initial": {
                                    "label": "lg_rpc_form",
                                    "next": "subSlot1"
                                },
                                "subSlot1": [
                                    {
                                        "third_party_contact": {
                                            "initial": [
                                                {
                                                    "label": "third_party_contact_form",
                                                    "next": "subSlot1"
                                                }
                                            ],
                                            "subSlot1": [
                                                {
                                                    "label": "stop_conversation"
                                                }
                                            ]
                                        },
                                        "call_back": {
                                            "initial": [
                                                {
                                                    "label": "call_back_form",
                                                    "next": "subSlot1"
                                                }
                                            ],
                                            "subSlot1": [
                                                {
                                                    "label": "stop_conversation"
                                                }
                                            ]
                                        },
                                        "small_talk": {
                                            "initial": [
                                                {
                                                    "label": "small_talk_form",
                                                    "next": "subSlot1"
                                                }
                                            ],
                                            "subSlot1": [
                                                {
                                                    "label": "stop_conversation"
                                                }
                                            ]
                                        }
                                    }
                                ]
                            }
                        ],
                        "slot2": [
                            {
                                "label": "rating_based_form",
                                "next": "slot3"
                            }
                        ],
                        "slot3": [
                            {
                                "call_back": {
                                    "initial": [
                                        {
                                            "label": "call_back_form",
                                            "next": "subSlot1"
                                        }
                                    ],
                                    "subSlot1": [
                                        {
                                            "label": "stop_conversation"
                                        }
                                    ]
                                }
                            }
                        ]
                    }
                }
            ],
            "accountId": "6450b926f3dfec320214812e",
            "agentName": "Stella",
            "domain": "Automobile",
            "subDomain": "General",
            "productType": "Four Wheeler",
            "agentId": "StellantisTesting_salesOnboarding_FourWheeler_12",
            "createdAt": "2023-05-05T06:11:54.021Z",
            "updatedAt": "2023-05-05T06:11:54.021Z",
            "id": "64549e2ac0e8415d50370c7c"
        },
        "useCaseId": "62c81c4a4a0affe91342aaaa",
        "accountId": "6450b926f3dfec320214812e",
        "isCampaignTesting": True
    }
    
    }
)


response = requests.request("POST", botEndPoint, headers=headers, data=payload).json()

# pprint(response)




#-------------------------#

text_list = []
response_1 = ["-"]
response_2 = ["-"]
response_3 = ["-"]
disposotion_list = []
staus_list = []

temp_status = response["custom"]["status"]
temp_disp = response["custom"]["disposition_id"]
temp_disp = ",".join(map(str, temp_disp))     #its like a text combining method with given delimeter.  map & str is added to reduce "sequence no N" error

val = response["data"]
for i in range(0,len(val)):    
      temp_text = response["data"][i]["text"]
      text_list.append(temp_text)

for i in range(0,len(text_list)):
    if i == 0:
        response_1 = [text_list[i]]
    if i == 1:
        response_2 = [text_list[i]]
    if i == 2:
        response_3 = [text_list[i]]

# return response_1,response_2,response_3, [temp_disp], [temp_status]



print(response_1,response_2,response_3, [temp_disp], [temp_status])
# Out:
# [' 👋🏼 नमस्ते tester !\n\nमेरा नाम stella है और मैं Jeep - Banglore से हूँ।\n\nहमने कॉल पर आपके व्हीकल KA 12 AD 2790 की सर्विस 12 June के लिए बुक करी थी\n\nहमें बस आपसे थोड़ी और जानकारी चाहिए। क्या आप Saarthi motors से सर्विस करवाना चाहेंगे?'] ['-'] ['-'] [''] [702]

# %%
pprint(response["data"][0]["template_name"])

pprint(response["data"][0]["text"])

pprint(response["custom"]["disposition_id"])

pprint(response["custom"]["status"])
# Out:
# 'utter_RPC_initial_message_stellantis_AB_appointment_booking_flow_FW_G_F'
# "Hi, I'm kumar , calling from Jeep sdfsdfsdf . Am I talking to ram ??"
# ['initial_message']
# 702

# %%
text_list = []
response_1 = ["-"]
response_2 = ["-"]
#response_3 = ["-"]
disposotion_list = []
staus_list = []

temp_status = response["custom"]["status"]
temp_disp = response["custom"]["disposition_id"]
temp_disp = ",".join(map(str, temp_disp))     #its like a text combining method with given delimeter.  map & str is added to reduce "sequence no N" error

val = response["data"]
for i in range(0,len(val)):    
      temp_text = response["data"][i]["text"]
      text_list.append(temp_text)

for i in range(0,len(text_list)):
    if i == 0:
        response_1 = [text_list[i]]
    if i == 1:
        response_2 = [text_list[i]]

# %%
print(response_2)
# Out:
# ['-']

# %%
headers = {'Content-Type':'application/json'}    
payload = json.dumps ({
"user_id": "9482152445",
"request_id": "request11127",
"sender": "te3selkulyuhhjjb",
"message": "/initial_message",

"customerData": {
     "customerInfo": {
                "others": {},
                "primaryInfo": {
                    "age": "",
                    "gender": "",
                    "geographicLocation": "Bangalore",
                    "region": "",
                    "collared": "",
                    "flow": "appointment_booking_flow",
                    "language": "English",
                    "firstName": "Manikandan",
                    "clientName": "",
                    "agentName": "Stella",
                    "customerUniqueId": "",
                    "vehicleIdentificationNumber": "KA52MC1507",
                    "sellingDealerName": "MJ Motors - Coimbatore",
                    "pincode": "637102",
                    "lastServiceDealerCity": "Coimbatore",
                    "lastServiceDealerName": "MJ Motors - Coimbatore",
                    "preferredAgentGender": "F",
                    "serviceNetworkName": "Jeep Aftersales Network",
                    "channel": "Voice",
                    "generalRepeatThreshold": "2",
                    "businessIntentThreshold": "2",
                    "previousDisposition": "Bot Call Back",
                    "status": "",
                    "utter_sub_flow_slot": "",
                    "serviceDueDate": "2023-07-23",
                    "captured_date": ""
                },
                "contactInfo": {
                    "primary": "7989476228",
                    "customerSupportNumber": "18002665337"
                },
                "loanAccountDetails": {
                    "emiAmount": "",
                    "emiDueDate": "",
                    "loanId": "",
                    "noOfLoans": "",
                    "totalLoanAmount": "",
                    "interestRate": "",
                    "principalAmount": "",
                    "lateFee": "",
                    "loanApplicationDate": "",
                    "loanEndingDate": "",
                    "loanAmountRemaining": "",
                    "loanTenureLeft": "",
                    "noofemi": "",
                    "noOfLoanTaken": "",
                    "noOfEmiPaid": ""
                },
                "behaviourDetails": {
                    "typology": "",
                    "riskType": "",
                    "callDisposition": ""
                },
                "address": {
                    "dealerAddressList": [
                        {
                            "dealerName": "Kalyan Automart Private Limited - Agra",
                            "msgFormatDealer": "Kalyan Automart - Agra",
                            "dealerCode": "0700024-3S",
                            "remarks": "Operational",
                            "address": "Near Mango Hotel, Opp Bhagwati Dhaba Sikandra, Bye Pass Road, Agra - 282007.",
                            "lat": 27.22088533,
                            "long": 77.93028885,
                            "name": "Agra",
                            "state": "Uttar Pradesh",
                            "pincode": 282007,
                            "contactNumber": 9837040814
                        },
                        {
                            "dealerName": "Landmark Lifestyle Cars Pvt Ltd(South Delhi)- Okhla - New Delhi",
                            "msgFormatDealer": "Landmark Lifestyle Okhla - New Delhi",
                            "dealerCode": "0700004-2S",
                            "remarks": "Operational",
                            "address": "B-238, Phase-1, Okhla, New Delhi-110020.",
                            "lat": 28.55448,
                            "long": 77.267662,
                            "name": "South Delhi",
                            "state": "NCR",
                            "pincode": 110020,
                            "contactNumber": 9711191575
                        },
                        {
                            "dealerName": "Landmark Lifestyle Cars Pvt Ltd - Gurugram",
                            "msgFormatDealer": "Landmark Lifestyle  - Gurugram",
                            "dealerCode": "0700016-2S",
                            "remarks": "Operational",
                            "address": "Plot No-10, Sector 34, Gurugram.",
                            "lat": 28.432393,
                            "long": 77.0108403,
                            "name": "Gurugram",
                            "state": "NCR",
                            "pincode": "",
                            "contactNumber": 9999384277
                        }
                    ],
                    "cityCapture": "Agra"
                },
                "email": {
                    "primary": ""
                }
            },
            "agentConfig": {
                "parentFlow": [
                    {
                        "flow": "main_flow",
                        "isParent": True,
                        "isChild": False,
                        "channel": [
                            "Whatsapp"
                        ],
                        "type": "Female",
                        "language": [
                            "English"
                        ],
                        "Whatsapp": {
                            "slotReminder": [
                                {
                                    "slot0": 120,
                                    "slot1": 300
                                }
                            ]
                        }
                    },
                    {
                        "flow": "follow_up",
                        "isParent": True,
                        "isChild": False,
                        "channel": [
                            "Whatsapp"
                        ],
                        "type": "Female",
                        "language": [
                            "English"
                        ],
                        "Whatsapp": {
                            "slotReminder": [
                                {
                                    "slot0": 120,
                                    "slot1": 300
                                }
                            ]
                        }
                    },
                    {
                        "flow": "reminder_flow",
                        "isParent": True,
                        "isChild": False,
                        "channel": [
                            "Whatsapp"
                        ],
                        "type": "Female",
                        "language": [
                            "English"
                        ],
                        "Whatsapp": {
                            "slotReminder": [
                                {
                                    "slot0": 120,
                                    "slot1": 300
                                }
                            ]
                        }
                    },
                    {
                        "flow": "feedback_flow",
                        "isParent": True,
                        "isChild": False,
                        "channel": [
                            "Whatsapp"
                        ],
                        "type": "Female",
                        "language": [
                            "English"
                        ],
                        "Whatsapp": {
                            "slotReminder": [
                                {
                                    "slot0": 120,
                                    "slot1": 300
                                }
                            ]
                        }
                    },
                    {
                        "flow": "location_flow",
                        "isParent": True,
                        "isChild": False,
                        "channel": [
                            "Whatsapp"
                        ],
                        "type": "Female",
                        "language": [
                            "English"
                        ],
                        "Whatsapp": {
                            "slotReminder": [
                                {
                                    "slot0": 120,
                                    "slot1": 300
                                }
                            ]
                        }
                    }
                ],
                "callFlow": {
                    "main_flow": {
                        "initial_message": {
                            "initial_message": "lg_rpc_form"
                        },
                        "lg_rpc_form": {
                            "deny": "date_capture_form",
                            "dealership_capture": "dealership_capture_form",
                            "not_interested": "not_interested_form"
                        },
                        "date_capture_form": {
                            "dealership_capture": "dealership_capture_form",
                            "not_interested": "not_interested_form"
                        },
                        "dealership_capture_form": {
                            "deny_dealership": "deny_dealership_flow_form",
                            "pickup_drop_capture": "pickup_drop_capture_form",
                            "not_interested": "not_interested_form"
                        },
                        "deny_dealership_flow_form": {
                            "pickup_drop_capture": "pickup_drop_capture_form",
                            "not_interested": "not_interested_form"
                        },
                        "pickup_drop_capture_form": {
                            "not_interested": "not_interested_form",
                            "deny": "stop_conversation_form"
                        },
                        "not_interested_form": {
                            "deny": "stop_conversation_form"
                        }
                    },
                    "follow_up": {
                        "spm_followup_form": {
                            "deny_dealership": "deny_dealership_flow_form",
                            "pickup_drop_capture": "pickup_drop_capture_form"
                        },
                        "deny_dealership_flow_form": {
                            "pickup_drop_capture": "pickup_drop_capture_form"
                        },
                        "pickup_drop_capture_form": {
                            "deny": "stop_conversation_form"
                        }
                    },
                    "reminder_flow": {
                        "spm_reminder_form": {
                            "deny": "date_capture_form"
                        },
                        "date_capture_form": {
                            "deny": "stop_conversation_form"
                        }
                    },
                    "feedback_flow": {
                        "spm_feedback_form": {
                            "deny": "stop_conversation_form"
                        }
                    },
                    "location_flow": {
                        "location_form": {
                            "pickup_drop_capture": "pickup_drop_capture_form"
                        },
                        "pickup_drop_capture_form": {
                            "deny": "stop_conversation_form"
                        }
                    }
                },
                "whatsappFlow": [],
                "accountId": "6450b926f3dfec320214812e",
                "agentName": "Stella",
                "domain": "Automobile",
                "subDomain": "General",
                "productType": "Four Wheeler",
                "agentId": "StellantisTesting_salesOnboarding_FourWheeler_12",
                "createdAt": "2023-06-08T17:25:08.410Z",
                "updatedAt": "2023-06-08T17:25:08.410Z",
                "id": "64820ef4a496607073a7c3a1"
            }
    }
    }
   )
#     response = requests.request("POST", botEndPoint, headers=headers, data=payload).json()
response = requests.request("POST", botEndPoint, headers=headers, data=payload).json()

#     return(response)



# def final_data(response):
text_list = []
response_1 = ["-"]
response_2 = ["-"]
response_3 = ["-"]
disposotion_list = []
staus_list = []

temp_status = response["custom"]["status"]
temp_disp = response["custom"]["disposition_id"]
temp_disp = ",".join(map(str, temp_disp))     #its like a text combining method with given delimeter.  map & str is added to reduce "sequence no N" error

val = response["data"]
for i in range(0,len(val)):    
      temp_text = response["data"][i]["text"]
      text_list.append(temp_text)

for i in range(0,len(text_list)):
    if i == 0:
        response_1 = [text_list[i]]
    if i == 1:
        response_2 = [text_list[i]]
    if i == 2:
        response_3 = [text_list[i]]

print(Final_T_NO, "\t", Final_Utterance, "\t", response_1, "\t", response_2, "\t", response_3, "\t", [temp_disp], "\t", [temp_status])        
# return Final_T_NO, Final_Utterance, response_1, response_2, response_3, [temp_disp], [temp_status]
# Out:
# 4 	 No, i wouldnt 	 ["👋 Hi, manikandan!\n \nI'm stella from Jeep Coimbatore Your vehicle number  is due for service on 23 July 2023\n \nWould you like to book an appointment on the same day?"] 	 ['-'] 	 ['-'] 	 ['initial_message'] 	 [702]
