# %%
#import the required dependencies

import requests
import json
import pandas as pd
from pprint import pprint
import csv
import time
import random
import datetime
import re

print("all required dependencies are imported successfully")
# Out:
# all required dependencies are imported successfully

# %%
#update the testset and final sheet's path. then run the block


language = "English"

dataCSV = "/Users/vinay_kl/Downloads/S-CSV.csv"

#stellantis
botEndPoint = "https://stage-threebot.saarthi.ai/stellantis_english/webhook"
#PoliticalEdge
# botEndPoint = "https://stage-threebot.saarthi.ai/politics_marathi/webhook"

v = datetime.datetime.now()
#print(v)

#pattern = '\d{4}-\d{2}-\d{2} (\d{2}:\d{2}:\d{2})\.\d{6}'
pattern = "[\d]+-[\d]+-[\d]+ ([\d]+:[\d]+:[\d]+)\.[\d]+"

required = re.findall(pattern,str(v))
#print(required)


#---------------------------------------------------------------------------------------#


Final_Sheet = "/Users/vinay_kl/Downloads/Final_Sheet_Stellantis_"+str(language)+"_"+str(required)+".csv"

print(Final_Sheet)

print("testset and final_sheet is pushed to respective variables")
# Out:
# /Users/vinay_kl/Downloads/Final_Sheet_Stellantis_English_['11:13:54'].csv
# testset and final_sheet is pushed to respective variables

# %%
#functions



def BOT_FUNCTION(Final_T_NO = None,Final_Utterance = None,Flow = None,GRT = None,BRT = None,Language = None):
    headers = {'Content-Type':'application/json'}    
    payload = json.dumps ({
    "user_id" : "9482152445",
    "request_id" : "request115j27",
    "sender" : "tej-24765798uu89"+str(Final_T_NO)+str(num),
    "message" :  Final_Utterance,

    "customerData" : {
        "callId": "12345",
        "bargingCall": "True",
        "accessToken": "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VySWQiOiI2NDUwYjkyN2YzZGZlYzMyMDIxNDgxMzciLCJhY2NvdW50SWQiOiI2NDUwYjkyNmYzZGZlYzMyMDIxNDgxMmUiLCJyb2xlIjoiQWRtaW4iLCJpYXQiOjE2ODM1NDM5NDAsImV4cCI6MTY4MzYzMDM0MH0.slLTPbIA92IDfsZUJKR0rxFnVgDi7M5mtDLaWDmlJsc",
        "clientName": "Stellantis Testing",
        "callType": "Internal UAT",
        "telephonyName": "Epicode",
        "customerInfo": {
            "contactInfo": {
                "primary": "9354069780",
                "customerSupportNumber": "4233423434",
                "customerCareNumber": ""
            },
            "primaryInfo": {
                "firstName": "tester",
                "vehicleIdentificationNumber": "KA 12 AD 2790",
                "sellingDealerName": "Saarthi motors - Banglore",
                "geographicLocation": "",
                "pincode": "",
                "lastServiceDealerCity": "Banglore",
                "lastServiceDealerName": "Saarthi motors",
                "preferredAgentGender": "F",
                "agentname": "Stella",
                "serviceDueDate":"2023-06-18",
                "captured_date":"2023-06-12",
                "serviceNetworkName": "dsfsfsdf",
                "flow": str(Flow),
                "status": "Appointment Confirmed",
                "channel": "Voice",
                "utter_sub_flow_slot": "main_flow",
                "generalRepeatThreshold": str(GRT),
                "businessIntentThreshold": str(BRT),
                "previousDisposition": "Campaign End",
                "language": str(Language),
                "age": "",
                "gender": "",
                "region": "",
                "collared": "",
                "customerUniqueId": ""
            },
            "loanAccountDetails": {
                "emiAmount": "",
                "emiDueDate": "",
                "loanApplicationDate": "",
                "loanEndingDate": "",
                "lateFee": "",
                "interestRate": "",
                "nextNachDate": "",
                "paidDate": "",
                "currentPaymentStatus": "",
                "noofemi": "",
                "noOfEmiPaid": "",
                "loanTenureLeft": "",
                "loanAmountRemaining": "",
                "loanStartDate": "",
                "principalAmount": "",
                "totalLoanAmount": "",
                "loanCategory": "",
                "loanId": "",
                "noOfLoans": "",
                "paymentMode": "",
                "cbCharges": "0",
                "penalCharges": "0"
            },
            "behaviourDetails": {
                "riskType": "",
                "typology": "",
                "callDisposition": ""
            },
            "email": {
                "primary": ""
            },
            "leadType": "Transactional"
        },
        "callingPartner": "epicode",
        "campaignId": "2345",
        "agentConfig": {
            "parentFlow": [
                {
                    "flow": "appointment_booking_flow",
                    "isParent": True,
                    "isChild": False,
                    "channel": [
                        "Call"
                    ],
                    "type": "Female",
                    "language": [
                        "English","Hindi"
                    ],
                    "Call": {
                        "voice": "Saarthi TTS",
                        "thresholdDateCallBack": 2,
                        "thresholdTimeCallBack": 30
                    }
                }
            ],
            "callFlow": [
                {
                    "appointment_booking_flow": {
                        "slot1": [
                            {
                                "initial": {
                                    "label": "lg_rpc_form",
                                    "next": "subSlot1"
                                },
                                "subSlot1": [
                                    {
                                        "third_party_contact": {
                                            "initial": [
                                                {
                                                    "label": "third_party_contact_form",
                                                    "next": "subSlot1"
                                                }
                                            ],
                                            "subSlot1": [
                                                {
                                                    "label": "stop_conversation"
                                                }
                                            ]
                                        },
                                        "call_back": {
                                            "initial": [
                                                {
                                                    "label": "call_back_form",
                                                    "next": "subSlot1"
                                                }
                                            ],
                                            "subSlot1": [
                                                {
                                                    "label": "stop_conversation"
                                                }
                                            ]
                                        },
                                        "small_talk": {
                                            "initial": [
                                                {
                                                    "label": "small_talk_form",
                                                    "next": "subSlot1"
                                                }
                                            ],
                                            "subSlot1": [
                                                {
                                                    "label": "stop_conversation"
                                                }
                                            ]
                                        }
                                    }
                                ]
                            }
                        ],
                        "slot2": [
                            {
                                "label": "date_confirmation_form",
                                "next": "slot3"
                            }
                        ],
                        "slot3": [
                            {
                                "not_interested": {
                                    "initial": [
                                        {
                                            "label": "not_interested_form",
                                            "next": "subSlot1"
                                        }
                                    ],
                                    "subSlot1": [
                                        {
                                            "label": "stop_conversation"
                                        }
                                    ]
                                },
                                "interested_later": {
                                    "initial": [
                                        {
                                            "label": "interested_later_form",
                                            "next": "subSlot1"
                                        }
                                    ],
                                    "subSlot1": [
                                        {
                                            "label": "stop_conversation"
                                        }
                                    ]
                                },
                                "call_back": {
                                    "initial": [
                                        {
                                            "label": "call_back_form",
                                            "next": "subSlot1"
                                        }
                                    ],
                                    "subSlot1": [
                                        {
                                            "label": "stop_conversation"
                                        }
                                    ]
                                },
                                "date_capture": {
                                    "initial": [
                                        {
                                            "label": "date_capture_form",
                                            "next": "subSlot1"
                                        }
                                    ],
                                    "subSlot1": [
                                        {
                                            "dealership_capture": {
                                                "initial": [
                                                    {
                                                        "label": "dealership_capture_form",
                                                        "next": "sub1Slot1"
                                                    }
                                                ],
                                                "sub1Slot1": [
                                                    {
                                                        "deny": {
                                                            "initial": [
                                                                {
                                                                    "label": "deny_dealership_form",
                                                                    "next": "sub2Slot1"
                                                                }
                                                            ],
                                                            "sub2Slot1": [
                                                                {
                                                                    "label": "stop_conversation"
                                                                }
                                                            ]
                                                        },
                                                        "affirm": {
                                                            "initial": [
                                                                {
                                                                    "label": "pickup_drop_capture_form",
                                                                    "next": "sub2Slot1"
                                                                }
                                                            ],
                                                            "sub2Slot1": [
                                                                {
                                                                    "label": "stop_conversation"
                                                                }
                                                            ]
                                                        }
                                                    }
                                                ]
                                            }
                                        }
                                    ]
                                },
                                "dealership_capture": {
                                    "initial": [
                                        {
                                            "label": "dealership_capture_form",
                                            "next": "sub1Slot1"
                                        }
                                    ],
                                    "sub1Slot1": [
                                        {
                                            "deny": {
                                                "initial": [
                                                    {
                                                        "label": "deny_dealership_form",
                                                        "next": "sub2Slot1"
                                                    }
                                                ],
                                                "sub2Slot1": [
                                                    {
                                                        "label": "stop_conversation"
                                                    }
                                                ]
                                            },
                                            "affirm": {
                                                "initial": [
                                                    {
                                                        "label": "pickup_drop_capture_form",
                                                        "next": "sub2Slot1"
                                                    }
                                                ],
                                                "sub2Slot1": [
                                                    {
                                                        "label": "stop_conversation"
                                                    }
                                                ]
                                            }
                                        }
                                    ]
                                }
                            }
                        ]
                    },
                    "follow_up_flow": {
                        "slot1": [
                            {
                                "initial": {
                                    "label": "lg_rpc_form",
                                    "next": "subSlot1"
                                },
                                "subSlot1": [
                                    {
                                        "third_party_contact": {
                                            "initial": [
                                                {
                                                    "label": "third_party_contact_form",
                                                    "next": "subSlot1"
                                                }
                                            ],
                                            "subSlot1": [
                                                {
                                                    "label": "stop_conversation"
                                                }
                                            ]
                                        },
                                        "call_back": {
                                            "initial": [
                                                {
                                                    "label": "call_back_form",
                                                    "next": "subSlot1"
                                                }
                                            ],
                                            "subSlot1": [
                                                {
                                                    "label": "stop_conversation"
                                                }
                                            ]
                                        },
                                        "small_talk": {
                                            "initial": [
                                                {
                                                    "label": "small_talk_form",
                                                    "next": "subSlot1"
                                                }
                                            ],
                                            "subSlot1": [
                                                {
                                                    "label": "stop_conversation"
                                                }
                                            ]
                                        }
                                    }
                                ]
                            }
                        ],
                        "slot2": [
                            {
                                "label": "followup_dealership_capture_form",
                                "next": "slot3"
                            }
                        ],
                        "slot3": [
                            {
                                "not_interested": {
                                    "initial": [
                                        {
                                            "label": "not_interested_form",
                                            "next": "subSlot1"
                                        }
                                    ],
                                    "subSlot1": [
                                        {
                                            "label": "stop_conversation"
                                        }
                                    ]
                                },
                                "interested_later": {
                                    "initial": [
                                        {
                                            "label": "interested_later_form",
                                            "next": "subSlot1"
                                        }
                                    ],
                                    "subSlot1": [
                                        {
                                            "label": "stop_conversation"
                                        }
                                    ]
                                },
                                "call_back": {
                                    "initial": [
                                        {
                                            "label": "call_back_form",
                                            "next": "subSlot1"
                                        }
                                    ],
                                    "subSlot1": [
                                        {
                                            "label": "stop_conversation"
                                        }
                                    ]
                                },
                                "new_date_capture": {
                                    "initial": [
                                        {
                                            "label": "date_capture_form",
                                            "next": "subSlot1"
                                        }
                                    ],
                                    "subSlot1": [
                                        {
                                            "dealership_capture": {
                                                "initial": [
                                                    {
                                                        "label": "dealership_capture_form",
                                                        "next": "sub1Slot1"
                                                    }
                                                ],
                                                "sub1Slot1": [
                                                    {
                                                        "deny": {
                                                            "initial": [
                                                                {
                                                                    "label": "deny_dealership_form",
                                                                    "next": "sub2Slot1"
                                                                }
                                                            ],
                                                            "sub2Slot1": [
                                                                {
                                                                    "label": "stop_conversation"
                                                                }
                                                            ]
                                                        },
                                                        "affirm": {
                                                            "initial": [
                                                                {
                                                                    "label": "pickup_drop_capture_form",
                                                                    "next": "sub2Slot1"
                                                                }
                                                            ],
                                                            "sub2Slot1": [
                                                                {
                                                                    "label": "stop_conversation"
                                                                }
                                                            ]
                                                        }
                                                    }
                                                ]
                                            }
                                        }
                                    ]
                                },
                                "deny_dealership": {
                                    "initial": [
                                        {
                                            "label": "deny_dealership_form",
                                            "next": "sub2Slot1"
                                        }
                                    ],
                                    "sub2Slot1": [
                                        {
                                            "label": "stop_conversation"
                                        }
                                    ]
                                },
                                "pickup_drop_capture": {
                                    "initial": [
                                        {
                                            "label": "pickup_drop_capture_form",
                                            "next": "sub2Slot1"
                                        }
                                    ],
                                    "sub2Slot1": [
                                        {
                                            "label": "stop_conversation"
                                        }
                                    ]
                                }
                            }
                        ]
                    },
                    "remainder_flow": {
                        "slot1": [
                            {
                                "initial": {
                                    "label": "lg_rpc_form",
                                    "next": "subSlot1"
                                },
                                "subSlot1": [
                                    {
                                        "third_party_contact": {
                                            "initial": [
                                                {
                                                    "label": "third_party_contact_form",
                                                    "next": "subSlot1"
                                                }
                                            ],
                                            "subSlot1": [
                                                {
                                                    "label": "stop_conversation"
                                                }
                                            ]
                                        },
                                        "call_back": {
                                            "initial": [
                                                {
                                                    "label": "call_back_form",
                                                    "next": "subSlot1"
                                                }
                                            ],
                                            "subSlot1": [
                                                {
                                                    "label": "stop_conversation"
                                                }
                                            ]
                                        },
                                        "small_talk": {
                                            "initial": [
                                                {
                                                    "label": "small_talk_form",
                                                    "next": "subSlot1"
                                                }
                                            ],
                                            "subSlot1": [
                                                {
                                                    "label": "stop_conversation"
                                                }
                                            ]
                                        }
                                    }
                                ]
                            }
                        ],
                        "slot2": [
                            {
                                "label": "booking_confirmation_form",
                                "next": "slot3"
                            }
                        ],
                        "slot3": [
                            {
                                "interested_later": {
                                    "initial": [
                                        {
                                            "label": "interested_later_form",
                                            "next": "subSlot1"
                                        }
                                    ],
                                    "subSlot1": [
                                        {
                                            "label": "stop_conversation"
                                        }
                                    ]
                                },
                                "call_back": {
                                    "initial": [
                                        {
                                            "label": "call_back_form",
                                            "next": "subSlot1"
                                        }
                                    ],
                                    "subSlot1": [
                                        {
                                            "label": "stop_conversation"
                                        }
                                    ]
                                }
                            }
                        ]
                    },
                    "feedback_flow": {
                        "slot1": [
                            {
                                "initial": {
                                    "label": "lg_rpc_form",
                                    "next": "subSlot1"
                                },
                                "subSlot1": [
                                    {
                                        "third_party_contact": {
                                            "initial": [
                                                {
                                                    "label": "third_party_contact_form",
                                                    "next": "subSlot1"
                                                }
                                            ],
                                            "subSlot1": [
                                                {
                                                    "label": "stop_conversation"
                                                }
                                            ]
                                        },
                                        "call_back": {
                                            "initial": [
                                                {
                                                    "label": "call_back_form",
                                                    "next": "subSlot1"
                                                }
                                            ],
                                            "subSlot1": [
                                                {
                                                    "label": "stop_conversation"
                                                }
                                            ]
                                        },
                                        "small_talk": {
                                            "initial": [
                                                {
                                                    "label": "small_talk_form",
                                                    "next": "subSlot1"
                                                }
                                            ],
                                            "subSlot1": [
                                                {
                                                    "label": "stop_conversation"
                                                }
                                            ]
                                        }
                                    }
                                ]
                            }
                        ],
                        "slot2": [
                            {
                                "label": "rating_based_form",
                                "next": "slot3"
                            }
                        ],
                        "slot3": [
                            {
                                "call_back": {
                                    "initial": [
                                        {
                                            "label": "call_back_form",
                                            "next": "subSlot1"
                                        }
                                    ],
                                    "subSlot1": [
                                        {
                                            "label": "stop_conversation"
                                        }
                                    ]
                                }
                            }
                        ]
                    }
                }
            ],
            "accountId": "6450b926f3dfec320214812e",
            "agentName": "Stella",
            "domain": "Automobile",
            "subDomain": "General",
            "productType": "Four Wheeler",
            "agentId": "StellantisTesting_salesOnboarding_FourWheeler_12",
            "createdAt": "2023-05-05T06:11:54.021Z",
            "updatedAt": "2023-05-05T06:11:54.021Z",
            "id": "64549e2ac0e8415d50370c7c"
        },
        "useCaseId": "62c81c4a4a0affe91342aaaa",
        "accountId": "6450b926f3dfec320214812e",
        "isCampaignTesting": True
    }
    
    }
    )
    
    response = requests.request("POST", botEndPoint, headers=headers, data=payload).json()

#     return(response)
    
    

# def final_data(response):
    text_list = []
    response_1 = ["-"]
    response_2 = ["-"]
    response_3 = ["-"]
    disposotion_list = []
    staus_list = []

    temp_status = response["custom"]["status"]
    temp_disp = response["custom"]["disposition_id"]
    temp_disp = ",".join(map(str, temp_disp))     #its like a text combining method with given delimeter.  map & str is added to reduce "sequence no N" error

    val = response["data"]
    for i in range(0,len(val)):    
          temp_text = response["data"][i]["text"]
          text_list.append(temp_text)

    for i in range(0,len(text_list)):
        if i == 0:
            response_1 = [text_list[i]]
        if i == 1:
            response_2 = [text_list[i]]
        if i == 2:
            response_3 = [text_list[i]]

    print(Final_T_NO, "\t", Final_Utterance, "\t", response_1, "\t", response_2, "\t", response_3, "\t", [temp_disp], "\t", [temp_status])        
    return Final_T_NO, Final_Utterance, response_1, response_2, response_3, [temp_disp], [temp_status]






print("all required functions are successfully called")
# Out:
# all required functions are successfully called

# %%
final_Tno = []
final_user_resp = []

final_response_1 = []
final_response_2 = []
final_response_3 = []
final_disposition = []
final_status = []

print("Empty lists created, --- Run next block")
# Out:
# Empty lists created, --- Run next block

# %%
num = random.random()

df = pd.read_csv(dataCSV)
df.head()


TestCase_No = df["T_N_O"]
Utterance_Coloum = df["Final_List"]
flow = df["Flow"]
grt = df["General_Intent_Threshold"]
brt = df["Business_Intent_Threshold"]
lang = df["Language"]

# for i in range(0,3132):
for i in range(5966, len(Utterance_Coloum)):
    
    
    MID_T_NO = TestCase_No[i]
    Flow = flow[i]
    GRT = grt[i]
    BRT = brt[i]
    Language = lang[i]
    
    print(MID_T_NO, Flow, GRT, BRT, Language)
    
    Utterance_List = eval(Utterance_Coloum[i])
    for j in range(0,len(Utterance_List)):
        Final_Utterance = Utterance_List[j]
        Final_T_NO = MID_T_NO
#         print(Final_T_NO)
#         print(Final_Utterance)
        
                
        try:

#             response = BOT_FUNCTION(Final_T_NO,Final_Utterance)
#             print("TestCaseNo - ", Final_T_NO," Passed")
            Final_T_NO, Final_Utterance, response_1, response_2, response_3, disposition, status = BOT_FUNCTION(Final_T_NO,Final_Utterance,Flow,GRT,BRT,Language)
            final_Tno.append(Final_T_NO)
            final_user_resp.append(Final_Utterance)        
            final_response_1.extend(response_1)
            final_response_2.extend(response_2)
            final_response_3.extend(response_3)            
            final_disposition.extend(disposition)
            final_status.extend(status)
            
#             time.sleep(1)

        except Exception as e:
#             print("TestCaseNo - ",Final_T_NO," failed ---> ",e)
            print(Final_T_NO, "\t", Final_Utterance, "\t", e, "\t", "error", "\t", "error", "\t", "error", "\t", "error")
    
            final_Tno.append(Final_T_NO)
            final_user_resp.append(Final_Utterance) 
            final_response_1.append(e)
            final_response_2.append("error")
            final_response_3.append("error")        
            final_disposition.append("error")
            final_status.append("error")
            
            
            
print("Testcases completed, --- Run next block")
# Out:
# HiEc2837 feedback_flow 2 2 Hindi
# HiEc2837 	 /initial_message 	 ['हेलो, मैं Jeep - Banglore से Stella बोल रही हूँ। क्या मेरी बात tester जी से हो रही है?'] 	 ['-'] 	 ['-'] 	 ['initial_message'] 	 [702]
# HiEc2837 	 Why are reminder calls being done? 	 ['आपके जीप व्हीकल के स्मूथ ऑपरेशन के लिए रेगुलर मेंटेनेंस इम्पोर्टेन्ट है। हमारा इरादा आपको परेशानी से मुक्त सर्विस एक्सपीरियंस देना है।'] 	 ['क्या मेरी बात tester जी से हो रही है?'] 	 ['-'] 	 ['Ask Reminder Call Reason,initial_message'] 	 [702]
# HiEc2837 	 Why are reminder calls being done? 	 ['आपके जीप व्हीकल के स्मूथ ऑपरेशन के लिए रेगुलर मेंटेनेंस इम्पोर्टेन्ट है। हमारा इरादा आपको परेशानी से मुक्त सर्विस एक्सपीरियंस देना है।'] 	 ['क्या मेरी बात tester जी से हो रही है?'] 	 ['-'] 	 ['Ask Reminder Call Reason,initial_message'] 	 [702]
# HiEc2837 	 Why are reminder calls being done? 	 ['अपना कीमती समय देने के लिए, धन्यवाद। आपका दिन शुभ हो।'] 	 ['-'] 	 ['-'] 	 ['Others'] 	 [701]
# HiEc2838 feedback_flow 2 2 Hindi
# ...

# %%
df2 = pd.DataFrame()

df2["TestCase_No"] = final_Tno
df2["Utterance"] = final_user_resp

df2["Bot_Response_1"] = final_response_1
df2["Bot_Response_2"] = final_response_2
df2["Bot_Response_3"] = final_response_3
df2["Disposition"] = final_disposition
df2["Status_Code"] = final_status

# df3 = pd.concat([df,df2], axis=1, join='inner')

# df3.to_csv(Final_Sheet, index=False)

df2.to_csv(Final_Sheet, index=False)


print('\n','\n','\n')
print ("required data is downloaded as a CSV in path = .......",Final_Sheet)
print('\n','\n','\n')


#df3.head(5)
# Out:
#
#
#
# required data is downloaded as a CSV in path = ....... /Users/vinay_kl/Downloads/Final_Sheet_Stellantis_English_['11:13:54'].csv

# %%
print(len(final_Tno))
print(len(final_user_resp))
print(len(final_response_1))
print(len(final_response_2))
print(len(final_response_3))
print(len(final_disposition))
print(len(final_status))

# print(final_response_3)
# print(final_response_3)
# Out:
# 1451
# 1451
# 1451
# 1451
# 1451
# 1451
# 1451

# %% [markdown]
# # Rough

# %%
headers = {'Content-Type':'application/json'}    
payload = json.dumps ({
    "user_id" : "9482152445",
    "request_id" : "request11j27",
    "sender" : "tej-24765798u89",
    "message" :  "/initial_message",

    "customerData" : {
        "callId": "12345",
        "bargingCall": "True",
        "accessToken": "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VySWQiOiI2NDUwYjkyN2YzZGZlYzMyMDIxNDgxMzciLCJhY2NvdW50SWQiOiI2NDUwYjkyNmYzZGZlYzMyMDIxNDgxMmUiLCJyb2xlIjoiQWRtaW4iLCJpYXQiOjE2ODM1NDM5NDAsImV4cCI6MTY4MzYzMDM0MH0.slLTPbIA92IDfsZUJKR0rxFnVgDi7M5mtDLaWDmlJsc",
        "clientName": "Stellantis Testing",
        "callType": "Internal UAT",
        "telephonyName": "Epicode",
        "customerInfo": {
            "contactInfo": {
                "primary": "9354069780",
                "customerSupportNumber": "4233423434",
                "customerCareNumber": ""
            },
            "primaryInfo": {
                "firstName": "tester",
                "vehicleIdentificationNumber": "KA 12 AD 2790",
                "sellingDealerName": "Saarthi motors - Banglore",
                "geographicLocation": "",
                "pincode": "",
                "lastServiceDealerCity": "Banglore",
                "lastServiceDealerName": "Saarthi motors",
                "preferredAgentGender": "F",
                "agentname": "Stella",
                "serviceDueDate":"2023-06-18",
                "captured_date":"2023-06-12",
                "serviceNetworkName": "dsfsfsdf",
                "flow": "follow_up_flow",
                "status": "Appointment Confirmed",
                "channel": "Voice",
                "utter_sub_flow_slot": "main_flow",
                "generalRepeatThreshold": "3",
                "businessIntentThreshold": "3",
                "previousDisposition": "Campaign End",
                "language": "Hindi",
                "age": "",
                "gender": "",
                "region": "",
                "collared": "",
                "customerUniqueId": ""
            },
            "loanAccountDetails": {
                "emiAmount": "",
                "emiDueDate": "",
                "loanApplicationDate": "",
                "loanEndingDate": "",
                "lateFee": "",
                "interestRate": "",
                "nextNachDate": "",
                "paidDate": "",
                "currentPaymentStatus": "",
                "noofemi": "",
                "noOfEmiPaid": "",
                "loanTenureLeft": "",
                "loanAmountRemaining": "",
                "loanStartDate": "",
                "principalAmount": "",
                "totalLoanAmount": "",
                "loanCategory": "",
                "loanId": "",
                "noOfLoans": "",
                "paymentMode": "",
                "cbCharges": "0",
                "penalCharges": "0"
            },
            "behaviourDetails": {
                "riskType": "",
                "typology": "",
                "callDisposition": ""
            },
            "email": {
                "primary": ""
            },
            "leadType": "Transactional"
        },
        "callingPartner": "epicode",
        "campaignId": "2345",
        "agentConfig": {
            "parentFlow": [
                {
                    "flow": "appointment_booking_flow",
                    "isParent": True,
                    "isChild": False,
                    "channel": [
                        "Call"
                    ],
                    "type": "Female",
                    "language": [
                        "English","Hindi"
                    ],
                    "Call": {
                        "voice": "Saarthi TTS",
                        "thresholdDateCallBack": 2,
                        "thresholdTimeCallBack": 30
                    }
                }
            ],
            "callFlow": [
                {
                    "appointment_booking_flow": {
                        "slot1": [
                            {
                                "initial": {
                                    "label": "lg_rpc_form",
                                    "next": "subSlot1"
                                },
                                "subSlot1": [
                                    {
                                        "third_party_contact": {
                                            "initial": [
                                                {
                                                    "label": "third_party_contact_form",
                                                    "next": "subSlot1"
                                                }
                                            ],
                                            "subSlot1": [
                                                {
                                                    "label": "stop_conversation"
                                                }
                                            ]
                                        },
                                        "call_back": {
                                            "initial": [
                                                {
                                                    "label": "call_back_form",
                                                    "next": "subSlot1"
                                                }
                                            ],
                                            "subSlot1": [
                                                {
                                                    "label": "stop_conversation"
                                                }
                                            ]
                                        },
                                        "small_talk": {
                                            "initial": [
                                                {
                                                    "label": "small_talk_form",
                                                    "next": "subSlot1"
                                                }
                                            ],
                                            "subSlot1": [
                                                {
                                                    "label": "stop_conversation"
                                                }
                                            ]
                                        }
                                    }
                                ]
                            }
                        ],
                        "slot2": [
                            {
                                "label": "date_confirmation_form",
                                "next": "slot3"
                            }
                        ],
                        "slot3": [
                            {
                                "not_interested": {
                                    "initial": [
                                        {
                                            "label": "not_interested_form",
                                            "next": "subSlot1"
                                        }
                                    ],
                                    "subSlot1": [
                                        {
                                            "label": "stop_conversation"
                                        }
                                    ]
                                },
                                "interested_later": {
                                    "initial": [
                                        {
                                            "label": "interested_later_form",
                                            "next": "subSlot1"
                                        }
                                    ],
                                    "subSlot1": [
                                        {
                                            "label": "stop_conversation"
                                        }
                                    ]
                                },
                                "call_back": {
                                    "initial": [
                                        {
                                            "label": "call_back_form",
                                            "next": "subSlot1"
                                        }
                                    ],
                                    "subSlot1": [
                                        {
                                            "label": "stop_conversation"
                                        }
                                    ]
                                },
                                "date_capture": {
                                    "initial": [
                                        {
                                            "label": "date_capture_form",
                                            "next": "subSlot1"
                                        }
                                    ],
                                    "subSlot1": [
                                        {
                                            "dealership_capture": {
                                                "initial": [
                                                    {
                                                        "label": "dealership_capture_form",
                                                        "next": "sub1Slot1"
                                                    }
                                                ],
                                                "sub1Slot1": [
                                                    {
                                                        "deny": {
                                                            "initial": [
                                                                {
                                                                    "label": "deny_dealership_form",
                                                                    "next": "sub2Slot1"
                                                                }
                                                            ],
                                                            "sub2Slot1": [
                                                                {
                                                                    "label": "stop_conversation"
                                                                }
                                                            ]
                                                        },
                                                        "affirm": {
                                                            "initial": [
                                                                {
                                                                    "label": "pickup_drop_capture_form",
                                                                    "next": "sub2Slot1"
                                                                }
                                                            ],
                                                            "sub2Slot1": [
                                                                {
                                                                    "label": "stop_conversation"
                                                                }
                                                            ]
                                                        }
                                                    }
                                                ]
                                            }
                                        }
                                    ]
                                },
                                "dealership_capture": {
                                    "initial": [
                                        {
                                            "label": "dealership_capture_form",
                                            "next": "sub1Slot1"
                                        }
                                    ],
                                    "sub1Slot1": [
                                        {
                                            "deny": {
                                                "initial": [
                                                    {
                                                        "label": "deny_dealership_form",
                                                        "next": "sub2Slot1"
                                                    }
                                                ],
                                                "sub2Slot1": [
                                                    {
                                                        "label": "stop_conversation"
                                                    }
                                                ]
                                            },
                                            "affirm": {
                                                "initial": [
                                                    {
                                                        "label": "pickup_drop_capture_form",
                                                        "next": "sub2Slot1"
                                                    }
                                                ],
                                                "sub2Slot1": [
                                                    {
                                                        "label": "stop_conversation"
                                                    }
                                                ]
                                            }
                                        }
                                    ]
                                }
                            }
                        ]
                    },
                    "follow_up_flow": {
                        "slot1": [
                            {
                                "initial": {
                                    "label": "lg_rpc_form",
                                    "next": "subSlot1"
                                },
                                "subSlot1": [
                                    {
                                        "third_party_contact": {
                                            "initial": [
                                                {
                                                    "label": "third_party_contact_form",
                                                    "next": "subSlot1"
                                                }
                                            ],
                                            "subSlot1": [
                                                {
                                                    "label": "stop_conversation"
                                                }
                                            ]
                                        },
                                        "call_back": {
                                            "initial": [
                                                {
                                                    "label": "call_back_form",
                                                    "next": "subSlot1"
                                                }
                                            ],
                                            "subSlot1": [
                                                {
                                                    "label": "stop_conversation"
                                                }
                                            ]
                                        },
                                        "small_talk": {
                                            "initial": [
                                                {
                                                    "label": "small_talk_form",
                                                    "next": "subSlot1"
                                                }
                                            ],
                                            "subSlot1": [
                                                {
                                                    "label": "stop_conversation"
                                                }
                                            ]
                                        }
                                    }
                                ]
                            }
                        ],
                        "slot2": [
                            {
                                "label": "followup_dealership_capture_form",
                                "next": "slot3"
                            }
                        ],
                        "slot3": [
                            {
                                "not_interested": {
                                    "initial": [
                                        {
                                            "label": "not_interested_form",
                                            "next": "subSlot1"
                                        }
                                    ],
                                    "subSlot1": [
                                        {
                                            "label": "stop_conversation"
                                        }
                                    ]
                                },
                                "interested_later": {
                                    "initial": [
                                        {
                                            "label": "interested_later_form",
                                            "next": "subSlot1"
                                        }
                                    ],
                                    "subSlot1": [
                                        {
                                            "label": "stop_conversation"
                                        }
                                    ]
                                },
                                "call_back": {
                                    "initial": [
                                        {
                                            "label": "call_back_form",
                                            "next": "subSlot1"
                                        }
                                    ],
                                    "subSlot1": [
                                        {
                                            "label": "stop_conversation"
                                        }
                                    ]
                                },
                                "new_date_capture": {
                                    "initial": [
                                        {
                                            "label": "date_capture_form",
                                            "next": "subSlot1"
                                        }
                                    ],
                                    "subSlot1": [
                                        {
                                            "dealership_capture": {
                                                "initial": [
                                                    {
                                                        "label": "dealership_capture_form",
                                                        "next": "sub1Slot1"
                                                    }
                                                ],
                                                "sub1Slot1": [
                                                    {
                                                        "deny": {
                                                            "initial": [
                                                                {
                                                                    "label": "deny_dealership_form",
                                                                    "next": "sub2Slot1"
                                                                }
                                                            ],
                                                            "sub2Slot1": [
                                                                {
                                                                    "label": "stop_conversation"
                                                                }
                                                            ]
                                                        },
                                                        "affirm": {
                                                            "initial": [
                                                                {
                                                                    "label": "pickup_drop_capture_form",
                                                                    "next": "sub2Slot1"
                                                                }
                                                            ],
                                                            "sub2Slot1": [
                                                                {
                                                                    "label": "stop_conversation"
                                                                }
                                                            ]
                                                        }
                                                    }
                                                ]
                                            }
                                        }
                                    ]
                                },
                                "deny_dealership": {
                                    "initial": [
                                        {
                                            "label": "deny_dealership_form",
                                            "next": "sub2Slot1"
                                        }
                                    ],
                                    "sub2Slot1": [
                                        {
                                            "label": "stop_conversation"
                                        }
                                    ]
                                },
                                "pickup_drop_capture": {
                                    "initial": [
                                        {
                                            "label": "pickup_drop_capture_form",
                                            "next": "sub2Slot1"
                                        }
                                    ],
                                    "sub2Slot1": [
                                        {
                                            "label": "stop_conversation"
                                        }
                                    ]
                                }
                            }
                        ]
                    },
                    "remainder_flow": {
                        "slot1": [
                            {
                                "initial": {
                                    "label": "lg_rpc_form",
                                    "next": "subSlot1"
                                },
                                "subSlot1": [
                                    {
                                        "third_party_contact": {
                                            "initial": [
                                                {
                                                    "label": "third_party_contact_form",
                                                    "next": "subSlot1"
                                                }
                                            ],
                                            "subSlot1": [
                                                {
                                                    "label": "stop_conversation"
                                                }
                                            ]
                                        },
                                        "call_back": {
                                            "initial": [
                                                {
                                                    "label": "call_back_form",
                                                    "next": "subSlot1"
                                                }
                                            ],
                                            "subSlot1": [
                                                {
                                                    "label": "stop_conversation"
                                                }
                                            ]
                                        },
                                        "small_talk": {
                                            "initial": [
                                                {
                                                    "label": "small_talk_form",
                                                    "next": "subSlot1"
                                                }
                                            ],
                                            "subSlot1": [
                                                {
                                                    "label": "stop_conversation"
                                                }
                                            ]
                                        }
                                    }
                                ]
                            }
                        ],
                        "slot2": [
                            {
                                "label": "booking_confirmation_form",
                                "next": "slot3"
                            }
                        ],
                        "slot3": [
                            {
                                "interested_later": {
                                    "initial": [
                                        {
                                            "label": "interested_later_form",
                                            "next": "subSlot1"
                                        }
                                    ],
                                    "subSlot1": [
                                        {
                                            "label": "stop_conversation"
                                        }
                                    ]
                                },
                                "call_back": {
                                    "initial": [
                                        {
                                            "label": "call_back_form",
                                            "next": "subSlot1"
                                        }
                                    ],
                                    "subSlot1": [
                                        {
                                            "label": "stop_conversation"
                                        }
                                    ]
                                }
                            }
                        ]
                    },
                    "feedback_flow": {
                        "slot1": [
                            {
                                "initial": {
                                    "label": "lg_rpc_form",
                                    "next": "subSlot1"
                                },
                                "subSlot1": [
                                    {
                                        "third_party_contact": {
                                            "initial": [
                                                {
                                                    "label": "third_party_contact_form",
                                                    "next": "subSlot1"
                                                }
                                            ],
                                            "subSlot1": [
                                                {
                                                    "label": "stop_conversation"
                                                }
                                            ]
                                        },
                                        "call_back": {
                                            "initial": [
                                                {
                                                    "label": "call_back_form",
                                                    "next": "subSlot1"
                                                }
                                            ],
                                            "subSlot1": [
                                                {
                                                    "label": "stop_conversation"
                                                }
                                            ]
                                        },
                                        "small_talk": {
                                            "initial": [
                                                {
                                                    "label": "small_talk_form",
                                                    "next": "subSlot1"
                                                }
                                            ],
                                            "subSlot1": [
                                                {
                                                    "label": "stop_conversation"
                                                }
                                            ]
                                        }
                                    }
                                ]
                            }
                        ],
                        "slot2": [
                            {
                                "label": "rating_based_form",
                                "next": "slot3"
                            }
                        ],
                        "slot3": [
                            {
                                "call_back": {
                                    "initial": [
                                        {
                                            "label": "call_back_form",
                                            "next": "subSlot1"
                                        }
                                    ],
                                    "subSlot1": [
                                        {
                                            "label": "stop_conversation"
                                        }
                                    ]
                                }
                            }
                        ]
                    }
                }
            ],
            "accountId": "6450b926f3dfec320214812e",
            "agentName": "Stella",
            "domain": "Automobile",
            "subDomain": "General",
            "productType": "Four Wheeler",
            "agentId": "StellantisTesting_salesOnboarding_FourWheeler_12",
            "createdAt": "2023-05-05T06:11:54.021Z",
            "updatedAt": "2023-05-05T06:11:54.021Z",
            "id": "64549e2ac0e8415d50370c7c"
        },
        "useCaseId": "62c81c4a4a0affe91342aaaa",
        "accountId": "6450b926f3dfec320214812e",
        "isCampaignTesting": True
    }
    
    }
)


response = requests.request("POST", botEndPoint, headers=headers, data=payload).json()

# pprint(response)




#-------------------------#

text_list = []
response_1 = ["-"]
response_2 = ["-"]
response_3 = ["-"]
disposotion_list = []
staus_list = []

temp_status = response["custom"]["status"]
temp_disp = response["custom"]["disposition_id"]
temp_disp = ",".join(map(str, temp_disp))     #its like a text combining method with given delimeter.  map & str is added to reduce "sequence no N" error

val = response["data"]
for i in range(0,len(val)):    
      temp_text = response["data"][i]["text"]
      text_list.append(temp_text)

for i in range(0,len(text_list)):
    if i == 0:
        response_1 = [text_list[i]]
    if i == 1:
        response_2 = [text_list[i]]
    if i == 2:
        response_3 = [text_list[i]]

# return response_1,response_2,response_3, [temp_disp], [temp_status]



print(response_1,response_2,response_3, [temp_disp], [temp_status])
# Out:
# ['हेलो, मैं Jeep - Banglore से Stella बोल रही हूँ। क्या मेरी बात tester जी से हो रही है?'] ['-'] ['-'] ['initial_message'] [702]

# %%
pprint(response["data"][0]["template_name"])

pprint(response["data"][0]["text"])

pprint(response["custom"]["disposition_id"])

pprint(response["custom"]["status"])
# Out:
# 'utter_RPC_initial_message_stellantis_AB_appointment_booking_flow_FW_G_F'
# "Hi, I'm kumar , calling from Jeep sdfsdfsdf . Am I talking to ram ??"
# ['initial_message']
# 702

# %%
text_list = []
response_1 = ["-"]
response_2 = ["-"]
#response_3 = ["-"]
disposotion_list = []
staus_list = []

temp_status = response["custom"]["status"]
temp_disp = response["custom"]["disposition_id"]
temp_disp = ",".join(map(str, temp_disp))     #its like a text combining method with given delimeter.  map & str is added to reduce "sequence no N" error

val = response["data"]
for i in range(0,len(val)):    
      temp_text = response["data"][i]["text"]
      text_list.append(temp_text)

for i in range(0,len(text_list)):
    if i == 0:
        response_1 = [text_list[i]]
    if i == 1:
        response_2 = [text_list[i]]

# %%
print(response_2)
# Out:
# ['-']
