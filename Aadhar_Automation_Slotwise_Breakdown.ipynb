# %% [markdown]
# # Actual Code

# %%
#import the required dependencies

import requests
import json
import pandas as pd
from pprint import pprint
import csv
import time
import random
import datetime
import re

print("all required dependencies are imported successfully")
# Out:
# all required dependencies are imported successfully

# %%
#update the current (pushData endpoint, bot endpoint & agent config)


pushData = "https://dsa.saarthi.ai/fetch_customer_data_maia"
botEndPoint = "https://dsa.saarthi.ai/maia_english/webhook_maia"

#-----------------------------------------------------------------------------#
#Axio
agentConfig = "{\"accountName\":\"Axio Testing\",\"product\":\"ConsumerLoan\",\"productCategory\":\"General\",\"accountId\":\"63d3c5ad1149ed575430767e\",\"agentId\":\"DbsMintekTesting_Collections_UnsecuredPersonalLoan_General_01\",\"domainId\":\"61f21a2f9cf0e005bb91eaea\",\"bankName\":\"Bajaj Finance \",\"maleAgentName\":\"Vinit\",\"femaleAgentName\":\"Medha\",\"displayName\":\"Sphot_Call_Whatsapp_01\",\"Call\":{\"flowTypes\":[{\"displayValue\":\"dpd_1_3\",\"value\":\"dpd_1_3\",\"whatsAppValue\":\"dpd_1_3\",\"languages\":[\"English\",\"Hindi\"],\"showFields\":[\"Mobile Number\",\"Customer Name\",\"Flow\",\"Language\",\"Disposition\",\"Bank Name\",\"Agent Name\",\"EMI Amount\",\"Due Date\",\"region\",\"gender\",\"Age\",\"occupation\",\"typology\",\"Number of Loans\",\"Loan Type\",\"Number of Loans\",\"Payment Mode\"],\"showCategories\":[\"Calling Info\",\"Loan Info\",\"Customer Demography\",\"Typology\"]}],\"partialPayment\":{\"dpd_8_15\":false,\"dpd_1_3\":false,\"dpd_4_7\":false,\"dpd_16_30\":false},\"paymentMode\":[\"Manual payment\"],\"paymentMethods\":{\"pay_via_online\":true,\"pay_via_agent\":false,\"pay_via_card\":false,\"pay_via_upi\":true,\"pay_via_netbanking\":true,\"pay_via_wallet\":true,\"pay_via_branch\":false,\"pay_via_app\":true},\"thresholdPtpDays\":4,\"thresholdCallBackTime\":\"18:00\",\"thresholdCallBackDate\":\"20/02/2023\",\"latePaymentPolicy\":\"A 5 % late fee will be charged on the EMI amount. For more details, please call our toll-free number.\",\"sms\":true},\"Whatsapp\":{\"flowTypes\":[{\"displayValue\":\"predue\",\"value\":\"predue\",\"whatsAppValue\":\"dpd_8_15\",\"languages\":[\"Telugu\",\"Tamil\"],\"showFields\":[\"Mobile Number\",\"Customer Name\",\"Flow\",\"Language\",\"Disposition\",\"Bank Name\",\"Agent Name\",\"EMI Amount\",\"Due Date\",\"region\",\"gender\",\"Age\",\"occupation\",\"typology\",\"Number of Loans\",\"Loan Type\",\"Number of Loans\",\"Payment Mode\"],\"showCategories\":[\"Calling Info\",\"Loan Info\",\"Customer Demography\",\"Typology\"]}],\"partialPayment\":{\"dpd_1_3\":true,\"dpd_4_7\":true,\"dpd_16_30\":false,\"dpd_8_15\":false},\"partialPaymentStage\":{\"dpd_1_3\":\"stage2\",\"dpd_4_7\":\"stage2\"},\"levelOfNegotiation\":{\"dpd_1_3\":\"1\",\"dpd_4_7\":\"1\"},\"minimumNegotiationPercentage\":{\"dpd_1_3\":\"50\",\"dpd_4_7\":\"50\"},\"paymentMode\":[\"auto debit with manual payment\"],\"paymentMethods\":{\"pay_via_online\":true,\"pay_via_agent\":false,\"pay_via_card\":false,\"pay_via_upi\":true,\"pay_via_netbanking\":true,\"pay_via_wallet\":true,\"pay_via_branch\":false,\"pay_via_app\":true},\"thresholdPtpDays\":4,\"latePaymentPolicy\":\"A 5 % late fee will be charged on the EMI amount. For more details ,Please call our toll free number.\",\"followUpTime\":{\"firstFollowup\":30,\"secondFollowup\":180}},\"createdAt\":\"2023-02-11T10:26:18.839Z\",\"updatedAt\":\"2023-02-16T09:31:10.580Z\",\"id\":\"63e76d4ac64a2b15672eac8c\"}"
#Adhar
#agentConfig = "{\"accountName\":\"Aadhar Housing Finance Testing\",\"product\":\"HomeLoan\",\"productCategory\":\"General\",\"accountId\":\"64252df630cc362c0bd424d7\",\"agentId\":\"AxioTesting_Collections_UnsecuredPersonalLoan_General_2\",\"domainId\":\"61f21a2f9cf0e005bb91eaea\",\"bankName\":\"Amazon Pay Later\",\"maleAgentName\":\"Diya\",\"femaleAgentName\":\"Diya\",\"displayName\":\"Sphot_Call_Whatsapp_2\",\"Call\":{\"flowTypes\":[{\"displayValue\":\"dpd_1_3\",\"value\":\"dpd_1_3\",\"whatsAppValue\":\"dpd_1_3\",\"languages\":[\"English\",\"Hindi\",\"Tamil\",\"Telugu\"],\"showFields\":[\"Mobile Number\",\"Customer Name\",\"Flow\",\"Language\",\"Disposition\",\"Bank Name\",\"Agent Name\",\"EMI Amount\",\"Due Date\",\"region\",\"gender\",\"Age\",\"occupation\",\"typology\",\"Number of Loans\",\"Loan Type\",\"Number of Loans\",\"Payment Mode\"],\"showCategories\":[\"Calling Info\",\"Loan Info\",\"Customer Demography\",\"Typology\"]},{\"displayValue\":\"dpd_4_7\",\"value\":\"dpd_4_7\",\"whatsAppValue\":\"dpd_4_7\",\"languages\":[\"English\",\"Hindi\",\"Tamil\",\"Telugu\"],\"showFields\":[\"Mobile Number\",\"Customer Name\",\"Flow\",\"Language\",\"Disposition\",\"Bank Name\",\"Agent Name\",\"EMI Amount\",\"Due Date\",\"region\",\"gender\",\"Age\",\"occupation\",\"typology\",\"Number of Loans\",\"Loan Type\",\"Number of Loans\",\"Payment Mode\"],\"showCategories\":[\"Calling Info\",\"Loan Info\",\"Customer Demography\",\"Typology\"]},{\"displayValue\":\"dpd_8_17\",\"value\":\"dpd_8_17\",\"whatsAppValue\":\"dpd_8_17\",\"languages\":[\"English\",\"Hindi\",\"Tamil\",\"Telugu\"],\"showFields\":[\"Mobile Number\",\"Customer Name\",\"Flow\",\"Language\",\"Disposition\",\"Bank Name\",\"Agent Name\",\"EMI Amount\",\"Due Date\",\"region\",\"gender\",\"Age\",\"occupation\",\"typology\",\"Number of Loans\",\"Loan Type\"],\"showCategories\":[\"Calling Info\",\"Loan Info\",\"Customer Demography\",\"Typology\"]},{\"displayValue\":\"dpd_18_25\",\"value\":\"dpd_18_25\",\"whatsAppValue\":\"dpd_18_25\",\"languages\":[\"English\",\"Hindi\",\"Tamil\",\"Telugu\"],\"showFields\":[\"Mobile Number\",\"Customer Name\",\"Flow\",\"Language\",\"Disposition\",\"Bank Name\",\"Agent Name\",\"EMI Amount\",\"Due Date\",\"region\",\"gender\",\"Age\",\"occupation\",\"typology\",\"Number of Loans\",\"Loan Type\"],\"showCategories\":[\"Calling Info\",\"Loan Info\",\"Customer Demography\",\"Typology\"]}],\"partialPayment\":{\"dpd_8_15\":false,\"dpd_1_3\":false,\"dpd_4_7\":false,\"dpd_16_30\":false,\"dpd_8_17\":false,\"dpd_18_25\":false,\"dpd_26_30\":false,\"dpd_31_45\":false,\"dpd_46_60\":false,\"dpd_61_90\":false},\"paymentMode\":[\"Manual payment\"],\"paymentMethods\":{\"pay_via_online\":true,\"pay_via_agent\":false,\"pay_via_card\":false,\"pay_via_upi\":true,\"pay_via_netbanking\":false,\"pay_via_wallet\":true,\"pay_via_branch\":false,\"pay_via_app\":true},\"thresholdPtpDays\":3,\"thresholdCallBackTime\":\"19:00\",\"thresholdCallBackDate\":\"25/09/2000\",\"latePaymentPolicy\":\"A 5 % late fee will be charged on the EMI amount. For more details, please call our toll-free number.\",\"sms\":false},\"Whatsapp\":{\"flowTypes\":[{\"displayValue\":\"dpd_1_3\",\"value\":\"dpd_1_3\",\"whatsAppValue\":\"dpd_1_3\",\"languages\":[\"English\",\"Hindi\",\"Telugu\",\"Tamil\"],\"showFields\":[\"Mobile Number\",\"Customer Name\",\"Flow\",\"Language\",\"Disposition\",\"Bank Name\",\"Agent Name\",\"EMI Amount\",\"Due Date\",\"region\",\"gender\",\"Age\",\"occupation\",\"typology\",\"Number of Loans\",\"Loan Type\",\"Number of Loans\",\"Payment Mode\"],\"showCategories\":[\"Calling Info\",\"Loan Info\",\"Customer Demography\",\"Typology\"]},{\"displayValue\":\"dpd_4_7\",\"value\":\"dpd_4_7\",\"whatsAppValue\":\"dpd_4_7\",\"languages\":[\"English\",\"Hindi\",\"Tamil\"],\"showFields\":[\"Mobile Number\",\"Customer Name\",\"Flow\",\"Language\",\"Disposition\",\"Bank Name\",\"Agent Name\",\"EMI Amount\",\"Due Date\",\"region\",\"gender\",\"Age\",\"occupation\",\"typology\",\"Number of Loans\",\"Loan Type\",\"Number of Loans\",\"Payment Mode\"],\"showCategories\":[\"Calling Info\",\"Loan Info\",\"Customer Demography\",\"Typology\"]}],\"partialPayment\":{\"dpd_1_3\":false,\"dpd_4_7\":false,\"dpd_8_15\":false,\"dpd_16_30\":false,\"dpd_8_17\":false,\"dpd_18_25\":false,\"dpd_26_30\":false,\"dpd_31_45\":false,\"dpd_46_60\":false,\"dpd_61_90\":false},\"paymentMode\":[\"Manual payment\"],\"paymentMethods\":{\"pay_via_online\":true,\"pay_via_agent\":false,\"pay_via_card\":false,\"pay_via_upi\":true,\"pay_via_netbanking\":false,\"pay_via_wallet\":true,\"pay_via_branch\":false,\"pay_via_app\":true},\"thresholdPtpDays\":2,\"latePaymentPolicy\":\"A 5 % late fee will be charged on the EMI amount. For more details, please call our toll-free number.\",\"followUpTime\":{\"firstFollowup\":3,\"secondFollowup\":5}},\"createdAt\":\"2023-04-06T10:06:42.754Z\",\"updatedAt\":\"2023-04-06T10:06:42.754Z\",\"id\":\"642e99b2a8f89a644a816bca\"}"

print("agent config and endpoints are pushed to respective variables")
# Out:
# agent config and endpoints are pushed to respective variables

# %%
#update required customer config details

agentName = "Sia"
customerName = "Vinay"
flow = "dpd_1_3"
language = "English"

locality = "Urban"
gender = "M"
age = "27"
collared = "White"
typology = "DICE"

dueDate = "05-05-2023"
emiAmount = "54321"
ptpDate = "31-04-2023"

print("required customer config details are updated")
# Out:
# required customer config details are updated

# %%
#update the testset and final sheet's path. then run the block

v = datetime.datetime.now()
#print(v)

#pattern = '\d{4}-\d{2}-\d{2} (\d{2}:\d{2}:\d{2})\.\d{6}'
pattern = "[\d]+-[\d]+-[\d]+ ([\d]+:[\d]+:[\d]+)\.[\d]+"

required = re.findall(pattern,str(v))
#print(required)


#---------------------------------------------------------------------------------------#


if int(age) >= 18 and int(age) <= 30:
    final_age = "Y"
    #print(final_age)
    
elif int(age) >= 31 and int(age) <= 45:
    final_age = "M"
    #print(final_age)
    
elif int(age) >= 46 and int(age) <= 60:
    final_age = "O"
    #print(final_age)   
    
else:
    final_age = "given age is not valid"
    print(final_age)  

    
    
#---------------------------------------------------------------------------------------#
    
    

demography = locality[0]+gender+final_age+collared[0]+"_"+typology
# print(demography)


#------------------------------------------------------------------#


dataCSV = "/Users/vinay_kl/Downloads/Test357.csv"
Final_Sheet = "/Users/vinay_kl/Downloads/Final_Sheet_"+str(language)+"_"+str(demography)+"_"+str(required)+".csv"

# print(demography)
print(Final_Sheet)

print("testset and final_sheet is pushed to respective variables")
# Out:
# /Users/vinay_kl/Downloads/Final_Sheet_English_UMYW_DICE_['11:10:23'].csv
# testset and final_sheet is pushed to respective variables

# %%
#Push the data to DB

headers = {'Content-Type':'application/json'}


payload = json.dumps ({
    "data": [
        {
            "age": age,
            "agent_config": agentConfig,
            "agent_name": agentName,
            "clientName": "Maia Bot Testing",
            "client_name": "Maia Bot Testing",
            "collared": collared,
            "contactInfo.primary": "6305450418",
            "disposition_name": "Default",
            "email.primary": "r18r18@gmail.com",
            "gender": gender,
            "geographic_location": "bangalore",
            "interest_rate": "15",
            "late_fees": "100",
            "loanAccountDetails.emiAmount": emiAmount,
            "loanAccountDetails.emiDueDate": dueDate,
            "loanAccountDetails.loanId": "test1",
            "loanAccountDetails.noOfLoans": "1",
            "loan_amount_remaining": "40000",
            "loan_end_date": "02-10-2025",
            "loan_start_date": "02-06-2022",
            "primaryInfo.firstName": customerName,
            "primaryInfo.flow": flow,
            "primaryInfo.language": language,
            "primaryInfo.region": locality,
            "principal_amount": "456799",
            "region": locality,
            "tenure_left": "5",
            "total_loan_amount": "4566",
            "typology": typology,
            "payment_status": "Paid",
            "paid_date": ptpDate,
            "loan_type": "",
            "Audio_server": "False",
            "loanAccountDetails.paymentMode": "auto debit with manual payment"
        }
    ]
})

response = requests.request("POST", pushData, headers=headers, data=payload).json()
print(response)
# Out:
# Data pushed successfully to maia bot

# %%
#functions


def LC(TestCaseNo = None,Message = None):



    headers = {'Content-Type':'application/json'}    
    payload = json.dumps ({
        "user_id": "6305450418",
        "request_id": "requestcd1127",
        "sender": "saarthibajajvinay555"+str(TestCaseNo)+str(num),
        "message": Message
    })
    response = requests.request("POST", botEndPoint, headers=headers, data=payload).json()

    return response



#     i = response["data"]

#     for dicts in i:
#         lastResponse = dicts["text"]
#         print(lastResponse,"\t", end=' ')




#     disposition = response["custom"]["disposition_id"]
#     status = response["custom"]["status"]  

#     print(disposition,'\t',status)
    
    
    
    
    
    
def LC_2(TestCaseNo = None,Message = None):


    headers = {'Content-Type':'application/json'}    
    payload = json.dumps ({
        "user_id": "6305450418",
        "request_id": "requestcd1127",
        "sender": "saarthibajajvinay555"+str(TestCaseNo)+str(num),
        "message": "can you speak any other languages"
    })
    response = requests.request("POST", botEndPoint, headers=headers, data=payload).json()



    headers = {'Content-Type':'application/json'}    
    payload = json.dumps ({
        "user_id": "6305450418",
        "request_id": "requestcd1127",
        "sender": "saarthibajajvinay555"+str(TestCaseNo)+str(num),
        "message": Message
    })
    response = requests.request("POST", botEndPoint, headers=headers, data=payload).json()

    return response
    



#     i = response["data"]

#     for dicts in i:
#         lastResponse = dicts["text"]
#         print(lastResponse,"\t", end=' ')




#     disposition = response["custom"]["disposition_id"]
#     status = response["custom"]["status"]  

#     print(disposition,'\t',status)
    
    
    
    
    
    
    
def RPN(TestCaseNo = None,Message = None):


    headers = {'Content-Type':'application/json'}    
    payload = json.dumps ({
        "user_id": "6305450418",
        "request_id": "requestcd1127",
        "sender": "saarthibajajvinay555"+str(TestCaseNo)+str(num),
        "message": "he is currently not here"
    })
    response = requests.request("POST", botEndPoint, headers=headers, data=payload).json()


    headers = {'Content-Type':'application/json'}    
    payload = json.dumps ({
        "user_id": "6305450418",
        "request_id": "requestcd1127",
        "sender": "saarthibajajvinay555"+str(TestCaseNo)+str(num),
        "message": "please call him after 20 days"
    })
    response = requests.request("POST", botEndPoint, headers=headers, data=payload).json()


    headers = {'Content-Type':'application/json'}    
    payload = json.dumps ({
        "user_id": "6305450418",
        "request_id": "requestcd1127",
        "sender": "saarthibajajvinay555"+str(TestCaseNo)+str(num),
        "message": Message
    })
    response = requests.request("POST", botEndPoint, headers=headers, data=payload).json()
    
    return response





#     i = response["data"]

#     for dicts in i:
#         lastResponse = dicts["text"]
#         print(lastResponse,"\t", end=' ')




#     disposition = response["custom"]["disposition_id"]
#     status = response["custom"]["status"]  

#     print(disposition,'\t',status)
    
    
    
    
    
    

def CBN(TestCaseNo = None,Message = None):


    headers = {'Content-Type':'application/json'}    
    payload = json.dumps ({
        "user_id": "6305450418",
        "request_id": "requestcd1127",
        "sender": "saarthibajajvinay555"+str(TestCaseNo)+str(num),
        "message": "please call me back later"
    })
    response = requests.request("POST", botEndPoint, headers=headers, data=payload).json()


    headers = {'Content-Type':'application/json'}    
    payload = json.dumps ({
        "user_id": "6305450418",
        "request_id": "requestcd1127",
        "sender": "saarthibajajvinay555"+str(TestCaseNo)+str(num),
        "message": "please call after 20 days"
    })
    response = requests.request("POST", botEndPoint, headers=headers, data=payload).json()


    headers = {'Content-Type':'application/json'}    
    payload = json.dumps ({
        "user_id": "6305450418",
        "request_id": "requestcd1127",
        "sender": "saarthibajajvinay555"+str(TestCaseNo)+str(num),
        "message": Message
    })
    response = requests.request("POST", botEndPoint, headers=headers, data=payload).json()
    
    return response




#     i = response["data"]

#     for dicts in i:
#         lastResponse = dicts["text"]
#         print(lastResponse,"\t", end=' ')




#     disposition = response["custom"]["disposition_id"]
#     status = response["custom"]["status"]  

#     print(disposition,'\t',status)
    
    
    
    
    
    
    
def no_message_Threshold(TestCaseNo = None,Message = None):


    headers = {'Content-Type':'application/json'}    
    payload = json.dumps ({
        "user_id": "6305450418",
        "request_id": "requestcd1127",
        "sender": "saarthibajajvinay555"+str(TestCaseNo)+str(num),
        "message": Message
    })
    response = requests.request("POST", botEndPoint, headers=headers, data=payload).json()


    headers = {'Content-Type':'application/json'}    
    payload = json.dumps ({
        "user_id": "6305450418",
        "request_id": "requestcd1127",
        "sender": "saarthibajajvinay555"+str(TestCaseNo)+str(num),
        "message": Message
    })
    response = requests.request("POST", botEndPoint, headers=headers, data=payload).json()


    headers = {'Content-Type':'application/json'}    
    payload = json.dumps ({
        "user_id": "6305450418",
        "request_id": "requestcd1127",
        "sender": "saarthibajajvinay555"+str(TestCaseNo)+str(num),
        "message": Message
    })
    response = requests.request("POST", botEndPoint, headers=headers, data=payload).json()
    
    return response




#     i = response["data"]

#     for dicts in i:
#         lastResponse = dicts["text"]
#         print(lastResponse,"\t", end=' ')




#     disposition = response["custom"]["disposition_id"]
#     status = response["custom"]["status"]  

#     print(disposition,'\t',status)    







#-------------------------------------------------------------------#







def final_data(response):
    text_list = []
    response_1 = ["-"]
    response_2 = ["-"]
    #response_3 = ["-"]
    disposotion_list = []
    staus_list = []

    temp_status = response["custom"]["status"]
    temp_disp = response["custom"]["disposition_id"]
    temp_disp = ",".join(map(str, temp_disp))     #its like a text combining method with given delimeter.  map & str is added to reduce "sequence no N" error

    val = response["data"]
    for i in range(0,len(val)):    
          temp_text = response["data"][i]["text"]
          text_list.append(temp_text)

    for i in range(0,len(text_list)):
        if i == 0:
            response_1 = [text_list[i]]
        if i == 1:
            response_2 = [text_list[i]]
        # if i == 2:
        #     response_3 = [text_list[i]]
        
    return response_1,response_2, [temp_disp], [temp_status]






print("all required functions are successfully called")
# Out:
# all required functions are successfully called

# %%
# final_response_1 = []
# final_response_2 = []
# final_disposition = []
# final_status = []

# %%
#RPC_SLOT (run this block to check testset in RPC slot)







final_response_1 = []
final_response_2 = []
final_disposition = []
final_status = []







num = random.random()

with open(dataCSV, 'r') as f:
    reader = csv.reader(f)
    the_whole_file = list(reader)    
    
count = 0
while(count < (len(the_whole_file)-1)):
#while(count < 10):
    count = count + 1
    TestCaseNo = the_whole_file[count][0]
    Message = the_whole_file[count][4]
    Category = the_whole_file[count][2]
    
    #print(TestCaseNo)
    #print(Message)
    #print(Category)
    #print(num)
    
    
    headers = {'Content-Type':'application/json'}    
    payload = json.dumps ({
        "user_id": "6305450418",
        "request_id": "requestcd1127",
        "sender": "saarthibajajvinay555"+str(TestCaseNo)+str(num),
        "message": "/initial_message"
    })
    response = requests.request("POST", botEndPoint, headers=headers, data=payload).json()
    
    
    if Category == "LC_2":
        try:

            response = LC_2(TestCaseNo,Message)
            response_1, response_2, disposition, status = final_data(response)
            final_response_1.extend(response_1)
            final_response_2.extend(response_2)
            final_disposition.extend(disposition)
            final_status.extend(status)
            
            time.sleep(1)

        except Exception as e:
            print("TestCaseNo -",TestCaseNo,"in RPC slot failed --->",e)
            final_response_1.append(e)
            final_response_2.append("error")
            final_disposition.append("error")
            final_status.append("error")
            
            
            
            
    elif Category == "RPN":
        try:

            response = RPN(TestCaseNo,Message)
            response_1, response_2, disposition, status = final_data(response)
            final_response_1.extend(response_1)
            final_response_2.extend(response_2)
            final_disposition.extend(disposition)
            final_status.extend(status)
            
            time.sleep(1)

        except Exception as e:
            print("TestCaseNo -",TestCaseNo,"in RPC slot failed --->",e)
            final_response_1.append(e)
            final_response_2.append("error")
            final_disposition.append("error")
            final_status.append("error")

            
            
    elif Category == "CBN":
        try:

            response = CBN(TestCaseNo,Message)
            response_1, response_2, disposition, status = final_data(response)
            final_response_1.extend(response_1)
            final_response_2.extend(response_2)
            final_disposition.extend(disposition)
            final_status.extend(status)
            
            time.sleep(1)

        except Exception as e:
            print("TestCaseNo -",TestCaseNo,"in RPC slot failed --->",e)
            final_response_1.append(e)
            final_response_2.append("error")
            final_disposition.append("error")
            final_status.append("error")
            
            
            
    elif Category == ["no_message_Threshold", "wait_Threshold"]:
        try:

            response = no_message_Threshold(TestCaseNo,Message)
            response_1, response_2, disposition, status = final_data(response)
            final_response_1.extend(response_1)
            final_response_2.extend(response_2)
            final_disposition.extend(disposition)
            final_status.extend(status)
            time.sleep(1)

        except Exception as e:
            print("TestCaseNo -",TestCaseNo,"in RPC slot failed --->",e)
            final_response_1.append(e)
            final_response_2.append("error")
            final_disposition.append("error")
            final_status.append("error")
            
            
            
            
    else:
        try:

            response = LC(TestCaseNo,Message)
            response_1, response_2, disposition, status = final_data(response)
            final_response_1.extend(response_1)
            final_response_2.extend(response_2)
            final_disposition.extend(disposition)
            final_status.extend(status)
            time.sleep(1)

        except Exception as e:
            print("TestCaseNo -",TestCaseNo,"in RPC slot failed --->",e)
            final_response_1.append(e)
            final_response_2.append("error")
            final_disposition.append("error")
            final_status.append("error")


            
print('\n','\n','\n')
print("RPC block is Completed, --- Run next block")
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File ~/opt/anaconda3/lib/python3.9/site-packages/requests/models.py:910, in Response.json(self, **kwargs)
#     909 try:
# --> 910     return complexjson.loads(self.text, **kwargs)
#     911 except JSONDecodeError as e:
#     912     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     913     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File ~/opt/anaconda3/lib/python3.9/json/__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#
# ...

# %%
time.sleep(5)

# %%
#PIC_SLOT (run this block to check testset in PIC slot)

num = random.random()

with open(dataCSV, 'r') as f:
    reader = csv.reader(f)
    the_whole_file = list(reader)    
    
count = 0
while(count < (len(the_whole_file)-1)):
    count = count + 1
    TestCaseNo = the_whole_file[count][0]
    Message = the_whole_file[count][4]
    Category = the_whole_file[count][2]
    
    #print(TestCaseNo)
    #print(Message)
    #print(Category)
    #print(num)
    
    
    headers = {'Content-Type':'application/json'}    
    payload = json.dumps ({
        "user_id": "6305450418",
        "request_id": "requestcd1127",
        "sender": "saarthibajajvinay555"+str(TestCaseNo)+str(num),
        "message": "/initial_message"
    })
    response = requests.request("POST", botEndPoint, headers=headers, data=payload).json()
    
    
    
    headers = {'Content-Type':'application/json'}    
    payload = json.dumps ({
        "user_id": "6305450418",
        "request_id": "requestcd1127",
        "sender": "saarthibajajvinay555"+str(TestCaseNo)+str(num),
        "message": "yes"
    })
    response = requests.request("POST", botEndPoint, headers=headers, data=payload).json()
    
    
    
    
    if Category == "LC_2":
        try:

            response = LC_2(TestCaseNo,Message)
            response_1, response_2, disposition, status = final_data(response)
            final_response_1.extend(response_1)
            final_response_2.extend(response_2)
            final_disposition.extend(disposition)
            final_status.extend(status)
            
            time.sleep(1)

        except Exception as e:
            print("TestCaseNo -",TestCaseNo,"in PIC slot failed --->",e)
            final_response_1.append(e)
            final_response_2.append("error")
            final_disposition.append("error")
            final_status.append("error")
            
            
            
            
    elif Category == "RPN":
        try:

            response = RPN(TestCaseNo,Message)
            response_1, response_2, disposition, status = final_data(response)
            final_response_1.extend(response_1)
            final_response_2.extend(response_2)
            final_disposition.extend(disposition)
            final_status.extend(status)
            
            time.sleep(1)

        except Exception as e:
            print("TestCaseNo -",TestCaseNo,"in PIC slot failed --->",e)
            final_response_1.append(e)
            final_response_2.append("error")
            final_disposition.append("error")
            final_status.append("error")
            
            
    elif Category == "CBN":
        try:

            response = CBN(TestCaseNo,Message)
            response_1, response_2, disposition, status = final_data(response)
            final_response_1.extend(response_1)
            final_response_2.extend(response_2)
            final_disposition.extend(disposition)
            final_status.extend(status)
            
            time.sleep(1)

        except Exception as e:
            print("TestCaseNo -",TestCaseNo,"in PIC slot failed --->",e)
            final_response_1.append(e)
            final_response_2.append("error")
            final_disposition.append("error")
            final_status.append("error")            
            
            
    elif Category == "no_message_Threshold":
        try:

            response = no_message_Threshold(TestCaseNo,Message)
            response_1, response_2, disposition, status = final_data(response)
            final_response_1.extend(response_1)
            final_response_2.extend(response_2)
            final_disposition.extend(disposition)
            final_status.extend(status)
            
            time.sleep(1)

        except Exception as e:
            print("TestCaseNo -",TestCaseNo,"in PIC slot failed --->",e)
            final_response_1.append(e)
            final_response_2.append("error")
            final_disposition.append("error")
            final_status.append("error")            
            
            
    else:
        try:

            response = LC(TestCaseNo,Message)
            response_1, response_2, disposition, status = final_data(response)
            final_response_1.extend(response_1)
            final_response_2.extend(response_2)
            final_disposition.extend(disposition)
            final_status.extend(status)
            
            time.sleep(1)

        except Exception as e:
            print("TestCaseNo -",TestCaseNo,"in PIC slot failed --->",e)
            final_response_1.append(e)
            final_response_2.append("error")
            final_disposition.append("error")
            final_status.append("error")
            
            
            
print('\n','\n','\n')
print("PIC block is Completed, --- Run next block")
# Out:
#
#
#
# PIC block is Completed, --- Run next block

# %%
time.sleep(5)

# %%
#COUNSELLING_SLOT (run this block to check testset in COUNSELLING slot)

num = random.random()

with open(dataCSV, 'r') as f:
    reader = csv.reader(f)
    the_whole_file = list(reader)    
    
count = 0
while(count < (len(the_whole_file)-1)):
    count = count + 1
    TestCaseNo = the_whole_file[count][0]
    Message = the_whole_file[count][4]
    Category = the_whole_file[count][2]
    
    #print(TestCaseNo)
    #print(Message)
    #print(Category)
    #print(num)
    
    
    headers = {'Content-Type':'application/json'}    
    payload = json.dumps ({
        "user_id": "6305450418",
        "request_id": "requestcd1127",
        "sender": "saarthibajajvinay555"+str(TestCaseNo)+str(num),
        "message": "/initial_message"
    })
    response = requests.request("POST", botEndPoint, headers=headers, data=payload).json()
    
    
    
    headers = {'Content-Type':'application/json'}    
    payload = json.dumps ({
        "user_id": "6305450418",
        "request_id": "requestcd1127",
        "sender": "saarthibajajvinay555"+str(TestCaseNo)+str(num),
        "message": "yes"
    })
    response = requests.request("POST", botEndPoint, headers=headers, data=payload).json()
    
    
    
    headers = {'Content-Type':'application/json'}    
    payload = json.dumps ({
        "user_id": "6305450418",
        "request_id": "requestcd1127",
        "sender": "saarthibajajvinay555"+str(TestCaseNo)+str(num),
        "message": "i wont do the payment"
    })
    response = requests.request("POST", botEndPoint, headers=headers, data=payload).json()
    
    
    
    
    if Category == "LC_2":
        try:

            response = LC_2(TestCaseNo,Message)
            response_1, response_2, disposition, status = final_data(response)
            final_response_1.extend(response_1)
            final_response_2.extend(response_2)
            final_disposition.extend(disposition)
            final_status.extend(status)
            
            time.sleep(1)

        except Exception as e:
            print("TestCaseNo -",TestCaseNo,"in COUNSELLING slot failed --->",e)
            final_response_1.append(e)
            final_response_2.append("error")
            final_disposition.append("error")
            final_status.append("error")            
            
            
            
    elif Category == "RPN":
        try:

            response = RPN(TestCaseNo,Message)
            response_1, response_2, disposition, status = final_data(response)
            final_response_1.extend(response_1)
            final_response_2.extend(response_2)
            final_disposition.extend(disposition)
            final_status.extend(status)
            
            time.sleep(1)

        except Exception as e:
            print("TestCaseNo -",TestCaseNo,"in COUNSELLING slot failed --->",e)
            final_response_1.append(e)
            final_response_2.append("error")
            final_disposition.append("error")
            final_status.append("error") 
            
            
    elif Category == "CBN":
        try:

            response = CBN(TestCaseNo,Message)
            response_1, response_2, disposition, status = final_data(response)
            final_response_1.extend(response_1)
            final_response_2.extend(response_2)
            final_disposition.extend(disposition)
            final_status.extend(status)
            
            time.sleep(1)

        except Exception as e:
            print("TestCaseNo -",TestCaseNo,"in COUNSELLING slot failed --->",e)
            final_response_1.append(e)
            final_response_2.append("error")
            final_disposition.append("error")
            final_status.append("error")             
            
            
    elif Category == "no_message_Threshold":
        try:

            response = no_message_Threshold(TestCaseNo,Message)
            response_1, response_2, disposition, status = final_data(response)
            final_response_1.extend(response_1)
            final_response_2.extend(response_2)
            final_disposition.extend(disposition)
            final_status.extend(status)
            
            time.sleep(1)

        except Exception as e:
            print("TestCaseNo -",TestCaseNo,"in COUNSELLING slot failed --->",e)
            final_response_1.append(e)
            final_response_2.append("error")
            final_disposition.append("error")
            final_status.append("error")             
            
            
    else:
        try:

            response = LC(TestCaseNo,Message)
            response_1, response_2, disposition, status = final_data(response)
            final_response_1.extend(response_1)
            final_response_2.extend(response_2)
            final_disposition.extend(disposition)
            final_status.extend(status)
            
            time.sleep(1)

        except Exception as e:
            print("TestCaseNo -",TestCaseNo,"in COUNSELLING slot failed --->",e)
            final_response_1.append(e)
            final_response_2.append("error")
            final_disposition.append("error")
            final_status.append("error") 
            
            
            
print('\n','\n','\n')
print("COUNSELLING block is Completed, --- Run next block")
# Out:
# TestCaseNo - 9 in COUNSELLING slot failed ---> [Errno Expecting value] Internal Server Error: 0
# TestCaseNo - 10 in COUNSELLING slot failed ---> [Errno Expecting value] Internal Server Error: 0
# TestCaseNo - 11 in COUNSELLING slot failed ---> [Errno Expecting value] Internal Server Error: 0
# TestCaseNo - 12 in COUNSELLING slot failed ---> [Errno Expecting value] Internal Server Error: 0
#
#
#
#
# COUNSELLING block is Completed, --- Run next block

# %%
time.sleep(5)

# %%
#ASK_DELAY_SLOT (run this block to check testset in ASK_DELAY slot)

num = random.random()

with open(dataCSV, 'r') as f:
    reader = csv.reader(f)
    the_whole_file = list(reader)    
    
count = 0
while(count < (len(the_whole_file)-1)):
    count = count + 1
    TestCaseNo = the_whole_file[count][0]
    Message = the_whole_file[count][4]
    Category = the_whole_file[count][2]
    
    #print(TestCaseNo)
    #print(Message)
    #print(Category)
    #print(num)
    
    
    headers = {'Content-Type':'application/json'}    
    payload = json.dumps ({
        "user_id": "6305450418",
        "request_id": "requestcd1127",
        "sender": "saarthibajajvinay555"+str(TestCaseNo)+str(num),
        "message": "/initial_message"
    })
    response = requests.request("POST", botEndPoint, headers=headers, data=payload).json()
    
    
    
    headers = {'Content-Type':'application/json'}    
    payload = json.dumps ({
        "user_id": "6305450418",
        "request_id": "requestcd1127",
        "sender": "saarthibajajvinay555"+str(TestCaseNo)+str(num),
        "message": "yes"
    })
    response = requests.request("POST", botEndPoint, headers=headers, data=payload).json()
    
    
    
    headers = {'Content-Type':'application/json'}    
    payload = json.dumps ({
        "user_id": "6305450418",
        "request_id": "requestcd1127",
        "sender": "saarthibajajvinay555"+str(TestCaseNo)+str(num),
        "message": "i dont want to pay"
    })
    response = requests.request("POST", botEndPoint, headers=headers, data=payload).json()
    
    
    
    headers = {'Content-Type':'application/json'}    
    payload = json.dumps ({
        "user_id": "6305450418",
        "request_id": "requestcd1127",
        "sender": "saarthibajajvinay555"+str(TestCaseNo)+str(num),
        "message": "i dont want to pay"
    })
    response = requests.request("POST", botEndPoint, headers=headers, data=payload).json()    
    
    
    if Category == "LC_2":
        try:

            response = LC_2(TestCaseNo,Message)
            response_1, response_2, disposition, status = final_data(response)
            final_response_1.extend(response_1)
            final_response_2.extend(response_2)
            final_disposition.extend(disposition)
            final_status.extend(status)
            
            time.sleep(1)

        except Exception as e:
            print("TestCaseNo -",TestCaseNo,"in ASK_DELAY slot failed --->",e)
            final_response_1.append(e)
            final_response_2.append("error")
            final_disposition.append("error")
            final_status.append("error")             
            
            
            
    elif Category == "RPN":
        try:

            response = RPN(TestCaseNo,Message)
            response_1, response_2, disposition, status = final_data(response)
            final_response_1.extend(response_1)
            final_response_2.extend(response_2)
            final_disposition.extend(disposition)
            final_status.extend(status)
            
            time.sleep(1)

        except Exception as e:
            print("TestCaseNo -",TestCaseNo,"in ASK_DELAY slot failed --->",e)
            final_response_1.append(e)
            final_response_2.append("error")
            final_disposition.append("error")
            final_status.append("error")
            
            
    elif Category == "CBN":
        try:

            response = CBN(TestCaseNo,Message)
            response_1, response_2, disposition, status = final_data(response)
            final_response_1.extend(response_1)
            final_response_2.extend(response_2)
            final_disposition.extend(disposition)
            final_status.extend(status)
            
            time.sleep(1)

        except Exception as e:
            print("TestCaseNo -",TestCaseNo,"in ASK_DELAY slot failed --->",e)
            final_response_1.append(e)
            final_response_2.append("error")
            final_disposition.append("error")
            final_status.append("error")            
            
            
    elif Category == "no_message_Threshold":
        try:

            response = no_message_Threshold(TestCaseNo,Message)
            response_1, response_2, disposition, status = final_data(response)
            final_response_1.extend(response_1)
            final_response_2.extend(response_2)
            final_disposition.extend(disposition)
            final_status.extend(status)
            
            time.sleep(1)

        except Exception as e:
            print("TestCaseNo -",TestCaseNo,"in ASK_DELAY slot failed --->",e)
            final_response_1.append(e)
            final_response_2.append("error")
            final_disposition.append("error")
            final_status.append("error")            
            
            
    else:
        try:

            response = LC(TestCaseNo,Message)
            response_1, response_2, disposition, status = final_data(response)
            final_response_1.extend(response_1)
            final_response_2.extend(response_2)
            final_disposition.extend(disposition)
            final_status.extend(status)
            
            time.sleep(1)

        except Exception as e:
            print("TestCaseNo -",TestCaseNo,"in ASK_DELAY slot failed --->",e)
            final_response_1.append(e)
            final_response_2.append("error")
            final_disposition.append("error")
            final_status.append("error")
            
            
            
            
print('\n','\n','\n')
print("ASK_DELAY block is Completed, --- Run next block")
# Out:
#
#
#
# ASK_DELAY block is Completed, --- Run next block

# %%
time.sleep(5)

# %%
#RPN__SLOT (run this block to check testset in RPN_ slot)

num = random.random()

with open(dataCSV, 'r') as f:
    reader = csv.reader(f)
    the_whole_file = list(reader)    
    
count = 0
while(count < (len(the_whole_file)-1)):
    count = count + 1
    TestCaseNo = the_whole_file[count][0]
    Message = the_whole_file[count][4]
    Category = the_whole_file[count][2]
    
    #print(TestCaseNo)
    #print(Message)
    #print(Category)
    #print(num)
    
    
    headers = {'Content-Type':'application/json'}    
    payload = json.dumps ({
        "user_id": "6305450418",
        "request_id": "requestcd1127",
        "sender": "saarthibajajvinay555"+str(TestCaseNo)+str(num),
        "message": "/initial_message"
    })
    response = requests.request("POST", botEndPoint, headers=headers, data=payload).json()
    
    
    
    headers = {'Content-Type':'application/json'}    
    payload = json.dumps ({
        "user_id": "6305450418",
        "request_id": "requestcd1127",
        "sender": "saarthibajajvinay555"+str(TestCaseNo)+str(num),
        "message": "he is not available now"
    })
    response = requests.request("POST", botEndPoint, headers=headers, data=payload).json()
    
    
    
    headers = {'Content-Type':'application/json'}    
    payload = json.dumps ({
        "user_id": "6305450418",
        "request_id": "requestcd1127",
        "sender": "saarthibajajvinay555"+str(TestCaseNo)+str(num),
        "message": "you can connect with him after an year"
    })
    response = requests.request("POST", botEndPoint, headers=headers, data=payload).json()
    
    
    
    if Category == "LC_2":
        try:

            response = LC_2(TestCaseNo,Message)
            response_1, response_2, disposition, status = final_data(response)
            final_response_1.extend(response_1)
            final_response_2.extend(response_2)
            final_disposition.extend(disposition)
            final_status.extend(status)
            
            time.sleep(1)

        except Exception as e:
            print("TestCaseNo -",TestCaseNo,"in RPN_ slot failed --->",e)
            final_response_1.append(e)
            final_response_2.append("error")
            final_disposition.append("error")
            final_status.append("error")            
            
            
            
    elif Category == "RPN":
        warn = ["RPN cannot be checked again within RPN"]
        err = ["error"]

        final_response_1.extend(warn)
        final_response_2.extend(err)
        final_disposition.extend(err)
        final_status.extend(err)

        time.sleep(1)

            
            
    elif Category == "CBN":
        warn = ["CBN cannot be checked again within RPN"]
        err = ["error"]
        
        final_response_1.extend(warn)
        final_response_2.extend(err)
        final_disposition.extend(err)
        final_status.extend(err)

        time.sleep(1)
        
            
            
    elif Category == "no_message_Threshold":
        try:

            response = no_message_Threshold(TestCaseNo,Message)
            response_1, response_2, disposition, status = final_data(response)
            final_response_1.extend(response_1)
            final_response_2.extend(response_2)
            final_disposition.extend(disposition)
            final_status.extend(status)
            
            time.sleep(1)

        except Exception as e:
            print("TestCaseNo -",TestCaseNo,"in RPN_ slot failed --->",e)
            final_response_1.append(e)
            final_response_2.append("error")
            final_disposition.append("error")
            final_status.append("error")            
            
            
    else:
        try:

            response = LC(TestCaseNo,Message)
            response_1, response_2, disposition, status = final_data(response)
            final_response_1.extend(response_1)
            final_response_2.extend(response_2)
            final_disposition.extend(disposition)
            final_status.extend(status)
            
            time.sleep(1)

        except Exception as e:
            print("TestCaseNo -",TestCaseNo,"in RPN_ slot failed --->",e)
            final_response_1.append(e)
            final_response_2.append("error")
            final_disposition.append("error")
            final_status.append("error")
            
            
            
            
print('\n','\n','\n')
print("RPN_ block is Completed, --- Run next block")
# Out:
#
#
#
# RPN_ block is Completed, --- Run next block

# %%
time.sleep(5)

# %%
#CBN__SLOT (run this block to check testset in CBN_ slot)

num = random.random()

with open(dataCSV, 'r') as f:
    reader = csv.reader(f)
    the_whole_file = list(reader)    
    
count = 0
while(count < (len(the_whole_file)-1)):
    count = count + 1
    TestCaseNo = the_whole_file[count][0]
    Message = the_whole_file[count][4]
    Category = the_whole_file[count][2]
    
    #print(TestCaseNo)
    #print(Message)
    #print(Category)
    #print(num)
    
    
    headers = {'Content-Type':'application/json'}    
    payload = json.dumps ({
        "user_id": "6305450418",
        "request_id": "requestcd1127",
        "sender": "saarthibajajvinay555"+str(TestCaseNo)+str(num),
        "message": "/initial_message"
    })
    response = requests.request("POST", botEndPoint, headers=headers, data=payload).json()
    
    
    
    headers = {'Content-Type':'application/json'}    
    payload = json.dumps ({
        "user_id": "6305450418",
        "request_id": "requestcd1127",
        "sender": "saarthibajajvinay555"+str(TestCaseNo)+str(num),
        "message": "i am busy, call me later"
    })
    response = requests.request("POST", botEndPoint, headers=headers, data=payload).json()
    
    
    
    headers = {'Content-Type':'application/json'}    
    payload = json.dumps ({
        "user_id": "6305450418",
        "request_id": "requestcd1127",
        "sender": "saarthibajajvinay555"+str(TestCaseNo)+str(num),
        "message": "you can call me after 1 year"
    })
    response = requests.request("POST", botEndPoint, headers=headers, data=payload).json()
    
    
    
    if Category == "LC_2":
        try:

            response = LC_2(TestCaseNo,Message)
            response_1, response_2, disposition, status = final_data(response)
            final_response_1.extend(response_1)
            final_response_2.extend(response_2)
            final_disposition.extend(disposition)
            final_status.extend(status)
            
            time.sleep(1)

        except Exception as e:
            print("TestCaseNo -",TestCaseNo,"in CBN_ slot failed --->",e)
            final_response_1.append(e)
            final_response_2.append("error")
            final_disposition.append("error")
            final_status.append("error")            
            
            
            
    elif Category == "RPN":
        warn = ["RPN cannot be checked again within CBN"]
        err = ["error"]

        final_response_1.extend(warn)
        final_response_2.extend(err)
        final_disposition.extend(err)
        final_status.extend(err)

        time.sleep(1)

            
            
    elif Category == "CBN":
        warn = ["CBN cannot be checked again within CBN"]
        err = ["error"]
        
        final_response_1.extend(warn)
        final_response_2.extend(err)
        final_disposition.extend(err)
        final_status.extend(err)

        time.sleep(1)
        
            
            
    elif Category == "no_message_Threshold":
        try:

            response = no_message_Threshold(TestCaseNo,Message)
            response_1, response_2, disposition, status = final_data(response)
            final_response_1.extend(response_1)
            final_response_2.extend(response_2)
            final_disposition.extend(disposition)
            final_status.extend(status)
            
            time.sleep(1)

        except Exception as e:
            print("TestCaseNo -",TestCaseNo,"in CBN_ slot failed --->",e)
            final_response_1.append(e)
            final_response_2.append("error")
            final_disposition.append("error")
            final_status.append("error")            
            
            
    else:
        try:

            response = LC(TestCaseNo,Message)
            response_1, response_2, disposition, status = final_data(response)
            final_response_1.extend(response_1)
            final_response_2.extend(response_2)
            final_disposition.extend(disposition)
            final_status.extend(status)
            
            time.sleep(1)

        except Exception as e:
            print("TestCaseNo -",TestCaseNo,"in CBN_ slot failed --->",e)
            final_response_1.append(e)
            final_response_2.append("error")
            final_disposition.append("error")
            final_status.append("error")
            
print('\n','\n','\n')
print("CBN block is Completed, --- Run next block")
# Out:
#
#
#
# CBN block is Completed, --- Run next block

# %%
time.sleep(5)

# %%
df = pd.DataFrame()
df["Bot_Response_1"] = final_response_1
df["Bot_Response_2"] = final_response_2
df["Disposition"] = final_disposition
df["Status_Code"] = final_status

df.to_csv(Final_Sheet, index=False)


print('\n','\n','\n')
print ("required data is downloaded as a CSV in path = .......",Final_Sheet)
print('\n','\n','\n')


#df.head(30)
# Out:
#
#
#
# required data is downloaded as a CSV in path = ....... /Users/vinay_kl/Downloads/Final_Sheet_hindi_UF27W_DICE_['18:55:18'].csv

# %%
#1:38 PM
#14:00:44
#24 minutes

# import datetime
# import re

# v = datetime.datetime.now()
# #print(v)

# #pattern = '\d{4}-\d{2}-\d{2} (\d{2}:\d{2}:\d{2})\.\d{6}'
# pattern = "[\d]+-[\d]+-[\d]+ ([\d]+:[\d]+:[\d]+)\.[\d]+"

# required = re.findall(pattern,str(v))
# #print(required)
# Out:
# 2023-04-03 16:01:35.008528
# ['16:01:35']

# %%
# print(len(final_response_1))
# print(len(final_response_2))
# print(len(final_disposition))
# print(len(final_status))

# %%
# df1 = pd.DataFrame()
# df1["Disposition"] = final_disposition
# df1.to_csv(Final_Sheet, index=False)

# %% [markdown]
# # Rough

# %%
import pandas as pd

df = pd.DataFrame()



num = random.random()
TestCaseNo = 1
Message = "i will pay today"

headers = {'Content-Type':'application/json'}    
payload = json.dumps ({
    "user_id": "6305450418",
    "request_id": "requestcd1127",
    "sender": "saarthibajajvinay555"+str(TestCaseNo)+str(num),
    "message": "/initial_message"
})
response = requests.request("POST", botEndPoint, headers=headers, data=payload).json()


headers = {'Content-Type':'application/json'}    
payload = json.dumps ({
    "user_id": "6305450418",
    "request_id": "requestcd1127",
    "sender": "saarthibajajvinay555"+str(TestCaseNo)+str(num),
    "message": "yes"
})
response = requests.request("POST", botEndPoint, headers=headers, data=payload).json()


headers = {'Content-Type':'application/json'}    
payload = json.dumps ({
    "user_id": "6305450418",
    "request_id": "requestcd1127",
    "sender": "saarthibajajvinay555"+str(TestCaseNo)+str(num),
    "message": Message
})
response = requests.request("POST", botEndPoint, headers=headers, data=payload).json()


def final_data(response):
    text_list = []
    response_1 = ["-"]
    response_2 = ["-"]
    #response_3 = ["-"]
    disposotion_list = []
    staus_list = []

    temp_status = response["custom"]["status"]
    temp_disp = response["custom"]["disposition_id"]
    temp_disp = ",".join(temp_disp)     #its like a text combining method with given delimeter

    val = response["data"]
    for i in range(0,len(val)):    
          temp_text = response["data"][i]["text"]
          text_list.append(temp_text)

    for i in range(0,len(text_list)):
        if i == 0:
            response_1 = [text_list[i]]
        if i == 1:
            response_2 = [text_list[i]]
        # if i == 2:
        #     response_3 = [text_list[i]]
        
    return response_1,response_2, [temp_disp], [temp_status]

final_response_1 = final_response_2 = final_disposition = final_status = []
response_1, response_2, disposition, status = final_data(response)

final_response_1.extend(response_1)
final_response_2.extend(response_2)
final_response_1.extend(response_1)
final_response_1.extend(response_1)
print(response_1, response_2, disposition, status)

# a = ["1"]
# b= ["2"]

# c = a.append(b) = ["1",["2"]]
# d = a.extend(b) = a+b = ["1","2"]




#print("vds",response_2)
df["response_1"] = response_1
df["response_2"] = response_2
#df["response_3"] = response_3
df["disposition"] = disposition
df["status"] = status



# df.to_csv("Temp.csv",index=False)

df.head(5)

# %%
response_1=response_2=disposition=status = []


    RPC = pd.DataFrame()


    num = random.random()

    with open(dataCSV, 'r') as f:
        reader = csv.reader(f)
        the_whole_file = list(reader)    

    count = 0
    while(count < 6):
        count = count + 1
        TestCaseNo = the_whole_file[count][0]
        Message = the_whole_file[count][4]
        Category = the_whole_file[count][2]

        #print(TestCaseNo)
        #print(Message)
        #print(Category)
        #print(num)

        headers = {'Content-Type':'application/json'}    
        payload = json.dumps ({
            "user_id": "6305450418",
            "request_id": "requestcd1127",
            "sender": "saarthibajajvinay555"+str(TestCaseNo)+str(num),
            "message": "/initial_message"
        })
        response = requests.request("POST", botEndPoint, headers=headers, data=payload).json()


        headers = {'Content-Type':'application/json'}    
        payload = json.dumps ({
            "user_id": "6305450418",
            "request_id": "requestcd1127",
            "sender": "saarthibajajvinay555"+str(TestCaseNo)+str(num),
            "message": "yes"
        })
        response = requests.request("POST", botEndPoint, headers=headers, data=payload).json()


        headers = {'Content-Type':'application/json'}    
        payload = json.dumps ({
            "user_id": "6305450418",
            "request_id": "requestcd1127",
            "sender": "saarthibajajvinay555"+str(TestCaseNo)+str(num),
            "message": Message
        })
        response = requests.request("POST", botEndPoint, headers=headers, data=payload).json()



        text_list = []
        response_1 = ["-"]
        response_2 = ["-"]
        disposition_list = []
        status_list = []



        temp_status = response["custom"]["status"]
        temp_disp = response["custom"]["disposition_id"]
        temp_disp = ",".join(temp_disp)     #its like a text combining method with given delimeter



        val = response["data"]
        for i in range(0,len(val)):    
              temp_text = response["data"][i]["text"]
              text_list.append(temp_text)



        for i in range(0,len(text_list)):
            if i == 0:
                Response_1 = [text_list[i]]
            if i == 1:
                Response_2 = [text_list[i]]



        RPC["response_1"] = response_1.append(Response_1)
        RPC["response_2"] = response_2.append(Response_1)
        RPC["disposition"] = disposition_list.append([temp_disp])
        RPC["status"] = status_list.append([temp_status])



        RPC.to_csv(RPC_Sheet, index=False)


    RPC.head(2)

# %%
with open(dataCSV, 'r') as f:
    reader = csv.reader(f)
    the_whole_file = list(reader)
    print(len(the_whole_file))

# %%
a = ["0","1"]
b = "2"
c = ["3","4"]
d = [["4"],["5","6"]]

a.append(d)
print(a)

a = ["0","1"]
a.extend(d)
print(a)

# %%
TestCaseNo = 1,
num = random.random()
message_list = ["/initial_message","i am busy, call me later","you can call me after an year"]
for i in range(0,len(message_list)):
    print(i,message_list[i])
    message = message_list[i]
    headers = {'Content-Type':'application/json'}    
    payload = json.dumps ({
        "user_id": "6305450418",
        "request_id": "requestcd1127",
        "sender":"saarthadjvinfay555",
        "message": message
    })
    response = requests.request("POST", botEndPoint, headers=headers, data=payload).json()

# %%
num = random.random()
TestCaseNo = 2
Message = "/initial_message"
    
    
headers = {'Content-Type':'application/json'}    
payload = json.dumps ({
    "user_id": "6305450418",
    "request_id": "requestcd1127",
    "sender": "saarthibajajvinay555"+str(TestCaseNo)+str(num),
    "message": Message
})
response = requests.request("POST", botEndPoint, headers=headers, data=payload).json()

# return response

#print(response)

i = response["data"]

for dicts in i:
    lastResponse = dicts["text"]
    print(lastResponse,"\t", end=' ')




disposition = response["custom"]["disposition_id"]
status = response["custom"]["status"]  

print(disposition,'\t',status)
