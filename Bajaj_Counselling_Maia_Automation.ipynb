# %%
import requests
import json
import pandas as pd
from pprint import pprint
import csv
import time
import random

# %%
pushData = "https://fedfina.saarthi.ai/fetch_customer_data_bajaj_maia"
botEndPoint = "https://fedfina.saarthi.ai/maia_bajaj_english/webhook_maia"
dataCSV = "/Users/vinay_kl/Downloads/Test.csv"

# %%
#change Number and run to push the data to that number

headers = {'Content-Type':'application/json'}


payload = json.dumps ({
    "data": [
        {
            "primaryInfo.firstName": "Tester",
            "contactInfo.primary": "6305450418",
            "primaryInfo.flow": "predue",
            "primaryInfo.language": "Hindi",
            "primaryInfo.region": "Urban",
            "age": "35",
            "loanAccountDetails.emiDueDate": "22-12-2022",
            "loanAccountDetails.emiAmount": "56789",
            "agent_name": "RamaKrishna",
            "client_name": "Bajaj Finserv Counselling Flow Testing",
            "clientName": "Bajaj Finserv Counselling Flow Testing",
            "collared": "Blue",
            "disposition_name": "Call Back - Regular",
            "email.primary": "r18r18@gmail.com",
            "gender": "M",
            "geographic_location": "bangalore",
            "late_fees": "100",
            "loanAccountDetails.loanId": "test1",
            "loanAccountDetails.noOfLoans": "1",
            "agent_config": "{\"accountName\":\"Bajaj Finserv Counselling Testing\",\"product\":\"loans_multi\",\"productCategory\":\"General\",\"accountId\":\"63d3c5ad1149ed575430767e\",\"agentId\":\"SmartcoinTesting_Collections_UnsecuredPersonalLoan_General_01\",\"domainId\":\"61f21a2f9cf0e005bb91eaea\",\"bankName\":\"Smartcoin Financials\",\"maleAgentName\":\"Vinit\",\"femaleAgentName\":\"Medha\",\"displayName\":\"Sphot_Call_Whatsapp_01\",\"Call\":{\"flowTypes\":[{\"displayValue\":\"predue\",\"value\":\"predue\",\"whatsAppValue\":\"predue\",\"languages\":[\"Hindi\",\"English\"],\"showFields\":[\"Mobile Number\",\"Customer Name\",\"Flow\",\"Language\",\"Disposition\",\"Bank Name\",\"Agent Name\",\"EMI Amount\",\"Due Date\",\"region\",\"gender\",\"Age\",\"occupation\",\"typology\",\"Number of Loans\",\"Loan Type\",\"Number of Loans\",\"Payment Mode\"],\"showCategories\":[\"Calling Info\",\"Loan Info\",\"Customer Demography\",\"Typology\"]}],\"partialPayment\":{\"predue\":false,\"dpd_1_3\":false,\"dpd_4_7\":false,\"dpd_16_30\":false},\"paymentMode\":[\"Auto Debit\"],\"paymentMethods\":{\"pay_via_online\":true,\"pay_via_agent\":false,\"pay_via_card\":false,\"pay_via_upi\":true,\"pay_via_netbanking\":true,\"pay_via_wallet\":true,\"pay_via_branch\":false,\"pay_via_app\":true},\"thresholdPtpDays\":4,\"thresholdCallBackTime\":\"18:00\",\"thresholdCallBackDate\":\"20/02/2023\",\"latePaymentPolicy\":\"A 5 % late fee will be charged on the EMI amount. For more details, please call our toll-free number.\",\"sms\":true},\"Whatsapp\":{\"flowTypes\":[{\"displayValue\":\"predue\",\"value\":\"predue\",\"whatsAppValue\":\"predue\",\"languages\":[\"Hindi\",\"English\"],\"showFields\":[\"Mobile Number\",\"Customer Name\",\"Flow\",\"Language\",\"Disposition\",\"Bank Name\",\"Agent Name\",\"EMI Amount\",\"Due Date\",\"region\",\"gender\",\"Age\",\"occupation\",\"typology\",\"Number of Loans\",\"Loan Type\",\"Number of Loans\",\"Payment Mode\"],\"showCategories\":[\"Calling Info\",\"Loan Info\",\"Customer Demography\",\"Typology\"]}],\"partialPayment\":{\"dpd_1_3\":true,\"dpd_4_7\":true,\"dpd_16_30\":false,\"predue\":false},\"partialPaymentStage\":{\"dpd_1_3\":\"stage2\",\"dpd_4_7\":\"stage2\"},\"levelOfNegotiation\":{\"dpd_1_3\":\"1\",\"dpd_4_7\":\"1\"},\"minimumNegotiationPercentage\":{\"dpd_1_3\":\"50\",\"dpd_4_7\":\"50\"},\"paymentMode\":[\"Auto Debit\"],\"paymentMethods\":{\"pay_via_online\":true,\"pay_via_agent\":false,\"pay_via_card\":false,\"pay_via_upi\":true,\"pay_via_netbanking\":true,\"pay_via_wallet\":true,\"pay_via_branch\":false,\"pay_via_app\":true},\"thresholdPtpDays\":4,\"latePaymentPolicy\":\"A 5 % late fee will be charged on the EMI amount. For more details ,Please call our toll free number.\",\"followUpTime\":{\"firstFollowup\":30,\"secondFollowup\":180}},\"createdAt\":\"2023-02-11T10:26:18.839Z\",\"updatedAt\":\"2023-02-16T09:31:10.580Z\",\"id\":\"63e76d4ac64a2b15672eac8c\"}",
            "loan_amount_remaining": "40000",
            "loan_end_date": "02-10-2022",
            "loan_start_date": "",
            "principal_amount": "",
            "region": "Urban",
            "tenure_left": "5",
            "total_loan_amount": "4566",
            "typology": "WAOR",
            "payment_status": "Paid",
            "paid_date": "02-10-2022",
            "loan_type": "",
            "behaviourDetails.ptpDate":"10-10-2022",
            "Audio_server": "False"        }
    ]
})

response = requests.request("POST", pushData, headers=headers, data=payload).json()
print(response)
# Out:
# Data pushed successfully for maiaaaaaa

# %%
# Bot Function

def request_bajaj(TestCaseNo = None,Message = None):
    
    num = random.random()

    headers = {'Content-Type':'application/json'}    
    payload = json.dumps ({
        "user_id": "6305450418",
        "request_id": "requestcd1127",
        "sender": "saarthibajajvinay555"+str(TestCaseNo)+str(num),
        "message": "/initial_message"
    })
    response = requests.request("POST", botEndPoint, headers=headers, data=payload).json()


    headers = {'Content-Type':'application/json'}    
    payload = json.dumps ({
        "user_id": "6305450418",
        "request_id": "requestcd1127",
        "sender": "saarthibajajvinay555"+str(TestCaseNo)+str(num),
        "message": "yes"
    })
    response = requests.request("POST", botEndPoint, headers=headers, data=payload).json()


    headers = {'Content-Type':'application/json'}    
    payload = json.dumps ({
        "user_id": "6305450418",
        "request_id": "requestcd1127",
        "sender": "saarthibajajvinay555"+str(TestCaseNo)+str(num),
        "message": Message
    })
    response = requests.request("POST", botEndPoint, headers=headers, data=payload).json()



    #pprint(response)
    # j = response["data"]
    # for i in range(len(j)):
    #     v = j[i]["transcript_text"]
    #     print("value is",v)

    expectedResponse = response["data"][0]["text"]
    print(expectedResponse)

# %%
with open(dataCSV, 'r') as f:
    reader = csv.reader(f)
    the_whole_file = list(reader)    
    
count = 0
while(count < len(the_whole_file)):
    count = count + 1
    TestCaseNo = the_whole_file[count][0]
    Message = the_whole_file[count][1]
    
    #print(TestCaseNo)
    #print(Message)
    
    try:

        request_bajaj(TestCaseNo,Message)
        time.sleep(1)
        
    except Exception as e:
        print(e)
# Out:
# इसके लिए हम आपको कॉन्टैक्ट करेंगे। अपने क्रेडिट स्कोर को पॉजिटिव बनाये रखने के लिए अपने अकाउंट में बैलेंस बनाए रखें, थैंक यू।
# इसके लिए हम आपको कॉन्टैक्ट करेंगे। अपने क्रेडिट स्कोर को पॉजिटिव बनाये रखने के लिए अपने अकाउंट में बैलेंस बनाए रखें, थैंक यू।
# इसके लिए हम आपको कॉन्टैक्ट करेंगे। अपने क्रेडिट स्कोर को पॉजिटिव बनाये रखने के लिए अपने अकाउंट में बैलेंस बनाए रखें, थैंक यू।
# इसके लिए हम आपको कॉन्टैक्ट करेंगे। अपने क्रेडिट स्कोर को पॉजिटिव बनाये रखने के लिए अपने अकाउंट में बैलेंस बनाए रखें, थैंक यू।
# इसके लिए हम आपको कॉन्टैक्ट करेंगे। अपने क्रेडिट स्कोर को पॉजिटिव बनाये रखने के लिए अपने अकाउंट में बैलेंस बनाए रखें, थैंक यू।
# इसके लिए हम आपको कॉन्टैक्ट करेंगे। अपने क्रेडिट स्कोर को पॉजिटिव बनाये रखने के लिए अपने अकाउंट में बैलेंस बनाए रखें, थैंक यू।
# इसके लिए हम आपको कॉन्टैक्ट करेंगे। अपने क्रेडिट स्कोर को पॉजिटिव बनाये रखने के लिए अपने अकाउंट में बैलेंस बनाए रखें, थैंक यू।
# ...
