# %%
# !pip install wolframalpha
# !pip install pyttsx3
# !pip install SpeechRecognition
# !pip install wikipedia
# !pip install ecapture
# !pip install twilio
# !pip install beautifulsoup4
# !pip install pywhatkit
# !pip install datetime
# !pip install winshell
# !pip install tkinter
# !pip install winshell
# !pip install feedparser
# !pip install smtplib
# !pip install pypiwin32
# !pip install pypiwin32
# Out:
# Requirement already satisfied: wolframalpha in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (5.0.0)
# Requirement already satisfied: jaraco.context in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from wolframalpha) (4.2.0)
# Requirement already satisfied: xmltodict in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from wolframalpha) (0.13.0)
# Requirement already satisfied: more-itertools in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from wolframalpha) (9.0.0)
# Requirement already satisfied: pyttsx3 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (2.90)
# Requirement already satisfied: pyobjc>=2.4 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyttsx3) (9.0.1)
# Requirement already satisfied: pyobjc-framework-IOSurface==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (9.0.1)
# Requirement already satisfied: pyobjc-framework-WebKit==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (9.0.1)
# Requirement already satisfied: pyobjc-framework-AppleScriptKit==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (9.0.1)
# Requirement already satisfied: pyobjc-framework-CryptoTokenKit==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (9.0.1)
# Requirement already satisfied: pyobjc-framework-LaunchServices==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (9.0.1)
# Requirement already satisfied: pyobjc-framework-OpenDirectory==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (9.0.1)
# Requirement already satisfied: pyobjc-framework-IMServicePlugIn==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (9.0.1)
# Requirement already satisfied: pyobjc-framework-DiscRecordingUI==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (9.0.1)
# Requirement already satisfied: pyobjc-framework-MetalPerformanceShadersGraph==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (9.0.1)
# Requirement already satisfied: pyobjc-framework-ClassKit==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (9.0.1)
# Requirement already satisfied: pyobjc-framework-MediaToolbox==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (9.0.1)
# Requirement already satisfied: pyobjc-framework-Collaboration==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (9.0.1)
# Requirement already satisfied: pyobjc-framework-ScriptingBridge==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (9.0.1)
# Requirement already satisfied: pyobjc-framework-MediaLibrary==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (9.0.1)
# Requirement already satisfied: pyobjc-framework-SoundAnalysis==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (9.0.1)
# Requirement already satisfied: pyobjc-framework-InputMethodKit==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (9.0.1)
# Requirement already satisfied: pyobjc-framework-Social==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (9.0.1)
# Requirement already satisfied: pyobjc-framework-ScreenTime==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (9.0.1)
# Requirement already satisfied: pyobjc-framework-SpriteKit==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (9.0.1)
# Requirement already satisfied: pyobjc-framework-KernelManagement==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (9.0.1)
# Requirement already satisfied: pyobjc-framework-Quartz==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (9.0.1)
# Requirement already satisfied: pyobjc-framework-DiscRecording==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (9.0.1)
# Requirement already satisfied: pyobjc-framework-CoreHaptics==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (9.0.1)
# Requirement already satisfied: pyobjc-framework-PhotosUI==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (9.0.1)
# Requirement already satisfied: pyobjc-framework-PencilKit==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (9.0.1)
# Requirement already satisfied: pyobjc-framework-QuickLookThumbnailing==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (9.0.1)
# Requirement already satisfied: pyobjc-framework-AudioVideoBridging==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (9.0.1)
# Requirement already satisfied: pyobjc-framework-CoreBluetooth==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (9.0.1)
# Requirement already satisfied: pyobjc-framework-SafetyKit==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (9.0.1)
# Requirement already satisfied: pyobjc-framework-MailKit==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (9.0.1)
# Requirement already satisfied: pyobjc-framework-AdServices==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (9.0.1)
# Requirement already satisfied: pyobjc-framework-ThreadNetwork==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (9.0.1)
# Requirement already satisfied: pyobjc-framework-ColorSync==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (9.0.1)
# Requirement already satisfied: pyobjc-framework-AppleScriptObjC==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (9.0.1)
# Requirement already satisfied: pyobjc-framework-AdSupport==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (9.0.1)
# Requirement already satisfied: pyobjc-framework-NetFS==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (9.0.1)
# Requirement already satisfied: pyobjc-framework-Vision==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (9.0.1)
# Requirement already satisfied: pyobjc-framework-FileProviderUI==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (9.0.1)
# Requirement already satisfied: pyobjc-framework-Security==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (9.0.1)
# Requirement already satisfied: pyobjc-framework-Speech==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (9.0.1)
# Requirement already satisfied: pyobjc-framework-NetworkExtension==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (9.0.1)
# Requirement already satisfied: pyobjc-framework-LatentSemanticMapping==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (9.0.1)
# Requirement already satisfied: pyobjc-framework-VideoSubscriberAccount==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (9.0.1)
# Requirement already satisfied: pyobjc-framework-ShazamKit==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (9.0.1)
# Requirement already satisfied: pyobjc-framework-CoreData==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (9.0.1)
# Requirement already satisfied: pyobjc-framework-UserNotificationsUI==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (9.0.1)
# Requirement already satisfied: pyobjc-framework-DataDetection==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (9.0.1)
# Requirement already satisfied: pyobjc-framework-CoreML==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (9.0.1)
# Requirement already satisfied: pyobjc-framework-PreferencePanes==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (9.0.1)
# Requirement already satisfied: pyobjc-framework-NotificationCenter==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (9.0.1)
# Requirement already satisfied: pyobjc-framework-GameCenter==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (9.0.1)
# Requirement already satisfied: pyobjc-core==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (9.0.1)
# Requirement already satisfied: pyobjc-framework-LocalAuthentication==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (9.0.1)
# Requirement already satisfied: pyobjc-framework-DictionaryServices==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (9.0.1)
# Requirement already satisfied: pyobjc-framework-ExceptionHandling==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (9.0.1)
# Requirement already satisfied: pyobjc-framework-NaturalLanguage==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (9.0.1)
# Requirement already satisfied: pyobjc-framework-OSAKit==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (9.0.1)
# Requirement already satisfied: pyobjc-framework-CoreAudioKit==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (9.0.1)
# Requirement already satisfied: pyobjc-framework-DVDPlayback==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (9.0.1)
# Requirement already satisfied: pyobjc-framework-Accessibility==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (9.0.1)
# Requirement already satisfied: pyobjc-framework-VideoToolbox==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (9.0.1)
# Requirement already satisfied: pyobjc-framework-iTunesLibrary==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (9.0.1)
# Requirement already satisfied: pyobjc-framework-AVKit==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (9.0.1)
# Requirement already satisfied: pyobjc-framework-ModelIO==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (9.0.1)
# Requirement already satisfied: pyobjc-framework-InstantMessage==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (9.0.1)
# Requirement already satisfied: pyobjc-framework-InstallerPlugins==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (9.0.1)
# Requirement already satisfied: pyobjc-framework-GameKit==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (9.0.1)
# Requirement already satisfied: pyobjc-framework-ExtensionKit==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (9.0.1)
# Requirement already satisfied: pyobjc-framework-CFNetwork==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (9.0.1)
# Requirement already satisfied: pyobjc-framework-Network==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (9.0.1)
# Requirement already satisfied: pyobjc-framework-MediaPlayer==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (9.0.1)
# Requirement already satisfied: pyobjc-framework-AVFoundation==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (9.0.1)
# Requirement already satisfied: pyobjc-framework-ExternalAccessory==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (9.0.1)
# Requirement already satisfied: pyobjc-framework-Automator==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (9.0.1)
# Requirement already satisfied: pyobjc-framework-AutomaticAssessmentConfiguration==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (9.0.1)
# Requirement already satisfied: pyobjc-framework-CoreMotion==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (9.0.1)
# Requirement already satisfied: pyobjc-framework-MediaAccessibility==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (9.0.1)
# Requirement already satisfied: pyobjc-framework-SecurityInterface==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (9.0.1)
# Requirement already satisfied: pyobjc-framework-AddressBook==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (9.0.1)
# Requirement already satisfied: pyobjc-framework-PushKit==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (9.0.1)
# Requirement already satisfied: pyobjc-framework-CoreServices==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (9.0.1)
# Requirement already satisfied: pyobjc-framework-SecurityFoundation==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (9.0.1)
# Requirement already satisfied: pyobjc-framework-Intents==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (9.0.1)
# Requirement already satisfied: pyobjc-framework-AuthenticationServices==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (9.0.1)
# Requirement already satisfied: pyobjc-framework-CloudKit==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (9.0.1)
# Requirement already satisfied: pyobjc-framework-ScreenSaver==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (9.0.1)
# Requirement already satisfied: pyobjc-framework-FSEvents==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (9.0.1)
# Requirement already satisfied: pyobjc-framework-ReplayKit==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (9.0.1)
# Requirement already satisfied: pyobjc-framework-ServiceManagement==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (9.0.1)
# Requirement already satisfied: pyobjc-framework-MapKit==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (9.0.1)
# Requirement already satisfied: pyobjc-framework-Photos==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (9.0.1)
# Requirement already satisfied: pyobjc-framework-CoreText==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (9.0.1)
# Requirement already satisfied: pyobjc-framework-ScreenCaptureKit==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (9.0.1)
# Requirement already satisfied: pyobjc-framework-Metal==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (9.0.1)
# Requirement already satisfied: pyobjc-framework-CallKit==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (9.0.1)
# Requirement already satisfied: pyobjc-framework-Cocoa==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (9.0.1)
# Requirement already satisfied: pyobjc-framework-CoreWLAN==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (9.0.1)
# Requirement already satisfied: pyobjc-framework-CoreSpotlight==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (9.0.1)
# Requirement already satisfied: pyobjc-framework-SystemExtensions==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (9.0.1)
# Requirement already satisfied: pyobjc-framework-MultipeerConnectivity==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (9.0.1)
# Requirement already satisfied: pyobjc-framework-LinkPresentation==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (9.0.1)
# Requirement already satisfied: pyobjc-framework-BusinessChat==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (9.0.1)
# Requirement already satisfied: pyobjc-framework-MLCompute==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (9.0.1)
# Requirement already satisfied: pyobjc-framework-MetalPerformanceShaders==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (9.0.1)
# Requirement already satisfied: pyobjc-framework-SharedWithYouCore==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (9.0.1)
# Requirement already satisfied: pyobjc-framework-libdispatch==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (9.0.1)
# Requirement already satisfied: pyobjc-framework-CoreMIDI==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (9.0.1)
# Requirement already satisfied: pyobjc-framework-SearchKit==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (9.0.1)
# Requirement already satisfied: pyobjc-framework-ContactsUI==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (9.0.1)
# Requirement already satisfied: pyobjc-framework-CalendarStore==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (9.0.1)
# Requirement already satisfied: pyobjc-framework-IntentsUI==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (9.0.1)
# Requirement already satisfied: pyobjc-framework-BackgroundAssets==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (9.0.1)
# Requirement already satisfied: pyobjc-framework-FinderSync==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (9.0.1)
# Requirement already satisfied: pyobjc-framework-SyncServices==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (9.0.1)
# Requirement already satisfied: pyobjc-framework-CoreMediaIO==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (9.0.1)
# Requirement already satisfied: pyobjc-framework-EventKit==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (9.0.1)
# Requirement already satisfied: pyobjc-framework-AVRouting==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (9.0.1)
# Requirement already satisfied: pyobjc-framework-CoreLocation==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (9.0.1)
# Requirement already satisfied: pyobjc-framework-UserNotifications==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (9.0.1)
# Requirement already satisfied: pyobjc-framework-AppTrackingTransparency==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (9.0.1)
# Requirement already satisfied: pyobjc-framework-ApplicationServices==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (9.0.1)
# Requirement already satisfied: pyobjc-framework-GameController==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (9.0.1)
# Requirement already satisfied: pyobjc-framework-SafariServices==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (9.0.1)
# Requirement already satisfied: pyobjc-framework-ExecutionPolicy==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (9.0.1)
# Requirement already satisfied: pyobjc-framework-OSLog==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (9.0.1)
# Requirement already satisfied: pyobjc-framework-PassKit==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (9.0.1)
# Requirement already satisfied: pyobjc-framework-GameplayKit==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (9.0.1)
# Requirement already satisfied: pyobjc-framework-Contacts==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (9.0.1)
# Requirement already satisfied: pyobjc-framework-FileProvider==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (9.0.1)
# Requirement already satisfied: pyobjc-framework-DeviceCheck==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (9.0.1)
# Requirement already satisfied: pyobjc-framework-CoreMedia==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (9.0.1)
# Requirement already satisfied: pyobjc-framework-MetalFX==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (9.0.1)
# Requirement already satisfied: pyobjc-framework-MetalKit==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (9.0.1)
# Requirement already satisfied: pyobjc-framework-SceneKit==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (9.0.1)
# Requirement already satisfied: pyobjc-framework-DiskArbitration==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (9.0.1)
# Requirement already satisfied: pyobjc-framework-ImageCaptureCore==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (9.0.1)
# Requirement already satisfied: pyobjc-framework-MetricKit==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (9.0.1)
# Requirement already satisfied: pyobjc-framework-Accounts==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (9.0.1)
# Requirement already satisfied: pyobjc-framework-LocalAuthenticationEmbeddedUI==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (9.0.1)
# Requirement already satisfied: pyobjc-framework-SharedWithYou==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (9.0.1)
# Requirement already satisfied: pyobjc-framework-HealthKit==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (9.0.1)
# Requirement already satisfied: pyobjc-framework-StoreKit==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (9.0.1)
# Requirement already satisfied: pyobjc-framework-UniformTypeIdentifiers==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (9.0.1)
# Requirement already satisfied: pyobjc-framework-SystemConfiguration==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (9.0.1)
# Requirement already satisfied: pyobjc-framework-Virtualization==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (9.0.1)
# Requirement already satisfied: pyobjc-framework-CoreAudio==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (9.0.1)
# Requirement already satisfied: SpeechRecognition in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (3.9.0)
# Requirement already satisfied: requests>=2.26.0 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from SpeechRecognition) (2.27.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.26.0->SpeechRecognition) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.26.0->SpeechRecognition) (1.26.9)
# Requirement already satisfied: idna<4,>=2.5 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.26.0->SpeechRecognition) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.26.0->SpeechRecognition) (2.0.4)
# Requirement already satisfied: wikipedia in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (1.4.0)
# Requirement already satisfied: requests<3.0.0,>=2.0.0 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from wikipedia) (2.27.1)
# Requirement already satisfied: beautifulsoup4 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from wikipedia) (4.11.1)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (1.26.9)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (2021.10.8)
# Requirement already satisfied: soupsieve>1.2 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from beautifulsoup4->wikipedia) (2.3.1)
# Requirement already satisfied: ecapture in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (2.0.2)
# Requirement already satisfied: opencv-python in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from ecapture) (4.7.0.68)
# Requirement already satisfied: numpy>=1.19.3 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from opencv-python->ecapture) (1.21.5)
# Requirement already satisfied: twilio in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (7.16.0)
# Requirement already satisfied: PyJWT<3.0.0,>=2.0.0 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from twilio) (2.1.0)
# Requirement already satisfied: pytz in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from twilio) (2021.3)
# Requirement already satisfied: requests>=2.0.0 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from twilio) (2.27.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.0.0->twilio) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.0.0->twilio) (1.26.9)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.0.0->twilio) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.0.0->twilio) (3.3)
# Requirement already satisfied: beautifulsoup4 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (4.11.1)
# Requirement already satisfied: soupsieve>1.2 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from beautifulsoup4) (2.3.1)
# Requirement already satisfied: pywhatkit in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (5.4)
# Requirement already satisfied: Flask in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pywhatkit) (1.1.2)
# Requirement already satisfied: requests in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pywhatkit) (2.27.1)
# Requirement already satisfied: pyautogui in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pywhatkit) (0.9.53)
# Requirement already satisfied: wikipedia in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pywhatkit) (1.4.0)
# Requirement already satisfied: Pillow in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pywhatkit) (9.0.1)
# Requirement already satisfied: click>=5.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from Flask->pywhatkit) (8.0.4)
# Requirement already satisfied: itsdangerous>=0.24 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from Flask->pywhatkit) (2.0.1)
# Requirement already satisfied: Jinja2>=2.10.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from Flask->pywhatkit) (2.11.3)
# Requirement already satisfied: Werkzeug>=0.15 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from Flask->pywhatkit) (2.0.3)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from Jinja2>=2.10.1->Flask->pywhatkit) (2.0.1)
# Requirement already satisfied: mouseinfo in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyautogui->pywhatkit) (0.1.3)
# Requirement already satisfied: pymsgbox in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyautogui->pywhatkit) (1.0.9)
# Requirement already satisfied: pyobjc in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyautogui->pywhatkit) (9.0.1)
# Requirement already satisfied: pyobjc-core in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyautogui->pywhatkit) (9.0.1)
# Requirement already satisfied: pygetwindow>=0.0.5 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyautogui->pywhatkit) (0.0.9)
# Requirement already satisfied: PyTweening>=1.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyautogui->pywhatkit) (1.0.4)
# Requirement already satisfied: pyscreeze>=0.1.21 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyautogui->pywhatkit) (0.1.28)
# Requirement already satisfied: pyrect in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pygetwindow>=0.0.5->pyautogui->pywhatkit) (0.2.0)
# Requirement already satisfied: pyperclip in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from mouseinfo->pyautogui->pywhatkit) (1.8.2)
# Requirement already satisfied: rubicon-objc in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from mouseinfo->pyautogui->pywhatkit) (0.4.3)
# Requirement already satisfied: pyobjc-framework-LinkPresentation==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (9.0.1)
# Requirement already satisfied: pyobjc-framework-Quartz==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (9.0.1)
# Requirement already satisfied: pyobjc-framework-SecurityInterface==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (9.0.1)
# Requirement already satisfied: pyobjc-framework-AutomaticAssessmentConfiguration==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (9.0.1)
# Requirement already satisfied: pyobjc-framework-ColorSync==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (9.0.1)
# Requirement already satisfied: pyobjc-framework-PushKit==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (9.0.1)
# Requirement already satisfied: pyobjc-framework-AppleScriptKit==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (9.0.1)
# Requirement already satisfied: pyobjc-framework-MediaLibrary==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (9.0.1)
# Requirement already satisfied: pyobjc-framework-CoreData==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (9.0.1)
# Requirement already satisfied: pyobjc-framework-MultipeerConnectivity==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (9.0.1)
# Requirement already satisfied: pyobjc-framework-PencilKit==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (9.0.1)
# Requirement already satisfied: pyobjc-framework-CoreMedia==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (9.0.1)
# Requirement already satisfied: pyobjc-framework-Speech==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (9.0.1)
# Requirement already satisfied: pyobjc-framework-DiskArbitration==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (9.0.1)
# Requirement already satisfied: pyobjc-framework-VideoSubscriberAccount==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (9.0.1)
# Requirement already satisfied: pyobjc-framework-OSAKit==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (9.0.1)
# Requirement already satisfied: pyobjc-framework-AudioVideoBridging==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (9.0.1)
# Requirement already satisfied: pyobjc-framework-ExtensionKit==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (9.0.1)
# Requirement already satisfied: pyobjc-framework-ApplicationServices==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (9.0.1)
# Requirement already satisfied: pyobjc-framework-MetricKit==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (9.0.1)
# Requirement already satisfied: pyobjc-framework-AdServices==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (9.0.1)
# Requirement already satisfied: pyobjc-framework-AppleScriptObjC==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (9.0.1)
# Requirement already satisfied: pyobjc-framework-ScreenCaptureKit==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (9.0.1)
# Requirement already satisfied: pyobjc-framework-PassKit==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (9.0.1)
# Requirement already satisfied: pyobjc-framework-GameKit==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (9.0.1)
# Requirement already satisfied: pyobjc-framework-CoreAudio==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (9.0.1)
# Requirement already satisfied: pyobjc-framework-DictionaryServices==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (9.0.1)
# Requirement already satisfied: pyobjc-framework-OpenDirectory==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (9.0.1)
# Requirement already satisfied: pyobjc-framework-CoreMIDI==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (9.0.1)
# Requirement already satisfied: pyobjc-framework-IntentsUI==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (9.0.1)
# Requirement already satisfied: pyobjc-framework-CloudKit==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (9.0.1)
# Requirement already satisfied: pyobjc-framework-Social==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (9.0.1)
# Requirement already satisfied: pyobjc-framework-MediaAccessibility==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (9.0.1)
# Requirement already satisfied: pyobjc-framework-ReplayKit==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (9.0.1)
# Requirement already satisfied: pyobjc-framework-AVFoundation==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (9.0.1)
# Requirement already satisfied: pyobjc-framework-BusinessChat==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (9.0.1)
# Requirement already satisfied: pyobjc-framework-LocalAuthentication==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (9.0.1)
# Requirement already satisfied: pyobjc-framework-StoreKit==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (9.0.1)
# Requirement already satisfied: pyobjc-framework-AVKit==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (9.0.1)
# Requirement already satisfied: pyobjc-framework-SearchKit==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (9.0.1)
# Requirement already satisfied: pyobjc-framework-FinderSync==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (9.0.1)
# Requirement already satisfied: pyobjc-framework-Cocoa==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (9.0.1)
# Requirement already satisfied: pyobjc-framework-MediaToolbox==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (9.0.1)
# Requirement already satisfied: pyobjc-framework-Automator==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (9.0.1)
# Requirement already satisfied: pyobjc-framework-Photos==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (9.0.1)
# Requirement already satisfied: pyobjc-framework-libdispatch==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (9.0.1)
# Requirement already satisfied: pyobjc-framework-Accounts==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (9.0.1)
# Requirement already satisfied: pyobjc-framework-CoreML==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (9.0.1)
# Requirement already satisfied: pyobjc-framework-CoreSpotlight==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (9.0.1)
# Requirement already satisfied: pyobjc-framework-ContactsUI==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (9.0.1)
# Requirement already satisfied: pyobjc-framework-LatentSemanticMapping==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (9.0.1)
# Requirement already satisfied: pyobjc-framework-SoundAnalysis==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (9.0.1)
# Requirement already satisfied: pyobjc-framework-BackgroundAssets==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (9.0.1)
# Requirement already satisfied: pyobjc-framework-SystemConfiguration==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (9.0.1)
# Requirement already satisfied: pyobjc-framework-MediaPlayer==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (9.0.1)
# Requirement already satisfied: pyobjc-framework-CoreText==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (9.0.1)
# Requirement already satisfied: pyobjc-framework-NaturalLanguage==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (9.0.1)
# Requirement already satisfied: pyobjc-framework-Intents==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (9.0.1)
# Requirement already satisfied: pyobjc-framework-GameCenter==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (9.0.1)
# Requirement already satisfied: pyobjc-framework-AVRouting==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (9.0.1)
# Requirement already satisfied: pyobjc-framework-ScreenSaver==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (9.0.1)
# Requirement already satisfied: pyobjc-framework-MetalPerformanceShaders==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (9.0.1)
# Requirement already satisfied: pyobjc-framework-CoreBluetooth==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (9.0.1)
# Requirement already satisfied: pyobjc-framework-NetworkExtension==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (9.0.1)
# Requirement already satisfied: pyobjc-framework-MLCompute==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (9.0.1)
# Requirement already satisfied: pyobjc-framework-Security==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (9.0.1)
# Requirement already satisfied: pyobjc-framework-DiscRecordingUI==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (9.0.1)
# Requirement already satisfied: pyobjc-framework-UserNotificationsUI==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (9.0.1)
# Requirement already satisfied: pyobjc-framework-CoreLocation==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (9.0.1)
# Requirement already satisfied: pyobjc-framework-HealthKit==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (9.0.1)
# Requirement already satisfied: pyobjc-framework-LaunchServices==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (9.0.1)
# Requirement already satisfied: pyobjc-framework-CoreMotion==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (9.0.1)
# Requirement already satisfied: pyobjc-framework-UserNotifications==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (9.0.1)
# Requirement already satisfied: pyobjc-framework-MetalFX==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (9.0.1)
# Requirement already satisfied: pyobjc-framework-UniformTypeIdentifiers==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (9.0.1)
# Requirement already satisfied: pyobjc-framework-Accessibility==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (9.0.1)
# Requirement already satisfied: pyobjc-framework-FSEvents==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (9.0.1)
# Requirement already satisfied: pyobjc-framework-GameController==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (9.0.1)
# Requirement already satisfied: pyobjc-framework-CoreHaptics==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (9.0.1)
# Requirement already satisfied: pyobjc-framework-ExceptionHandling==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (9.0.1)
# Requirement already satisfied: pyobjc-framework-SecurityFoundation==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (9.0.1)
# Requirement already satisfied: pyobjc-framework-IOSurface==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (9.0.1)
# Requirement already satisfied: pyobjc-framework-MetalPerformanceShadersGraph==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (9.0.1)
# Requirement already satisfied: pyobjc-framework-SafetyKit==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (9.0.1)
# Requirement already satisfied: pyobjc-framework-SystemExtensions==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (9.0.1)
# Requirement already satisfied: pyobjc-framework-AuthenticationServices==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (9.0.1)
# Requirement already satisfied: pyobjc-framework-AppTrackingTransparency==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (9.0.1)
# Requirement already satisfied: pyobjc-framework-SceneKit==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (9.0.1)
# Requirement already satisfied: pyobjc-framework-FileProvider==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (9.0.1)
# Requirement already satisfied: pyobjc-framework-PreferencePanes==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (9.0.1)
# Requirement already satisfied: pyobjc-framework-iTunesLibrary==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (9.0.1)
# Requirement already satisfied: pyobjc-framework-ImageCaptureCore==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (9.0.1)
# Requirement already satisfied: pyobjc-framework-InputMethodKit==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (9.0.1)
# Requirement already satisfied: pyobjc-framework-ServiceManagement==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (9.0.1)
# Requirement already satisfied: pyobjc-framework-CoreMediaIO==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (9.0.1)
# Requirement already satisfied: pyobjc-framework-SafariServices==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (9.0.1)
# Requirement already satisfied: pyobjc-framework-ScriptingBridge==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (9.0.1)
# Requirement already satisfied: pyobjc-framework-QuickLookThumbnailing==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (9.0.1)
# Requirement already satisfied: pyobjc-framework-AdSupport==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (9.0.1)
# Requirement already satisfied: pyobjc-framework-ModelIO==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (9.0.1)
# Requirement already satisfied: pyobjc-framework-SharedWithYou==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (9.0.1)
# Requirement already satisfied: pyobjc-framework-NotificationCenter==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (9.0.1)
# Requirement already satisfied: pyobjc-framework-IMServicePlugIn==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (9.0.1)
# Requirement already satisfied: pyobjc-framework-Contacts==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (9.0.1)
# Requirement already satisfied: pyobjc-framework-ShazamKit==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (9.0.1)
# Requirement already satisfied: pyobjc-framework-CryptoTokenKit==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (9.0.1)
# Requirement already satisfied: pyobjc-framework-Metal==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (9.0.1)
# Requirement already satisfied: pyobjc-framework-SyncServices==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (9.0.1)
# Requirement already satisfied: pyobjc-framework-WebKit==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (9.0.1)
# Requirement already satisfied: pyobjc-framework-MapKit==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (9.0.1)
# Requirement already satisfied: pyobjc-framework-AddressBook==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (9.0.1)
# Requirement already satisfied: pyobjc-framework-ScreenTime==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (9.0.1)
# Requirement already satisfied: pyobjc-framework-DataDetection==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (9.0.1)
# Requirement already satisfied: pyobjc-framework-DiscRecording==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (9.0.1)
# Requirement already satisfied: pyobjc-framework-MailKit==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (9.0.1)
# Requirement already satisfied: pyobjc-framework-VideoToolbox==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (9.0.1)
# Requirement already satisfied: pyobjc-framework-SpriteKit==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (9.0.1)
# Requirement already satisfied: pyobjc-framework-NetFS==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (9.0.1)
# Requirement already satisfied: pyobjc-framework-LocalAuthenticationEmbeddedUI==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (9.0.1)
# Requirement already satisfied: pyobjc-framework-Network==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (9.0.1)
# Requirement already satisfied: pyobjc-framework-ExecutionPolicy==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (9.0.1)
# Requirement already satisfied: pyobjc-framework-InstallerPlugins==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (9.0.1)
# Requirement already satisfied: pyobjc-framework-CFNetwork==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (9.0.1)
# Requirement already satisfied: pyobjc-framework-CoreWLAN==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (9.0.1)
# Requirement already satisfied: pyobjc-framework-SharedWithYouCore==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (9.0.1)
# Requirement already satisfied: pyobjc-framework-MetalKit==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (9.0.1)
# Requirement already satisfied: pyobjc-framework-CoreServices==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (9.0.1)
# Requirement already satisfied: pyobjc-framework-CalendarStore==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (9.0.1)
# Requirement already satisfied: pyobjc-framework-KernelManagement==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (9.0.1)
# Requirement already satisfied: pyobjc-framework-ExternalAccessory==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (9.0.1)
# Requirement already satisfied: pyobjc-framework-CoreAudioKit==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (9.0.1)
# Requirement already satisfied: pyobjc-framework-Collaboration==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (9.0.1)
# Requirement already satisfied: pyobjc-framework-Virtualization==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (9.0.1)
# Requirement already satisfied: pyobjc-framework-OSLog==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (9.0.1)
# Requirement already satisfied: pyobjc-framework-InstantMessage==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (9.0.1)
# Requirement already satisfied: pyobjc-framework-DeviceCheck==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (9.0.1)
# Requirement already satisfied: pyobjc-framework-ClassKit==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (9.0.1)
# Requirement already satisfied: pyobjc-framework-ThreadNetwork==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (9.0.1)
# Requirement already satisfied: pyobjc-framework-DVDPlayback==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (9.0.1)
# Requirement already satisfied: pyobjc-framework-FileProviderUI==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (9.0.1)
# Requirement already satisfied: pyobjc-framework-PhotosUI==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (9.0.1)
# Requirement already satisfied: pyobjc-framework-Vision==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (9.0.1)
# Requirement already satisfied: pyobjc-framework-CallKit==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (9.0.1)
# Requirement already satisfied: pyobjc-framework-GameplayKit==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (9.0.1)
# Requirement already satisfied: pyobjc-framework-EventKit==9.0.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (9.0.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from requests->pywhatkit) (1.26.9)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from requests->pywhatkit) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from requests->pywhatkit) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from requests->pywhatkit) (3.3)
# Requirement already satisfied: beautifulsoup4 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from wikipedia->pywhatkit) (4.11.1)
# Requirement already satisfied: soupsieve>1.2 in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from beautifulsoup4->wikipedia->pywhatkit) (2.3.1)
# Requirement already satisfied: datetime in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (4.9)
# Requirement already satisfied: pytz in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from datetime) (2021.3)
# Requirement already satisfied: zope.interface in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from datetime) (5.4.0)
# Requirement already satisfied: setuptools in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from zope.interface->datetime) (61.2.0)
# Requirement already satisfied: winshell in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (0.6)
# ERROR: Could not find a version that satisfies the requirement tkinter (from versions: none)
# ERROR: No matching distribution found for tkinter
# Requirement already satisfied: winshell in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (0.6)
# Requirement already satisfied: feedparser in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (6.0.10)
# Requirement already satisfied: sgmllib3k in /Users/vinay_kl/opt/anaconda3/lib/python3.9/site-packages (from feedparser) (1.0.0)
# ERROR: Could not find a version that satisfies the requirement smtplib (from versions: none)
# ERROR: No matching distribution found for smtplib
# Collecting pypiwin32
#   Downloading pypiwin32-223-py3-none-any.whl (1.7 kB)
#   Downloading pypiwin32-219.zip (4.8 MB)
#      |████████████████████████████████| 4.8 MB 5.2 MB/s eta 0:00:01
#     ERROR: Command errored out with exit status 1:
#      command: /Users/vinay_kl/opt/anaconda3/bin/python -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/tr/mwr4dkgn0tb5jh53c7lyvfmw0000gn/T/pip-install-lj92vts2/pypiwin32_dd9779aeddbb4e3d89c6f6f48e784c18/setup.py'"'"'; __file__='"'"'/private/var/folders/tr/mwr4dkgn0tb5jh53c7lyvfmw0000gn/T/pip-install-lj92vts2/pypiwin32_dd9779aeddbb4e3d89c6f6f48e784c18/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /private/var/folders/tr/mwr4dkgn0tb5jh53c7lyvfmw0000gn/T/pip-pip-egg-info-w3xc9m3a
#          cwd: /private/var/folders/tr/mwr4dkgn0tb5jh53c7lyvfmw0000gn/T/pip-install-lj92vts2/pypiwin32_dd9779aeddbb4e3d89c6f6f48e784c18/
#     Complete output (6 lines):
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "/private/var/folders/tr/mwr4dkgn0tb5jh53c7lyvfmw0000gn/T/pip-install-lj92vts2/pypiwin32_dd9779aeddbb4e3d89c6f6f48e784c18/setup.py", line 121
#         print "Building pywin32", pywin32_version
#               ^
#     SyntaxError: Missing parentheses in call to 'print'. Did you mean print("Building pywin32", pywin32_version)?
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/2b/ca/5c086c18de8f70222787b3e824e755b68d99272531522e77bb381d4f60c8/pypiwin32-219.zip#sha256=06d478295c89dbdd4187e1ac099bb8eab93c29e298bded4e2fbc77009287fa44 (from https://pypi.org/simple/pypiwin32/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
# ERROR: Could not find a version that satisfies the requirement pywin32>=223 (from pypiwin32) (from versions: none)
# ERROR: No matching distribution found for pywin32>=223

# %%
import subprocess
import wolframalpha
import pyttsx3
import tkinter
import json
import random
import operator
import speech_recognition as sr
import datetime
import wikipedia
import webbrowser
import os
import winshell
import pyjokes
import feedparser
import smtplib
import ctypes
import time
import requests
import shutil
from twilio.rest import Client
from clint.textui import progress
from ecapture import ecapture as ec
from bs4 import BeautifulSoup
import win32com.client as wincl
from urllib.request import urlopen
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [17], in <cell line: 13>()
#      11 import webbrowser
#      12 import os
# ---> 13 import winshell
#      14 import pyjokes
#      15 import feedparser
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/winshell.py:30, in <module>
#      28 import os, sys
#      29 import datetime
# ---> 30 import win32con
#      31 from win32com import storagecon
#      32 from win32com.shell import shell, shellcon
#
# ModuleNotFoundError: No module named 'win32con'

# %%
engine = pyttsx3.init('sapi5')
voices = engine.getProperty('voices')
engine.setProperty('voice', voices[1].id)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/opt/anaconda3/lib/python3.9/site-packages/pyttsx3/__init__.py:20, in init(driverName, debug)
#      19 try:
# ---> 20     eng = _activeEngines[driverName]
#      21 except KeyError:
#
# File ~/opt/anaconda3/lib/python3.9/weakref.py:137, in WeakValueDictionary.__getitem__(self, key)
#     136     self._commit_removals()
# --> 137 o = self.data[key]()
#     138 if o is None:
#
# KeyError: 'sapi5'
#
# During handling of the above exception, another exception occurred:
#
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [18], in <cell line: 1>()
# ----> 1 engine = pyttsx3.init('sapi5')
#       2 voices = engine.getProperty('voices')
#       3 engine.setProperty('voice', voices[1].id)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pyttsx3/__init__.py:22, in init(driverName, debug)
#      20     eng = _activeEngines[driverName]
#      21 except KeyError:
# ---> 22     eng = Engine(driverName, debug)
#      23     _activeEngines[driverName] = eng
#      24 return eng
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pyttsx3/engine.py:30, in Engine.__init__(self, driverName, debug)
#      20 def __init__(self, driverName=None, debug=False):
#      21     """
#      22     Constructs a new TTS engine instance.
#      23
#    (...)
#      28     @type debug: bool
#      29     """
# ---> 30     self.proxy = driver.DriverProxy(weakref.proxy(self), driverName, debug)
#      31     # initialize other vars
#      32     self._connects = {}
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pyttsx3/driver.py:50, in DriverProxy.__init__(self, engine, driverName, debug)
#      48 # import driver module
#      49 name = 'pyttsx3.drivers.%s' % driverName
# ---> 50 self._module = importlib.import_module(name)
#      51 # build driver instance
#      52 self._driver = self._module.buildDriver(weakref.proxy(self))
#
# File ~/opt/anaconda3/lib/python3.9/importlib/__init__.py:127, in import_module(name, package)
#     125             break
#     126         level += 1
# --> 127 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1030, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1007, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:986, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:680, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:850, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:228, in _call_with_frames_removed(f, *args, **kwds)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pyttsx3/drivers/sapi5.py:1, in <module>
# ----> 1 import comtypes.client  # Importing comtypes.client will make the gen subpackage
#       2 try:
#       3     from comtypes.gen import SpeechLib  # comtypes
#
# ModuleNotFoundError: No module named 'comtypes'

# %%
def speak(audio):
	engine.say(audio)
	engine.runAndWait()

def wishMe():
	hour = int(datetime.datetime.now().hour)
	if hour>= 0 and hour<12:
		speak("Good Morning Sir !")

	elif hour>= 12 and hour<18:
		speak("Good Afternoon Sir !")

	else:
		speak("Good Evening Sir !")

	assname =("Jarvis 1 point o")
	speak("I am your Assistant")
	speak(assname)
	

def username():
	speak("What should i call you sir")
	uname = takeCommand()
	speak("Welcome Mister")
	speak(uname)
	columns = shutil.get_terminal_size().columns
	
	print("#####################".center(columns))
	print("Welcome Mr.", uname.center(columns))
	print("#####################".center(columns))
	
	speak("How can i Help you, Sir")

def takeCommand():
	
	r = sr.Recognizer()
	
	with sr.Microphone() as source:
		
		print("Listening...")
		r.pause_threshold = 1
		audio = r.listen(source)

	try:
		print("Recognizing...")
		query = r.recognize_google(audio, language ='en-in')
		print(f"User said: {query}\n")

	except Exception as e:
		print(e)
		print("Unable to Recognize your voice.")
		return "None"
	
	return query

def sendEmail(to, content):
	server = smtplib.SMTP('smtp.gmail.com', 587)
	server.ehlo()
	server.starttls()
	
	# Enable low security in gmail
	server.login('your email id', 'your email password')
	server.sendmail('your email id', to, content)
	server.close()

# %%
if __name__ == '__main__':
	clear = lambda: os.system('cls')
	
	# This Function will clean any
	# command before execution of this python file
	clear()
	wishMe()
	username()
	
	while True:
		
		query = takeCommand().lower()
		
		# All the commands said by user will be
		# stored here in 'query' and will be
		# converted to lower case for easily
		# recognition of command
		if 'wikipedia' in query:
			speak('Searching Wikipedia...')
			query = query.replace("wikipedia", "")
			results = wikipedia.summary(query, sentences = 3)
			speak("According to Wikipedia")
			print(results)
			speak(results)

		elif 'open youtube' in query:
			speak("Here you go to Youtube\n")
			webbrowser.open("youtube.com")

		elif 'open google' in query:
			speak("Here you go to Google\n")
			webbrowser.open("google.com")

		elif 'open stackoverflow' in query:
			speak("Here you go to Stack Over flow.Happy coding")
			webbrowser.open("stackoverflow.com")

		elif 'play music' in query or "play song" in query:
			speak("Here you go with music")
			# music_dir = "G:\\Song"
			music_dir = "C:\\Users\\GAURAV\\Music"
			songs = os.listdir(music_dir)
			print(songs)
			random = os.startfile(os.path.join(music_dir, songs[1]))

		elif 'the time' in query:
			strTime = datetime.datetime.now().strftime("% H:% M:% S")
			speak(f"Sir, the time is {strTime}")

		elif 'open opera' in query:
			codePath = r"C:\\Users\\GAURAV\\AppData\\Local\\Programs\\Opera\\launcher.exe"
			os.startfile(codePath)

		elif 'email to gaurav' in query:
			try:
				speak("What should I say?")
				content = takeCommand()
				to = "Receiver email address"
				sendEmail(to, content)
				speak("Email has been sent !")
			except Exception as e:
				print(e)
				speak("I am not able to send this email")

		elif 'send a mail' in query:
			try:
				speak("What should I say?")
				content = takeCommand()
				speak("whome should i send")
				to = input()
				sendEmail(to, content)
				speak("Email has been sent !")
			except Exception as e:
				print(e)
				speak("I am not able to send this email")

		elif 'how are you' in query:
			speak("I am fine, Thank you")
			speak("How are you, Sir")

		elif 'fine' in query or "good" in query:
			speak("It's good to know that your fine")

		elif "change my name to" in query:
			query = query.replace("change my name to", "")
			assname = query

		elif "change name" in query:
			speak("What would you like to call me, Sir ")
			assname = takeCommand()
			speak("Thanks for naming me")

		elif "what's your name" in query or "What is your name" in query:
			speak("My friends call me")
			speak(assname)
			print("My friends call me", assname)

		elif 'exit' in query:
			speak("Thanks for giving me your time")
			exit()

		elif "who made you" in query or "who created you" in query:
			speak("I have been created by Gaurav.")
			
		elif 'joke' in query:
			speak(pyjokes.get_joke())
			
		elif "calculate" in query:
			
			app_id = "Wolframalpha api id"
			client = wolframalpha.Client(app_id)
			indx = query.lower().split().index('calculate')
			query = query.split()[indx + 1:]
			res = client.query(' '.join(query))
			answer = next(res.results).text
			print("The answer is " + answer)
			speak("The answer is " + answer)

		elif 'search' in query or 'play' in query:
			
			query = query.replace("search", "")
			query = query.replace("play", "")		
			webbrowser.open(query)

		elif "who i am" in query:
			speak("If you talk then definitely your human.")

		elif "why you came to world" in query:
			speak("Thanks to Gaurav. further It's a secret")

		elif 'power point presentation' in query:
			speak("opening Power Point presentation")
			power = r"C:\\Users\\GAURAV\\Desktop\\Minor Project\\Presentation\\Voice Assistant.pptx"
			os.startfile(power)

		elif 'is love' in query:
			speak("It is 7th sense that destroy all other senses")

		elif "who are you" in query:
			speak("I am your virtual assistant created by Gaurav")

		elif 'reason for you' in query:
			speak("I was created as a Minor project by Mister Gaurav ")

		elif 'change background' in query:
			ctypes.windll.user32.SystemParametersInfoW(20,
													0,
													"Location of wallpaper",
													0)
			speak("Background changed successfully")

		elif 'open bluestack' in query:
			appli = r"C:\\ProgramData\\BlueStacks\\Client\\Bluestacks.exe"
			os.startfile(appli)

		elif 'news' in query:
			
			try:
				jsonObj = urlopen('''https://newsapi.org / v1 / articles?source = the-times-of-india&sortBy = top&apiKey =\\times of India Api key\\''')
				data = json.load(jsonObj)
				i = 1
				
				speak('here are some top news from the times of india')
				print('''=============== TIMES OF INDIA ============'''+ '\n')
				
				for item in data['articles']:
					
					print(str(i) + '. ' + item['title'] + '\n')
					print(item['description'] + '\n')
					speak(str(i) + '. ' + item['title'] + '\n')
					i += 1
			except Exception as e:
				
				print(str(e))

		
		elif 'lock window' in query:
				speak("locking the device")
				ctypes.windll.user32.LockWorkStation()

		elif 'shutdown system' in query:
				speak("Hold On a Sec ! Your system is on its way to shut down")
				subprocess.call('shutdown / p /f')
				
		elif 'empty recycle bin' in query:
			winshell.recycle_bin().empty(confirm = False, show_progress = False, sound = True)
			speak("Recycle Bin Recycled")

		elif "don't listen" in query or "stop listening" in query:
			speak("for how much time you want to stop jarvis from listening commands")
			a = int(takeCommand())
			time.sleep(a)
			print(a)

		elif "where is" in query:
			query = query.replace("where is", "")
			location = query
			speak("User asked to Locate")
			speak(location)
			webbrowser.open("https://www.google.nl / maps / place/" + location + "")

		elif "camera" in query or "take a photo" in query:
			ec.capture(0, "Jarvis Camera ", "img.jpg")

		elif "restart" in query:
			subprocess.call(["shutdown", "/r"])
			
		elif "hibernate" in query or "sleep" in query:
			speak("Hibernating")
			subprocess.call("shutdown / h")

		elif "log off" in query or "sign out" in query:
			speak("Make sure all the application are closed before sign-out")
			time.sleep(5)
			subprocess.call(["shutdown", "/l"])

		elif "write a note" in query:
			speak("What should i write, sir")
			note = takeCommand()
			file = open('jarvis.txt', 'w')
			speak("Sir, Should i include date and time")
			snfm = takeCommand()
			if 'yes' in snfm or 'sure' in snfm:
				strTime = datetime.datetime.now().strftime("% H:% M:% S")
				file.write(strTime)
				file.write(" :- ")
				file.write(note)
			else:
				file.write(note)
		
		elif "show note" in query:
			speak("Showing Notes")
			file = open("jarvis.txt", "r")
			print(file.read())
			speak(file.read(6))

		elif "update assistant" in query:
			speak("After downloading file please replace this file with the downloaded one")
			url = '# url after uploading file'
			r = requests.get(url, stream = True)
			
			with open("Voice.py", "wb") as Pypdf:
				
				total_length = int(r.headers.get('content-length'))
				
				for ch in progress.bar(r.iter_content(chunk_size = 2391975),
									expected_size =(total_length / 1024) + 1):
					if ch:
						Pypdf.write(ch)
					
		# NPPR9-FWDCX-D2C8J-H872K-2YT43
		elif "jarvis" in query:
			
			wishMe()
			speak("Jarvis 1 point o in your service Mister")
			speak(assname)

		elif "weather" in query:
			
			# Google Open weather website
			# to get API of Open weather
			api_key = "Api key"
			base_url = "http://api.openweathermap.org / data / 2.5 / weather?"
			speak(" City name ")
			print("City name : ")
			city_name = takeCommand()
			complete_url = base_url + "appid =" + api_key + "&q =" + city_name
			response = requests.get(complete_url)
			x = response.json()
			
			if x["code"] != "404":
				y = x["main"]
				current_temperature = y["temp"]
				current_pressure = y["pressure"]
				current_humidiy = y["humidity"]
				z = x["weather"]
				weather_description = z[0]["description"]
				print(" Temperature (in kelvin unit) = " +str(current_temperature)+"\n atmospheric pressure (in hPa unit) ="+str(current_pressure) +"\n humidity (in percentage) = " +str(current_humidiy) +"\n description = " +str(weather_description))
			
			else:
				speak(" City Not Found ")
			
		elif "send message " in query:
				# You need to create an account on Twilio to use this service
				account_sid = 'Account Sid key'
				auth_token = 'Auth token'
				client = Client(account_sid, auth_token)

				message = client.messages \
								.create(
									body = takeCommand(),
									from_='Sender No',
									to ='Receiver No'
								)

				print(message.sid)

		elif "wikipedia" in query:
			webbrowser.open("wikipedia.com")

		elif "Good Morning" in query:
			speak("A warm" +query)
			speak("How are you Mister")
			speak(assname)

		# most asked question from google Assistant
		elif "will you be my gf" in query or "will you be my bf" in query:
			speak("I'm not sure about, may be you should give me some time")

		elif "how are you" in query:
			speak("I'm fine, glad you me that")

		elif "i love you" in query:
			speak("It's hard to understand")

		elif "what is" in query or "who is" in query:
			
			# Use the same API key
			# that we have generated earlier
			client = wolframalpha.Client("API_ID")
			res = client.query(query)
			
			try:
				print (next(res.results).text)
				speak (next(res.results).text)
			except StopIteration:
				print ("No results")

		# elif "" in query:
			# Command go here
			# For adding more commands
# Out:
# sh: cls: command not found
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [23], in <cell line: 1>()
#       4 # This Function will clean any
#       5 # command before execution of this python file
#       6 clear()
# ----> 7 wishMe()
#       8 username()
#      10 while True:
#
# Input In [19], in wishMe()
#       8 	speak("Good Morning Sir !")
#      10 elif hour>= 12 and hour<18:
# ---> 11 	speak("Good Afternoon Sir !")
#      13 else:
#      14 	speak("Good Evening Sir !")
#
# Input In [19], in speak(audio)
#       1 def speak(audio):
# ----> 2 	engine.say(audio)
#       3 	engine.runAndWait()
#
# NameError: name 'engine' is not defined
